# %% [markdown]
# # CTC version 1
#
#
#
#
# ### Paper Reference
# - [Connectionist Temporal Classification (IDSIA)](ftp://ftp.idsia.ch/pub/juergen/icml2006.pdf)
#
#
# ### English Test
# First we test English

# %%
# Include And 
import sys
sys.path.append("/home/pika/nntools/")

import theano
import theano.tensor as T
import numpy as np
from theano_toolkit import utils as U
from theano_toolkit import updates
from theano.printing import Print
from theano_toolkit.parameters import Parameters

import lasagne
from lasagne.layers import *

from time import time

import ctc_cost_2

import cPickle
import sys
sys.setrecursionlimit(100000)

from random import shuffle
# Out:
# Using gpu device 0: GeForce GTX 980
# /home/pika/nntools/lasagne/init.py:86: UserWarning: The uniform initializer no longer uses Glorot et al.'s approach to determine the bounds, but defaults to the range (-0.01, 0.01) instead. Please use the new GlorotUniform initializer to get the old behavior. GlorotUniform is now the default for all layers.
#   warnings.warn("The uniform initializer no longer uses Glorot et al.'s "

# %% [markdown]
# # Data

# %%
'''
Doing : 
    - Read data and return x_train, y_train
'''
# TRAINING_ACOUSTIC_FEATURE = "./dataCebuano/train.f0_ffv_fbank.fea"
# TRAINING_ACOUSTIC_FEATURE = "./dataCebuano/train_Normalized_SELFVALID.ark"
TRAINING_ACOUSTIC_FEATURE = "./dataCebuano/tlkagk/train.dnn.fea.lessThen500.ark"
TRAINING_LABELS = "./dataCebuano/train.txt"
CHAR_CORPUS = "./dataCebuano/corpus.txt"


def readDataSet () :
    
    # -- Mapping char to integer and reverse
    char_map = {}    # eg. { a -> 1 }
    char_unMap = {}  # eg. { 1 -> a }
    with open( CHAR_CORPUS, 'r' ) as f:
        char_index = 0
        for lines in f:
            char_map  [ lines[:-1] ] = char_index
            char_unMap[ char_index ] = lines[:-1]
            char_index += 1
        # add Blank, take '.' as blank (not space)
        char_map['.'] = char_index
        char_unMap[char_index] = '.'
    
    
    # -- Reading X = id -> [ list of feature ] 
    idMapX = {}
    idDeck = []
    id = ''
    
    tmp_l = 0;
    with open( TRAINING_ACOUSTIC_FEATURE, 'r') as f:
        for lines in f: 
            if '[' in lines :
                id = lines.split(' ')[0]
                idDeck.append(id)
                idMapX[id] = []
            elif ']' in lines :
                if( len( lines.split('\n')[0].split(' ') [0:-1] ) != 90 ) :
                    print "err"
                    return 
                idMapX[id].append([float(x) for x in lines.split('\n')[0].split(' ') [:-1] ])
            else :
                if( len( lines.split('\n')[0].split(' ')) != 90 ):
                    print len( lines.split('\n')[0].split(' '))
                    print lines.split('\n')[0].split(' ')
                    print lines
                    print id
                    print "fuck"
                    return
                idMapX[id].append([float(x) for x in lines.split('\n')[0].split(' ') ])
    
    # Move to  3 - main - 3
    '''
    monoDimension = 33;
    zeroFeature = [0] * monoDimension
    #print len( zeroFeature ) 
    #print zeroFeature
    for id in idDeck:
        # print id
        tmpIdMapXWithID = []
        if len(idMapX[id]) < 6 :
            print "ERROR in length"
            return 
        for idxX in xrange( len(idMapX[id]) ):
            if idxX == 0:
                tmpIdMapXWithID.append( zeroFeature + zeroFeature + zeroFeature + idMapX[id][idxX] + idMapX[id][idxX+1] + idMapX[id][idxX+2] + idMapX[id][idxX+3] )    
            elif idxX == 1:
                tmpIdMapXWithID.append( zeroFeature + zeroFeature + idMapX[id][idxX-1] + idMapX[id][idxX] + idMapX[id][idxX+1] + idMapX[id][idxX+2] + idMapX[id][idxX+3] )  
            elif idxX == 2:
                tmpIdMapXWithID.append( zeroFeature + idMapX[id][idxX-2] + idMapX[id][idxX-1] + idMapX[id][idxX] + idMapX[id][idxX+1] + idMapX[id][idxX+2] + idMapX[id][idxX+3] )  
            elif idxX == (len(idMapX[id]) - 3 ):
                tmpIdMapXWithID.append( idMapX[id][idxX-3] + idMapX[id][idxX-2] + idMapX[id][idxX-1] + idMapX[id][idxX] + idMapX[id][idxX+1] + idMapX[id][idxX+2] + zeroFeature )  
            elif idxX == (len(idMapX[id]) - 2 ):
                tmpIdMapXWithID.append( idMapX[id][idxX-3] + idMapX[id][idxX-2] + idMapX[id][idxX-1] + idMapX[id][idxX] + idMapX[id][idxX+1] + zeroFeature + zeroFeature )  
            elif idxX == (len(idMapX[id]) - 1 ):
                tmpIdMapXWithID.append( idMapX[id][idxX-3] + idMapX[id][idxX-2] + idMapX[id][idxX-1] + idMapX[id][idxX] + zeroFeature + zeroFeature + zeroFeature )  
            else:
                tmpIdMapXWithID.append( idMapX[id][idxX-3] + idMapX[id][idxX-2] + idMapX[id][idxX-1] + idMapX[id][idxX] + idMapX[id][idxX+1] + idMapX[id][idxX+2] + idMapX[id][idxX+3] )  
        idMapX[id] = tmpIdMapXWithID
    '''
    
    print "Concate"
    
    # Standardlize X (Done in PrepreProcessing )
   
    # Shuffle the speaker to slice training and validation
    totalSpeech = len(idMapX)
    slicePointFive = totalSpeech // 20
    shuffle(idDeck)
    id_train = idDeck[slicePointFive+1:]
    id_valid = idDeck[:slicePointFive]
    
    idMapY = {} 
    
    # -- Reading Y = id -> [ Sentence(list of char[int] ) ]
    with open( TRAINING_LABELS, 'r') as f:
        specific = '?'
        for lines in f:
            yWithId = lines.split('\n')[0].split(' ', 1)
            idMapY[ yWithId[0] ] = []
            judgeSpecific = False
            for char in yWithId[1] :
                if char == '<' :
                    judgeSpecific = True;                
                if( judgeSpecific ):
                    if char == '>':
                        idMapY[ yWithId[0] ].append( char_map[specific] )
                        judgeSpecific = False
                else :
                    idMapY[ yWithId[0] ].append( char_map[char] )
    
    # -- concatenate X and Y
    x_train = []
    x_valid = []
    y_train = []
    y_valid = []
    
    for id in id_train:
        concateId = []
        for i in range( len( idMapX[id] ) ) :
            concateId.append( idMapX[id][i] )
        x_train.append( floatX( concateId )  )
        y_train.append( floatX( idMapY[id]) )
        
    for id in id_valid:
        concateId = []
        for i in range( len( idMapX[id] ) ) :
            concateId.append( idMapX[id][i] )
        x_valid.append( floatX( concateId ) )
        y_valid.append( floatX( idMapY[id]) )
        
    print "Dataset Finish : "
    print "total x_train = " + str(len(x_train))
    print x_train[0]
    print "total y_train = " + str(len(y_train))
    print y_train[0]
    print "total x_valid = " + str(len(x_valid))
    print x_valid[0]
    print "total y_valid = " + str(len(y_valid))
    print y_valid[0]
    
    return char_map, char_unMap, x_train, y_train, x_valid, y_valid

def floatX(x):
    return np.asarray(x, dtype=theano.config.floatX)


char_map, char_unMap, x_train, y_train, x_valid, y_valid = readDataSet()
# Out:
# Concate
# Dataset Finish :
# total x_train = 3722
# [[ 1.25719237  2.29442787 -0.41066572 ...,  0.47558177 -0.39980564
#    0.59627146]
#  [ 1.05800343  1.33436692  0.20377633 ...,  0.48123786 -0.06338868
#    0.36188135]
#  [ 0.33803442  0.77952909  0.11712263 ..., -0.0938624   0.24491337
#   -0.69495291]
#  ...,
#  [ 3.31121826 -1.77417123 -0.64911497 ..., -0.67235559  0.10313957
#   -0.66156721]
#  [ 2.59105372 -1.01509523 -0.42729658 ..., -0.33058587 -0.1686597
#    0.04819651]
#  [ 2.31533217 -0.73655921 -0.57874519 ..., -0.11882957 -0.41028976
#    0.62231231]]
# total y_train = 3722
# [ 16.   5.  22.   0.  16.   5.   5.  28.  18.   0.  19.   5.   0.  19.  10.
#    5.   0.  19.   5.   5.   0.  12.  19.  10.   0.   5.   9.  17.   5.  26.
#    0.  14.   5.  28.  12.  22.   5.]
# total x_valid = 195
# [[ 1.2807467   1.70732117  0.17548041 ..., -0.55313861  0.1064376
#   -1.05069315]
#  [ 1.38818455  0.88886184  0.53637934 ..., -0.64630091 -0.58293504
#   -2.0416832 ]
#  [ 1.5415405   0.71509635  0.50502288 ..., -0.28110331 -1.2292254
#   -2.55443954]
#  ...,
#  [ 0.87254101 -0.58007771  0.48090202 ...,  0.23777518 -0.2952871   0.091911  ]
#  [ 1.47450042 -0.62137461  0.50901067 ...,  0.02089129  0.02163509
#   -0.48082656]
#  [ 1.63936627 -0.41611552  0.45981044 ..., -0.09339778  0.14479131
#   -0.81041294]]
# total y_valid = 195
# [ 22.  12.  17.   5.   0.  27.   5.  19.  19.  12.   8.   0.  18.  14.   5.
#   28.   0.  16.   5.  19.   0.  19.   5.   0.  14.   5.  28.   0.  16.  10.
#    5.   0.  25.   5.   7.   5.   1.   0.  16.   5.  19.]

# %%
# 500 -> 3722 / 195
# 600 -> 3821 / 201
# 3000 -> 3937 / 207
x_train[0].shape
# Out:
# (195, 90)

# %%
max( [X.shape[0] for X in x_train] )
# Out:
# 501

# %%
'''
    https://github.com/craffel/lstm_benchmarks/blob/master/lasagne/experiment.py
    
    Convert a list of matrices into batches of uniform length
    :parameters:
        - X : list of np.ndarray
            List of matrices
        - length : int
            Desired sequence length.  Smaller sequences will be padded with 0s,
            longer will be truncated.
        - batch_size : int
            Mini-batch size
    :returns:
        - X_batch : np.ndarray
            Tensor of time series matrix batches,
            shape=(n_batches, length, batch_size, n_features)
        - X_mask : np.ndarray
            shape=(n_batches, length, batch_size)
            Mask denoting whether to include each time step of each time series
            matrix
    '''
    
def make_batches_X(X, length, batch_size=30):
    n_batches = len(X)//batch_size
    X_batch = np.zeros( (n_batches, batch_size, length, X[0].shape[1]),
                         dtype=theano.config.floatX)
    X_mask  = np.zeros( (n_batches, length, batch_size ), 
                         dtype=theano.config.floatX)
    
    for b in range(n_batches): 
        for n in range(batch_size): # go thorough batch size       
            X_m = X[b*batch_size + n] # seq_length X feature dim            
            X_batch[b, n, :X_m.shape[0]] = X_m[:length]
            X_mask[b, :X_m.shape[0], n] = 1
            
    return X_batch, X_mask

def make_batches_Y( X, length, batch_size=30):
    n_batches = len(X)//batch_size
    
    X_batch = np.zeros( (n_batches, length, batch_size ), dtype='float32')
    
    X_mask = np.zeros(X_batch.shape, dtype=theano.config.floatX)
    
    for b in range(n_batches):
        for n in range(batch_size):
            X_m = X[ b*batch_size + n ]
            X_batch[b, :X_m.shape[0], n ] = X_m[:length]
            X_mask[b, :X_m.shape[0], n] = 1
    return X_batch, X_mask

# %%
batch_size = 40

# Find the longest sequence
length_x = max( max( [X.shape[0] for X in x_train] ),
                max( [X.shape[0] for X in x_valid] ))

length_y = max( max( [X.shape[0] for X in y_train] ),
                max( [X.shape[0] for X in y_valid] ))

# Convert to batches of time series of uniform length
# x_train_mask: seq_length X batch_size
# y_train_mask: output_length X batch_size
# y_pred_mask = x_train_mask, since pred by sequence
x_train, x_train_mask = make_batches_X(x_train, length_x, batch_size)
y_train, y_train_mask = make_batches_Y(y_train, length_y, batch_size)
x_valid, x_valid_mask = make_batches_X(x_valid, length_x, batch_size)
y_valid, y_valid_mask = make_batches_Y(y_valid, length_y, batch_size)

# %%
print x_train.shape
print y_train.shape
print x_valid.shape
print y_valid.shape
print "================mask================"
print x_train_mask.shape
print y_train_mask.shape

# print x_train_mask[0][400][0]
# Out:
# (93, 40, 501, 90)
# (93, 132, 40)
# (4, 40, 501, 90)
# (4, 132, 40)
# ================mask================
# (93, 501, 40)
# (93, 132, 40)

# %% [markdown]
# # Model Part

# %%
'''
credit by NLTK package of measure edit distance
'''

def _edit_dist_init(len1, len2):
    lev = []
    for i in range(len1):
        lev.append([0] * len2)  # initialize 2D array to zero
    for i in range(len1):
        lev[i][0] = i           # column 0: 0,1,2,3,4,...
    for j in range(len2):
        lev[0][j] = j           # row 0: 0,1,2,3,4,...
    return lev


def _edit_dist_step(lev, i, j, s1, s2, transpositions=False):
    c1 = s1[i - 1]
    c2 = s2[j - 1]

    # skipping a character in s1
    a = lev[i - 1][j] + 1
    # skipping a character in s2
    b = lev[i][j - 1] + 1
    # substitution
    c = lev[i - 1][j - 1] + (c1 != c2)

    # transposition
    d = c + 1  # never picked by default
    if transpositions and i > 1 and j > 1:
        if s1[i - 2] == c2 and s2[j - 2] == c1:
            d = lev[i - 2][j - 2] + 1

    # pick the cheapest
    lev[i][j] = min(a, b, c, d)


def check_label_error( real , predict, transpositions=False):
    ## length of real >= length of predict
    """
    Calculate the Levenshtein edit-distance between two strings.
    The edit distance is the number of characters that need to be
    substituted, inserted, or deleted, to transform s1 into s2.  For
    example, transforming "rain" to "shine" requires three steps,
    consisting of two substitutions and one insertion:
    "rain" -> "sain" -> "shin" -> "shine".  These operations could have
    been done in other orders, but at least three steps are needed.

    This also optionally allows transposition edits (e.g., "ab" -> "ba"),
    though this is disabled by default.

    :param s1, s2: The strings to be analysed
    :param transpositions: Whether to allow transposition edits
    :type s1: str
    :type s2: str
    :type transpositions: bool
    :rtype int
    """
    # set up a 2-D array
    len1 = len(predict)
    len2 = len(real)
    lev = _edit_dist_init(len1 + 1, len2 + 1)

    # iterate over the array
    for i in range(len1):
        for j in range(len2):
            _edit_dist_step(lev, i + 1, j + 1, predict, real, transpositions=transpositions)
            
    return lev[len1][len2]*1.0/len2


def clean_up( y ):
    """
    for final output clean up
    B(a − ab−) = B(−aa − −abb) = aab
    """
    answer = ""

    for i in range(len(y)):
        if y[i] == '.':
            continue
        else:
            if y[i-1] != y[i]:
                answer += y[i]
    
    return answer

def remap_back( y , actual):
    answer = ""
    
    for i in y:
        answer += char_unMap[i]
    
    if not actual:
        answer = clean_up(answer)
        
    return answer

def decode_all_actual( y, y_mask ,batch_size , actual=False):
    """
    y     : label_length X batch_size
    y_mask: label_length X batch_size
    """
    result = []
    for i in xrange(batch_size):
        mask = np.swapaxes( y_mask, 0, 1)[i]
        ans = np.swapaxes( y, 0 , 1)[i]
        result.append(remap_back( ans[np.nonzero(mask)] , actual ))
    return result


def decode_all_pred( y, y_mask ,batch_size , actual=False):
    """
    y     : label_length X batch_size
    y_mask: label_length X batch_size
    """
    result = []
    for i in xrange(batch_size):
        mask = np.swapaxes( y_mask, 0, 1)[i]
        ans = y[i]
        result.append(remap_back( ans[np.nonzero(mask)] , actual ))
    return result

def check_all( y, y_mask, y_pred, y_pred_mask, batch_size ):
    
    actual = decode_all_actual( y, y_mask, batch_size , True )
    predict = decode_all_pred( y_pred, y_pred_mask, batch_size , False )
    
    error = 0.
    for a,b in zip (actual, predict):
        error += check_label_error(a,b)
    
    return error/len(actual)

# %%
class end_to_end():  
    def __init__(self, input_shape, max_seq_length, hidden_layer,
                 batch, max_epochs, output_num_units,
                 patience, up_learning_rate, file_name):
        
        self.input_shape = input_shape # [batch, dim]
        
        self.hidden_layer = hidden_layer # hidden [l1, l2, l3]
        self.output_num_units = output_num_units # [ # of class ]
        
        self.batch = batch
        self.max_epochs = max_epochs
        
        self.up_learning_rate = up_learning_rate
                 
        self.patience = patience
        self.best_valid = np.inf
        self.best_valid_epoch = 0
        self.best_params = None
        
        self.train_history_ = []
        self.epochs = 0
        
        self.file_name = file_name
        
        self.max_seq_length = max_seq_length
        
        """
        input data type
        y_hat : T x B x C+1
        y : L x B
        y_hat_mask : T x B
        y_mask : L x B
        """
        
        print "Why model build so long ... "
        # T x B x F
        # B X T X F (Lasagne format)
        x = T.tensor3('X', dtype=theano.config.floatX)
        # L x B
        y = T.matrix ('y', dtype=theano.config.floatX)

        # L x B
        y_mask = T.matrix('y_mask', dtype=theano.config.floatX)
        # T x B
        y_hat_mask = T.matrix('y_hat_mask', dtype=theano.config.floatX)
    
        # Min/max sequence length
        MAX_LENGTH = max_seq_length
        
        # Number of training sequences in each batch
        N_BATCH = batch
        
        #===========================================================================================
        # dEEP lSTM
        #===========================================================================================
        print "Input : (N_BATCH) : " + str(N_BATCH) +", ML :" + str(MAX_LENGTH) + "ss :" + str(self.input_shape[1])
        
        # Recurrent layers expect input of shape
        # (batch size, max sequence length, number of features)
        l_in     = lasagne.layers.InputLayer( shape=( N_BATCH, MAX_LENGTH, self.input_shape[1] ) )
        l_in_gau = lasagne.layers.GaussianNoiseLayer( l_in, sigma=0.5 )
        
        # LSTM layer 1
        l_forward_1   = lasagne.layers.LSTMLayer(l_in_gau, num_units=hidden_layer[0], learn_init=True, peepholes=True)
        l_backward_1  = lasagne.layers.LSTMLayer(l_in_gau, num_units=hidden_layer[0], backwards=True, learn_init=True, peepholes=True)
        l_recurrent_1 = ElemwiseSumLayer( [l_forward_1, l_backward_1] )

        
        # LSTM layer 2
        l_forward_2   = lasagne.layers.LSTMLayer(l_recurrent_1, num_units=hidden_layer[1], learn_init=True, peepholes=True)
        l_backward_2  = lasagne.layers.LSTMLayer(l_recurrent_1, num_units=hidden_layer[1], backwards=True, learn_init=True, peepholes=True)
        l_recurrent_2 = ElemwiseSumLayer( [l_forward_2, l_backward_2] )
        
        '''
        # LSTM layer 3
        l_forward_3   = lasagne.layers.LSTMLayer(l_recurrent_2, num_units=hidden_layer[2], learn_init=True, peepholes=True)
        l_backward_3  = lasagne.layers.LSTMLayer(l_recurrent_2, num_units=hidden_layer[2], backwards=True, learn_init=True, peepholes=True)
        l_recurrent_3 = ElemwiseSumLayer( [l_forward_3, l_backward_3] )
        
        # LSTM layer 4
        l_forward_4   = lasagne.layers.LSTMLayer(l_recurrent_3, num_units=hidden_layer[3], learn_init=True, peepholes=True)
        l_backward_4  = lasagne.layers.LSTMLayer(l_recurrent_3, num_units=hidden_layer[3], backwards=True, learn_init=True, peepholes=True)
        l_recurrent_4 = ElemwiseSumLayer( [l_forward_4, l_backward_4] )
        '''
        
        # l_reshape = lasagne.layers.ReshapeLayer(l_recurrent_4, (N_BATCH*MAX_LENGTH, hidden_layer[3])  )
        l_reshape = lasagne.layers.ReshapeLayer(l_recurrent_2, (N_BATCH*MAX_LENGTH, hidden_layer[1])  )

        
        #===========================================================================================
        # COMMON SETUP
        #===========================================================================================
        
        # Our output layer is a simple dense connection
        l_recurrent_out      = lasagne.layers.DenseLayer( l_reshape, num_units=output_num_units[0] , nonlinearity=lasagne.nonlinearities.identity)
        
        # Now, reshape the output back to the RNN format
        l_out_shp            = lasagne.layers.ReshapeLayer( l_recurrent_out, (N_BATCH, MAX_LENGTH, output_num_units[0]) )
        
        # dimshuffle to shape format (input_seq_len, batch_size, num_classes + 1)
        l_out_shp_ctc        = lasagne.layers.DimshuffleLayer( l_out_shp, (1, 0, 2))

        l_out_softmax        = lasagne.layers.NonlinearityLayer( l_recurrent_out, nonlinearity=lasagne.nonlinearities.softmax)
        l_out_softmax_shp    = lasagne.layers.ReshapeLayer( l_out_softmax, (N_BATCH, MAX_LENGTH, output_num_units[0] ))
        
        # since we use gaussian noise in input, False means use noise, True means dont use noise
        output_lin_ctc_train = lasagne.layers.get_output( l_out_shp_ctc, x, deterministic=False)
        output_softmax_train = lasagne.layers.get_output( l_out_softmax_shp, x, deterministic=False)
        
        output_lin_ctc_val   = lasagne.layers.get_output(l_out_shp_ctc, x, deterministic=True)
        output_softmax_val   = lasagne.layers.get_output(l_out_softmax_shp, x, deterministic=True)
        
        self.all_params      = lasagne.layers.get_all_params(l_out_shp)
    
        # the CTC cross entropy between y and linear output network
        pseudo_cost = ctc_cost_2.pseudo_cost(
            y, output_lin_ctc_train, y_mask, y_hat_mask,
            skip_softmax=True)
        
        
        pseudo_cost_grad = T.grad(pseudo_cost.mean(), self.all_params)
        true_cost        = ctc_cost_2.cost(y, output_softmax_train.dimshuffle(1, 0, 2), y_mask, y_hat_mask)
        cost             = T.mean(true_cost)
        
        pseudo_cost_scaled_grads = lasagne.updates.total_norm_constraint(pseudo_cost_grad, 5)
        updates_rms          = lasagne.updates.rmsprop(pseudo_cost_scaled_grads, self.all_params, learning_rate = self.up_learning_rate)
        updates = lasagne.updates.apply_momentum(updates_rms,  self.all_params, momentum=0.9)
        
        self.train = theano.function(
            inputs = [x, y, y_hat_mask, y_mask],
            outputs = [ pseudo_cost.mean(), cost, output_softmax_train ],
#             outputs = [output_lin_ctc, output_softmax, cost],
            updates=updates
        )
        
        self.predict = theano.function( 
            inputs=[x], 
            outputs = [ output_softmax_val] 
        )

        
    # x_mask and y_mask is the same
    # x_test_mask and y_test_mask is the same
    def fit(self, x_train, y_train, x_test,  y_test , x_mask, y_mask, x_test_mask, y_test_mask ):
        print " "
        print "start training!!!!"
        print " "
        sys.stdout.flush()
        
        for i in range(self.max_epochs):
            self.epochs +=1
            t0 = time()
            
            cs = 0.
            pseudo_cs = 0.
            for index in range(len(x_train)):
                pseudo, cost, output_softmax = self.train( x_train[index] , y_train[index],
                                                          x_mask[index], y_mask[index])
                cs += cost
                pseudo_cs += pseudo
                gg = index
                if index % 10 == 0:
                    print index, pseudo, cost
                sys.stdout.flush()
            
            cs /= len(x_train)
            pseudo_cs /= len(x_train)
            
#             cPickle.dump( self , open("./"+self.file_name+".pkl","wb"))
            if self.epochs <= 1:
                previous_cs = "-"
            else:
                previous_cs = self.train_history_[-1]['cost']
            print "\n==============================="
            print 'epoch {0} : pseudo= {1}, cost= {2}, previous_cost= {3}, train_time = {4} s'.format(self.epochs,
                                                                                                      pseudo_cs, 
                                                                                                      cs,
                                                                                                      previous_cs, 
                                                                                                      time() - t0)
            
            sys.stdout.flush()
            
            t0 = time()
            
#             print np.argmax(output_softmax[:],axis=2)
#             print decode_all( np.argmax(output_softmax[:],axis=2) , x_train_mask[gg],  batch_size , True)
            
            # save model first
            # dont know the LER performance yet
#             cPickle.dump( self , open("./"+self.file_name+".pkl","wb"))
    
            y_actual = []
            y_predict= []
            label_error_rate = 0.
            print len(x_test)
            for index in range( len(x_test) ) :

                prepre = self.predict( x_test[index])
                
                label_error_rate += check_all( y_test[index], y_test_mask[index],
                                              np.argmax(prepre[0],axis=2) , x_test_mask[index],
                                              batch_size)
                
                if (( index + self.epochs ) % 4 == 0 ):
                    ## print actual
                    y_actual = decode_all_actual( y_test[index], y_test_mask[index], batch_size , True)

                    ## print pred
                    y_predict = decode_all_pred( np.argmax(prepre[0],axis=2) , x_test_mask[index],  batch_size , False)
                
            label_error_rate /= len(x_test)
            self.train_history_.append({"epoch":self.epochs, "cost": cs, "LER":label_error_rate})
            
            print '\t\t\t val_= {0}, test_time  = {1} s'.format(label_error_rate, time() - t0)
            print "===============================\n"
            
            sys.stdout.flush()
            
            for a , b in zip (y_actual,y_predict):
                print "Target== ",a 
                print "\tAns => ",b
            
            sys.stdout.flush()
            
            """
            should use cost do early stopping
            """
            current_cs = self.train_history_[-1]['cost']
            current_epoch = self.train_history_[-1]['epoch']
            if current_cs < self.best_valid:
                self.best_valid = current_cs
                self.best_valid_epoch = current_epoch
                self.best_params = [w.get_value() for w in self.all_params]
                cPickle.dump( self , open("./"+self.file_name+".pkl","wb"))
                
            elif self.best_valid_epoch + self.patience <= current_epoch:
                print ""
                print "Early stopping."
                print self.best_valid_epoch,self.best_valid
                print "Best valid ler {:.6f} at epoch {}.".format(self.best_valid, self.best_valid_epoch)              
#                 for qq in range (len(self.all_params)):
#                     self.all_params[qq].set_value( self.best_params[qq] )
#                 break

            """
            can not use label error rate do early stopping
            """
#             current_ler = self.train_history_[-1]['LER']
#             current_epoch = self.train_history_[-1]['epoch']
#             if current_ler < self.best_valid:
# #                 print "********************* Now best ************************"
#                 sys.stdout.flush()
#                 self.best_valid = current_ler
#                 self.best_valid_epoch = current_epoch
#                 self.best_params = [w.get_value() for w in self.all_params]
# #                 cPickle.dump( self , open("./"+self.file_name+".pkl","wb"))
                
#             elif self.best_valid_epoch + self.patience <= current_epoch:
#                 print ""
#                 print "Early stopping."
#                 print self.best_valid_epoch,self.best_valid
#                 print "Best valid ler {:.6f} at epoch {}.".format(self.best_valid, self.best_valid_epoch)
#                 sys.stdout.flush()                
#                 for qq in range (len(self.all_params)):
#                     self.all_params[qq].set_value( self.best_params[qq] )
#                 break


#     def prediction(self, x, x_mask) :
        
#         abc =  self.predict(x, x_mask)
        
#         return np.argmax(abc[0], axis = 1 )

# %%
'''
ONE lAYER
'''

model4L_Noise_momemtumClip_bottleneckfea = end_to_end (
    input_shape      = (1, x_train.shape[3] ) , # batch of 1, (110, 30, 777, 117)
    max_seq_length = x_train.shape[2],
    hidden_layer     = [ 250, 250, 250, 250 ], # maximum layer to LSTM 3 layer only
    batch            = batch_size, 
    max_epochs       = 300, 
    output_num_units = [ len(char_unMap) ],
    up_learning_rate = 0.0005, 
    patience         = 7,
    file_name = "model2L(new)_Noise_momemtumClip_bottleneckfea"
)
# Out:
# /home/pika/nntools/lasagne/layers/helper.py:69: UserWarning: get_all_layers() has been changed to return layers in topological order. The former implementation is still available as get_all_layers_old(), but will be removed before the first release of Lasagne. To ignore this warning, use `warnings.filterwarnings('ignore', '.*topo.*')`.
#   warnings.warn("get_all_layers() has been changed to return layers in "
# /home/pika/anaconda/lib/python2.7/site-packages/theano/scan_module/scan.py:1017: Warning: In the strict mode, all neccessary shared variables must be passed as a part of non_sequences
#   'must be passed as a part of non_sequences', Warning)
# Why model build so long ...
# Input : (N_BATCH) : 40, ML :501ss :90
# /home/pika/anaconda/lib/python2.7/site-packages/theano/scan_module/scan_perform_ext.py:133: RuntimeWarning: numpy.ndarray size changed, may indicate binary incompatibility
#   from scan_perform.scan_perform import *

# %%
# %time model4L_Noise_momemtumClip_bottleneckfea.fit( x_train, y_train, x_valid, y_valid, x_train_mask, y_train_mask , x_valid_mask, y_valid_mask )
# Out:
#
# start training!!!!
#
# 0 -16.1343040466 637.782104492
# 10 812.13494873 847.369445801
# 20 573.181274414 615.125915527
# 30 426.569732666 512.980224609
# 40 758.03338623 843.110717773
# 50 514.79095459 561.178039551
# 60 181.424102783 276.060333252
# 70 101.99887085 184.845916748
# 80 54.192943573 141.744033813
# 90 45.5574455261 132.244781494
#
# ===============================
# epoch 1 : pseudo= 379.254931722, cost= inf, previous_cost= -, train_time = 1153.05810308 s
# 4
# 			 val_= 0.959650173374, test_time  = 1.08960103989 s
# ===============================
#
# Target==  bumble bee ? sa ato' pa ? gayod diay ka
# 	Ans =>
# Target==  nindot na kadto imo nga kuan sa una
# 	Ans =>
# Target==  piro kad- kadali' ra man to nga si ati mildred
# 	Ans =>
# Target==  ? gahapon nakakuwarta kagahapon
# 	Ans =>
# Target==  ? wala' ra ba kay budget
# 	Ans =>
# Target==  ang tulo kakuan traha
# 	Ans =>
# Target==  nagtrabaho davao light
# 	Ans =>
# Target==  mao lagi ba unsa nga urasa muabot diay
# 	Ans =>
# Target==  ? ako' pod mupalit pod ko' og gatas sa ako' nga anak diri
# 	Ans =>
# Target==  unsa man ila nga gidula' ?
# 	Ans =>   a
# Target==  kuyawa gayod pila ang ?
# 	Ans =>
# Target==  ipalihog ko' ingon nga
# 	Ans =>  ?
# Target==  ? sigi siya suroy-suroy
# 	Ans =>  ?
# Target==  kuyawa no paspasa pod nila manganak no ?
# 	Ans =>
# Target==  ? ? unsa man nawala' man nadawat
# 	Ans =>  ?
# Target==  ? uniya'
# 	Ans =>
# Target==  piro wala' na ka miadto
# 	Ans =>
# Target==  bala kaayo ka maunahan gani' ka gani'
# 	Ans =>
# Target==  ? mao gayod na
# 	Ans =>
# Target==  kay daghan man gayod kaayo sila mama gayod dira'
# 	Ans =>
# Target==  arkilaha ?
# 	Ans =>
# Target==  o asa man siya nag-iskuwila karon
# 	Ans =>
# Target==  uniya' wala'-wala' wala' mo ing video ato' nga
# 	Ans =>
# Target==  kuyog piro ? hapon na lagi kaayo maayo man to nga nakuha kadto ganiha kay
# 	Ans =>
# Target==  ? nangita' ta og kana' nga maayo unsa ing unsa og grasiya uniya' sa ginuo ba
# 	Ans =>
# Target==  ? usa na man lang ? mao diay wala' na lang
# 	Ans =>
# Target==  blue uniya' blue ra pod ako' nga
# 	Ans =>
# Target==  o trisi
# 	Ans =>
# Target==  mapundasiyunan ang kuan
# 	Ans =>
# Target==  magsakit-sakit biya' ni sarah og si janmar
# 	Ans =>
# Target==  o ngano diay muuban ka
# 	Ans =>
# Target==  ? ka didto sigi ra og tindog
# 	Ans =>
# Target==  ay usahay lang dili' man pod siya ingon nga dalo' piro
# 	Ans =>
# Target==  uniya' kanus-a man to muuli' imo nga bana
# 	Ans =>
# Target==  ? si luke ? wala' na man siya ing ? wala' na man
# 	Ans =>  ?
# Target==  ikaw kumusta na man mo sa imo nga uyab
# 	Ans =>
# Target==  sa una mao man unta' to ang plano namo' sa una
# 	Ans =>
# Target==  ? sunod ini og magkita' ta ?
# 	Ans =>
# Target==  og wala' nawala' ? abi nako' og wala' pa
# 	Ans =>  ?
# Target==  o tabang ? kadto nga ? sa bohol ba
# 	Ans =>
# 0 30.9034175873 132.852996826
# 10 55.9729270935 143.987136841
# 20 118.27658844 161.297790527
# 30 -36.0310745239 154.745269775
# 40 26.3030757904 130.159698486
# 50 35.2204475403 128.236297607
# 60 63.3630142212 145.596298218
# 70 16.690574646 116.523208618
# 80 -11.6467285156 111.193313599
# 90 -17.5495853424 124.440505981
#
# ===============================
# epoch 2 : pseudo= 23.47006917, cost= 131.310817185, previous_cost= inf, train_time = 1145.99130702 s
# 4
# 			 val_= 0.970557763296, test_time  = 1.07947397232 s
# ===============================
#
# Target==  uo didto uo uo kadto bitaw tribute ba to
# 	Ans =>  ?a
# Target==  ? college level man pod ?
# 	Ans =>  a
# Target==  ambot oy tapos kuan
# 	Ans =>  ?a
# Target==  si manilyn kana' iya nga damit ihat- ihatod
# 	Ans =>  ?
# Target==  kay manayaw mga bata' ?
# 	Ans =>  a
# Target==  na nga nag siyagit-siyagit
# 	Ans =>  i
# Target==  ? ? basta ang suman ha ? og naa mabilin bigiyan mo gayod ko'
# 	Ans =>  ?
# Target==  ay okay lang okay lang gihapon
# 	Ans =>  ?
# Target==  sila nanti naana' sila nga nanti naana'
# 	Ans =>  i
# Target==  mmm kanus-a man kadto mangha-
# 	Ans =>  ?
# Target==  ? ?
# 	Ans =>  a
# Target==  didto siya na assign sa una mao nga didto gani' mi nagkita'
# 	Ans =>  i
# Target==  gahapon unsa diay ?
# 	Ans =>  i
# Target==  naa ing gamay naa sa ing buhat sakto ra naa ra ing kuan gayod
# 	Ans =>  ?
# Target==  ? basta maayo lang nga pagkatrabaho basta dili' lang ingon nga
# 	Ans =>  i
# Target==  ay commercial ipaganda o ipaganda
# 	Ans =>  a
# Target==  tigtubig boy lang ta sa ilaha
# 	Ans =>  ?i
# Target==  mawala'-wala' lagi ka dili' kaayo ta ka madungog
# 	Ans =>  a
# Target==  ? lagi impas na akua piro ang prublima diri ko' nga ma-flat-an mahurot sa hantakan tanan ?
# 	Ans =>  a
# Target==  natingala gani' siya nga duha ra daw kabulan kapin
# 	Ans =>  ?
# Target==  dalan lang tika dalan tika
# 	Ans =>  i
# Target==  ay gibalita' na pod diay naana' pod bagiyo
# 	Ans =>  a
# Target==  anhi lang diri ini og human nimo og panglaba
# 	Ans =>  a
# Target==  naana' la ?
# 	Ans =>  ?
# Target==  laa- mukuan sala' gani' to sila musimba
# 	Ans =>  ?
# Target==  aw o si lenny ang kauban niya si kuan maricris
# 	Ans =>  a
# Target==  ? lisod na ang ingon miana' mok
# 	Ans =>  ?
# Target==  mmm ana' gayod kana' mari gayod kinahanglan
# 	Ans =>  ?
# Target==  ? didto sa ingon nila nga guadalupe unsa kadto nga lugara kadto
# 	Ans =>  ?
# Target==  iskuwila tanan o humana ang uban
# 	Ans =>  i
# Target==  o ato' ra man gihapon na ba inig
# 	Ans =>  a
# Target==  ? daghan og dalhon tika
# 	Ans =>  ?
# Target==  wala' ing signal amo' nga bukid ? bukid
# 	Ans =>  ?
# Target==  pait kaayo amo' nga kinabuhi' ingon ana' ra oy motor-motor pait kaayo
# 	Ans =>  a
# Target==  sapatos bag-o nga sapatos alangan dili' ka magsapatos
# 	Ans =>  ia
# Target==  oh oh oh dinha' gayod
# 	Ans =>  i
# Target==  uo mag-propose nako' sa imo hapit na
# 	Ans =>  a
# Target==  three years lang baya' sila didto
# 	Ans =>  ?a
# Target==  diri sa kuan gayod sa may iskuwilahan duol banda
# 	Ans =>  ia
# Target==  pila na may anak nimo karon
# 	Ans =>  ?a
# 0 55.0880393982 120.600265503
# 10 -19.9456424713 131.447769165
# 20 73.1881866455 136.355178833
# 30 78.9140625 145.164505005
# 40 31.2357063293 112.175765991
# 50 -30.4555912018 135.053497314
# 60 7.66138935089 121.890563965
# 70 -15.8261356354 107.483665466
# 80 1.96588134766 104.603233337
# 90 18.2819461823 114.977096558
#
# ===============================
# epoch 3 : pseudo= 12.7990205519, cost= 119.818392928, previous_cost= 131.310817185, train_time = 1140.61678481 s
# 4
# 			 val_= 0.971983555159, test_time  = 1.07475805283 s
# ===============================
#
# Target==  mikalit man gayod kadto nga nga naa ing talk uniya' kuan pod ba kana' nga ?
# 	Ans =>  u
# Target==  ay nagtrabaho ko' sa kuan sa factory
# 	Ans =>  a
# Target==  gikuan kuno to ? gipalitan to og itlog
# 	Ans =>  a
# Target==  ayaw kay gutom gayod na nga alas-dusi na man
# 	Ans =>  aa
# Target==  ma-level ba diay nako' nga sumbagay lang
# 	Ans =>  a
# Target==  sa akua diay dili' madunggan nimo
# 	Ans =>  a
# Target==  na sa bata'
# 	Ans =>
# Target==  asa mo dapit gasuroy-suroy
# 	Ans =>
# Target==  pariha ana' oscar ana' ba
# 	Ans =>  a
# Target==  o adtuon lang nako' si jed
# 	Ans =>
# Target==  lech- litson na baboy
# 	Ans =>
# Target==  sa kuan lang kana' nga mga makaagi ko' og simbahan
# 	Ans =>  a
# Target==  girl manglaag kita' ila shirla sunod ba
# 	Ans =>  a
# Target==  o mmm
# 	Ans =>
# Target==  uyabon uyab-uyab na man daw kuno
# 	Ans =>  a
# Target==  kato nga nabahaan ato' nga una ba
# 	Ans =>
# Target==  o ngano nalagot man ka ni ? o
# 	Ans =>  a
# Target==  sa february mag-lima siya kabulan
# 	Ans =>  a
# Target==  musalig og kana' nga mga ingon ana' oy maningkamot ako' oy mangita' ko' og paagi kay lisod kaayo man gayod na ang
# 	Ans =>  a
# Target==  manok uniya' kaha iya elot unsa
# 	Ans =>
# Target==  og mas tigulang ko' sa imuha ba ?
# 	Ans =>  a
# Target==  lisod kana' ang bungol ba bungol baya' ko'
# 	Ans =>  a
# Target==  si ?
# 	Ans =>  a
# Target==  o i-announce
# 	Ans =>  a
# Target==  kay malipong man kaha' siya ?
# 	Ans =>  a
# Target==  o wala' ? hinuon wala' man hinuon
# 	Ans =>  a
# Target==  bitaw day tama' gayod ka day
# 	Ans =>  a
# Target==  dinhi man gayod mi mabuhi' bay
# 	Ans =>  a
# Target==  ? wala' diay giapas ni alex
# 	Ans =>  a
# Target==  wala' ing tarong og iskuwila sigi lang og climb-climb na
# 	Ans =>  a
# Target==  usa lay nagdungan nimo dong
# 	Ans =>  a
# Target==  naako' wala' oy luuya oy
# 	Ans =>  a
# Target==  hapit na alas-dusi padulong siya duty ron
# 	Ans =>  a
# Target==  uniya' mama nimo nakauli' na
# 	Ans =>  ha
# Target==  mao na nga ukasiyon na man libri gayod
# 	Ans =>  a
# Target==  dili' pod tama' tama' lang
# 	Ans =>  a
# Target==  guwapo man pod na ingon ana' salo-salo tanan mga
# 	Ans =>  a
# Target==  naa diay ka ing exam karon sayo man lagi
# 	Ans =>  a
# Target==  kana' nga dili' na siya magpalakas og kaon diay ti
# 	Ans =>  a
# Target==  unsa man nga naa man kay klasi inig gawas nimo sa klasi
# 	Ans =>  a
# 0 57.2838134766 114.585205078
# 10 34.2746582031 127.584693909
# 20 -26.0351314545 124.833984375
# 30 15.8378419876 123.555381775
# 40 8.79371070862 103.337303162
# 50 9.66759490967 111.984107971
# 60 17.8407344818 113.801429749
# 70 -6.75871276855 106.21736145
# 80 27.4285335541 101.770957947
# 90 13.0208864212 113.854049683
#
# ===============================
# epoch 4 : pseudo= 5.04257462342, cost= 111.676663963, previous_cost= 119.818392928, train_time = 1140.81988001 s
# 4
# 			 val_= 0.941842240651, test_time  = 1.07898497581 s
# ===============================
#
# Target==  sila vannie okay man na kay mga taba' man
# 	Ans =>  uaa  a
# Target==  pangit man na ang rain or shine hinay kaayo na oy
# 	Ans =>  aa
# Target==  mura lagi og dili' ikaw ?
# 	Ans =>  u
# Target==  no nagkauyab man diay mo ato' niya no
# 	Ans =>  a
# Target==  o karon na anhi lang diri
# 	Ans =>  a
# Target==  taod-taod taod-taod na sad
# 	Ans =>  a
# Target==  ay sigi man musulti man siya sa akua piro wala' ko' kita' sa lalaki giingnan nako' ayaw sa paadtua og balay
# 	Ans =>  a
# Target==  cook nako' dinha' mag-cook puwidi mag-cook nako' dinha'
# 	Ans =>  ua a
# Target==  o kato lang siya one three
# 	Ans =>  ?
# Target==  ting-break time ? ? ting-break time
# 	Ans =>  ?
# Target==  mao lagi siguro sa kuan putol-putol
# 	Ans =>  aa
# Target==  uniya' kumusta man imo nga pa check-up balik nay
# 	Ans =>  uaaa
# Target==  useless lang gihapon imo nga sigi ka og pangutana sa akua
# 	Ans =>  ua
# Target==  wal- wal- wala' diay bugas
# 	Ans =>  u
# Target==  ? kana' nga mga uso karon
# 	Ans =>  ?
# Target==  oh wala' ing signal amo' nga bukid ?
# 	Ans =>  u
# Target==  o para ?
# 	Ans =>  ?
# Target==  wala' pa wala' pa
# 	Ans =>
# Target==  si neneng og si sweetie ra man to
# 	Ans =>  a
# Target==  dako' na na nga panalangin sa ginuo
# 	Ans =>  a
# Target==  ? age does not matter bitaw na ati
# 	Ans =>  a
# Target==  maayo og madayon maayo og dili'
# 	Ans =>  a
# Target==  namaligiya' man si caloy diri oh halos kami tanan namalit
# 	Ans =>  a a
# Target==  dondie naunsa diay si dondie diay
# 	Ans =>  u
# Target==  prak- ? prak- ha
# 	Ans =>  a
# Target==  maayo unta' og kumplito to nga ?
# 	Ans =>  a
# Target==  layas ? layas ni nga bataa ni bisan
# 	Ans =>  a
# Target==  mao ana' man gayod kana' dili' na man gayod kana' ma-control tir
# 	Ans =>  a
# Target==  na-addict na kaayo si doogie ba o
# 	Ans =>  a
# Target==  basi og imo nga suwirti naa sa lain wala' dinha'
# 	Ans =>  ua a
# Target==  duol pa gayod ka sa mga bata' nimo imo nga mga anak
# 	Ans =>  a a
# Target==  o bag-o ato' dili' ka ? tsoy ato'
# 	Ans =>  a
# Target==  thursday ba huwibis
# 	Ans =>  a
# Target==  pagkadako' sa pabo oy mura man og kabaw
# 	Ans =>  a a a a
# Target==  wala' pa ing valid i_d si papa
# 	Ans =>  a
# Target==  last year pabuto man kadto last year
# 	Ans =>  a
# Target==  hala no luuya gayod niya gayod
# 	Ans =>  a
# Target==  ? unsa iya nga course kurso
# 	Ans =>  a
# Target==  ? magbaktas ? duol ra man pod
# 	Ans =>  ?a
# Target==  ha ?
# 	Ans =>  ?
# 0 22.1051311493 107.577590942
# 10 64.910118103 146.246368408
# 20 61.7224845886 132.603881836
# 30 550.702697754 651.321899414
# 40 829.426391602 854.523620605
# 50 291.157226562 338.374908447
# 60 90.1764678955 183.58895874
# 70 4.54477548599 155.671386719
# 80 -4.77824735641 121.413742065
# 90 27.3996334076 118.924278259
#
# ===============================
# epoch 5 : pseudo= 178.306373842, cost= 266.176507355, previous_cost= 111.676663963, train_time = 1140.72049093 s
# 4
# 			 val_= 0.969649457151, test_time  = 1.0796289444 s
# ===============================
#
# Target==  bumble bee ? sa ato' pa ? gayod diay ka
# 	Ans =>  wa
# Target==  nindot na kadto imo nga kuan sa una
# 	Ans =>  o
# Target==  piro kad- kadali' ra man to nga si ati mildred
# 	Ans =>  i
# Target==  ? gahapon nakakuwarta kagahapon
# 	Ans =>  a
# Target==  ? wala' ra ba kay budget
# 	Ans =>  a
# Target==  ang tulo kakuan traha
# 	Ans =>  u
# Target==  nagtrabaho davao light
# 	Ans =>  n
# Target==  mao lagi ba unsa nga urasa muabot diay
# 	Ans =>  w
# Target==  ? ako' pod mupalit pod ko' og gatas sa ako' nga anak diri
# 	Ans =>  u
# Target==  unsa man ila nga gidula' ?
# 	Ans =>  u
# Target==  kuyawa gayod pila ang ?
# 	Ans =>  i
# Target==  ipalihog ko' ingon nga
# 	Ans =>  i
# Target==  ? sigi siya suroy-suroy
# 	Ans =>  ui
# Target==  kuyawa no paspasa pod nila manganak no ?
# 	Ans =>  u
# Target==  ? ? unsa man nawala' man nadawat
# 	Ans =>  ?
# Target==  ? uniya'
# 	Ans =>  n
# Target==  piro wala' na ka miadto
# 	Ans =>  a
# Target==  bala kaayo ka maunahan gani' ka gani'
# 	Ans =>  a
# Target==  ? mao gayod na
# 	Ans =>  u
# Target==  kay daghan man gayod kaayo sila mama gayod dira'
# 	Ans =>  ia
# Target==  arkilaha ?
# 	Ans =>  a
# Target==  o asa man siya nag-iskuwila karon
# 	Ans =>  un
# Target==  uniya' wala'-wala' wala' mo ing video ato' nga
# 	Ans =>  a
# Target==  kuyog piro ? hapon na lagi kaayo maayo man to nga nakuha kadto ganiha kay
# 	Ans =>  u
# Target==  ? nangita' ta og kana' nga maayo unsa ing unsa og grasiya uniya' sa ginuo ba
# 	Ans =>  u
# Target==  ? usa na man lang ? mao diay wala' na lang
# 	Ans =>  w
# Target==  blue uniya' blue ra pod ako' nga
# 	Ans =>  wa
# Target==  o trisi
# 	Ans =>  u
# Target==  mapundasiyunan ang kuan
# 	Ans =>  ua
# Target==  magsakit-sakit biya' ni sarah og si janmar
# 	Ans =>  w
# Target==  o ngano diay muuban ka
# 	Ans =>  u
# Target==  ? ka didto sigi ra og tindog
# 	Ans =>  ua
# Target==  ay usahay lang dili' man pod siya ingon nga dalo' piro
# 	Ans =>  a
# Target==  uniya' kanus-a man to muuli' imo nga bana
# 	Ans =>  n
# Target==  ? si luke ? wala' na man siya ing ? wala' na man
# 	Ans =>  n
# Target==  ikaw kumusta na man mo sa imo nga uyab
# 	Ans =>  a
# Target==  sa una mao man unta' to ang plano namo' sa una
# 	Ans =>  i
# Target==  ? sunod ini og magkita' ta ?
# 	Ans =>  i
# Target==  og wala' nawala' ? abi nako' og wala' pa
# 	Ans =>  ua
# Target==  o tabang ? kadto nga ? sa bohol ba
# 	Ans =>  w
# 0 23.3531131744 112.371299744
# 10 44.3807258606 126.95451355
# 20 58.003200531 129.859954834
# 30 -24.913476944 125.737426758
# 40 38.275390625 104.182395935
# 50 -7.34829092026 118.374839783
# 60 -18.3970222473 115.642868042
# 70 70.4056396484 114.943786621
# 80 -10.9028806686 103.944107056
# 90 13.8775272369 113.446975708
#
# ===============================
# epoch 6 : pseudo= 6.66431881656, cost= 112.913820492, previous_cost= 266.176507355, train_time = 1140.84182596 s
# 4
# 			 val_= 0.950286909874, test_time  = 1.07763695717 s
# ===============================
#
# Target==  uo didto uo uo kadto bitaw tribute ba to
# 	Ans =>  u
# Target==  ? college level man pod ?
# 	Ans =>  a
# Target==  ambot oy tapos kuan
# 	Ans =>  ?
# Target==  si manilyn kana' iya nga damit ihat- ihatod
# 	Ans =>  ui
# Target==  kay manayaw mga bata' ?
# 	Ans =>  a
# Target==  na nga nag siyagit-siyagit
# 	Ans =>  ua
# Target==  ? ? basta ang suman ha ? og naa mabilin bigiyan mo gayod ko'
# 	Ans =>  ?
# Target==  ay okay lang okay lang gihapon
# 	Ans =>  ?
# Target==  sila nanti naana' sila nga nanti naana'
# 	Ans =>  i
# Target==  mmm kanus-a man kadto mangha-
# 	Ans =>  ?
# Target==  ? ?
# 	Ans =>  ?
# Target==  didto siya na assign sa una mao nga didto gani' mi nagkita'
# 	Ans =>  i
# Target==  gahapon unsa diay ?
# 	Ans =>  u
# Target==  naa ing gamay naa sa ing buhat sakto ra naa ra ing kuan gayod
# 	Ans =>  aa
# Target==  ? basta maayo lang nga pagkatrabaho basta dili' lang ingon nga
# 	Ans =>  a
# Target==  ay commercial ipaganda o ipaganda
# 	Ans =>  a
# Target==  tigtubig boy lang ta sa ilaha
# 	Ans =>  ?i
# Target==  mawala'-wala' lagi ka dili' kaayo ta ka madungog
# 	Ans =>  ua
# Target==  ? lagi impas na akua piro ang prublima diri ko' nga ma-flat-an mahurot sa hantakan tanan ?
# 	Ans =>  aa
# Target==  natingala gani' siya nga duha ra daw kabulan kapin
# 	Ans =>  a a
# Target==  dalan lang tika dalan tika
# 	Ans =>  ua
# Target==  ay gibalita' na pod diay naana' pod bagiyo
# 	Ans =>  u
# Target==  anhi lang diri ini og human nimo og panglaba
# 	Ans =>  a
# Target==  naana' la ?
# 	Ans =>
# Target==  laa- mukuan sala' gani' to sila musimba
# 	Ans =>  a
# Target==  aw o si lenny ang kauban niya si kuan maricris
# 	Ans =>  u
# Target==  ? lisod na ang ingon miana' mok
# 	Ans =>  ?
# Target==  mmm ana' gayod kana' mari gayod kinahanglan
# 	Ans =>  ?
# Target==  ? didto sa ingon nila nga guadalupe unsa kadto nga lugara kadto
# 	Ans =>  ua
# Target==  iskuwila tanan o humana ang uban
# 	Ans =>  u
# Target==  o ato' ra man gihapon na ba inig
# 	Ans =>  u
# Target==  ? daghan og dalhon tika
# 	Ans =>  ?
# Target==  wala' ing signal amo' nga bukid ? bukid
# 	Ans =>  ua
# Target==  pait kaayo amo' nga kinabuhi' ingon ana' ra oy motor-motor pait kaayo
# 	Ans =>  a
# Target==  sapatos bag-o nga sapatos alangan dili' ka magsapatos
# 	Ans =>  uaa
# Target==  oh oh oh dinha' gayod
# 	Ans =>  ?
# Target==  uo mag-propose nako' sa imo hapit na
# 	Ans =>  u
# Target==  three years lang baya' sila didto
# 	Ans =>  ?
# Target==  diri sa kuan gayod sa may iskuwilahan duol banda
# 	Ans =>  ua a
# Target==  pila na may anak nimo karon
# 	Ans =>  ?
# 0 22.789648056 107.418228149
# 10 -24.1007823944 129.842529297
# 20 41.5729484558 125.989059448
# 30 -8.48087215424 124.962509155
# 40 -11.2874326706 107.043655396
# 50 -11.6737308502 113.737571716
# 60 26.8069515228 112.959396362
# 70 -9.68746376038 104.854324341
# 80 -10.8591308594 101.650993347
# 90 -22.88646698 109.100730896
#
# ===============================
# epoch 7 : pseudo= 8.15338395728, cost= 111.463856851, previous_cost= 112.913820492, train_time = 1140.52388096 s
# 4
# 			 val_= 0.964218199198, test_time  = 1.08234286308 s
# ===============================
#
# Target==  mikalit man gayod kadto nga nga naa ing talk uniya' kuan pod ba kana' nga ?
# 	Ans =>  uiaa
# Target==  ay nagtrabaho ko' sa kuan sa factory
# 	Ans =>  a
# Target==  gikuan kuno to ? gipalitan to og itlog
# 	Ans =>  i
# Target==  ayaw kay gutom gayod na nga alas-dusi na man
# 	Ans =>  ?a
# Target==  ma-level ba diay nako' nga sumbagay lang
# 	Ans =>  a
# Target==  sa akua diay dili' madunggan nimo
# 	Ans =>  a
# Target==  na sa bata'
# 	Ans =>  a
# Target==  asa mo dapit gasuroy-suroy
# 	Ans =>  ?
# Target==  pariha ana' oscar ana' ba
# 	Ans =>  ?
# Target==  o adtuon lang nako' si jed
# 	Ans =>  ?
# Target==  lech- litson na baboy
# 	Ans =>  i
# Target==  sa kuan lang kana' nga mga makaagi ko' og simbahan
# 	Ans =>  m
# Target==  girl manglaag kita' ila shirla sunod ba
# 	Ans =>  ui
# Target==  o mmm
# 	Ans =>  ?
# Target==  uyabon uyab-uyab na man daw kuno
# 	Ans =>  i
# Target==  kato nga nabahaan ato' nga una ba
# 	Ans =>  ua
# Target==  o ngano nalagot man ka ni ? o
# 	Ans =>  ?
# Target==  sa february mag-lima siya kabulan
# 	Ans =>  a
# Target==  musalig og kana' nga mga ingon ana' oy maningkamot ako' oy mangita' ko' og paagi kay lisod kaayo man gayod na ang
# 	Ans =>  ?a
# Target==  manok uniya' kaha iya elot unsa
# 	Ans =>  ma
# Target==  og mas tigulang ko' sa imuha ba ?
# 	Ans =>  a
# Target==  lisod kana' ang bungol ba bungol baya' ko'
# 	Ans =>  ma
# Target==  si ?
# 	Ans =>  a
# Target==  o i-announce
# 	Ans =>  ?
# Target==  kay malipong man kaha' siya ?
# 	Ans =>  ia
# Target==  o wala' ? hinuon wala' man hinuon
# 	Ans =>  ?
# Target==  bitaw day tama' gayod ka day
# 	Ans =>  m
# Target==  dinhi man gayod mi mabuhi' bay
# 	Ans =>  i
# Target==  ? wala' diay giapas ni alex
# 	Ans =>  ?
# Target==  wala' ing tarong og iskuwila sigi lang og climb-climb na
# 	Ans =>  ma
# Target==  usa lay nagdungan nimo dong
# 	Ans =>  ?
# Target==  naako' wala' oy luuya oy
# 	Ans =>  a
# Target==  hapit na alas-dusi padulong siya duty ron
# 	Ans =>  a
# Target==  uniya' mama nimo nakauli' na
# 	Ans =>  m
# Target==  mao na nga ukasiyon na man libri gayod
# 	Ans =>  ma
# Target==  dili' pod tama' tama' lang
# 	Ans =>  i
# Target==  guwapo man pod na ingon ana' salo-salo tanan mga
# 	Ans =>  a
# Target==  naa diay ka ing exam karon sayo man lagi
# 	Ans =>  ?
# Target==  kana' nga dili' na siya magpalakas og kaon diay ti
# 	Ans =>  a
# Target==  unsa man nga naa man kay klasi inig gawas nimo sa klasi
# 	Ans =>  na
# 0 16.526807785 101.720214844
# 10 9.36267089844 119.092895508
# 20 -18.5414428711 116.546798706
# 30 12.6137638092 120.125953674
# 40 31.3661136627 104.11051178
# 50 15.4176635742 115.87033844
# 60 -10.6082029343 113.569564819
# 70 -7.36832284927 105.252761841
# 80 -22.5188484192 101.933135986
# 90 28.1781749725 109.980796814
#
# ===============================
# epoch 8 : pseudo= 3.22470752975, cost= 107.240162839, previous_cost= 111.463856851, train_time = 1140.81282306 s
# 4
# 			 val_= 0.903720793658, test_time  = 1.08718085289 s
# ===============================
#
# Target==  sila vannie okay man na kay mga taba' man
# 	Ans =>  ia a a
# Target==  pangit man na ang rain or shine hinay kaayo na oy
# 	Ans =>  ka
# Target==  mura lagi og dili' ikaw ?
# 	Ans =>  ua
# Target==  no nagkauyab man diay mo ato' niya no
# 	Ans =>  naa a
# Target==  o karon na anhi lang diri
# 	Ans =>  o
# Target==  taod-taod taod-taod na sad
# 	Ans =>  aa
# Target==  ay sigi man musulti man siya sa akua piro wala' ko' kita' sa lalaki giingnan nako' ayaw sa paadtua og balay
# 	Ans =>  ka
# Target==  cook nako' dinha' mag-cook puwidi mag-cook nako' dinha'
# 	Ans =>  u  a
# Target==  o kato lang siya one three
# 	Ans =>  o
# Target==  ting-break time ? ? ting-break time
# 	Ans =>  s
# Target==  mao lagi siguro sa kuan putol-putol
# 	Ans =>  maa a
# Target==  uniya' kumusta man imo nga pa check-up balik nay
# 	Ans =>  ?
# Target==  useless lang gihapon imo nga sigi ka og pangutana sa akua
# 	Ans =>  mu a
# Target==  wal- wal- wala' diay bugas
# 	Ans =>  ua
# Target==  ? kana' nga mga uso karon
# 	Ans =>  ?
# Target==  oh wala' ing signal amo' nga bukid ?
# 	Ans =>  o
# Target==  o para ?
# 	Ans =>  ?
# Target==  wala' pa wala' pa
# 	Ans =>  ma
# Target==  si neneng og si sweetie ra man to
# 	Ans =>  i
# Target==  dako' na na nga panalangin sa ginuo
# 	Ans =>  a
# Target==  ? age does not matter bitaw na ati
# 	Ans =>  a
# Target==  maayo og madayon maayo og dili'
# 	Ans =>  ma
# Target==  namaligiya' man si caloy diri oh halos kami tanan namalit
# 	Ans =>  ma a
# Target==  dondie naunsa diay si dondie diay
# 	Ans =>  u
# Target==  prak- ? prak- ha
# 	Ans =>  ka
# Target==  maayo unta' og kumplito to nga ?
# 	Ans =>  na a
# Target==  layas ? layas ni nga bataa ni bisan
# 	Ans =>  na
# Target==  mao ana' man gayod kana' dili' na man gayod kana' ma-control tir
# 	Ans =>  ma
# Target==  na-addict na kaayo si doogie ba o
# 	Ans =>  a
# Target==  basi og imo nga suwirti naa sa lain wala' dinha'
# 	Ans =>  ma a
# Target==  duol pa gayod ka sa mga bata' nimo imo nga mga anak
# 	Ans =>  ni
# Target==  o bag-o ato' dili' ka ? tsoy ato'
# 	Ans =>  o
# Target==  thursday ba huwibis
# 	Ans =>  ka
# Target==  pagkadako' sa pabo oy mura man og kabaw
# 	Ans =>  ka a a
# Target==  wala' pa ing valid i_d si papa
# 	Ans =>  a
# Target==  last year pabuto man kadto last year
# 	Ans =>  a
# Target==  hala no luuya gayod niya gayod
# 	Ans =>  a
# Target==  ? unsa iya nga course kurso
# 	Ans =>  ?
# Target==  ? magbaktas ? duol ra man pod
# 	Ans =>  m
# Target==  ha ?
# 	Ans =>  ?
# 0 -22.6097297668 103.368774414
# 10 -3.63629603386 116.434524536
# 20 -8.5843296051 115.045837402
# 30 -3.93032073975 117.907714844
# 40 49.8077392578 104.826889038
# 50 8.67534637451 107.876441956
# 60 0.490274041891 111.325241089
# 70 -1.14052808285 102.793411255
# 80 -29.9433116913 99.4174118042
# 90 17.7812786102 106.995445251
#
# ===============================
# epoch 9 : pseudo= 1.55485250729, cost= 105.507162115, previous_cost= 107.240162839, train_time = 1141.66815996 s
# 4
# 			 val_= 0.898459723584, test_time  = 1.08690500259 s
# ===============================
#
# Target==  bumble bee ? sa ato' pa ? gayod diay ka
# 	Ans =>  ma
# Target==  nindot na kadto imo nga kuan sa una
# 	Ans =>  n
# Target==  piro kad- kadali' ra man to nga si ati mildred
# 	Ans =>  p aa a
# Target==  ? gahapon nakakuwarta kagahapon
# 	Ans =>  ? a a
# Target==  ? wala' ra ba kay budget
# 	Ans =>  ?
# Target==  ang tulo kakuan traha
# 	Ans =>  n
# Target==  nagtrabaho davao light
# 	Ans =>  na
# Target==  mao lagi ba unsa nga urasa muabot diay
# 	Ans =>  ma a
# Target==  ? ako' pod mupalit pod ko' og gatas sa ako' nga anak diri
# 	Ans =>  ka a
# Target==  unsa man ila nga gidula' ?
# 	Ans =>  mna
# Target==  kuyawa gayod pila ang ?
# 	Ans =>  il
# Target==  ipalihog ko' ingon nga
# 	Ans =>  i
# Target==  ? sigi siya suroy-suroy
# 	Ans =>  ?
# Target==  kuyawa no paspasa pod nila manganak no ?
# 	Ans =>  ia
# Target==  ? ? unsa man nawala' man nadawat
# 	Ans =>  ?
# Target==  ? uniya'
# 	Ans =>  ?
# Target==  piro wala' na ka miadto
# 	Ans =>  kaa
# Target==  bala kaayo ka maunahan gani' ka gani'
# 	Ans =>  naa
# Target==  ? mao gayod na
# 	Ans =>  a
# Target==  kay daghan man gayod kaayo sila mama gayod dira'
# 	Ans =>  dia a a
# Target==  arkilaha ?
# 	Ans =>  ?
# Target==  o asa man siya nag-iskuwila karon
# 	Ans =>  ?
# Target==  uniya' wala'-wala' wala' mo ing video ato' nga
# 	Ans =>  kaa a a a
# Target==  kuyog piro ? hapon na lagi kaayo maayo man to nga nakuha kadto ganiha kay
# 	Ans =>  u' a ai a a a
# Target==  ? nangita' ta og kana' nga maayo unsa ing unsa og grasiya uniya' sa ginuo ba
# 	Ans =>  a
# Target==  ? usa na man lang ? mao diay wala' na lang
# 	Ans =>  ? a
# Target==  blue uniya' blue ra pod ako' nga
# 	Ans =>  mn
# Target==  o trisi
# 	Ans =>  o
# Target==  mapundasiyunan ang kuan
# 	Ans =>  ma
# Target==  magsakit-sakit biya' ni sarah og si janmar
# 	Ans =>  oa ia a a a
# Target==  o ngano diay muuban ka
# 	Ans =>  o
# Target==  ? ka didto sigi ra og tindog
# 	Ans =>  wa
# Target==  ay usahay lang dili' man pod siya ingon nga dalo' piro
# 	Ans =>  a
# Target==  uniya' kanus-a man to muuli' imo nga bana
# 	Ans =>  un aa
# Target==  ? si luke ? wala' na man siya ing ? wala' na man
# 	Ans =>  o a
# Target==  ikaw kumusta na man mo sa imo nga uyab
# 	Ans =>  naa
# Target==  sa una mao man unta' to ang plano namo' sa una
# 	Ans =>  saaa
# Target==  ? sunod ini og magkita' ta ?
# 	Ans =>  i
# Target==  og wala' nawala' ? abi nako' og wala' pa
# 	Ans =>  d a
# Target==  o tabang ? kadto nga ? sa bohol ba
# 	Ans =>  o a a
# 0 -12.8581790924 99.9319610596
# 10 14.8656492233 115.66809082
# 20 0.967969894409 113.741317749
# 30 10.170882225 118.043296814
# 40 17.183013916 98.8698501587
# 50 -14.6441774368 108.177474976
# 60 -3.63101196289 108.922386169
# 70 3.29568481445 99.631187439
# 80 -14.6269598007 93.91065979
# 90 18.0704479218 100.627914429
#
# ===============================
# epoch 10 : pseudo= 1.15845257508, cost= 104.013827006, previous_cost= 105.507162115, train_time = 1141.85957909 s
# 4
# 			 val_= 0.907419154747, test_time  = 1.08892202377 s
# ===============================
#
# Target==  uo didto uo uo kadto bitaw tribute ba to
# 	Ans =>  o
# Target==  ? college level man pod ?
# 	Ans =>  ?  '
# Target==  ambot oy tapos kuan
# 	Ans =>  m
# Target==  si manilyn kana' iya nga damit ihat- ihatod
# 	Ans =>  s
# Target==  kay manayaw mga bata' ?
# 	Ans =>  ka
# Target==  na nga nag siyagit-siyagit
# 	Ans =>  ma
# Target==  ? ? basta ang suman ha ? og naa mabilin bigiyan mo gayod ko'
# 	Ans =>  ?  a
# Target==  ay okay lang okay lang gihapon
# 	Ans =>  a
# Target==  sila nanti naana' sila nga nanti naana'
# 	Ans =>  ia
# Target==  mmm kanus-a man kadto mangha-
# 	Ans =>  ?
# Target==  ? ?
# 	Ans =>  ?
# Target==  didto siya na assign sa una mao nga didto gani' mi nagkita'
# 	Ans =>  i
# Target==  gahapon unsa diay ?
# 	Ans =>  dlr
# Target==  naa ing gamay naa sa ing buhat sakto ra naa ra ing kuan gayod
# 	Ans =>  ua'  a
# Target==  ? basta maayo lang nga pagkatrabaho basta dili' lang ingon nga
# 	Ans =>  si
# Target==  ay commercial ipaganda o ipaganda
# 	Ans =>  a
# Target==  tigtubig boy lang ta sa ilaha
# 	Ans =>  d
# Target==  mawala'-wala' lagi ka dili' kaayo ta ka madungog
# 	Ans =>  m
# Target==  ? lagi impas na akua piro ang prublima diri ko' nga ma-flat-an mahurot sa hantakan tanan ?
# 	Ans =>  i'
# Target==  natingala gani' siya nga duha ra daw kabulan kapin
# 	Ans =>  na'
# Target==  dalan lang tika dalan tika
# 	Ans =>  pta
# Target==  ay gibalita' na pod diay naana' pod bagiyo
# 	Ans =>  o
# Target==  anhi lang diri ini og human nimo og panglaba
# 	Ans =>  na
# Target==  naana' la ?
# 	Ans =>  n
# Target==  laa- mukuan sala' gani' to sila musimba
# 	Ans =>  na
# Target==  aw o si lenny ang kauban niya si kuan maricris
# 	Ans =>  ?
# Target==  ? lisod na ang ingon miana' mok
# 	Ans =>  ?
# Target==  mmm ana' gayod kana' mari gayod kinahanglan
# 	Ans =>  m
# Target==  ? didto sa ingon nila nga guadalupe unsa kadto nga lugara kadto
# 	Ans =>  ?
# Target==  iskuwila tanan o humana ang uban
# 	Ans =>  s
# Target==  o ato' ra man gihapon na ba inig
# 	Ans =>  o
# Target==  ? daghan og dalhon tika
# 	Ans =>  ?
# Target==  wala' ing signal amo' nga bukid ? bukid
# 	Ans =>  wal'
# Target==  pait kaayo amo' nga kinabuhi' ingon ana' ra oy motor-motor pait kaayo
# 	Ans =>  a'
# Target==  sapatos bag-o nga sapatos alangan dili' ka magsapatos
# 	Ans =>  k
# Target==  oh oh oh dinha' gayod
# 	Ans =>  o
# Target==  uo mag-propose nako' sa imo hapit na
# 	Ans =>  o
# Target==  three years lang baya' sila didto
# 	Ans =>  di
# Target==  diri sa kuan gayod sa may iskuwilahan duol banda
# 	Ans =>  dli'
# Target==  pila na may anak nimo karon
# 	Ans =>  ?
# 0 12.0671892166 93.2579879761
# 10 -33.4954986572 108.030578613
# 20 -23.6421413422 100.602714539
# 30 -33.1546096802 98.9003067017
# 40 36.6697998047 85.0104751587
# 50 -21.3163948059 84.1301803589
# 60 -16.3632926941 86.175491333
# 70 18.5030822754 76.4175872803
# 80 -20.1434803009 68.0709533691
# 90 2.77767634392 74.7294998169
#
# ===============================
# epoch 11 : pseudo= -2.92621001409, cost= 84.8281088798, previous_cost= 104.013827006, train_time = 1141.28467011 s
# 4
# 			 val_= 0.644616255405, test_time  = 1.15123987198 s
# ===============================
#
# Target==  mikalit man gayod kadto nga nga naa ing talk uniya' kuan pod ba kana' nga ?
# 	Ans =>  ikanan gaykaaataya'kuaaao akaa
# Target==  ay nagtrabaho ko' sa kuan sa factory
# 	Ans =>  ayagaako' kakuo'kasatakoai
# Target==  gikuan kuno to ? gipalitan to og itlog
# 	Ans =>  ikanka naoituano  kaitangiy i
# Target==  ayaw kay gutom gayod na nga alas-dusi na man
# 	Ans =>  akayo'  na galauiyna
# Target==  ma-level ba diay nako' nga sumbagay lang
# 	Ans =>  waliya diay inako'saagaya
# Target==  sa akua diay dili' madunggan nimo
# 	Ans =>  kuai mandao
# Target==  na sa bata'
# 	Ans =>  naso a aa
# Target==  asa mo dapit gasuroy-suroy
# 	Ans =>  ?tonmo aiy isriury
# Target==  pariha ana' oscar ana' ba
# 	Ans =>  pa'na'aanaba
# Target==  o adtuon lang nako' si jed
# 	Ans =>  ?auoaako's
# Target==  lech- litson na baboy
# 	Ans =>  ddis nabaoy
# Target==  sa kuan lang kana' nga mga makaagi ko' og simbahan
# 	Ans =>  akaa maaosiba
# Target==  girl manglaag kita' ila shirla sunod ba
# 	Ans =>  mm lata laaoba
# Target==  o mmm
# 	Ans =>  o
# Target==  uyabon uyab-uyab na man daw kuno
# 	Ans =>  dauiyauy'namanako
# Target==  kato nga nabahaan ato' nga una ba
# 	Ans =>  kaaa
# Target==  o ngano nalagot man ka ni ? o
# 	Ans =>  oaalao a laay
# Target==  sa february mag-lima siya kabulan
# 	Ans =>  saaimaiasiya kapua
# Target==  musalig og kana' nga mga ingon ana' oy maningkamot ako' oy mangita' ko' og paagi kay lisod kaayo man gayod na ang
# 	Ans =>  saaa
# Target==  manok uniya' kaha iya elot unsa
# 	Ans =>  aoiyakaayla
# Target==  og mas tigulang ko' sa imuha ba ?
# 	Ans =>  daa iulangko' iymaa
# Target==  lisod kana' ang bungol ba bungol baya' ko'
# 	Ans =>  msaoagabaubay'ko
# Target==  si ?
# 	Ans =>  ai
# Target==  o i-announce
# 	Ans =>  ?a na
# Target==  kay malipong man kaha' siya ?
# 	Ans =>  kaymaito  mangkasia
# Target==  o wala' ? hinuon wala' man hinuon
# 	Ans =>  ola'wala'ani
# Target==  bitaw day tama' gayod ka day
# 	Ans =>  mita aytamaniyd tayay
# Target==  dinhi man gayod mi mabuhi' bay
# 	Ans =>  i iyi mkay
# Target==  ? wala' diay giapas ni alex
# 	Ans =>  waai kaaa
# Target==  wala' ing tarong og iskuwila sigi lang og climb-climb na
# 	Ans =>  waaaia gi agkaana'
# Target==  usa lay nagdungan nimo dong
# 	Ans =>  usa la naaio
# Target==  naako' wala' oy luuya oy
# 	Ans =>  ako' waay
# Target==  hapit na alas-dusi padulong siya duty ron
# 	Ans =>  ?iauipa oi
# Target==  uniya' mama nimo nakauli' na
# 	Ans =>  iya' aa aka
# Target==  mao na nga ukasiyon na man libri gayod
# 	Ans =>  makaiynamanig
# Target==  dili' pod tama' tama' lang
# 	Ans =>  dipoamatamaan
# Target==  guwapo man pod na ingon ana' salo-salo tanan mga
# 	Ans =>  ako' nko' nayanasa saltananmamga
# Target==  naa diay ka ing exam karon sayo man lagi
# 	Ans =>  ?ayasa ngkaranayan nai
# Target==  kana' nga dili' na siya magpalakas og kaon diay ti
# 	Ans =>  kana' ngii'napaaka o kaaytay
# Target==  unsa man nga naa man kay klasi inig gawas nimo sa klasi
# 	Ans =>  nsama  aamankaykulaiyanagwwaosa aiy
# 0 3.37830281258 69.3509368896
# 10 4.06628513336 80.4332504272
# 20 5.34592580795 80.5308074951
# 30 18.3611812592 76.7456207275
# 40 -6.7882065773 64.9082794189
# 50 -25.7441158295 69.7857894897
# 60 -9.17271709442 75.1713256836
# 70 4.58917856216 65.5024795532
# 80 37.9505996704 108.088279724
# 90 -5.55248594284 64.9005508423
#
# ===============================
# epoch 12 : pseudo= 4.27162128398, cost= 73.4234442352, previous_cost= 84.8281088798, train_time = 1141.31164408 s
# 4
# 			 val_= 0.592679157634, test_time  = 1.16066598892 s
# ===============================
#
# Target==  sila vannie okay man na kay mga taba' man
# 	Ans =>  silabaniokay  man natangmatabam
# Target==  pangit man na ang rain or shine hinay kaayo na oy
# 	Ans =>  png ay kay ay
# Target==  mura lagi og dili' ikaw ?
# 	Ans =>  wwala gidilikaw
# Target==  no nagkauyab man diay mo ato' niya no
# 	Ans =>  a nakauya p iy uato niya n
# Target==  o karon na anhi lang diri
# 	Ans =>  o karona nlagdi
# Target==  taod-taod taod-taod na sad
# 	Ans =>  ?pataad
# Target==  ay sigi man musulti man siya sa akua piro wala' ko' kita' sa lalaki giingnan nako' ayaw sa paadtua og balay
# 	Ans =>  kangsiingtoti yupuo a' asaina' nkpo'tbaray
# Target==  cook nako' dinha' mag-cook puwidi mag-cook nako' dinha'
# 	Ans =>  ponao' diha' mako'kuwmanagko napo' diha'
# Target==  o kato lang siya one three
# 	Ans =>  okatolang siya atry
# Target==  ting-break time ? ? ting-break time
# 	Ans =>  gga n
# Target==  mao lagi siguro sa kuan putol-putol
# 	Ans =>  alagiiuro sa kuantoto kuto
# Target==  uniya' kumusta man imo nga pa check-up balik nay
# 	Ans =>  ?iya' ko's man nimo ngaaia akualinay
# Target==  useless lang gihapon imo nga sigi ka og pangutana sa akua
# 	Ans =>  lwisang ihapomosigitopamuta' nagkua
# Target==  wal- wal- wala' diay bugas
# 	Ans =>  pwl'wal'wla' di ba
# Target==  ? kana' nga mga uso karon
# 	Ans =>  ?a na ngaosokaron
# Target==  oh wala' ing signal amo' nga bukid ?
# 	Ans =>  omaysig na na moguki
# Target==  o para ?
# 	Ans =>  opara
# Target==  wala' pa wala' pa
# 	Ans =>  'awla'
# Target==  si neneng og si sweetie ra man to
# 	Ans =>  siingnitinmannto
# Target==  dako' na na nga panalangin sa ginuo
# 	Ans =>  ako'tanang pana laisino
# Target==  ? age does not matter bitaw na ati
# 	Ans =>  ?dasi matita ti
# Target==  maayo og madayon maayo og dili'
# 	Ans =>  ?mayyadayy mayyoi'
# Target==  namaligiya' man si caloy diri oh halos kami tanan namalit
# 	Ans =>  aligiha asaldriaotrsa na na mal
# Target==  dondie naunsa diay si dondie diay
# 	Ans =>  diasa iuiy
# Target==  prak- ? prak- ha
# 	Ans =>  a a
# Target==  maayo unta' og kumplito to nga ?
# 	Ans =>  ala ntatong trputo' ngn
# Target==  layas ? layas ni nga bataa ni bisan
# 	Ans =>  ayaayo tani
# Target==  mao ana' man gayod kana' dili' na man gayod kana' ma-control tir
# 	Ans =>  mana' manayda'i' na maina ai
# Target==  na-addict na kaayo si doogie ba o
# 	Ans =>  nai'a tibao
# Target==  basi og imo nga suwirti naa sa lain wala' dinha'
# 	Ans =>  baimo swirsiy nasta naguaiyha'
# Target==  duol pa gayod ka sa mga bata' nimo imo nga mga anak
# 	Ans =>  opaaytao' mpata' iom ggana
# Target==  o bag-o ato' dili' ka ? tsoy ato'
# 	Ans =>  omaguto ikangi
# Target==  thursday ba huwibis
# 	Ans =>  pa
# Target==  pagkadako' sa pabo oy mura man og kabaw
# 	Ans =>  pagtadawgko'ayosataabun o kabah
# Target==  wala' pa ing valid i_d si papa
# 	Ans =>  ?aantadipapa
# Target==  last year pabuto man kadto last year
# 	Ans =>  a' toto' ai
# Target==  hala no luuya gayod niya gayod
# 	Ans =>  wla'nnuya od iyaguod
# Target==  ? unsa iya nga course kurso
# 	Ans =>   h
# Target==  ? magbaktas ? duol ra man pod
# 	Ans =>  ?maaakaur mao
# Target==  ha ?
# 	Ans =>   h
# 0 7.66565084457 70.9783401489
# 10 39.7314453125 100.776130676
# 20 18.7059516907 74.3260421753
# 30 21.7016506195 74.6838226318
# 40 11.4758577347 64.4177017212
# 50 5.76839017868 65.3674240112
# 60 -1.41145098209 67.70362854
# 70 6.72259998322 62.5581130981
# 80 -7.91833496094 56.7069282532
# 90 2.49331068993 60.8839187622
#
# ===============================
# epoch 13 : pseudo= 7.00019222886, cost= 70.5586650397, previous_cost= 73.4234442352, train_time = 1140.97975492 s
# 4
# 			 val_= 0.530428764442, test_time  = 1.1800801754 s
# ===============================
#
# Target==  bumble bee ? sa ato' pa ? gayod diay ka
# 	Ans =>  mabudiitakata paasrs diay ka
# Target==  nindot na kadto imo nga kuan sa una
# 	Ans =>  indutota imo nga kuan sa kana
# Target==  piro kad- kadali' ra man to nga si ati mildred
# 	Ans =>  opakadali' a naiadrd
# Target==  ? gahapon nakakuwarta kagahapon
# 	Ans =>  angahaponnakakasa ma gahapo
# Target==  ? wala' ra ba kay budget
# 	Ans =>  ?aaamabakaybadyd
# Target==  ang tulo kakuan traha
# 	Ans =>  gtulokakuan naha
# Target==  nagtrabaho davao light
# 	Ans =>  nagrabahodabala
# Target==  mao lagi ba unsa nga urasa muabot diay
# 	Ans =>  mala  bansa n rasa muaboya
# Target==  ? ako' pod mupalit pod ko' og gatas sa ako' nga anak diri
# 	Ans =>  natopokay mogpaliko' gkogdatasa kunakdiri
# Target==  unsa man ila nga gidula' ?
# 	Ans =>  masa mailanga il na
# Target==  kuyawa gayod pila ang ?
# 	Ans =>  pyawa gyopilia n
# Target==  ipalihog ko' ingon nga
# 	Ans =>  palinogko' ningonga
# Target==  ? sigi siya suroy-suroy
# 	Ans =>  sigi i rsar
# Target==  kuyawa no paspasa pod nila manganak no ?
# 	Ans =>  ya wan noasasapona maga nan
# Target==  ? ? unsa man nawala' man nadawat
# 	Ans =>  ?magdlamala' wa'g manna dawa
# Target==  ? uniya'
# 	Ans =>  ?nniya'
# Target==  piro wala' na ka miadto
# 	Ans =>  ro wala' na kania pkuwnahang
# Target==  bala kaayo ka maunahan gani' ka gani'
# 	Ans =>  ala' kayka manani a gani'
# Target==  ? mao gayod na
# 	Ans =>  lamgayona
# Target==  kay daghan man gayod kaayo sila mama gayod dira'
# 	Ans =>  dadakanang ko kay sila mammagayod diiha'
# Target==  arkilaha ?
# 	Ans =>  asilanga ang si
# Target==  o asa man siya nag-iskuwila karon
# 	Ans =>  an sanalra aa
# Target==  uniya' wala'-wala' wala' mo ing video ato' nga
# 	Ans =>  waya' wa' wala'  mapan wala' manwala' man aydidadto
# Target==  kuyog piro ? hapon na lagi kaayo maayo man to nga nakuha kadto ganiha kay
# 	Ans =>  klyoaponna ilm na ta ng ga kiaagayakay
# Target==  ? nangita' ta og kana' nga maayo unsa ing unsa og grasiya uniya' sa ginuo ba
# 	Ans =>  ngkatatarang ay  a sasangmaasiya na sa gimuwa
# Target==  ? usa na man lang ? mao diay wala' na lang
# 	Ans =>  ?ta na ma lang amadiay nla' na' ngng
# Target==  blue uniya' blue ra pod ako' nga
# 	Ans =>  luniya' lulapo dagaku an g ma
# Target==  o trisi
# 	Ans =>  ?trisi
# Target==  mapundasiyunan ang kuan
# 	Ans =>  mapongtasila nangkua
# Target==  magsakit-sakit biya' ni sarah og si janmar
# 	Ans =>  asasisakidayni sara siganma
# Target==  o ngano diay muuban ka
# 	Ans =>  onadiaymubanka
# Target==  ? ka didto sigi ra og tindog
# 	Ans =>  waga diytoigiya tidog
# Target==  ay usahay lang dili' man pod siya ingon nga dalo' piro
# 	Ans =>  ayaalangdina' ko sa gan dalosiro
# Target==  uniya' kanus-a man to muuli' imo nga bana
# 	Ans =>  uiya' kansa ma ko mo io nga ana
# Target==  ? si luke ? wala' na man siya ing ? wala' na man
# 	Ans =>  ?si  naggi ta natay n kayrn ay mmagra na sa
# Target==  ikaw kumusta na man mo sa imo nga uyab
# 	Ans =>  kakar mosa ra ma nga si mo gauiya
# Target==  sa una mao man unta' to ang plano namo' sa una
# 	Ans =>  ssa una mamankato nggplana na musa na
# Target==  ? sunod ini og magkita' ta ?
# 	Ans =>  unoini ga i maita' ta
# Target==  og wala' nawala' ? abi nako' og wala' pa
# 	Ans =>  lasaowa'na' waginato wa'pa
# Target==  o tabang ? kadto nga ? sa bohol ba
# 	Ans =>  o tabannggakato' nginsa bulba
# 0 2.33497476578 58.5790328979
# 10 7.56695175171 68.1548919678
# 20 2.72920203209 71.3504104614
# 30 -0.664575219154 72.3768692017
# 40 6.06782102585 56.6130142212
# 50 -5.70412397385 58.1842651367
# 60 -5.30234861374 65.0636520386
# 70 5.35717391968 58.3494186401
# 80 0.0371234901249 50.9486160278
# 90 -4.66138601303 57.7625846863
#
# ===============================
# epoch 14 : pseudo= 0.504325007599, cost= 59.6999527306, previous_cost= 70.5586650397, train_time = 1141.52303886 s
# 4
# 			 val_= 0.508206346819, test_time  = 1.17913508415 s
# ===============================
#
# Target==  uo didto uo uo kadto bitaw tribute ba to
# 	Ans =>  ?gia ka to ga ta ngsatrigdo nato
# Target==  ? college level man pod ?
# 	Ans =>  twakot maknnpo
# Target==  ambot oy tapos kuan
# 	Ans =>  mbot tapokuan
# Target==  si manilyn kana' iya nga damit ihat- ihatod
# 	Ans =>  smanisna gka na nnan to
# Target==  kay manayaw mga bata' ?
# 	Ans =>  kaymnayangabata'
# Target==  na nga nag siyagit-siyagit
# 	Ans =>  nikana na ngini
# Target==  ? ? basta ang suman ha ? og naa mabilin bigiyan mo gayod ko'
# 	Ans =>  ?matamto manaolmaodili ndigonto
# Target==  ay okay lang okay lang gihapon
# 	Ans =>  ?ka lang ka lang gihapo
# Target==  sila nanti naana' sila nga nanti naana'
# 	Ans =>  silanang ti nna' sa ng anti nna'
# Target==  mmm kanus-a man kadto mangha-
# 	Ans =>  mmansa ra  m a'
# Target==  ? ?
# 	Ans =>  ?o
# Target==  didto siya na assign sa una mao nga didto gani' mi nagkita'
# 	Ans =>  idtosiya nasa nsana limagidto r m nagkita'
# Target==  gahapon unsa diay ?
# 	Ans =>  dhapo sa di o
# Target==  naa ing gamay naa sa ing buhat sakto ra naa ra ing kuan gayod
# 	Ans =>  nakamay naasigbuhatatora nara kuan dod
# Target==  ? basta maayo lang nga pagkatrabaho basta dili' lang ingon nga
# 	Ans =>   attor gaagadab na  pagtgbamasa dili' nang mo nga
# Target==  ay commercial ipaganda o ipaganda
# 	Ans =>  kay kon lta gsdaoanata
# Target==  tigtubig boy lang ta sa ilaha
# 	Ans =>  sb nsisa
# Target==  mawala'-wala' lagi ka dili' kaayo ta ka madungog
# 	Ans =>  ma wala' wala' lagika dli'kao i a maduog
# Target==  ? lagi impas na akua piro ang prublima diri ko' nga ma-flat-an mahurot sa hantakan tanan ?
# 	Ans =>  laginsa na kuapiro npogmima gi komlnnurot a tatantanana
# Target==  natingala gani' siya nga duha ra daw kabulan kapin
# 	Ans =>  naigaa naa sia nga ugna  katola
# Target==  dalan lang tika dalan tika
# 	Ans =>  dalanan ta ka dika
# Target==  ay gibalita' na pod diay naana' pod bagiyo
# 	Ans =>  ?dibalita' napod dia na nat bago
# Target==  anhi lang diri ini og human nimo og panglaba
# 	Ans =>  nilang i ni' mopong slaba
# Target==  naana' la ?
# 	Ans =>  naana la
# Target==  laa- mukuan sala' gani' to sila musimba
# 	Ans =>  nammogkan  silam sinba
# Target==  aw o si lenny ang kauban niya si kuan maricris
# 	Ans =>  a  si gini ang kabaniya sikuaan maii'ds
# Target==  ? lisod na ang ingon miana' mok
# 	Ans =>  ng isodngo nango
# Target==  mmm ana' gayod kana' mari gayod kinahanglan
# 	Ans =>  na' di a'gnn
# Target==  ? didto sa ingon nila nga guadalupe unsa kadto nga lugara kadto
# 	Ans =>  tosasta mlan go mto ma
# Target==  iskuwila tanan o humana ang uban
# 	Ans =>  kuwila na mmannn ga
# Target==  o ato' ra man gihapon na ba inig
# 	Ans =>  t gihko na ka
# Target==  ? daghan og dalhon tika
# 	Ans =>  odakniskn dan k
# Target==  wala' ing signal amo' nga bukid ? bukid
# 	Ans =>  wala'si na langmogbkidlogbukid
# Target==  pait kaayo amo' nga kinabuhi' ingon ana' ra oy motor-motor pait kaayo
# 	Ans =>  ?ka mo ng nga ilabuhigana ko mo tumototakayo
# Target==  sapatos bag-o nga sapatos alangan dili' ka magsapatos
# 	Ans =>  kto  baakto ditato
# Target==  oh oh oh dinha' gayod
# 	Ans =>  oiaayod
# Target==  uo mag-propose nako' sa imo hapit na
# 	Ans =>  omagpo na ko' sa imo apina
# Target==  three years lang baya' sila didto
# 	Ans =>  il
# Target==  diri sa kuan gayod sa may iskuwilahan duol banda
# 	Ans =>  dirisa kuan gyosa ma skuwilahanduon banda
# Target==  pila na may anak nimo karon
# 	Ans =>  ila na ma nagngmo ro
# 0 4.08812713623 54.202796936
# 10 -2.71100616455 61.4228439331
# 20 7.08519458771 65.4049835205
# 30 1.33542430401 62.2188224792
# 40 1.4021011591 55.9401741028
# 50 -5.45236968994 53.1240463257
# 60 12.2447280884 60.8639526367
# 70 3.34707760811 54.0410575867
# 80 -13.1705389023 48.1695251465
# 90 -4.27522754669 56.2361526489
#
# ===============================
# epoch 15 : pseudo= 2.07925675946, cost= 57.1319572285, previous_cost= 59.6999527306, train_time = 1141.27151299 s
# 4
# 			 val_= 0.495701403155, test_time  = 1.18287110329 s
# ===============================
#
# Target==  mikalit man gayod kadto nga nga naa ing talk uniya' kuan pod ba kana' nga ?
# 	Ans =>  ikan man gayodkongta niya' kuaan tod bakana' nga n
# Target==  ay nagtrabaho ko' sa kuan sa factory
# 	Ans =>  ay nagklabahoko'  kakuan sa tato' na i
# Target==  gikuan kuno to ? gipalitan to og itlog
# 	Ans =>  ikuan to atogplunan popnipan  diog
# Target==  ayaw kay gutom gayod na nga alas-dusi na man
# 	Ans =>  a'ay to m namglastusi nan
# Target==  ma-level ba diay nako' nga sumbagay lang
# 	Ans =>  balidr mo diay  nako' n sabagday la
# Target==  sa akua diay dili' madunggan nimo
# 	Ans =>  sakudigi nadamo
# Target==  na sa bata'
# 	Ans =>  iato na s baa'
# Target==  asa mo dapit gasuroy-suroy
# 	Ans =>  snmodasi dsurisuroy
# Target==  pariha ana' oscar ana' ba
# 	Ans =>  ana' usana ba
# Target==  o adtuon lang nako' si jed
# 	Ans =>  o ton lang nako' sjd
# Target==  lech- litson na baboy
# 	Ans =>  litiliso nababo
# Target==  sa kuan lang kana' nga mga makaagi ko' og simbahan
# 	Ans =>  sa n namponsinba
# Target==  girl manglaag kita' ila shirla sunod ba
# 	Ans =>  rmgta lasnasuba
# Target==  o mmm
# 	Ans =>  o
# Target==  uyabon uyab-uyab na man daw kuno
# 	Ans =>  iyaunpiyau naman dawkonno
# Target==  kato nga nabahaan ato' nga una ba
# 	Ans =>  tao n nabaa ko ng ba
# Target==  o ngano nalagot man ka ni ? o
# 	Ans =>  o lako na lan dati o
# Target==  sa february mag-lima siya kabulan
# 	Ans =>  sasrar mai pasiya kapulan
# Target==  musalig og kana' nga mga ingon ana' oy maningkamot ako' oy mangita' ko' og paagi kay lisod kaayo man gayod na ang
# 	Ans =>  sninmo'ipnn n
# Target==  manok uniya' kaha iya elot unsa
# 	Ans =>  banlo niya kahailosa
# Target==  og mas tigulang ko' sa imuha ba ?
# 	Ans =>  s  stiulang ko sa imomua ba
# Target==  lisod kana' ang bungol ba bungol baya' ko'
# 	Ans =>  asod nabunbabuon bya' ko'
# Target==  si ?
# 	Ans =>  ai
# Target==  o i-announce
# 	Ans =>  ?o  naon
# Target==  kay malipong man kaha' siya ?
# 	Ans =>  kay malito ma ksiya
# Target==  o wala' ? hinuon wala' man hinuon
# 	Ans =>  o walainun wala' man ninun
# Target==  bitaw day tama' gayod ka day
# 	Ans =>  mita' dia tama gayod  ka bay
# Target==  dinhi man gayod mi mabuhi' bay
# 	Ans =>  dili man gid nimogikay
# Target==  ? wala' diay giapas ni alex
# 	Ans =>  wat  kihatsid
# Target==  wala' ing tarong og iskuwila sigi lang og climb-climb na
# 	Ans =>  wlal' gkwilaio n kas na
# Target==  usa lay nagdungan nimo dong
# 	Ans =>  usala nagdunga ngoduo ng
# Target==  naako' wala' oy luuya oy
# 	Ans =>  nko' waldoyluyooy
# Target==  hapit na alas-dusi padulong siya duty ron
# 	Ans =>  pitapsi pa-ugtigen
# Target==  uniya' mama nimo nakauli' na
# 	Ans =>  niya' maopakoi na
# Target==  mao na nga ukasiyon na man libri gayod
# 	Ans =>  mao na n pukasiy na man gibr go
# Target==  dili' pod tama' tama' lang
# 	Ans =>  dili'po ta matama' lang
# Target==  guwapo man pod na ingon ana' salo-salo tanan mga
# 	Ans =>  mako n po na nasalusaltana' ngmga
# Target==  naa diay ka ing exam karon sayo man lagi
# 	Ans =>   samkarn sayo man nagi
# Target==  kana' nga dili' na siya magpalakas og kaon diay ti
# 	Ans =>  kana' nga dili'  napanaka s gkaon diay ti
# Target==  unsa man nga naa man kay klasi inig gawas nimo sa klasi
# 	Ans =>  usa manga na man kay klasia nagkawasion sa lasi
# 0 4.71308135986 53.1628112793
# 10 13.9711580276 57.8662338257
# 20 24.9359931946 67.0914001465
# 30 22.8625488281 61.8632278442
# 40 -0.951637268066 52.9565658569
# 50 13.7092409134 56.8066635132
# 60 4.79539489746 59.9234619141
# 70 -3.34369063377 48.5814743042
# 80 -4.94191122055 45.8599891663
# 90 1.57076299191 52.9600524902
#
# ===============================
# epoch 16 : pseudo= 4.21741432865, cost= 55.0654519604, previous_cost= 57.1319572285, train_time = 1141.44900393 s
# 4
# 			 val_= 0.46120530377, test_time  = 1.19513201714 s
# ===============================
#
# ...
# Target==  diri sa kuan gayod sa may iskuwilahan duol banda
# 	Ans =>  diri sa kuan gayodsa may gskuwilahandon banda
# Target==  pila na may anak nimo karon
# 	Ans =>  napila na many nakg imaron
# 0 0.658235967159 32.9718513489
# 10 -0.238201141357 39.8615264893
# 20 11.2110366821 49.6159896851
# 30 7.06894159317 44.4390220642
# 40 3.10621237755 35.9647216797
# 50 218.800491333 178.238739014
# 60 232.931350708 178.639938354
# 70 92.8583297729 147.683120728
# 80 39.0983886719 163.435913086
# 90 13.7966432571 52.6656074524
#
# ===============================
# epoch 27 : pseudo= 33.8727000684, cost= 74.0383559196, previous_cost= 39.0819802848, train_time = 1135.6147368 s
# 4
# 			 val_= 0.440830115661, test_time  = 1.20717000961 s
# ===============================
#
# Target==  mikalit man gayod kadto nga nga naa ing talk uniya' kuan pod ba kana' nga ?
# 	Ans =>  ikonk lan gayod dko nga ata uniya' kuaan pod ba kana' nga s
# Target==  ay nagtrabaho ko' sa kuan sa factory
# 	Ans =>  ay nagtrabahokoka kuan sa pako' na y
# Target==  gikuan kuno to ? gipalitan to og itlog
# 	Ans =>  gikuan ko ndto gitulu-anp nyd o paliton e dit lyod
# Target==  ayaw kay gutom gayod na nga alas-dusi na man
# 	Ans =>  al kay uuto' ko nanga alas-dusiy aman
# Target==  ma-level ba diay nako' nga sumbagay lang
# 	Ans =>  balider mod diay nako' ng sa baggay na
# Target==  sa akua diay dili' madunggan nimo
# 	Ans =>  kur diya' diyi' nadalimo
# Target==  na sa bata'
# 	Ans =>  sia sto na sa baa
# Target==  asa mo dapit gasuroy-suroy
# 	Ans =>  asor mo dasa juosureysuroy
# Target==  pariha ana' oscar ana' ba
# 	Ans =>  rana' taana' ba
# Target==  o adtuon lang nako' si jed
# 	Ans =>  o aton lang nako' sijayod
# Target==  lech- litson na baboy
# 	Ans =>  disti ditso na baboy
# Target==  sa kuan lang kana' nga mga makaagi ko' og simbahan
# 	Ans =>  sa a nlagmako'  siba
# Target==  girl manglaag kita' ila shirla sunod ba
# 	Ans =>   mo-ata las nasuod ba
# Target==  o mmm
# 	Ans =>  o ma
# Target==  uyabon uyab-uyab na man daw kuno
# 	Ans =>  ayabuon payapuyo  na man da pu no
# Target==  kato nga nabahaan ato' nga una ba
# 	Ans =>  kato nganabahahaa ko' nga aba
# Target==  o ngano nalagot man ka ni ? o
# 	Ans =>  o an lagaod na lan da ti o
# Target==  sa february mag-lima siya kabulan
# 	Ans =>  sae buar magi pa siya ka pudan
# Target==  musalig og kana' nga mga ingon ana' oy maningkamot ako' oy mangita' ko' og paagi kay lisod kaayo man gayod na ang
# 	Ans =>  s an akiyo ni lan kaokako' ti t sa  od na
# Target==  manok uniya' kaha iya elot unsa
# 	Ans =>  malok niya' kaayilos sa
# Target==  og mas tigulang ko' sa imuha ba ?
# 	Ans =>  lasa ng mustidolang ko' sa imo muha ba??
# Target==  lisod kana' ang bungol ba bungol baya' ko'
# 	Ans =>  musod na ngubuha ba buulbaya' ko'
# Target==  si ?
# 	Ans =>  ladi
# Target==  o i-announce
# 	Ans =>  anaon
# Target==  kay malipong man kaha' siya ?
# 	Ans =>  kay maliton ma kar siya
# Target==  o wala' ? hinuon wala' man hinuon
# 	Ans =>  o walainuon wala' man ninon
# Target==  bitaw day tama' gayod ka day
# 	Ans =>  mita' day tawa' gayod ka bay
# Target==  dinhi man gayod mi mabuhi' bay
# 	Ans =>  peri  man gayod  nimo  buhi' tay
# Target==  ? wala' diay giapas ni alex
# 	Ans =>   wata la haato siala
# Target==  wala' ing tarong og iskuwila sigi lang og climb-climb na
# 	Ans =>  wala' ngraykuwila  kao og kirasra na
# Target==  usa lay nagdungan nimo dong
# 	Ans =>  usa la nagdunga n koduong
# Target==  naako' wala' oy luuya oy
# 	Ans =>  na ako' wala'ldoyluyo oy
# Target==  hapit na alas-dusi padulong siya duty ron
# 	Ans =>  hapisaw layi  osi to-usy  mo tigod
# Target==  uniya' mama nimo nakauli' na
# 	Ans =>  niya ma ko na kbiyi na
# Target==  mao na nga ukasiyon na man libri gayod
# 	Ans =>  mao na ng tikasiyo na man giybri gayo
# Target==  dili' pod tama' tama' lang
# 	Ans =>  dili' pota matama' l
# Target==  guwapo man pod na ingon ana' salo-salo tanan mga
# 	Ans =>  mapon kod na an na' sa lustal tana' ng mga
# Target==  naa diay ka ing exam karon sayo man lagi
# 	Ans =>  ??ya samkaron sayo nan lagi
# Target==  kana' nga dili' na siya magpalakas og kaon diay ti
# 	Ans =>  kana' nga dilidi'  maanaka taod gkaon day ti
# Target==  unsa man nga naa man kay klasi inig gawas nimo sa klasi
# 	Ans =>  sa mang naa ma kay klasiy inagawas so sa kasi
# 0 31.277387619 32.9107131958
# 10 6.80527973175 38.2859115601
# 20 19.3309497833 49.9261550903
# 30 -0.15380859375 42.6214408875
# 40 14.817407608 31.1303710938
# 50 3.51935505867 41.0707855225
# 60 1.48770177364 43.5730361938
# 70 4.52549219131 36.6589279175
# 80 53.3708267212 37.3585281372
# 90 23.6557979584 47.7323532104
#
# ===============================
# epoch 28 : pseudo= 4.6972702154, cost= 39.7774171932, previous_cost= 74.0383559196, train_time = 1136.42694402 s
# 4
# 			 val_= 0.456169186588, test_time  = 1.2002530098 s
# ===============================
#
# Target==  sila vannie okay man na kay mga taba' man
# 	Ans =>  silaban okay man natang mga taba'
# Target==  pangit man na ang rain or shine hinay kaayo na oy
# 	Ans =>  pang ynayaninay kay naoy
# Target==  mura lagi og dili' ikaw ?
# 	Ans =>  walagi dili' kaw u
# Target==  no nagkauyab man diay mo ato' niya no
# 	Ans =>  no nakauya ga diay imu apo uniya no
# Target==  o karon na anhi lang diri
# 	Ans =>  o kaon nai anilagi diri
# Target==  taod-taod taod-taod na sad
# 	Ans =>  kadta ko' g aokaygaya
# Target==  ay sigi man musulti man siya sa akua piro wala' ko' kita' sa lalaki giingnan nako' ayaw sa paadtua og balay
# 	Ans =>  angsigi gousongosay akua pio ko na sala pina na po ing ka ptaumaay
# Target==  cook nako' dinha' mag-cook puwidi mag-cook nako' dinha'
# 	Ans =>  tut na pod dinha' mako' puwidi m pnagpot na pood dinha'
# Target==  o kato lang siya one three
# 	Ans =>  o kato lang siya rthre
# Target==  ting-break time ? ? ting-break time
# 	Ans =>  tiport n desin
# Target==  mao lagi siguro sa kuan putol-putol
# 	Ans =>  mao lagi siguro sa a kuan puto potor
# Target==  uniya' kumusta man imo nga pa check-up balik nay
# 	Ans =>  ?uniya' kusa na man imo nga katinakuai nay
# Target==  useless lang gihapon imo nga sigi ka og pangutana sa akua
# 	Ans =>  bupri lang giapon no nga sigi topanguta nagku
# Target==  wal- wal- wala' diay bugas
# 	Ans =>  wala' wala' wala' diay bga
# Target==  ? kana' nga mga uso karon
# 	Ans =>  ? kiana nga mga sokaron
# Target==  oh wala' ing signal amo' nga bukid ?
# 	Ans =>  o ya ma sig na la moog mokid
# Target==  o para ?
# 	Ans =>  o para
# Target==  wala' pa wala' pa
# 	Ans =>  mad a pala pra
# Target==  si neneng og si sweetie ra man to
# 	Ans =>  siminina cetrte ra manto
# Target==  dako' na na nga panalangin sa ginuo
# 	Ans =>  ako' tanang panala misgino
# Target==  ? age does not matter bitaw na ati
# 	Ans =>  ? gisdre mat di nati
# Target==  maayo og madayon maayo og dili'
# 	Ans =>  a mayo ba dayo mayo di'
# Target==  namaligiya' man si caloy diri oh halos kami tanan namalit
# 	Ans =>  maligiyha a saloy diri ? aopanustana na malot
# Target==  dondie naunsa diay si dondie diay
# 	Ans =>  mdasa i und diay
# Target==  prak- ? prak- ha
# 	Ans =>  t ?ao ha
# Target==  maayo unta' og kumplito to nga ?
# 	Ans =>  nala an patunprpato nga ang
# Target==  layas ? layas ni nga bataa ni bisan
# 	Ans =>  naaiyas kayo  hauta ni
# Target==  mao ana' man gayod kana' dili' na man gayod kana' ma-control tir
# 	Ans =>  maoo?ana' man gayod kna dilili' na man gaiod knapaama a sa er
# Target==  na-addict na kaayo si doogie ba o
# 	Ans =>  naa dika tiba o
# Target==  basi og imo nga suwirti naa sa lain wala' dinha'
# 	Ans =>  bagigigo nga surir s nasanaigura diya'
# Target==  duol pa gayod ka sa mga bata' nimo imo nga mga anak
# 	Ans =>  duol pa gayod ka pa mmga bata' himo mo  ana
# Target==  o bag-o ato' dili' ka ? tsoy ato'
# 	Ans =>  o mgguto ilikaong _ono ia
# Target==  thursday ba huwibis
# 	Ans =>  aisdu ba o ds
# Target==  pagkadako' sa pabo oy mura man og kabaw
# 	Ans =>  agtadako' kayo sapahabuon da mgagtabag
# Target==  wala' pa ing valid i_d si papa
# 	Ans =>  bay bal taidi  papa
# Target==  last year pabuto man kadto last year
# 	Ans =>  na gutoga kukad
# Target==  hala no luuya gayod niya gayod
# 	Ans =>  alnonawuya poyod niyaa bd
# Target==  ? unsa iya nga course kurso
# 	Ans =>  ? i iya nga colwuraso
# Target==  ? magbaktas ? duol ra man pod
# 	Ans =>  mag bahitakburo man m
# Target==  ha ?
# 	Ans =>   n nnn
# 0 28.424665451 40.546546936
# 10 -2.99319148064 39.8430976868
# 20 4.96710014343 47.9288635254
# 30 27.7829589844 81.7080535889
# 40 28.8868465424 inf
# 50 1.50512623787 40.9629631042
# 60 -4.33963727951 40.2050514221
# 70 -0.788709282875 33.6890068054
# 80 1.8010559082 36.6884002686
# 90 4.08786773682 40.4326133728
#
# ===============================
# epoch 29 : pseudo= 30.5407781764, cost= inf, previous_cost= 39.7774171932, train_time = 1138.14046001 s
# 4
# 			 val_= 0.44801815671, test_time  = 1.33173704147 s
# ===============================
#
# Target==  bumble bee ? sa ato' pa ? gayod diay ka
# 	Ans =>  maudili' pa ka to padatchel k diay ka
# Target==  nindot na kadto imo nga kuan sa una
# 	Ans =>  nindoto to imo nga kuan sa muuna
# Target==  piro kad- kadali' ra man to nga si ati mildred
# 	Ans =>  piopa kadali' la n  papana red
# Target==  ? gahapon nakakuwarta kagahapon
# 	Ans =>  a gahapon na kgakuwarsa ma gahapon
# Target==  ? wala' ra ba kay budget
# 	Ans =>   wo mba tay bar gayod
# Target==  ang tulo kakuan traha
# 	Ans =>  gtuloka kuan laha
# Target==  nagtrabaho davao light
# 	Ans =>  nagrabao dabalai
# Target==  mao lagi ba unsa nga urasa muabot diay
# 	Ans =>  mao lan nabaunsa nga ra sa muabot diaya
# Target==  ? ako' pod mupalit pod ko' og gatas sa ako' nga anak diri
# 	Ans =>  na ato pod kay mugpali ko' g kogdata sa ako anak diri
# Target==  unsa man ila nga gidula' ?
# 	Ans =>  unsa magina'ng ginuna
# Target==  kuyawa gayod pila ang ?
# 	Ans =>  puyawa gayo pily og kana
# Target==  ipalihog ko' ingon nga
# 	Ans =>  i palino g ko' ingo nga
# Target==  ? sigi siya suroy-suroy
# 	Ans =>  sgin si urisaroy
# Target==  kuyawa no paspasa pod nila manganak no ?
# 	Ans =>  huyawan no paspas- pod nina ganat no?
# Target==  ? ? unsa man nawala' man nadawat
# 	Ans =>    ila ma la wala' mannagawat
# Target==  ? uniya'
# 	Ans =>  ?  uniya'
# Target==  piro wala' na ka miadto
# 	Ans =>  piro gala' naka niya' puskuwinahan
# Target==  bala kaayo ka maunahan gani' ka gani'
# 	Ans =>  hala' kay tamhunan i sya gani'
# Target==  ? mao gayod na
# 	Ans =>  lam gayodd na
# Target==  kay daghan man gayod kaayo sila mama gayod dira'
# 	Ans =>  dilidaghalang gayod kayo sila maman gayod dinya'
# Target==  arkilaha ?
# 	Ans =>  asilaan kaa o si
# Target==  o asa man siya nag-iskuwila karon
# 	Ans =>  an siyansila taa
# Target==  uniya' wala'-wala' wala' mo ing video ato' nga
# 	Ans =>  uniya' wa' wala' pa?nwala' man wala' man giyo didio adto
# Target==  kuyog piro ? hapon na lagi kaayo maayo man to nga nakuha kadto ganiha kay
# 	Ans =>  uyod dirla apona  na ilomaa n sa nnga ku gaa kay
# Target==  ? nangita' ta og kana' nga maayo unsa ing unsa og grasiya uniya' sa ginuo ba
# 	Ans =>   ingkatan kara ng mgayo ng onsya lsaya n a gaasiya nia sa oginura
# Target==  ? usa na man lang ? mao diay wala' na lang
# 	Ans =>  musta na man lang amadiay ng ula' na' ngan
# Target==  blue uniya' blue ra pod ako' nga
# 	Ans =>  dluuniya' loapod dangakoha ng a
# Target==  o trisi
# 	Ans =>  o turisi
# Target==  mapundasiyunan ang kuan
# 	Ans =>  magpuntasi laana ngkuan
# Target==  magsakit-sakit biya' ni sarah og si janmar
# 	Ans =>  unsa kikakit diay ni' ng isa ra o sidianma
# Target==  o ngano diay muuban ka
# 	Ans =>  o manga diay mobanka
# Target==  ? ka didto sigi ra og tindog
# 	Ans =>  h bai to giy ngtndog
# Target==  ay usahay lang dili' man pod siya ingon nga dalo' piro
# 	Ans =>  ay salang wa' po sa ingaon dalo piro
# Target==  uniya' kanus-a man to muuli' imo nga bana
# 	Ans =>  uniya' kanusa makomo nimo nga ana
# Target==  ? si luke ? wala' na man siya ing ? wala' na man
# 	Ans =>  ? dinsa nanggitaning si no kayo lan k mmg-una na siyg
# Target==  ikaw kumusta na man mo sa imo nga uyab
# 	Ans =>  ungkawramusi na man ma simo na uniya
# Target==  sa una mao man unta' to ang plano namo' sa una
# 	Ans =>  sa una mao man kadto nga plana a musa una
# Target==  ? sunod ini og magkita' ta ?
# 	Ans =>  ion d ni gdi magkita' ta
# Target==  og wala' nawala' ? abi nako' og wala' pa
# 	Ans =>  pila og awa' naa wla' abinako gwa pa
# Target==  o tabang ? kadto nga ? sa bohol ba
# 	Ans =>  o taba ngind kato' nga mindo  sabl ba
# 0 5.41178655624 37.2789535522
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-de344a277b60> in <module>()
# ----> 1 get_ipython().magic(u'time model4L_Noise_momemtumClip_bottleneckfea.fit( x_train, y_train, x_valid, y_valid, x_train_mask, y_train_mask , x_valid_mask, y_valid_mask )')
#
# /home/pika/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2302         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2303         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2304         return self.run_line_magic(magic_name, magic_arg_s)
#    2305
#    2306     #-------------------------------------------------------------------------
#
# /home/pika/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2223                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2224             with self.builtin_trap:
# -> 2225                 result = fn(*args,**kwargs)
#    2226             return result
#    2227
#
# /home/pika/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#
# /home/pika/anaconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /home/pika/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1160         if mode=='eval':
#    1161             st = clock2()
# -> 1162             out = eval(code, glob, local_ns)
#    1163             end = clock2()
#    1164         else:
#
# <timed eval> in <module>()
#
# <ipython-input-11-a6301260d91d> in fit(self, x_train, y_train, x_test, y_test, x_mask, y_mask, x_test_mask, y_test_mask)
#     157             for index in range(len(x_train)):
#     158                 pseudo, cost, output_softmax = self.train( x_train[index] , y_train[index],
# --> 159                                                           x_mask[index], y_mask[index])
#     160                 cs += cost
#     161                 pseudo_cs += pseudo
#
# /home/pika/anaconda/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     595         t0_fn = time.time()
#     596         try:
# --> 597             outputs = self.fn()
#     598         except Exception:
#     599             if hasattr(self.fn, 'position_of_error'):
#
# /home/pika/anaconda/lib/python2.7/site-packages/theano/scan_module/scan_op.pyc in rval(p, i, o, n, allow_gc)
#     670         def rval(p=p, i=node_input_storage, o=node_output_storage, n=node,
#     671                  allow_gc=allow_gc):
# --> 672             r = p(n, [x[0] for x in i], o)
#     673             for o in node.outputs:
#     674                 compute_map[o][0] = True
#
# /home/pika/anaconda/lib/python2.7/site-packages/theano/scan_module/scan_op.pyc in <lambda>(node, args, outs)
#     659                         args,
#     660                         outs,
# --> 661                         self, node)
#     662         except (ImportError, theano.gof.cmodule.MissingGXX):
#     663             p = self.execute
#
# scan_perform.pyx in theano.scan_module.scan_perform.perform (/home/pika/.theano/compiledir_Linux-3.13--generic-x86_64-with-debian-jessie-sid-x86_64-2.7.9-64/scan_perform/mod.cpp:3537)()
#
# /home/pika/anaconda/lib/python2.7/site-packages/theano/gof/op.pyc in rval(p, i, o, n)
#     765         if ctx is graph.NoContext:
#     766             # default arguments are stored in the closure of `rval`
# --> 767             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
#     768                 r = p(n, [x[0] for x in i], o)
#     769                 for o in node.outputs:
#
# KeyboardInterrupt:

# %%
＃ Not used below

# %% [markdown]
# # Only Process once

# %%
''' 
[ Doing : ]
    - Read character from *.txt to build the corpus 

[ Result : ]

-- Without Develope Data:

Building corpus without develope data:
set([' ', "'", '-', '?', '_', 'a', 'c', 'b', 'e', 'd', 'g', 'f', 'i', 'h', 'k', 'j', 'm', 'l', 'o', 'n', 'q', 'p', 's', 'r', 'u', 't', 'w', 'v', 'y', 'x', 'z'])
Total len is : 31
Done Write to [./dataCebuano/corpus.txt]

-- With Develope Data:

Building corpus with develope data:
set([' ', "'", ')', '(', '-', '?', '_', 'a', 'c', 'b', 'e', 'd', 'g', 'f', 'i', 'h', 'k', 'j', 'm', 'l', 'o', 'n', 'q', 'p', 's', 'r', 'u', 't', 'w', 'v', 'y', 'x', 'z'])
Total len is : 33
Done Write to [./dataCebuano/corpus.txt]
'''

TRAINING_LABEL = "./dataCebuano/train.txt"
DEVELOPE_LABEL = "./dataCebuano/dev.txt"
WRITING_TO = "./dataCebuano/corpus.txt"

# Special part to build corpus
def buildCharacterCorpus(withDevelopeData = False) :
    corpus = set( )
    with open(TRAINING_LABEL, 'r') as ft:
        for lines in ft:
            for word in lines.split('\n')[0].split(' ')[1:]:
                if word[0] == '<':
                    # We take every <...> as <unk> 
                    unKnownTag = '?'
                    corpus.add( unKnownTag ) 
                else:
                    for char in word:
                        corpus.add(char.lower())
    
    if( withDevelopeData ) :
        with open(DEVELOPE_LABEL, 'r') as fd:
            for lines in fd:
                for word in lines.split('\n')[0].split(' ')[1:]:
                    if word[0] == '<':
                        unKnownTag = '?'
                        corpus.add( unKnownTag ) 
                        # corpus.add(word.split('\n')[0].lower())
                    else:
                        for char in word:
                            corpus.add(char.lower())
    
    corpus.add(' ')
    print "Building corpus with" + ("" if withDevelopeData else "out") + " develope data:"
    print corpus
    print "Total len is : " + str(len(corpus))
    
    
    with open(WRITING_TO, 'w+') as fw:
        for item in corpus:
            fw.write(item + '\n')        
    print "Done Write to [" + WRITING_TO + "]"
    return corpus

trainingCorpus = buildCharacterCorpus()
# Out:
# Building corpus without develope data:
# set([' ', "'", '-', '?', '_', 'a', 'c', 'b', 'e', 'd', 'g', 'f', 'i', 'h', 'k', 'j', 'm', 'l', 'o', 'n', 'q', 'p', 's', 'r', 'u', 't', 'w', 'v', 'y', 'x', 'z'])
# Total len is : 31
# Done Write to [./dataCebuano/corpus.txt]

# %%
# import theano
# from theano import tensor as T
# from theano.sandbox.rng_mrg import MRG_RandomStreams as RandomStreams
import numpy as np

from sklearn import cross_validation as cv
from sklearn import metrics
from sklearn import grid_search as gs
from sklearn.metrics import accuracy_score
from itertools import repeat

#proprocessor
from sklearn import preprocessing
from time import time

from itertools import repeat
import numpy as np
import random
from sklearn import preprocessing


def floatX(X):
    return np.asarray(X, dtype=theano.config.floatX)

def vectorized_result ( j , siz) :
    e = np.zeros((siz, 1))
    e[j] = 1.0
    return np.reshape( e, siz)

TRAINING_DATA   = './dataCebuano/tlkagk/train.dnn.fea'
# VALIDATION_DATA = './dataCebuano/dev.f0_ffv_fbank.fea'
TRAIN_ARK  = './dataCebuano/tlkagk/train.dnn.fea.lessThen500.ark'
# TRAIN_ARK  = './dataCebuano/train_Normalized_SELFVALID_LenLessThen600.ark'


def normalizeAndFilterData ( maxLength = 3000) :
    # Dataset
    x_data = []
    x_name = []
    record_seq = []

    with open( TRAINING_DATA, 'r') as f:
        for lines in f: 
            if '[' in lines :
                id = lines.split(' ')[0]
                x_name.append(id)
                seq = 0
            elif ']' in lines :
                if seq > maxLength :
                    x_name.pop()
                    del x_data[-seq:]
                else :
                    seq += 1
                    record_seq.append(seq)
                    x_data.append([float(x) for x in lines.split(' ') [2:-1] ])
            else :
                seq += 1
                x_data.append([float(x) for x in lines.split(' ') [2:-1] ])

    print "Normalized"
    x_data = preprocessing.scale( np.array(x_data) )

    # x_data[separate+1]
    # x_name
    bitch = record_seq.index(max(record_seq))
    print "Max len is ", record_seq[bitch]
    
    print "Each Length is ", len(x_data[bitch])
    print "Original Total training data", len(x_name)

    # trainF = open(TRAIN_ARK, 'w+')
    with open(TRAIN_ARK, 'w+') as trainF:
        currentSeq = 0
        for nameIndex in range( len(x_name) ):

            trainF.write(str(x_name[nameIndex])+"  [\n")

            for valueIndex in range( (record_seq[nameIndex]) ):
                for featureIndex in range( len(x_data[0]) ):
                    if ( featureIndex+1) != len(x_data[0] ) :
                        trainF.write( str(x_data[ currentSeq  + valueIndex][featureIndex]) + " ")
                    else:
                        trainF.write( str(x_data[ currentSeq  + valueIndex][featureIndex]) )
                if valueIndex+1 == (record_seq[nameIndex]):
                    trainF.write(" ]\n")
                else:
                    trainF.write("\n")
            currentSeq += record_seq[nameIndex]

    print "MIssion ComplEte"


normalizeAndFilterData(500)
# ORIGINAL 3918
# Out:
# Normalized
# Max len is  501
# Each Length is  90
# Original Total training data 3918
# MIssion ComplEte

# %%
# Out:
# array([[ 0.01      ,  0.002     ],
#        [ 1.20000005,  1.10000002]], dtype=float32)
