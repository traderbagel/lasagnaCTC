# %% [markdown]
# # CTC version 1
#
#
#
#
# ### Paper Reference
# - [Connectionist Temporal Classification (IDSIA)](ftp://ftp.idsia.ch/pub/juergen/icml2006.pdf)
#
#
# ### English Test
# First we test English

# %%
# Include And 
import sys
sys.path.append("/home/pika/nntools/")

import theano
import theano.tensor as T
import numpy as np
from theano_toolkit import utils as U
from theano_toolkit import updates
from theano.printing import Print
from theano_toolkit.parameters import Parameters

import lasagne
from lasagne.layers import *

from time import time

import ctc_cost_2

import cPickle
import sys
sys.setrecursionlimit(100000)

from random import shuffle
# Out:
# Using gpu device 0: GeForce GTX 980
# /home/pika/nntools/lasagne/init.py:86: UserWarning: The uniform initializer no longer uses Glorot et al.'s approach to determine the bounds, but defaults to the range (-0.01, 0.01) instead. Please use the new GlorotUniform initializer to get the old behavior. GlorotUniform is now the default for all layers.
#   warnings.warn("The uniform initializer no longer uses Glorot et al.'s "

# %% [markdown]
# # Data

# %%
'''
Doing : 
    - Read data and return x_train, y_train
'''
# TRAINING_ACOUSTIC_FEATURE = "./dataCebuano/train.f0_ffv_fbank.fea"
# TRAINING_ACOUSTIC_FEATURE = "./dataCebuano/train_Normalized_SELFVALID.ark"
TRAINING_ACOUSTIC_FEATURE = "./dataCebuano/train_Normalized_SELFVALID_LenLessThen500.ark"

TRAINING_LABELS = "./dataCebuano/train.txt"
CHAR_CORPUS = "./dataCebuano/corpus.txt"


def readDataSet () :
    
    # -- Mapping char to integer and reverse
    char_map = {}    # eg. { a -> 1 }
    char_unMap = {}  # eg. { 1 -> a }
    with open( CHAR_CORPUS, 'r' ) as f:
        char_index = 0
        for lines in f:
            char_map  [ lines[:-1] ] = char_index
            char_unMap[ char_index ] = lines[:-1]
            char_index += 1
        # add Blank, take '.' as blank (not space)
        char_map['.'] = char_index
        char_unMap[char_index] = '.'
    
    
    # -- Reading X = id -> [ list of feature ] 
    idMapX = {}
    idDeck = []
    id = ''
    
    tmp_l = 0;
    with open( TRAINING_ACOUSTIC_FEATURE, 'r') as f:
        for lines in f: 
            if '[' in lines :
                id = lines.split(' ')[0]
                idDeck.append(id)
                idMapX[id] = []
            elif ']' in lines :
                if( len( lines.split('\n')[0].split(' ') [0:-1] ) != 33 ) :
                    print "err"
                    return 
                idMapX[id].append([float(x) for x in lines.split('\n')[0].split(' ') [:-1] ])
            else :
                if( len( lines.split('\n')[0].split(' ')) != 33 ):
                    print len( lines.split('\n')[0].split(' '))
                    print lines.split('\n')[0].split(' ')
                    print lines
                    print id
                    print "fuck"
                    return
                idMapX[id].append([float(x) for x in lines.split('\n')[0].split(' ') ])
    
    # Move to  3 - main - 3
    
    monoDimension = 33;
    zeroFeature = [0] * monoDimension
    #print len( zeroFeature ) 
    #print zeroFeature
    for id in idDeck:
        # print id
        tmpIdMapXWithID = []
        if len(idMapX[id]) < 6 :
            print "ERROR in length"
            return 
        for idxX in xrange( len(idMapX[id]) ):
            if idxX == 0:
                tmpIdMapXWithID.append( zeroFeature + zeroFeature + zeroFeature + idMapX[id][idxX] + idMapX[id][idxX+1] + idMapX[id][idxX+2] + idMapX[id][idxX+3] )    
            elif idxX == 1:
                tmpIdMapXWithID.append( zeroFeature + zeroFeature + idMapX[id][idxX-1] + idMapX[id][idxX] + idMapX[id][idxX+1] + idMapX[id][idxX+2] + idMapX[id][idxX+3] )  
            elif idxX == 2:
                tmpIdMapXWithID.append( zeroFeature + idMapX[id][idxX-2] + idMapX[id][idxX-1] + idMapX[id][idxX] + idMapX[id][idxX+1] + idMapX[id][idxX+2] + idMapX[id][idxX+3] )  
            elif idxX == (len(idMapX[id]) - 3 ):
                tmpIdMapXWithID.append( idMapX[id][idxX-3] + idMapX[id][idxX-2] + idMapX[id][idxX-1] + idMapX[id][idxX] + idMapX[id][idxX+1] + idMapX[id][idxX+2] + zeroFeature )  
            elif idxX == (len(idMapX[id]) - 2 ):
                tmpIdMapXWithID.append( idMapX[id][idxX-3] + idMapX[id][idxX-2] + idMapX[id][idxX-1] + idMapX[id][idxX] + idMapX[id][idxX+1] + zeroFeature + zeroFeature )  
            elif idxX == (len(idMapX[id]) - 1 ):
                tmpIdMapXWithID.append( idMapX[id][idxX-3] + idMapX[id][idxX-2] + idMapX[id][idxX-1] + idMapX[id][idxX] + zeroFeature + zeroFeature + zeroFeature )  
            else:
                tmpIdMapXWithID.append( idMapX[id][idxX-3] + idMapX[id][idxX-2] + idMapX[id][idxX-1] + idMapX[id][idxX] + idMapX[id][idxX+1] + idMapX[id][idxX+2] + idMapX[id][idxX+3] )  
        idMapX[id] = tmpIdMapXWithID
    
    print "Concate"
    
    # Standardlize X (Done in PrepreProcessing )
   
    # Shuffle the speaker to slice training and validation
    totalSpeech = len(idMapX)
    slicePointFive = totalSpeech // 20
    shuffle(idDeck)
    id_train = idDeck[slicePointFive+1:]
    id_valid = idDeck[:slicePointFive]
    
    idMapY = {} 
    
    # -- Reading Y = id -> [ Sentence(list of char[int] ) ]
    with open( TRAINING_LABELS, 'r') as f:
        specific = '?'
        for lines in f:
            yWithId = lines.split('\n')[0].split(' ', 1)
            idMapY[ yWithId[0] ] = []
            judgeSpecific = False
            for char in yWithId[1] :
                if char == '<' :
                    judgeSpecific = True;                
                if( judgeSpecific ):
                    if char == '>':
                        idMapY[ yWithId[0] ].append( char_map[specific] )
                        judgeSpecific = False
                else :
                    idMapY[ yWithId[0] ].append( char_map[char] )
    
    # -- concatenate X and Y
    x_train = []
    x_valid = []
    y_train = []
    y_valid = []
    
    for id in id_train:
        concateId = []
        for i in range( len( idMapX[id] ) ) :
            concateId.append( idMapX[id][i] )
        x_train.append( floatX( concateId )  )
        y_train.append( floatX( idMapY[id]) )
        
    for id in id_valid:
        concateId = []
        for i in range( len( idMapX[id] ) ) :
            concateId.append( idMapX[id][i] )
        x_valid.append( floatX( concateId ) )
        y_valid.append( floatX( idMapY[id]) )
        
    print "Dataset Finish : "
    print "total x_train = " + str(len(x_train))
    print x_train[0]
    print "total y_train = " + str(len(y_train))
    print y_train[0]
    print "total x_valid = " + str(len(x_valid))
    print x_valid[0]
    print "total y_valid = " + str(len(y_valid))
    print y_valid[0]
    
    return char_map, char_unMap, x_train, y_train, x_valid, y_valid

def floatX(x):
    return np.asarray(x, dtype=theano.config.floatX)


char_map, char_unMap, x_train, y_train, x_valid, y_valid = readDataSet()
# Out:
# Concate
# Dataset Finish :
# total x_train = 3722
# [[ 0.          0.          0.         ...,  0.7333411   1.11533034
#   -0.71583152]
#  [ 0.          0.          0.         ..., -0.78239328  0.04649827
#   -0.97195017]
#  [ 0.          0.          0.         ...,  1.09216201  1.3399446
#   -1.1914742 ]
#  ...,
#  [ 0.22230056  0.27325568 -0.030542   ...,  0.          0.          0.        ]
#  [ 0.12296346 -0.0282144  -0.20728323 ...,  0.          0.          0.        ]
#  [ 0.54621345  0.38485798  0.35828772 ...,  0.          0.          0.        ]]
# total y_train = 3722
# [ 16.   5.  22.   0.  16.   5.   5.  28.  18.   0.  19.   5.   0.  19.  10.
#    5.   0.  19.   5.   5.   0.  12.  19.  10.   0.   5.   9.  17.   5.  26.
#    0.  14.   5.  28.  12.  22.   5.]
# total x_valid = 195
# [[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   5.06372750e-01
#     6.06346667e-01  -7.82309353e-01]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,  -4.87222642e-01
#    -1.69904798e-01   2.80898559e-04]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,  -1.37560517e-01
#     4.92138594e-01   1.01360822e+00]
#  ...,
#  [  5.27318101e-04   6.63717151e-01   4.93163854e-01 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [ -2.78016418e-01   5.88251710e-01   3.58893156e-01 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [ -5.16767800e-01   3.76005948e-01   1.12593554e-01 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]]
# total y_valid = 195
# [ 22.  12.  17.   5.   0.  27.   5.  19.  19.  12.   8.   0.  18.  14.   5.
#   28.   0.  16.   5.  19.   0.  19.   5.   0.  14.   5.  28.   0.  16.  10.
#    5.   0.  25.   5.   7.   5.   1.   0.  16.   5.  19.]

# %%
# 500 -> 3722 / 195
# 600 -> 3821 / 201
# 3000 -> 3937 / 207
x_train[0].shape
# Out:
# (195, 231)

# %%
max( [X.shape[0] for X in x_train] )
# Out:
# 501

# %%
'''
    https://github.com/craffel/lstm_benchmarks/blob/master/lasagne/experiment.py
    
    Convert a list of matrices into batches of uniform length
    :parameters:
        - X : list of np.ndarray
            List of matrices
        - length : int
            Desired sequence length.  Smaller sequences will be padded with 0s,
            longer will be truncated.
        - batch_size : int
            Mini-batch size
    :returns:
        - X_batch : np.ndarray
            Tensor of time series matrix batches,
            shape=(n_batches, length, batch_size, n_features)
        - X_mask : np.ndarray
            shape=(n_batches, length, batch_size)
            Mask denoting whether to include each time step of each time series
            matrix
    '''
    
def make_batches_X(X, length, batch_size=30):
    n_batches = len(X)//batch_size
    X_batch = np.zeros( (n_batches, batch_size, length, X[0].shape[1]),
                         dtype=theano.config.floatX)
    X_mask  = np.zeros( (n_batches, length, batch_size ), 
                         dtype=theano.config.floatX)
    
    for b in range(n_batches): 
        for n in range(batch_size): # go thorough batch size       
            X_m = X[b*batch_size + n] # seq_length X feature dim            
            X_batch[b, n, :X_m.shape[0]] = X_m[:length]
            X_mask[b, :X_m.shape[0], n] = 1
            
    return X_batch, X_mask

def make_batches_Y( X, length, batch_size=30):
    n_batches = len(X)//batch_size
    
    X_batch = np.zeros( (n_batches, length, batch_size ), dtype='float32')
    
    X_mask = np.zeros(X_batch.shape, dtype=theano.config.floatX)
    
    for b in range(n_batches):
        for n in range(batch_size):
            X_m = X[ b*batch_size + n ]
            X_batch[b, :X_m.shape[0], n ] = X_m[:length]
            X_mask[b, :X_m.shape[0], n] = 1
    return X_batch, X_mask

# %%
batch_size = 40

# Find the longest sequence
length_x = max( max( [X.shape[0] for X in x_train] ),
                max( [X.shape[0] for X in x_valid] ))

length_y = max( max( [X.shape[0] for X in y_train] ),
                max( [X.shape[0] for X in y_valid] ))

# Convert to batches of time series of uniform length
# x_train_mask: seq_length X batch_size
# y_train_mask: output_length X batch_size
# y_pred_mask = x_train_mask, since pred by sequence
x_train, x_train_mask = make_batches_X(x_train, length_x, batch_size)
y_train, y_train_mask = make_batches_Y(y_train, length_y, batch_size)
x_valid, x_valid_mask = make_batches_X(x_valid, length_x, batch_size)
y_valid, y_valid_mask = make_batches_Y(y_valid, length_y, batch_size)

# %%
print x_train.shape
print y_train.shape
print x_valid.shape
print y_valid.shape
print "================mask================"
print x_train_mask.shape
print y_train_mask.shape

# print x_train_mask[0][400][0]
# Out:
# (93, 40, 501, 231)
# (93, 132, 40)
# (4, 40, 501, 231)
# (4, 132, 40)
# ================mask================
# (93, 501, 40)
# (93, 132, 40)

# %% [markdown]
# # Model Part

# %%
'''
credit by NLTK package of measure edit distance
'''

def _edit_dist_init(len1, len2):
    lev = []
    for i in range(len1):
        lev.append([0] * len2)  # initialize 2D array to zero
    for i in range(len1):
        lev[i][0] = i           # column 0: 0,1,2,3,4,...
    for j in range(len2):
        lev[0][j] = j           # row 0: 0,1,2,3,4,...
    return lev


def _edit_dist_step(lev, i, j, s1, s2, transpositions=False):
    c1 = s1[i - 1]
    c2 = s2[j - 1]

    # skipping a character in s1
    a = lev[i - 1][j] + 1
    # skipping a character in s2
    b = lev[i][j - 1] + 1
    # substitution
    c = lev[i - 1][j - 1] + (c1 != c2)

    # transposition
    d = c + 1  # never picked by default
    if transpositions and i > 1 and j > 1:
        if s1[i - 2] == c2 and s2[j - 2] == c1:
            d = lev[i - 2][j - 2] + 1

    # pick the cheapest
    lev[i][j] = min(a, b, c, d)


def check_label_error( real , predict, transpositions=False):
    ## length of real >= length of predict
    """
    Calculate the Levenshtein edit-distance between two strings.
    The edit distance is the number of characters that need to be
    substituted, inserted, or deleted, to transform s1 into s2.  For
    example, transforming "rain" to "shine" requires three steps,
    consisting of two substitutions and one insertion:
    "rain" -> "sain" -> "shin" -> "shine".  These operations could have
    been done in other orders, but at least three steps are needed.

    This also optionally allows transposition edits (e.g., "ab" -> "ba"),
    though this is disabled by default.

    :param s1, s2: The strings to be analysed
    :param transpositions: Whether to allow transposition edits
    :type s1: str
    :type s2: str
    :type transpositions: bool
    :rtype int
    """
    # set up a 2-D array
    len1 = len(predict)
    len2 = len(real)
    lev = _edit_dist_init(len1 + 1, len2 + 1)

    # iterate over the array
    for i in range(len1):
        for j in range(len2):
            _edit_dist_step(lev, i + 1, j + 1, predict, real, transpositions=transpositions)
            
    return lev[len1][len2]*1.0/len2


def clean_up( y ):
    """
    for final output clean up
    B(a − ab−) = B(−aa − −abb) = aab
    """
    answer = ""

    for i in range(len(y)):
        if y[i] == '.':
            continue
        else:
            if y[i-1] != y[i]:
                answer += y[i]
    
    return answer

def remap_back( y , actual):
    answer = ""
    
    for i in y:
        answer += char_unMap[i]
    
    if not actual:
        answer = clean_up(answer)
        
    return answer

def decode_all_actual( y, y_mask ,batch_size , actual=False):
    """
    y     : label_length X batch_size
    y_mask: label_length X batch_size
    """
    result = []
    for i in xrange(batch_size):
        mask = np.swapaxes( y_mask, 0, 1)[i]
        ans = np.swapaxes( y, 0 , 1)[i]
        result.append(remap_back( ans[np.nonzero(mask)] , actual ))
    return result


def decode_all_pred( y, y_mask ,batch_size , actual=False):
    """
    y     : label_length X batch_size
    y_mask: label_length X batch_size
    """
    result = []
    for i in xrange(batch_size):
        mask = np.swapaxes( y_mask, 0, 1)[i]
        ans = y[i]
        result.append(remap_back( ans[np.nonzero(mask)] , actual ))
    return result

def check_all( y, y_mask, y_pred, y_pred_mask, batch_size ):
    
    actual = decode_all_actual( y, y_mask, batch_size , True )
    predict = decode_all_pred( y_pred, y_pred_mask, batch_size , False )
    
    error = 0.
    for a,b in zip (actual, predict):
        error += check_label_error(a,b)
    
    return error/len(actual)

# %%
class end_to_end():  
    def __init__(self, input_shape, max_seq_length, hidden_layer,
                 batch, max_epochs, output_num_units,
                 patience, up_learning_rate, file_name):
        
        self.input_shape = input_shape # [batch, dim]
        
        self.hidden_layer = hidden_layer # hidden [l1, l2, l3]
        self.output_num_units = output_num_units # [ # of class ]
        
        self.batch = batch
        self.max_epochs = max_epochs
        
        self.up_learning_rate = up_learning_rate
                 
        self.patience = patience
        self.best_valid = np.inf
        self.best_valid_epoch = 0
        self.best_params = None
        
        self.train_history_ = []
        self.epochs = 0
        
        self.file_name = file_name
        
        self.max_seq_length = max_seq_length
        
        """
        input data type
        y_hat : T x B x C+1
        y : L x B
        y_hat_mask : T x B
        y_mask : L x B
        """
        
        print "Why model build so long ... "
        # T x B x F
        # B X T X F (Lasagne format)
        x = T.tensor3('X', dtype=theano.config.floatX)
        # L x B
        y = T.matrix ('y', dtype=theano.config.floatX)

        # L x B
        y_mask = T.matrix('y_mask', dtype=theano.config.floatX)
        # T x B
        y_hat_mask = T.matrix('y_hat_mask', dtype=theano.config.floatX)
    
        # Min/max sequence length
        MAX_LENGTH = max_seq_length
        
        # Number of training sequences in each batch
        N_BATCH = batch
        
        #===========================================================================================
        # dEEP lSTM
        #===========================================================================================
        print "Input : (N_BATCH) : " + str(N_BATCH) +", ML :" + str(MAX_LENGTH) + "ss :" + str(self.input_shape[1])
        
        # Recurrent layers expect input of shape
        # (batch size, max sequence length, number of features)
        l_in     = lasagne.layers.InputLayer( shape=( N_BATCH, MAX_LENGTH, self.input_shape[1] ) )
        l_in_gau = lasagne.layers.GaussianNoiseLayer( l_in, sigma=0.5 )
        
        # LSTM layer 1
        l_forward_1   = lasagne.layers.LSTMLayer(l_in_gau, num_units=hidden_layer[0], learn_init=True, peepholes=True)
        l_backward_1  = lasagne.layers.LSTMLayer(l_in_gau, num_units=hidden_layer[0], backwards=True, learn_init=True, peepholes=True)
        l_recurrent_1 = ElemwiseSumLayer( [l_forward_1, l_backward_1] )

        
        # LSTM layer 2
        l_forward_2   = lasagne.layers.LSTMLayer(l_recurrent_1, num_units=hidden_layer[1], learn_init=True, peepholes=True)
        l_backward_2  = lasagne.layers.LSTMLayer(l_recurrent_1, num_units=hidden_layer[1], backwards=True, learn_init=True, peepholes=True)
        l_recurrent_2 = ElemwiseSumLayer( [l_forward_2, l_backward_2] )
        
        # LSTM layer 3
        l_forward_3   = lasagne.layers.LSTMLayer(l_recurrent_2, num_units=hidden_layer[2], learn_init=True, peepholes=True)
        l_backward_3  = lasagne.layers.LSTMLayer(l_recurrent_2, num_units=hidden_layer[2], backwards=True, learn_init=True, peepholes=True)
        l_recurrent_3 = ElemwiseSumLayer( [l_forward_3, l_backward_3] )
        '''
        # LSTM layer 4
        l_forward_4   = lasagne.layers.LSTMLayer(l_recurrent_3, num_units=hidden_layer[3], learn_init=True, peepholes=True)
        l_backward_4  = lasagne.layers.LSTMLayer(l_recurrent_3, num_units=hidden_layer[3], backwards=True, learn_init=True, peepholes=True)
        l_recurrent_4 = ElemwiseSumLayer( [l_forward_4, l_backward_4] )
        '''
        
        #l_reshape = lasagne.layers.ReshapeLayer(l_recurrent_4, (N_BATCH*MAX_LENGTH, hidden_layer[3])  )
        l_reshape = lasagne.layers.ReshapeLayer(l_recurrent_3, (N_BATCH*MAX_LENGTH, hidden_layer[2])  )

        
        #===========================================================================================
        # COMMON SETUP
        #===========================================================================================
        
        # Our output layer is a simple dense connection
        l_recurrent_out      = lasagne.layers.DenseLayer( l_reshape           , num_units=output_num_units[0] , nonlinearity=lasagne.nonlinearities.identity)
        
        # Now, reshape the output back to the RNN format
        l_out_shp            = lasagne.layers.ReshapeLayer( l_recurrent_out, (N_BATCH, MAX_LENGTH, output_num_units[0]) )
        
        # dimshuffle to shape format (input_seq_len, batch_size, num_classes + 1)
        l_out_shp_ctc        = lasagne.layers.DimshuffleLayer( l_out_shp, (1, 0, 2))

        l_out_softmax        = lasagne.layers.NonlinearityLayer( l_recurrent_out, nonlinearity=lasagne.nonlinearities.softmax)
        l_out_softmax_shp    = lasagne.layers.ReshapeLayer( l_out_softmax, (N_BATCH, MAX_LENGTH, output_num_units[0] ))
        
        # since we use gaussian noise in input, False means use noise, True means dont use noise
        output_lin_ctc_train = lasagne.layers.get_output( l_out_shp_ctc, x, deterministic=False)
        output_softmax_train = lasagne.layers.get_output( l_out_softmax_shp, x, deterministic=False)
        
        output_lin_ctc_val   = lasagne.layers.get_output(l_out_shp_ctc, x, deterministic=True)
        output_softmax_val   = lasagne.layers.get_output(l_out_softmax_shp, x, deterministic=True)
        
        self.all_params      = lasagne.layers.get_all_params(l_out_shp)
    
        # the CTC cross entropy between y and linear output network
        pseudo_cost = ctc_cost_2.pseudo_cost(
            y, output_lin_ctc_train, y_mask, y_hat_mask,
            skip_softmax=True)
        
        
        pseudo_cost_grad = T.grad(pseudo_cost.mean(), self.all_params)
        true_cost        = ctc_cost_2.cost(y, output_softmax_train.dimshuffle(1, 0, 2), y_mask, y_hat_mask)
        cost             = T.mean(true_cost)
        
        pseudo_cost_scaled_grads = lasagne.updates.total_norm_constraint(pseudo_cost_grad, 5)
        updates_rms          = lasagne.updates.rmsprop(pseudo_cost_scaled_grads, self.all_params, learning_rate = self.up_learning_rate)
        updates = lasagne.updates.apply_momentum(updates_rms,  self.all_params, momentum=0.9)
        
        self.train = theano.function(
            inputs = [x, y, y_hat_mask, y_mask],
            outputs = [ pseudo_cost.mean(), cost, output_softmax_train ],
#             outputs = [output_lin_ctc, output_softmax, cost],
            updates=updates
        )
        
        self.predict = theano.function( 
            inputs=[x], 
            outputs = [ output_softmax_val] 
        )

        
    # x_mask and y_mask is the same
    # x_test_mask and y_test_mask is the same
    def fit(self, x_train, y_train, x_test,  y_test , x_mask, y_mask, x_test_mask, y_test_mask ):
        print " "
        print "start training!!!!"
        print " "
        sys.stdout.flush()
        
        for i in range(self.max_epochs):
            self.epochs +=1
            t0 = time()
            
            cs = 0.
            pseudo_cs = 0.
            for index in range(len(x_train)):
                pseudo, cost, output_softmax = self.train( x_train[index] , y_train[index],
                                                          x_mask[index], y_mask[index])
                cs += cost
                pseudo_cs += pseudo
                gg = index
                if index % 10 == 0:
                    print index, pseudo, cost
                sys.stdout.flush()
            
            cs /= len(x_train)
            pseudo_cs /= len(x_train)
            
#             cPickle.dump( self , open("./"+self.file_name+".pkl","wb"))
            if self.epochs <= 1:
                previous_cs = "-"
            else:
                previous_cs = self.train_history_[-1]['cost']
            print "\n==============================="
            print 'epoch {0} : pseudo= {1}, cost= {2}, previous_cost= {3}, train_time = {4} s'.format(self.epochs,
                                                                                                      pseudo_cs, 
                                                                                                      cs,
                                                                                                      previous_cs, 
                                                                                                      time() - t0)
            
            sys.stdout.flush()
            
            t0 = time()
            
#             print np.argmax(output_softmax[:],axis=2)
#             print decode_all( np.argmax(output_softmax[:],axis=2) , x_train_mask[gg],  batch_size , True)
            
            # save model first
            # dont know the LER performance yet
#             cPickle.dump( self , open("./"+self.file_name+".pkl","wb"))
    

            label_error_rate = 0.
            print len(x_test)
            for index in range( len(x_test) ) :

                prepre = self.predict( x_test[index])
                
                label_error_rate += check_all( y_test[index], y_test_mask[index],
                                              np.argmax(prepre[0],axis=2) , x_test_mask[index],
                                              batch_size)
                
                if (( index + self.epochs ) % 4 == 0 ):
                    ## print actual
                    y_actual = decode_all_actual( y_test[index], y_test_mask[index], batch_size , True)

                    ## print pred
                    y_predict = decode_all_pred( np.argmax(prepre[0],axis=2) , x_test_mask[index],  batch_size , False)
                
            label_error_rate /= len(x_test)
            self.train_history_.append({"epoch":self.epochs, "cost": cs, "LER":label_error_rate})
            
            print '\t\t\t val_= {0}, test_time  = {1} s'.format(label_error_rate, time() - t0)
            print "===============================\n"
            
            sys.stdout.flush()
            
            for a , b in zip (y_actual,y_predict):
                print "Target== ",a 
                print "\tAns => ",b
            
            sys.stdout.flush()
            
            """
            should use cost do early stopping
            """
            current_cs = self.train_history_[-1]['cost']
            current_epoch = self.train_history_[-1]['epoch']
            if current_cs < self.best_valid:
                self.best_valid = current_cs
                self.best_valid_epoch = current_epoch
                self.best_params = [w.get_value() for w in self.all_params]
                cPickle.dump( self , open("./"+self.file_name+".pkl","wb"))
                
            elif self.best_valid_epoch + self.patience <= current_epoch:
                print ""
                print "Early stopping."
                print self.best_valid_epoch,self.best_valid
                print "Best valid ler {:.6f} at epoch {}.".format(self.best_valid, self.best_valid_epoch)              
#                 for qq in range (len(self.all_params)):
#                     self.all_params[qq].set_value( self.best_params[qq] )
#                 break

            """
            can not use label error rate do early stopping
            """
#             current_ler = self.train_history_[-1]['LER']
#             current_epoch = self.train_history_[-1]['epoch']
#             if current_ler < self.best_valid:
# #                 print "********************* Now best ************************"
#                 sys.stdout.flush()
#                 self.best_valid = current_ler
#                 self.best_valid_epoch = current_epoch
#                 self.best_params = [w.get_value() for w in self.all_params]
# #                 cPickle.dump( self , open("./"+self.file_name+".pkl","wb"))
                
#             elif self.best_valid_epoch + self.patience <= current_epoch:
#                 print ""
#                 print "Early stopping."
#                 print self.best_valid_epoch,self.best_valid
#                 print "Best valid ler {:.6f} at epoch {}.".format(self.best_valid, self.best_valid_epoch)
#                 sys.stdout.flush()                
#                 for qq in range (len(self.all_params)):
#                     self.all_params[qq].set_value( self.best_params[qq] )
#                 break


#     def prediction(self, x, x_mask) :
        
#         abc =  self.predict(x, x_mask)
        
#         return np.argmax(abc[0], axis = 1 )

# %%
'''
ONE lAYER
'''

model3L_Noise_with313 = end_to_end (
    input_shape      = (1, x_train.shape[3] ) , # batch of 1, (110, 30, 777, 117)
    max_seq_length = x_train.shape[2],
    hidden_layer     = [ 250, 250, 250, 250 ], # maximum layer to LSTM 3 layer only
    batch            = batch_size, 
    max_epochs       = 300, 
    output_num_units = [ len(char_unMap) ],
    up_learning_rate = 0.00001, 
    patience         = 7,
    file_name = "model3L_Noise_momemtumClip_with313"
)
# Out:
# Why model build so long ...
# Input : (N_BATCH) : 40, ML :501ss :231

# %%
# %time model3L_Noise_with313.fit( x_train, y_train, x_valid, y_valid, x_train_mask, y_train_mask , x_valid_mask, y_valid_mask )
# Out:
#
# start training!!!!
#
# 0 144.218185425 637.893554688
# 10 24.8332042694 675.803894043
# 20 35.2622871399 722.030578613
# 30 26.6749458313 742.096862793
# 40 52.7339477539 758.049682617
# 50 86.7796859741 798.629272461
# 60 44.7486534119 729.799682617
# 70 213.707260132 689.829833984
# 80 159.546676636 684.306152344
# 90 47.1976089478 577.143798828
#
# ===============================
# epoch 1 : pseudo= 105.022706622, cost= 693.030417165, previous_cost= -, train_time = 1328.97746706 s
# 4
# 			 val_= 1.47764300749, test_time  = 2.0525970459 s
# ===============================
#
# Target==  bumble bee ? sa ato' pa ? gayod diay ka
# 	Ans =>  qhzmztjx-scuvcrqiueupx_bc'vivbu-eovmj'mubiugu'kxwaiviemevev-
# Target==  nindot na kadto imo nga kuan sa una
# 	Ans =>   vdg'vxv'mam?-cmcmehdmibo?bxymyvcxcvmicvgoxif
# Target==  piro kad- kadali' ra man to nga si ati mildred
# 	Ans =>  arar
# Target==  ? gahapon nakakuwarta kagahapon
# 	Ans =>  'aqeivxzmm?bimhlhl-akvs?-p?vcqvqoebusdyuh'zwgwc i'iy-_kuu'
# Target==  ? wala' ra ba kay budget
# 	Ans =>  jq'v euvuauzntnbmauqvu h ua-asamuibzua-w
# Target==  ang tulo kakuan traha
# 	Ans =>  jy'kyty'znhibj'y-'dwjnx'pfpf'vbid?cb?bhf
# Target==  nagtrabaho davao light
# 	Ans =>  j-a-mcicbcsceclcvkh-mizgf
# Target==  mao lagi ba unsa nga urasa muabot diay
# 	Ans =>  me vecazmtixsey auzuezvzcyq'uxpzmimurakaykfzllclzeimz
# Target==  ? ako' pod mupalit pod ko' og gatas sa ako' nga anak diri
# 	Ans =>  ?cbjvzub-jz?gq'bd_gk'fmvix -xjmyq'maeubdjzqvlbthqzpeyakei?gjffjk?ibf'vmi-idf'veaevzozoh
# Target==  unsa man ila nga gidula' ?
# 	Ans =>  zxgc
# Target==  kuyawa gayod pila ang ?
# 	Ans =>  vhimivhuememuhtzhra-z-'mvimyxmffemcmtiyqh
# Target==  ipalihog ko' ingon nga
# 	Ans =>  -c-cb-bfb muj-kyv'ehcgkvuhkhhk
# Target==  ? sigi siya suroy-suroy
# 	Ans =>  fvvsfgvo omzvicvie-qzpavzbi-pfopcpzs
# Target==  kuyawa no paspasa pod nila manganak no ?
# 	Ans =>  hcxmimeie?mcmekhkcscdomsveai mohmavhihgh-zvyvvusu-jvmlx'qmasysdsvb?luv?
# Target==  ? ? unsa man nawala' man nadawat
# 	Ans =>  -'usgfkqygefwanruzazulut'txkuvpcecol clhcses-auqhuhu-lkuahuz'a-uahsv
# Target==  ? uniya'
# 	Ans =>  '?lrcecncsy'y'k'ylaspsgsqgfsmkekekjk
# Target==  piro wala' na ka miadto
# 	Ans =>  kleiuqseu?u?-usus-uzxttlyhz?z-cmimimkyiutkuhpo
# Target==  bala kaayo ka maunahan gani' ka gani'
# 	Ans =>  yj'xalsu-zxfraclaplkckusncaochlkhloalaokuuk
# Target==  ? mao gayod na
# 	Ans =>  mvsfvmv'hfp-cozmcxojozozwqjq'
# Target==  kay daghan man gayod kaayo sila mama gayod dira'
# 	Ans =>  kbow_gvi-ie-ukacqvsmz zuzpzccxivi-hpepvhzlckmzbuigjh
# Target==  arkilaha ?
# 	Ans =>  ovo_cvmvz-z'-v-'fzioagqs-_
# Target==  o asa man siya nag-iskuwila karon
# 	Ans =>  ?jmemxome wsmlqlmumlmusuatzkfsk-fx'kk
# Target==  uniya' wala'-wala' wala' mo ing video ato' nga
# 	Ans =>  mvxvcxvxuvimvmcevoivuy-hamixmevmu vseusay'zazuk'zrkruaoeiclecs_wset-ahkylvzk
# Target==  kuyog piro ? hapon na lagi kaayo maayo man to nga nakuha kadto ganiha kay
# 	Ans =>  savi
# Target==  ? nangita' ta og kana' nga maayo unsa ing unsa og grasiya uniya' sa ginuo ba
# 	Ans =>  azaz
# Target==  ? usa na man lang ? mao diay wala' na lang
# 	Ans =>
# Target==  blue uniya' blue ra pod ako' nga
# 	Ans =>  qp?uruayzsarma-utuah'q'xa?xxkauqyqxarxaucm-zua?
# Target==  o trisi
# 	Ans =>  yiqlutzt'klrlc'nvbipj'fkurzgoz
# Target==  mapundasiyunan ang kuan
# 	Ans =>
# Target==  magsakit-sakit biya' ni sarah og si janmar
# 	Ans =>  -jfztllztcothk'v_myf'hxb?zkhclilmuqhakzmvmvimnw-?zuyxvlkihevlyc'
# Target==  o ngano diay muuban ka
# 	Ans =>  -'-aua'uocofpbmsaukaruauaurxzklklsaduo-sud-f
# Target==  ? ka didto sigi ra og tindog
# 	Ans =>  vlkuarau ka-hk -a bze-u zvzg-zaklk
# Target==  ay usahay lang dili' man pod siya ingon nga dalo' piro
# 	Ans =>  fwjpe ebkvyy'vsvcecvxbvcbcxczcaxcxczxcxkcdcecybcvy
# Target==  uniya' kanus-a man to muuli' imo nga bana
# 	Ans =>  kufzhzsqova - -a-aydcmbtcaycsecsckfyzkc zvmimyq
# Target==  ? si luke ? wala' na man siya ing ? wala' na man
# 	Ans =>  ov
# Target==  ikaw kumusta na man mo sa imo nga uyab
# 	Ans =>  g'voycvmve?lecie-vmv-?iu?b?mhzmzxw-pzeho?doa-
# Target==  sa una mao man unta' to ang plano namo' sa una
# 	Ans =>  fnau-sqluo-b-z -qscmbzozaf_jq'cgo-sfsmeadgsks?smagmvbwiamok'kf
# Target==  ? sunod ini og magkita' ta ?
# 	Ans =>  ax
# Target==  og wala' nawala' ? abi nako' og wala' pa
# 	Ans =>  kqhkbkuakahatkl'auzlk'xkxxxucxcxilutqa'kaklru'pybvlzlqlaqzhtalalt'shtkl
# Target==  o tabang ? kadto nga ? sa bohol ba
# 	Ans =>  q'lxlcukobluuhiu-u-bhczyh-iviuiuiu-rulumshrusuispyzuszoqqz
# 0 100.396995544 595.135437012
# 10 26.3987922668 631.819213867
# 20 86.7513046265 671.159545898
# 30 18.8591060638 675.698608398
# 40 55.0085868835 610.434692383
# 50 170.836273193 748.232055664
# 60 91.3958892822 647.31463623
# 70 2.22442936897 617.492797852
# 80 45.3580932617 703.336669922
# 90 58.0843772888 587.251220703
#
# ===============================
# epoch 2 : pseudo= 95.1937469488, cost= 649.424085391, previous_cost= 693.030417165, train_time = 1322.71154809 s
# 4
# 			 val_= 1.30693146769, test_time  = 2.04552817345 s
# ===============================
#
# Target==  uo didto uo uo kadto bitaw tribute ba to
# 	Ans =>  -vuitxvau-atzxpnuaualalazuavevzlzmvemv-qaktlatiz vsylhlyahqk-kllkatazt vmavq
# Target==  ? college level man pod ?
# 	Ans =>  z -
# Target==  ambot oy tapos kuan
# 	Ans =>  kquckcvc_yf?xff'vo_d-vyoevibcgc
# Target==  si manilyn kana' iya nga damit ihat- ihatod
# 	Ans =>  tzzkzs kzbzd_tf ytkzzfjzgj-tzk'da'kd_
# Target==  kay manayaw mga bata' ?
# 	Ans =>  awcwc
# Target==  na nga nag siyagit-siyagit
# 	Ans =>  qa
# Target==  ? ? basta ang suman ha ? og naa mabilin bigiyan mo gayod ko'
# 	Ans =>  m'fredckmbsdvulvlklclvlvkimibyvgvv'vmxiyxg?x cygrwxacarmxwyguc?xuxerxewv maczgq?p?
# Target==  ay okay lang okay lang gihapon
# 	Ans =>  zza-zak?uluz zu?uakvlvhfxzcvubk-la'k
# Target==  sila nanti naana' sila nga nanti naana'
# 	Ans =>
# Target==  mmm kanus-a man kadto mangha-
# 	Ans =>  jzczcac
# Target==  ? ?
# 	Ans =>  hvmvmvak'xhklkutswyvasmeauzuasaxuakauxaqvxdyotktuza
# Target==  didto siya na assign sa una mao nga didto gani' mi nagkita'
# 	Ans =>  'v imi vivoiumvkigclpmcvk-culuqvkuzwajgozkyc-zvm-iui-mi-cm'f-v-f_qf
# Target==  gahapon unsa diay ?
# 	Ans =>  vmvigdh'm'eizuvazjeow-paogwgjz'xal'uvgw
# Target==  naa ing gamay naa sa ing buhat sakto ra naa ra ing kuan gayod
# 	Ans =>  kuzmiua-izktvhvk'k'atzuajgd'kbolx-tzuhu-z-cazkhts-
# Target==  ? basta maayo lang nga pagkatrabaho basta dili' lang ingon nga
# 	Ans =>  zu- a-u-utu-kukuaukukzh-aukazkuaqlkrslklauauz zl'k-izxrlakhkakaluaqz
# Target==  ay commercial ipaganda o ipaganda
# 	Ans =>  _?z?z?z_z_?_z
# Target==  tigtubig boy lang ta sa ilaha
# 	Ans =>  r_slkvkl'olk'f'bkzxfkxkpfpxlxklflf'f
# Target==  mawala'-wala' lagi ka dili' kaayo ta ka madungog
# 	Ans =>  la
# Target==  ? lagi impas na akua piro ang prublima diri ko' nga ma-flat-an mahurot sa hantakan tanan ?
# 	Ans =>  heaumug-vuiuyhztx'quauhdiefuacrcoyohepovpxyklaksku-yuva-wvkpcjk'v?bhgea''peaqt-q'v-qvjbz-ucgcqeuoxegw?
# Target==  natingala gani' siya nga duha ra daw kabulan kapin
# 	Ans =>  da
# Target==  dalan lang tika dalan tika
# 	Ans =>  d dcc
# Target==  ay gibalita' na pod diay naana' pod bagiyo
# 	Ans =>  'q?kexatcklzylklakvuvoityvmxtymhauiveveu?svahf ?-t-vuvuecacqsemevuvomv
# Target==  anhi lang diri ini og human nimo og panglaba
# 	Ans =>  a
# Target==  naana' la ?
# 	Ans =>  zqlqlq
# Target==  laa- mukuan sala' gani' to sila musimba
# 	Ans =>  lrlr
# Target==  aw o si lenny ang kauban niya si kuan maricris
# 	Ans =>  zmeikl aeilhz-h-hau-e-?vkvekilhmahlvhkhthv'zaqehqhxhivu-auh?-bsz mvyobmouisrmgqgjnc cwmv?gsudfovcwhyx'kymxpikm'c_wdcpcaqwqv
# Target==  ? lisod na ang ingon miana' mok
# 	Ans =>  z
# Target==  mmm ana' gayod kana' mari gayod kinahanglan
# 	Ans =>  xk'x'b fw-tg'gbgbdxkzkzwxyt'klokuxlzg'ualkbk_z
# Target==  ? didto sa ingon nila nga guadalupe unsa kadto nga lugara kadto
# 	Ans =>  lalalav
# Target==  iskuwila tanan o humana ang uban
# 	Ans =>  aex
# Target==  o ato' ra man gihapon na ba inig
# 	Ans =>  dhha
# Target==  ? daghan og dalhon tika
# 	Ans =>
# Target==  wala' ing signal amo' nga bukid ? bukid
# 	Ans =>  aasas
# Target==  pait kaayo amo' nga kinabuhi' ingon ana' ra oy motor-motor pait kaayo
# 	Ans =>  kxel-lqdm zj'-akclcc'hcohlhlhqalunaklakhky'laqatkqaklu-qlslsaoak'
# Target==  sapatos bag-o nga sapatos alangan dili' ka magsapatos
# 	Ans =>  'kvwd-'vmakzaq'zg'j'gv'qacxmxcxav?k?ck_'dbsbgk''ak_f
# Target==  oh oh oh dinha' gayod
# 	Ans =>  g
# Target==  uo mag-propose nako' sa imo hapit na
# 	Ans =>  'vula'eja'ab uqzmuyqqvu uautxatzvavqgo
# Target==  three years lang baya' sila didto
# 	Ans =>  az
# Target==  diri sa kuan gayod sa may iskuwilahan duol banda
# 	Ans =>  zkluo ushdvxiualamzzxusgsdzvz iurhaokgsodfvfhvyz-?uzkuisfv
# Target==  pila na may anak nimo karon
# 	Ans =>  moaxwvxw'viktak-vib badffj alecu-ujzxm
# 0 135.695175171 649.518737793
# 10 1.34269416332 582.818237305
# 20 19.145980835 576.067443848
# 30 19.1979465485 607.703491211
# 40 164.276046753 619.440856934
# 50 95.8488540649 646.159790039
# 60 118.223022461 615.652954102
# 70 33.3234977722 507.761566162
# 80 75.7392807007 569.338256836
# 90 -36.5140647888 496.917144775
#
# ===============================
# epoch 3 : pseudo= 88.2020887053, cost= 611.280924807, previous_cost= 649.424085391, train_time = 1323.56093884 s
# 4
# 			 val_= 1.16333322857, test_time  = 2.01996779442 s
# ===============================
#
# Target==  mikalit man gayod kadto nga nga naa ing talk uniya' kuan pod ba kana' nga ?
# 	Ans =>  hcyvesauohka'aqulhailvlamuvuo osfuaola'icevatshkaamivgakyqzqaumvuuvalflaqmkruhakaok
# Target==  ay nagtrabaho ko' sa kuan sa factory
# 	Ans =>  gaoa_
# Target==  gikuan kuno to ? gipalitan to og itlog
# 	Ans =>  cacacaczczcacazcazca
# Target==  ayaw kay gutom gayod na nga alas-dusi na man
# 	Ans =>  mmm'asxmdvmvqx'kusv_cvzkchzzvavacqhtytaiavhc-khz
# Target==  ma-level ba diay nako' nga sumbagay lang
# 	Ans =>  iy_la
# Target==  sa akua diay dili' madunggan nimo
# 	Ans =>  u'kok'leuyu'l'kfkktzkdla
# Target==  na sa bata'
# 	Ans =>  akuktutukmvevijo
# Target==  asa mo dapit gasuroy-suroy
# 	Ans =>  ''aaaaa
# Target==  pariha ana' oscar ana' ba
# 	Ans =>  eieiviovkvioxviv?avauv
# Target==  o adtuon lang nako' si jed
# 	Ans =>  'eataa-h-a auhauh-k-k
# Target==  lech- litson na baboy
# 	Ans =>  vclaxa-wj vcvi-bmbi xikawcp uiuz
# Target==  sa kuan lang kana' nga mga makaagi ko' og simbahan
# 	Ans =>
# Target==  girl manglaag kita' ila shirla sunod ba
# 	Ans =>  mcuivuxzal miivlmiv eivi ? ?cim'aceagzqztkaveac
# Target==  o mmm
# 	Ans =>  klaluakmbmuzkok'lfl
# Target==  uyabon uyab-uyab na man daw kuno
# 	Ans =>  ohi-gzcaus?udf a ?- hhi-umv-auhluuaqukx-d-rf
# Target==  kato nga nabahaan ato' nga una ba
# 	Ans =>  gvmvmycytzhoexpkk
# Target==  o ngano nalagot man ka ni ? o
# 	Ans =>  vvimxavevelahahl?ltzou?ueqh?h-f'xvax
# Target==  sa february mag-lima siya kabulan
# 	Ans =>  jazmimviaia-?b?nyozbeivva?g-'oczkivjw-
# Target==  musalig og kana' nga mga ingon ana' oy maningkamot ako' oy mangita' ko' og paagi kay lisod kaayo man gayod na ang
# 	Ans =>  a
# Target==  manok uniya' kaha iya elot unsa
# 	Ans =>  y_qaemtamgffvad-a'a a zasa-zdcvg-ln_krsasasjg
# Target==  og mas tigulang ko' sa imuha ba ?
# 	Ans =>  casyazpczcvmh-zhy''y-aohveylazhceibk
# Target==  lisod kana' ang bungol ba bungol baya' ko'
# 	Ans =>  acacz'
# Target==  si ?
# 	Ans =>  vvposu-k-iuicj gjakuo
# Target==  o i-announce
# 	Ans =>  sqqsbsllkuklkluluasvrutzjlutulkulukvlvlfa
# Target==  kay malipong man kaha' siya ?
# 	Ans =>  vkivf ockzvi?sopipipxvlkuamtyvjzghcicz_i_axlkchl
# Target==  o wala' ? hinuon wala' man hinuon
# 	Ans =>  oaa'le'aeuiua-lclmanauaczpmpmmxmxxvclvmvsymsyh?shau-la?ozazv
# Target==  bitaw day tama' gayod ka day
# 	Ans =>  mvki?mivi?l?vutxiov izui-a-c?z
# Target==  dinhi man gayod mi mabuhi' bay
# 	Ans =>  yakaoakz'kakrsqalakakoll
# Target==  ? wala' diay giapas ni alex
# 	Ans =>  'fuk'u?zsuklhsfzkualuakukxzuvusasaszusulskxcdsdsh
# Target==  wala' ing tarong og iskuwila sigi lang og climb-climb na
# 	Ans =>  qzll s u-zhkuaah'a'tkui
# Target==  usa lay nagdungan nimo dong
# 	Ans =>  k-a?-uukzxlzlflklauok
# Target==  naako' wala' oy luuya oy
# 	Ans =>  ag?uqal?vl-uuaklaxuaauatl
# Target==  hapit na alas-dusi padulong siya duty ron
# 	Ans =>  earsavaku?zuahkhkokswtofusruaztxakkhazk
# Target==  uniya' mama nimo nakauli' na
# 	Ans =>  -y'ks'vsulz-a'j'j'-
# Target==  mao na nga ukasiyon na man libri gayod
# 	Ans =>  hauluaztvvbigsnb it ua-ua'azlcyvkaltptxtl
# Target==  dili' pod tama' tama' lang
# 	Ans =>
# Target==  guwapo man pod na ingon ana' salo-salo tanan mga
# 	Ans =>  oazgataguvackzoau_fwdv?fadsndjfdgj_rcdmg
# Target==  naa diay ka ing exam karon sayo man lagi
# 	Ans =>  lkalnkok yxaxakuaklkdklklzak'zzl
# Target==  kana' nga dili' na siya magpalakas og kaon diay ti
# 	Ans =>  vivmihx pkzbw?ivo?v'u-tvzvmimtal'aopvcimivuvxiovpaifoxz
# Target==  unsa man nga naa man kay klasi inig gawas nimo sa klasi
# 	Ans =>
# 0 69.7695083618 545.298278809
# 10 55.5348930359 557.01361084
# 20 -44.0442695618 540.782775879
# 30 -20.5496520996 573.752563477
# 40 39.7039451599 444.854400635
# 50 68.3128433228 601.948364258
# 60 111.866821289 586.447265625
# 70 9.86501502991 487.619232178
# 80 35.6508140564 527.526550293
# 90 -17.7211914062 499.204833984
#
# ===============================
# epoch 4 : pseudo= 54.6837609337, cost= 562.696007185, previous_cost= 611.280924807, train_time = 1323.04322886 s
# 4
# 			 val_= 1.06656937989, test_time  = 1.99029397964 s
# ===============================
#
# Target==  sila vannie okay man na kay mga taba' man
# 	Ans =>  mk uxaxk'kvukua-vu ubu k axsknsmqaslqltsqfn
# Target==  pangit man na ang rain or shine hinay kaayo na oy
# 	Ans =>  'sawf_fazxollrcdxkx'qkvvfik-u-cgwwzikiiko-k
# Target==  mura lagi og dili' ikaw ?
# 	Ans =>  ia'gpimv?xvk-uokbsuagh
# Target==  no nagkauyab man diay mo ato' niya no
# 	Ans =>  at?apv-zazvmiaqjhaz h vh
# Target==  o karon na anhi lang diri
# 	Ans =>
# Target==  taod-taod taod-taod na sad
# 	Ans =>  a
# Target==  ay sigi man musulti man siya sa akua piro wala' ko' kita' sa lalaki giingnan nako' ayaw sa paadtua og balay
# 	Ans =>  vkoz agbz mabs mitmtxzkjhkkslsmauagxakskb--as  cbm-bsasauak thakuzu z kusf
# Target==  cook nako' dinha' mag-cook puwidi mag-cook nako' dinha'
# 	Ans =>  lea_jqaqauxuaav?eigldxmumhaifu_qk'va_qaqagqv
# Target==  o kato lang siya one three
# 	Ans =>  eves?av'lpaheiaiaoaoz
# Target==  ting-break time ? ? ting-break time
# 	Ans =>  araz
# Target==  mao lagi siguro sa kuan putol-putol
# 	Ans =>  maaalahh'?mxiasqqlq'd?fg
# Target==  uniya' kumusta man imo nga pa check-up balik nay
# 	Ans =>  a a a a a
# Target==  useless lang gihapon imo nga sigi ka og pangutana sa akua
# 	Ans =>  rvuavil-f b ?i-i-iuauaecfw- _zja-amiwp
# Target==  wal- wal- wala' diay bugas
# 	Ans =>  va-?waaqeavexauauklevbud
# Target==  ? kana' nga mga uso karon
# 	Ans =>  amvxmhnaxagvaxaa-
# Target==  oh wala' ing signal amo' nga bukid ?
# 	Ans =>  aaca
# Target==  o para ?
# 	Ans =>
# Target==  wala' pa wala' pa
# 	Ans =>
# Target==  si neneng og si sweetie ra man to
# 	Ans =>  r
# Target==  dako' na na nga panalangin sa ginuo
# 	Ans =>  j'vtjpgv ?kcvxkqtau
# Target==  ? age does not matter bitaw na ati
# 	Ans =>  vevauakuaxu zt_ha uakyuauklkl-k
# Target==  maayo og madayon maayo og dili'
# 	Ans =>  vvulpxiksilululqalukuuuluhhla-a-tl
# Target==  namaligiya' man si caloy diri oh halos kami tanan namalit
# 	Ans =>  au-yvmigd'fgfh??ivzkbd
# Target==  dondie naunsa diay si dondie diay
# 	Ans =>
# Target==  prak- ? prak- ha
# 	Ans =>  aacac
# Target==  maayo unta' og kumplito to nga ?
# 	Ans =>  f ujakuftff sa-tf
# Target==  layas ? layas ni nga bataa ni bisan
# 	Ans =>  cacac_
# Target==  mao ana' man gayod kana' dili' na man gayod kana' ma-control tir
# 	Ans =>  aaaacac c a aca a a azaza z'a z
# Target==  na-addict na kaayo si doogie ba o
# 	Ans =>  llllla
# Target==  basi og imo nga suwirti naa sa lain wala' dinha'
# 	Ans =>  aaalllllal
# Target==  duol pa gayod ka sa mga bata' nimo imo nga mga anak
# 	Ans =>  awwgcaacaaaca_hzm?ixuacaqmqaa?ah
# Target==  o bag-o ato' dili' ka ? tsoy ato'
# 	Ans =>  a
# Target==  thursday ba huwibis
# 	Ans =>  toaog-g'aausuakuivmigao-so_y
# Target==  pagkadako' sa pabo oy mura man og kabaw
# 	Ans =>  'vi-tqci-vakimaia-a-a-u-pvalaukak?iar samvbh'
# Target==  wala' pa ing valid i_d si papa
# 	Ans =>  bqbqaalilidbkvevuihukka-okovi
# Target==  last year pabuto man kadto last year
# 	Ans =>  azaz'
# Target==  hala no luuya gayod niya gayod
# 	Ans =>  axgnnxxn??x?xax
# Target==  ? unsa iya nga course kurso
# 	Ans =>  avp-dk-u-vu-vud ua
# Target==  ? magbaktas ? duol ra man pod
# 	Ans =>
# Target==  ha ?
# 	Ans =>  o
# 0 31.246887207 501.290527344
# 10 18.161939621 546.162414551
# 20 -31.681476593 520.061706543
# 30 6.43713378906 531.163452148
# 40 2.83191537857 439.030700684
# 50 -7.54547739029 536.99420166
# 60 -2.35919189453 540.15045166
# 70 -16.0753917694 482.669769287
# 80 -13.4713010788 530.617736816
# 90 -49.124874115 493.549468994
#
# ===============================
# epoch 5 : pseudo= 13.7154733263, cost= 514.361096454, previous_cost= 562.696007185, train_time = 1322.0887692 s
# 4
# 			 val_= 1.00015815191, test_time  = 1.97448801994 s
# ===============================
#
# Target==  bumble bee ? sa ato' pa ? gayod diay ka
# 	Ans =>  t?acyaqrqruvivuaiuavv
# Target==  nindot na kadto imo nga kuan sa una
# 	Ans =>  dgab?-cmhmiz?v cmivv
# Target==  piro kad- kadali' ra man to nga si ati mildred
# 	Ans =>
# Target==  ? gahapon nakakuwarta kagahapon
# 	Ans =>  k
# Target==  ? wala' ra ba kay budget
# 	Ans =>  aava?auiu ahua-
# Target==  ang tulo kakuan traha
# 	Ans =>  -ywj-
# Target==  nagtrabaho davao light
# 	Ans =>  aaibiicaiiai
# Target==  mao lagi ba unsa nga urasa muabot diay
# 	Ans =>   ieiacmazmayauq'tuxauaacalvlh
# Target==  ? ako' pod mupalit pod ko' og gatas sa ako' nga anak diri
# 	Ans =>  cjzu-uag'bdi xbieiuayifdai-aidaeiaa-aozo
# Target==  unsa man ila nga gidula' ?
# 	Ans =>  ac
# Target==  kuyawa gayod pila ang ?
# 	Ans =>  hiva?auta-imivwcv
# Target==  ipalihog ko' ingon nga
# 	Ans =>  -c j-h-cag
# Target==  ? sigi siya suroy-suroy
# 	Ans =>  ? m?vzvivivvhiqzazvzif-
# Target==  kuyawa no paspasa pod nila manganak no ?
# 	Ans =>  havi?bmacmvkkc aihahihha?daasdsfvb?-l?
# Target==  ? ? unsa man nawala' man nadawat
# 	Ans =>  a a c a  ca
# Target==  ? uniya'
# 	Ans =>  aiuno_oahhknk
# Target==  piro wala' na ka miadto
# 	Ans =>  auaavau?auuj-iyuko
# Target==  bala kaayo ka maunahan gani' ka gani'
# 	Ans =>  llasvuaalkaohhha
# Target==  ? mao gayod na
# 	Ans =>  vpecacixjthiaagc
# Target==  kay daghan man gayod kaayo sila mama gayod dira'
# 	Ans =>  wa_gdviivg-aizugivfpvhlclckm uaijh
# Target==  arkilaha ?
# 	Ans =>  ov_cv- izaoa
# Target==  o asa man siya nag-iskuwila karon
# 	Ans =>  v wwgsm mlmumlauatzkkskc-fak
# Target==  uniya' wala'-wala' wala' mo ing video ato' nga
# 	Ans =>  vavxvmhana heqha'zuhlgh
# Target==  kuyog piro ? hapon na lagi kaayo maayo man to nga nakuha kadto ganiha kay
# 	Ans =>  ac a a ac  sv
# Target==  ? nangita' ta og kana' nga maayo unsa ing unsa og grasiya uniya' sa ginuo ba
# 	Ans =>  alalalk k
# Target==  ? usa na man lang ? mao diay wala' na lang
# 	Ans =>  aaa
# Target==  blue uniya' blue ra pod ako' nga
# 	Ans =>  acacazavaaaaa
# Target==  o trisi
# 	Ans =>  fauaka'kixiuxagao
# Target==  mapundasiyunan ang kuan
# 	Ans =>
# Target==  magsakit-sakit biya' ni sarah og si janmar
# 	Ans =>  vxaailahamiauxvhal
# Target==  o ngano diay muuban ka
# 	Ans =>  acouauvuauvualsaad aud
# Target==  ? ka didto sigi ra og tindog
# 	Ans =>  -l a va-u v?zakk
# Target==  ay usahay lang dili' man pod siya ingon nga dalo' piro
# 	Ans =>   k
# Target==  uniya' kanus-a man to muuli' imo nga bana
# 	Ans =>  aa cmtcycveaccakc miimy
# Target==  ? si luke ? wala' na man siya ing ? wala' na man
# 	Ans =>  azag
# Target==  ikaw kumusta na man mo sa imo nga uyab
# 	Ans =>  vcvcvvvhmxywfpzeh?a
# Target==  sa una mao man unta' to ang plano namo' sa una
# 	Ans =>  auzbu-az aqbza_'fa'gadgmks?agnvba_
# Target==  ? sunod ini og magkita' ta ?
# 	Ans =>  alalalalalgkgv
# Target==  og wala' nawala' ? abi nako' og wala' pa
# 	Ans =>  aaa
# Target==  o tabang ? kadto nga ? sa bohol ba
# 	Ans =>  auaabauhia?hdaa?ak??hhu ahuh?h'
# 0 98.087059021 516.209350586
# 10 -42.2181587219 517.100036621
# 20 -54.3668479919 422.570953369
# 30 -61.3911323547 470.201080322
# 40 61.8666191101 400.637969971
# 50 74.7096176147 484.667724609
# 60 -70.6222763062 448.67578125
# 70 49.2896614075 429.246154785
# 80 35.9815406799 431.06137085
# 90 -87.6989517212 425.586242676
#
# ===============================
# epoch 6 : pseudo= -11.1128210364, cost= 469.700039443, previous_cost= 514.361096454, train_time = 1322.10429406 s
# 4
# 			 val_= 0.947013173351, test_time  = 1.87774300575 s
# ===============================
#
# Target==  uo didto uo uo kadto bitaw tribute ba to
# 	Ans =>  aaaaaxv'mvm?naaatmaq
# Target==  ? college level man pod ?
# 	Ans =>  aaavwvw
# Target==  ambot oy tapos kuan
# 	Ans =>  chccfzdvecgckc
# Target==  si manilyn kana' iya nga damit ihat- ihatod
# 	Ans =>  tzzazzt tktj?tzxzgdkakluk
# Target==  kay manayaw mga bata' ?
# 	Ans =>  ad
# Target==  na nga nag siyagit-siyagit
# 	Ans =>
# Target==  ? ? basta ang suman ha ? og naa mabilin bigiyan mo gayod ko'
# 	Ans =>  aizoxioixixidi
# Target==  ay okay lang okay lang gihapon
# 	Ans =>  ulaau-k
# Target==  sila nanti naana' sila nga nanti naana'
# 	Ans =>
# Target==  mmm kanus-a man kadto mangha-
# 	Ans =>  o
# Target==  ? ?
# 	Ans =>  pakswagmaavtua
# Target==  didto siya na assign sa una mao nga didto gani' mi nagkita'
# 	Ans =>  imivii?gcma'
# Target==  gahapon unsa diay ?
# 	Ans =>  iz kz-aogwpaaua
# Target==  naa ing gamay naa sa ing buhat sakto ra naa ra ing kuan gayod
# 	Ans =>  aa-kracwgu-
# Target==  ? basta maayo lang nga pagkatrabaho basta dili' lang ingon nga
# 	Ans =>
# Target==  ay commercial ipaganda o ipaganda
# 	Ans =>  agag'gh'hc-g'sa'
# Target==  tigtubig boy lang ta sa ilaha
# 	Ans =>  'k'xol'nf'bkpaxaxkhf
# Target==  mawala'-wala' lagi ka dili' kaayo ta ka madungog
# 	Ans =>  ii'naqviiuiuiavaz
# Target==  ? lagi impas na akua piro ang prublima diri ko' nga ma-flat-an mahurot sa hantakan tanan ?
# 	Ans =>  aum mg-zzamacavaachaea'v-by?azmeg?
# Target==  natingala gani' siya nga duha ra daw kabulan kapin
# 	Ans =>  a
# Target==  dalan lang tika dalan tika
# 	Ans =>  aa
# Target==  ay gibalita' na pod diay naana' pod bagiyo
# 	Ans =>  etkattaameauvkv
# Target==  anhi lang diri ini og human nimo og panglaba
# 	Ans =>  la
# Target==  naana' la ?
# 	Ans =>
# Target==  laa- mukuan sala' gani' to sila musimba
# 	Ans =>
# Target==  aw o si lenny ang kauban niya si kuan maricris
# 	Ans =>  iaahaaaha eaau?mnbymcqvcdq'wvwdcpcaw
# Target==  ? lisod na ang ingon miana' mok
# 	Ans =>
# Target==  mmm ana' gayod kana' mari gayod kinahanglan
# 	Ans =>  ''kakfkodatg'kbdxay x klo'kbkz
# Target==  ? didto sa ingon nila nga guadalupe unsa kadto nga lugara kadto
# 	Ans =>  a _f_
# Target==  iskuwila tanan o humana ang uban
# 	Ans =>  z
# Target==  o ato' ra man gihapon na ba inig
# 	Ans =>  sapapg
# Target==  ? daghan og dalhon tika
# 	Ans =>  sax
# Target==  wala' ing signal amo' nga bukid ? bukid
# 	Ans =>  aaa
# Target==  pait kaayo amo' nga kinabuhi' ingon ana' ra oy motor-motor pait kaayo
# 	Ans =>  ljgahhhaakaaaakala
# Target==  sapatos bag-o nga sapatos alangan dili' ka magsapatos
# 	Ans =>  ''a?'ak
# Target==  oh oh oh dinha' gayod
# 	Ans =>  iu-a-a-auaiu-lau
# Target==  uo mag-propose nako' sa imo hapit na
# 	Ans =>  aaa
# Target==  three years lang baya' sila didto
# 	Ans =>
# Target==  diri sa kuan gayod sa may iskuwilahan duol banda
# 	Ans =>  aalaguav
# Target==  pila na may anak nimo karon
# 	Ans =>  aaxc-ib afaf fua
# 0 18.2309455872 428.99041748
# 10 -53.2916755676 479.095550537
# 20 -67.0645599365 409.552154541
# 30 -29.9029483795 455.337219238
# 40 33.2193069458 501.501556396
# 50 33.0912742615 507.871582031
# 60 121.820999146 483.084533691
# 70 55.8123855591 408.589538574
# 80 64.1284713745 463.907562256
# 90 41.9039726257 452.688659668
#
# ===============================
# epoch 7 : pseudo= 31.6528943598, cost= 467.944188928, previous_cost= 469.700039443, train_time = 1310.44017315 s
# 4
# 			 val_= 0.967690132682, test_time  = 1.7894449234 s
# ===============================
#
# Target==  mikalit man gayod kadto nga nga naa ing talk uniya' kuan pod ba kana' nga ?
# 	Ans =>  ciahaaaaaaak
# Target==  ay nagtrabaho ko' sa kuan sa factory
# 	Ans =>  xa
# Target==  gikuan kuno to ? gipalitan to og itlog
# 	Ans =>  a
# Target==  ayaw kay gutom gayod na nga alas-dusi na man
# 	Ans =>
# Target==  ma-level ba diay nako' nga sumbagay lang
# 	Ans =>  ggaha
# Target==  sa akua diay dili' madunggan nimo
# 	Ans =>  '
# Target==  na sa bata'
# 	Ans =>
# Target==  asa mo dapit gasuroy-suroy
# 	Ans =>
# Target==  pariha ana' oscar ana' ba
# 	Ans =>
# Target==  o adtuon lang nako' si jed
# 	Ans =>
# Target==  lech- litson na baboy
# 	Ans =>  iacwm
# Target==  sa kuan lang kana' nga mga makaagi ko' og simbahan
# 	Ans =>  a
# Target==  girl manglaag kita' ila shirla sunod ba
# 	Ans =>  ivmva
# Target==  o mmm
# 	Ans =>  uakmauauaas't'v
# Target==  uyabon uyab-uyab na man daw kuno
# 	Ans =>  a-aq-
# Target==  kato nga nabahaan ato' nga una ba
# 	Ans =>  wsyicgytyjczh
# Target==  o ngano nalagot man ka ni ? o
# 	Ans =>  iaaia??ha
# Target==  sa february mag-lima siya kabulan
# 	Ans =>  miaab?w
# Target==  musalig og kana' nga mga ingon ana' oy maningkamot ako' oy mangita' ko' og paagi kay lisod kaayo man gayod na ang
# 	Ans =>  agagc c
# Target==  manok uniya' kaha iya elot unsa
# 	Ans =>  _qamad' a sa
# Target==  og mas tigulang ko' sa imuha ba ?
# 	Ans =>  cczyyxc-ai
# Target==  lisod kana' ang bungol ba bungol baya' ko'
# 	Ans =>
# Target==  si ?
# 	Ans =>  aicja a galk
# Target==  o i-announce
# 	Ans =>  a
# Target==  kay malipong man kaha' siya ?
# 	Ans =>
# Target==  o wala' ? hinuon wala' man hinuon
# 	Ans =>  iahaaao'z
# Target==  bitaw day tama' gayod ka day
# 	Ans =>  iivitiiiacz
# Target==  dinhi man gayod mi mabuhi' bay
# 	Ans =>  aaoaalal
# Target==  ? wala' diay giapas ni alex
# 	Ans =>  ''usuklskksvaakszklusausklsls
# Target==  wala' ing tarong og iskuwila sigi lang og climb-climb na
# 	Ans =>  auai
# Target==  usa lay nagdungan nimo dong
# 	Ans =>  -ao
# Target==  naako' wala' oy luuya oy
# 	Ans =>  aaa
# Target==  hapit na alas-dusi padulong siya duty ron
# 	Ans =>  ao?okazt
# Target==  uniya' mama nimo nakauli' na
# 	Ans =>  ks's'vlz-aa-a-aw'
# Target==  mao na nga ukasiyon na man libri gayod
# 	Ans =>  avcbliaalkataa
# Target==  dili' pod tama' tama' lang
# 	Ans =>  a?
# Target==  guwapo man pod na ingon ana' salo-salo tanan mga
# 	Ans =>  ai
# Target==  naa diay ka ing exam karon sayo man lagi
# 	Ans =>  kaak-lkla
# Target==  kana' nga dili' na siya magpalakas og kaon diay ti
# 	Ans =>
# Target==  unsa man nga naa man kay klasi inig gawas nimo sa klasi
# 	Ans =>  aa
# 0 75.2432098389 574.649230957
# 10 48.4586181641 463.917541504
# 20 76.8629760742 491.245178223
# 30 -29.329908371 476.190917969
# 40 68.1619491577 424.02545166
# 50 132.024536133 542.52911377
# 60 66.3138275146 478.986328125
# 70 20.7708072662 417.106262207
# 80 49.1230735779 497.821228027
# 90 24.1228313446 453.303375244
#
# ===============================
# epoch 8 : pseudo= 91.7374902682, cost= 489.084283972, previous_cost= 467.944188928, train_time = 1309.81801486 s
# 4
# 			 val_= 0.97187242493, test_time  = 1.78518104553 s
# ===============================
#
# Target==  sila vannie okay man na kay mga taba' man
# 	Ans =>  aaqaslqltsl
# Target==  pangit man na ang rain or shine hinay kaayo na oy
# 	Ans =>  a
# Target==  mura lagi og dili' ikaw ?
# 	Ans =>  iagp
# Target==  no nagkauyab man diay mo ato' niya no
# 	Ans =>  aiv-imiaz ava
# Target==  o karon na anhi lang diri
# 	Ans =>
# Target==  taod-taod taod-taod na sad
# 	Ans =>  ha
# Target==  ay sigi man musulti man siya sa akua piro wala' ko' kita' sa lalaki giingnan nako' ayaw sa paadtua og balay
# 	Ans =>  k'aak zasiatmjxzjzkslamjby-yklthkha kzkuk
# Target==  cook nako' dinha' mag-cook puwidi mag-cook nako' dinha'
# 	Ans =>  _ildxaq_aao
# Target==  o kato lang siya one three
# 	Ans =>  aaz
# Target==  ting-break time ? ? ting-break time
# 	Ans =>  a
# Target==  mao lagi siguro sa kuan putol-putol
# 	Ans =>  a'd
# Target==  uniya' kumusta man imo nga pa check-up balik nay
# 	Ans =>  g o
# Target==  useless lang gihapon imo nga sigi ka og pangutana sa akua
# 	Ans =>  ai-iaceci
# Target==  wal- wal- wala' diay bugas
# 	Ans =>
# Target==  ? kana' nga mga uso karon
# 	Ans =>  c
# Target==  oh wala' ing signal amo' nga bukid ?
# 	Ans =>
# Target==  o para ?
# 	Ans =>  abo
# Target==  wala' pa wala' pa
# 	Ans =>
# Target==  si neneng og si sweetie ra man to
# 	Ans =>
# Target==  dako' na na nga panalangin sa ginuo
# 	Ans =>  ia e
# Target==  ? age does not matter bitaw na ati
# 	Ans =>  -
# Target==  maayo og madayon maayo og dili'
# 	Ans =>  al
# Target==  namaligiya' man si caloy diri oh halos kami tanan namalit
# 	Ans =>  akak-
# Target==  dondie naunsa diay si dondie diay
# 	Ans =>  gqgara
# Target==  prak- ? prak- ha
# 	Ans =>  o x
# Target==  maayo unta' og kumplito to nga ?
# 	Ans =>  uts-
# Target==  layas ? layas ni nga bataa ni bisan
# 	Ans =>  al
# Target==  mao ana' man gayod kana' dili' na man gayod kana' ma-control tir
# 	Ans =>
# Target==  na-addict na kaayo si doogie ba o
# 	Ans =>
# Target==  basi og imo nga suwirti naa sa lain wala' dinha'
# 	Ans =>
# Target==  duol pa gayod ka sa mga bata' nimo imo nga mga anak
# 	Ans =>  iaaau
# Target==  o bag-o ato' dili' ka ? tsoy ato'
# 	Ans =>  sga
# Target==  thursday ba huwibis
# 	Ans =>  agaaiso
# Target==  pagkadako' sa pabo oy mura man og kabaw
# 	Ans =>  c-aaaamvb
# Target==  wala' pa ing valid i_d si papa
# 	Ans =>   a
# Target==  last year pabuto man kadto last year
# 	Ans =>  kk
# Target==  hala no luuya gayod niya gayod
# 	Ans =>  lr
# Target==  ? unsa iya nga course kurso
# 	Ans =>  a az
# Target==  ? magbaktas ? duol ra man pod
# 	Ans =>  ax
# Target==  ha ?
# 	Ans =>  zo
# 0 311.608886719 545.91809082
# 10 156.224899292 513.260620117
# 20 232.301391602 498.284484863
# 30 -28.8327274323 430.738098145
# 40 49.8701896667 439.523193359
# 50 90.881149292 563.594238281
# 60 152.571075439 459.016021729
# 70 159.575515747 522.085083008
# 80 100.438995361 452.775634766
# 90 66.814414978 406.081848145
#
# ===============================
# epoch 9 : pseudo= 121.906488651, cost= 489.889422017, previous_cost= 489.084283972, train_time = 1308.53103995 s
# 4
# 			 val_= 0.965685547189, test_time  = 1.78520607948 s
# ===============================
#
# Target==  bumble bee ? sa ato' pa ? gayod diay ka
# 	Ans =>  cbirvaa
# Target==  nindot na kadto imo nga kuan sa una
# 	Ans =>  ?-cma i
# Target==  piro kad- kadali' ra man to nga si ati mildred
# 	Ans =>
# Target==  ? gahapon nakakuwarta kagahapon
# 	Ans =>  aa
# Target==  ? wala' ra ba kay budget
# 	Ans =>  ala-ae
# Target==  ang tulo kakuan traha
# 	Ans =>
# Target==  nagtrabaho davao light
# 	Ans =>  ii
# Target==  mao lagi ba unsa nga urasa muabot diay
# 	Ans =>  iacaa
# Target==  ? ako' pod mupalit pod ko' og gatas sa ako' nga anak diri
# 	Ans =>  caiiaiaaxz
# Target==  unsa man ila nga gidula' ?
# 	Ans =>  a
# Target==  kuyawa gayod pila ang ?
# 	Ans =>  iia-iyv
# Target==  ipalihog ko' ingon nga
# 	Ans =>  ch-ag
# Target==  ? sigi siya suroy-suroy
# 	Ans =>  lia
# Target==  kuyawa no paspasa pod nila manganak no ?
# 	Ans =>  gx?vanavavdvb?-l
# Target==  ? ? unsa man nawala' man nadawat
# 	Ans =>  a n c c adad
# Target==  ? uniya'
# 	Ans =>  ioa
# Target==  piro wala' na ka miadto
# 	Ans =>  aui
# Target==  bala kaayo ka maunahan gani' ka gani'
# 	Ans =>  suvaao
# Target==  ? mao gayod na
# 	Ans =>  oa
# Target==  kay daghan man gayod kaayo sila mama gayod dira'
# 	Ans =>  gaa
# Target==  arkilaha ?
# 	Ans =>  la
# Target==  o asa man siya nag-iskuwila karon
# 	Ans =>  vas lmumlauzk
# Target==  uniya' wala'-wala' wala' mo ing video ato' nga
# 	Ans =>  a
# Target==  kuyog piro ? hapon na lagi kaayo maayo man to nga nakuha kadto ganiha kay
# 	Ans =>  kp
# Target==  ? nangita' ta og kana' nga maayo unsa ing unsa og grasiya uniya' sa ginuo ba
# 	Ans =>  ao
# Target==  ? usa na man lang ? mao diay wala' na lang
# 	Ans =>
# Target==  blue uniya' blue ra pod ako' nga
# 	Ans =>
# Target==  o trisi
# 	Ans =>
# Target==  mapundasiyunan ang kuan
# 	Ans =>  ak
# Target==  magsakit-sakit biya' ni sarah og si janmar
# 	Ans =>  aahh
# Target==  o ngano diay muuban ka
# 	Ans =>  q i   --
# Target==  ? ka didto sigi ra og tindog
# 	Ans =>  vvvaaav
# Target==  ay usahay lang dili' man pod siya ingon nga dalo' piro
# 	Ans =>
# Target==  uniya' kanus-a man to muuli' imo nga bana
# 	Ans =>  tic
# Target==  ? si luke ? wala' na man siya ing ? wala' na man
# 	Ans =>  ag
# Target==  ikaw kumusta na man mo sa imo nga uyab
# 	Ans =>  yw-ah
# Target==  sa una mao man unta' to ang plano namo' sa una
# 	Ans =>
# Target==  ? sunod ini og magkita' ta ?
# 	Ans =>  a
# Target==  og wala' nawala' ? abi nako' og wala' pa
# 	Ans =>  o
# Target==  o tabang ? kadto nga ? sa bohol ba
# 	Ans =>
# 0 341.802764893 513.556518555
# 10 62.6923332214 513.541381836
# 20 42.9777832031 469.529968262
# 30 -0.418286144733 431.483398438
# 40 -18.8672943115 391.760284424
# 50 117.656692505 454.292877197
# 60 91.8963699341 451.249755859
# 70 92.3786621094 399.042053223
# 80 52.5497817993 442.65512085
# 90 48.1006736755 374.094329834
#
# ===============================
# epoch 10 : pseudo= 69.3050842394, cost= 444.676289876, previous_cost= 489.889422017, train_time = 1309.71273685 s
# 4
# 			 val_= 0.955523376479, test_time  = 1.79078793526 s
# ===============================
#
# Target==  uo didto uo uo kadto bitaw tribute ba to
# 	Ans =>  aavaqaa
# Target==  ? college level man pod ?
# 	Ans =>  ag g
# Target==  ambot oy tapos kuan
# 	Ans =>  ?ccfdvcgc
# Target==  si manilyn kana' iya nga damit ihat- ihatod
# 	Ans =>  zvlkkd'alk
# Target==  kay manayaw mga bata' ?
# 	Ans =>  a
# Target==  na nga nag siyagit-siyagit
# 	Ans =>
# Target==  ? ? basta ang suman ha ? og naa mabilin bigiyan mo gayod ko'
# 	Ans =>  a
# Target==  ay okay lang okay lang gihapon
# 	Ans =>  ak
# Target==  sila nanti naana' sila nga nanti naana'
# 	Ans =>
# Target==  mmm kanus-a man kadto mangha-
# 	Ans =>  a
# Target==  ? ?
# 	Ans =>  kak
# Target==  didto siya na assign sa una mao nga didto gani' mi nagkita'
# 	Ans =>  iac?
# Target==  gahapon unsa diay ?
# 	Ans =>  paoaa
# Target==  naa ing gamay naa sa ing buhat sakto ra naa ra ing kuan gayod
# 	Ans =>  znnm
# Target==  ? basta maayo lang nga pagkatrabaho basta dili' lang ingon nga
# 	Ans =>  qq b
# Target==  ay commercial ipaganda o ipaganda
# 	Ans =>  ggx
# Target==  tigtubig boy lang ta sa ilaha
# 	Ans =>  'llkkf'mlxarksha
# Target==  mawala'-wala' lagi ka dili' kaayo ta ka madungog
# 	Ans =>  ia
# Target==  ? lagi impas na akua piro ang prublima diri ko' nga ma-flat-an mahurot sa hantakan tanan ?
# 	Ans =>  aav?
# Target==  natingala gani' siya nga duha ra daw kabulan kapin
# 	Ans =>  aax
# Target==  dalan lang tika dalan tika
# 	Ans =>  al
# Target==  ay gibalita' na pod diay naana' pod bagiyo
# 	Ans =>  aalavhv
# Target==  anhi lang diri ini og human nimo og panglaba
# 	Ans =>  a
# Target==  naana' la ?
# 	Ans =>  aa
# Target==  laa- mukuan sala' gani' to sila musimba
# 	Ans =>
# Target==  aw o si lenny ang kauban niya si kuan maricris
# 	Ans =>  a
# Target==  ? lisod na ang ingon miana' mok
# 	Ans =>  ah
# Target==  mmm ana' gayod kana' mari gayod kinahanglan
# 	Ans =>  'ktga'kbklxak'k
# Target==  ? didto sa ingon nila nga guadalupe unsa kadto nga lugara kadto
# 	Ans =>  g o o _
# Target==  iskuwila tanan o humana ang uban
# 	Ans =>  aai
# Target==  o ato' ra man gihapon na ba inig
# 	Ans =>
# Target==  ? daghan og dalhon tika
# 	Ans =>  v
# Target==  wala' ing signal amo' nga bukid ? bukid
# 	Ans =>
# Target==  pait kaayo amo' nga kinabuhi' ingon ana' ra oy motor-motor pait kaayo
# 	Ans =>  aaaa
# Target==  sapatos bag-o nga sapatos alangan dili' ka magsapatos
# 	Ans =>  aak
# Target==  oh oh oh dinha' gayod
# 	Ans =>   rno
# Target==  uo mag-propose nako' sa imo hapit na
# 	Ans =>
# Target==  three years lang baya' sila didto
# 	Ans =>
# Target==  diri sa kuan gayod sa may iskuwilahan duol banda
# 	Ans =>  ga
# Target==  pila na may anak nimo karon
# 	Ans =>  j-zaptfa
# 0 64.456413269 380.174499512
# 10 36.9174613953 415.7315979
# 20 105.761940002 392.35647583
# 30 -86.7637481689 398.302062988
# 40 45.2828369141 408.248321533
# 50 41.9043693542 467.855072021
# 60 58.7139053345 408.157012939
# 70 5.80343008041 363.12387085
# 80 -5.69082021713 402.571899414
# 90 16.1128482819 395.29196167
#
# ===============================
# epoch 11 : pseudo= 49.4769357968, cost= 401.745870283, previous_cost= 444.676289876, train_time = 1309.37178111 s
# 4
# 			 val_= 0.954447802369, test_time  = 1.78196001053 s
# ===============================
#
# Target==  mikalit man gayod kadto nga nga naa ing talk uniya' kuan pod ba kana' nga ?
# 	Ans =>  aa
# Target==  ay nagtrabaho ko' sa kuan sa factory
# 	Ans =>  awowowtnw-c
# Target==  gikuan kuno to ? gipalitan to og itlog
# 	Ans =>
# Target==  ayaw kay gutom gayod na nga alas-dusi na man
# 	Ans =>  ax
# Target==  ma-level ba diay nako' nga sumbagay lang
# 	Ans =>
# Target==  sa akua diay dili' madunggan nimo
# 	Ans =>
# Target==  na sa bata'
# 	Ans =>
# Target==  asa mo dapit gasuroy-suroy
# 	Ans =>
# Target==  pariha ana' oscar ana' ba
# 	Ans =>  aa
# Target==  o adtuon lang nako' si jed
# 	Ans =>
# Target==  lech- litson na baboy
# 	Ans =>  apfc
# Target==  sa kuan lang kana' nga mga makaagi ko' og simbahan
# 	Ans =>  o
# Target==  girl manglaag kita' ila shirla sunod ba
# 	Ans =>  ddda
# Target==  o mmm
# 	Ans =>  as'
# Target==  uyabon uyab-uyab na man daw kuno
# 	Ans =>  a
# Target==  kato nga nabahaan ato' nga una ba
# 	Ans =>  vv'ytzh
# Target==  o ngano nalagot man ka ni ? o
# 	Ans =>  vnv?vh
# Target==  sa february mag-lima siya kabulan
# 	Ans =>  b?
# Target==  musalig og kana' nga mga ingon ana' oy maningkamot ako' oy mangita' ko' og paagi kay lisod kaayo man gayod na ang
# 	Ans =>  aag
# Target==  manok uniya' kaha iya elot unsa
# 	Ans =>  sa
# Target==  og mas tigulang ko' sa imuha ba ?
# 	Ans =>
# Target==  lisod kana' ang bungol ba bungol baya' ko'
# 	Ans =>
# Target==  si ?
# 	Ans =>  i?j
# Target==  o i-announce
# 	Ans =>  d
# Target==  kay malipong man kaha' siya ?
# 	Ans =>  ?a?
# Target==  o wala' ? hinuon wala' man hinuon
# 	Ans =>  a
# Target==  bitaw day tama' gayod ka day
# 	Ans =>  va
# Target==  dinhi man gayod mi mabuhi' bay
# 	Ans =>  aaa
# Target==  ? wala' diay giapas ni alex
# 	Ans =>
# Target==  wala' ing tarong og iskuwila sigi lang og climb-climb na
# 	Ans =>
# Target==  usa lay nagdungan nimo dong
# 	Ans =>  zlzl
# Target==  naako' wala' oy luuya oy
# 	Ans =>  a
# Target==  hapit na alas-dusi padulong siya duty ron
# 	Ans =>  ka
# Target==  uniya' mama nimo nakauli' na
# 	Ans =>  kaaz-aaa
# Target==  mao na nga ukasiyon na man libri gayod
# 	Ans =>  i
# Target==  dili' pod tama' tama' lang
# 	Ans =>
# Target==  guwapo man pod na ingon ana' salo-salo tanan mga
# 	Ans =>  aoauf_fan'j_c
# Target==  naa diay ka ing exam karon sayo man lagi
# 	Ans =>  a
# Target==  kana' nga dili' na siya magpalakas og kaon diay ti
# 	Ans =>  av
# Target==  unsa man nga naa man kay klasi inig gawas nimo sa klasi
# 	Ans =>
# 0 33.8903579712 355.284118652
# 10 -0.630944848061 438.683410645
# 20 170.498199463 351.75
# 30 -81.1509475708 388.747619629
# 40 53.4935188293 388.175323486
# 50 121.83769989 415.312347412
# 60 132.301071167 412.074707031
# 70 11.5530767441 364.083831787
# 80 19.781835556 386.360870361
# 90 38.3531684875 330.252990723
#
# ===============================
# epoch 12 : pseudo= 62.670836282, cost= 408.023646201, previous_cost= 401.745870283, train_time = 1309.16179609 s
# 4
# 			 val_= 0.962519986879, test_time  = 1.77511501312 s
# ===============================
#
# Target==  sila vannie okay man na kay mga taba' man
# 	Ans =>  qalqlts
# Target==  pangit man na ang rain or shine hinay kaayo na oy
# 	Ans =>  aa
# Target==  mura lagi og dili' ikaw ?
# 	Ans =>
# Target==  no nagkauyab man diay mo ato' niya no
# 	Ans =>  v
# Target==  o karon na anhi lang diri
# 	Ans =>  nk
# Target==  taod-taod taod-taod na sad
# 	Ans =>  xx
# Target==  ay sigi man musulti man siya sa akua piro wala' ko' kita' sa lalaki giingnan nako' ayaw sa paadtua og balay
# 	Ans =>   zkt-aat_kakkuk
# Target==  cook nako' dinha' mag-cook puwidi mag-cook nako' dinha'
# 	Ans =>  ibd
# Target==  o kato lang siya one three
# 	Ans =>  a
# Target==  ting-break time ? ? ting-break time
# 	Ans =>  ap
# Target==  mao lagi siguro sa kuan putol-putol
# 	Ans =>  abb
# Target==  uniya' kumusta man imo nga pa check-up balik nay
# 	Ans =>
# Target==  useless lang gihapon imo nga sigi ka og pangutana sa akua
# 	Ans =>
# Target==  wal- wal- wala' diay bugas
# 	Ans =>  vk
# Target==  ? kana' nga mga uso karon
# 	Ans =>  amm
# Target==  oh wala' ing signal amo' nga bukid ?
# 	Ans =>
# Target==  o para ?
# 	Ans =>
# Target==  wala' pa wala' pa
# 	Ans =>
# Target==  si neneng og si sweetie ra man to
# 	Ans =>  nn
# Target==  dako' na na nga panalangin sa ginuo
# 	Ans =>  v?a
# Target==  ? age does not matter bitaw na ati
# 	Ans =>
# Target==  maayo og madayon maayo og dili'
# 	Ans =>
# Target==  namaligiya' man si caloy diri oh halos kami tanan namalit
# 	Ans =>  a
# Target==  dondie naunsa diay si dondie diay
# 	Ans =>  ra-
# Target==  prak- ? prak- ha
# 	Ans =>  a
# Target==  maayo unta' og kumplito to nga ?
# 	Ans =>  -a
# Target==  layas ? layas ni nga bataa ni bisan
# 	Ans =>
# Target==  mao ana' man gayod kana' dili' na man gayod kana' ma-control tir
# 	Ans =>  a
# Target==  na-addict na kaayo si doogie ba o
# 	Ans =>
# Target==  basi og imo nga suwirti naa sa lain wala' dinha'
# 	Ans =>  a al
# Target==  duol pa gayod ka sa mga bata' nimo imo nga mga anak
# 	Ans =>
# Target==  o bag-o ato' dili' ka ? tsoy ato'
# 	Ans =>  gg
# Target==  thursday ba huwibis
# 	Ans =>  a
# Target==  pagkadako' sa pabo oy mura man og kabaw
# 	Ans =>
# Target==  wala' pa ing valid i_d si papa
# 	Ans =>
# Target==  last year pabuto man kadto last year
# 	Ans =>
# Target==  hala no luuya gayod niya gayod
# 	Ans =>
# Target==  ? unsa iya nga course kurso
# 	Ans =>  da
# Target==  ? magbaktas ? duol ra man pod
# 	Ans =>  a-
# Target==  ha ?
# 	Ans =>
# 0 161.02897644 406.779418945
# 10 74.560295105 424.100036621
# 20 0.480993658304 327.754455566
# 30 -50.7087554932 354.389343262
# 40 0.772760033607 353.643493652
# 50 106.666893005 460.578369141
# 60 184.347137451 419.140136719
# 70 5.40927457809 308.062988281
# 80 123.624084473 376.738586426
# 90 48.3771247864 395.989685059
#
# ===============================
# epoch 13 : pseudo= 65.9692847758, cost= 394.613176571, previous_cost= 408.023646201, train_time = 1308.39492607 s
# 4
# 			 val_= 0.965613735664, test_time  = 1.77833890915 s
# ===============================
#
# Target==  bumble bee ? sa ato' pa ? gayod diay ka
# 	Ans =>  br
# Target==  nindot na kadto imo nga kuan sa una
# 	Ans =>  -
# Target==  piro kad- kadali' ra man to nga si ati mildred
# 	Ans =>
# Target==  ? gahapon nakakuwarta kagahapon
# 	Ans =>
# Target==  ? wala' ra ba kay budget
# 	Ans =>
# Target==  ang tulo kakuan traha
# 	Ans =>  n
# Target==  nagtrabaho davao light
# 	Ans =>
# Target==  mao lagi ba unsa nga urasa muabot diay
# 	Ans =>  a
# Target==  ? ako' pod mupalit pod ko' og gatas sa ako' nga anak diri
# 	Ans =>  ci
# Target==  unsa man ila nga gidula' ?
# 	Ans =>  aggvm
# Target==  kuyawa gayod pila ang ?
# 	Ans =>  v
# Target==  ipalihog ko' ingon nga
# 	Ans =>
# Target==  ? sigi siya suroy-suroy
# 	Ans =>
# Target==  kuyawa no paspasa pod nila manganak no ?
# 	Ans =>  h
# Target==  ? ? unsa man nawala' man nadawat
# 	Ans =>  ra?alalala
# Target==  ? uniya'
# 	Ans =>
# Target==  piro wala' na ka miadto
# 	Ans =>
# Target==  bala kaayo ka maunahan gani' ka gani'
# 	Ans =>  sa
# Target==  ? mao gayod na
# 	Ans =>
# Target==  kay daghan man gayod kaayo sila mama gayod dira'
# 	Ans =>
# Target==  arkilaha ?
# 	Ans =>  gcgzgsxd
# Target==  o asa man siya nag-iskuwila karon
# 	Ans =>  a mlmumla'u
# Target==  uniya' wala'-wala' wala' mo ing video ato' nga
# 	Ans =>  a
# Target==  kuyog piro ? hapon na lagi kaayo maayo man to nga nakuha kadto ganiha kay
# 	Ans =>  pp u
# Target==  ? nangita' ta og kana' nga maayo unsa ing unsa og grasiya uniya' sa ginuo ba
# 	Ans =>  aa-
# Target==  ? usa na man lang ? mao diay wala' na lang
# 	Ans =>  aa
# Target==  blue uniya' blue ra pod ako' nga
# 	Ans =>
# Target==  o trisi
# 	Ans =>  aakk
# Target==  mapundasiyunan ang kuan
# 	Ans =>  z
# Target==  magsakit-sakit biya' ni sarah og si janmar
# 	Ans =>
# Target==  o ngano diay muuban ka
# 	Ans =>
# Target==  ? ka didto sigi ra og tindog
# 	Ans =>
# Target==  ay usahay lang dili' man pod siya ingon nga dalo' piro
# 	Ans =>  a
# Target==  uniya' kanus-a man to muuli' imo nga bana
# 	Ans =>  t
# Target==  ? si luke ? wala' na man siya ing ? wala' na man
# 	Ans =>  ag
# Target==  ikaw kumusta na man mo sa imo nga uyab
# 	Ans =>
# Target==  sa una mao man unta' to ang plano namo' sa una
# 	Ans =>
# Target==  ? sunod ini og magkita' ta ?
# 	Ans =>
# Target==  og wala' nawala' ? abi nako' og wala' pa
# 	Ans =>  n
# Target==  o tabang ? kadto nga ? sa bohol ba
# 	Ans =>  az
# 0 57.5162124634 368.120483398
# 10 42.6677207947 402.629547119
# 20 46.2517051697 382.673095703
# 30 -20.9124279022 353.714508057
# 40 56.421169281 341.440612793
# 50 42.2875442505 441.357727051
# 60 182.644439697 413.034667969
# 70 131.099777222 370.070465088
# 80 89.5410461426 341.553497314
# 90 7.34693622589 324.314056396
#
# ===============================
# epoch 14 : pseudo= 99.9652254146, cost= 411.937701482, previous_cost= 394.613176571, train_time = 1310.17690611 s
# 4
# 			 val_= 0.975208402292, test_time  = 1.77631998062 s
# ===============================
#
# Target==  uo didto uo uo kadto bitaw tribute ba to
# 	Ans =>  q
# Target==  ? college level man pod ?
# 	Ans =>  znpn
# Target==  ambot oy tapos kuan
# 	Ans =>  d'vcgv
# Target==  si manilyn kana' iya nga damit ihat- ihatod
# 	Ans =>
# Target==  kay manayaw mga bata' ?
# 	Ans =>  aa
# Target==  na nga nag siyagit-siyagit
# 	Ans =>
# Target==  ? ? basta ang suman ha ? og naa mabilin bigiyan mo gayod ko'
# 	Ans =>  allllalas e
# Target==  ay okay lang okay lang gihapon
# 	Ans =>  k
# Target==  sila nanti naana' sila nga nanti naana'
# 	Ans =>  d
# Target==  mmm kanus-a man kadto mangha-
# 	Ans =>  ag
# Target==  ? ?
# 	Ans =>  a
# Target==  didto siya na assign sa una mao nga didto gani' mi nagkita'
# 	Ans =>
# Target==  gahapon unsa diay ?
# 	Ans =>  paa
# Target==  naa ing gamay naa sa ing buhat sakto ra naa ra ing kuan gayod
# 	Ans =>  a
# Target==  ? basta maayo lang nga pagkatrabaho basta dili' lang ingon nga
# 	Ans =>  gna
# Target==  ay commercial ipaganda o ipaganda
# 	Ans =>  a
# Target==  tigtubig boy lang ta sa ilaha
# 	Ans =>  kxkb zksarl
# Target==  mawala'-wala' lagi ka dili' kaayo ta ka madungog
# 	Ans =>  mi
# Target==  ? lagi impas na akua piro ang prublima diri ko' nga ma-flat-an mahurot sa hantakan tanan ?
# 	Ans =>  ac?
# Target==  natingala gani' siya nga duha ra daw kabulan kapin
# 	Ans =>  a
# Target==  dalan lang tika dalan tika
# 	Ans =>  ad
# Target==  ay gibalita' na pod diay naana' pod bagiyo
# 	Ans =>
# Target==  anhi lang diri ini og human nimo og panglaba
# 	Ans =>
# Target==  naana' la ?
# 	Ans =>
# Target==  laa- mukuan sala' gani' to sila musimba
# 	Ans =>
# Target==  aw o si lenny ang kauban niya si kuan maricris
# 	Ans =>
# Target==  ? lisod na ang ingon miana' mok
# 	Ans =>  g
# Target==  mmm ana' gayod kana' mari gayod kinahanglan
# 	Ans =>  xkz'kk
# Target==  ? didto sa ingon nila nga guadalupe unsa kadto nga lugara kadto
# 	Ans =>   a
# Target==  iskuwila tanan o humana ang uban
# 	Ans =>  ??
# Target==  o ato' ra man gihapon na ba inig
# 	Ans =>
# Target==  ? daghan og dalhon tika
# 	Ans =>  xaoa
# Target==  wala' ing signal amo' nga bukid ? bukid
# 	Ans =>
# Target==  pait kaayo amo' nga kinabuhi' ingon ana' ra oy motor-motor pait kaayo
# 	Ans =>
# Target==  sapatos bag-o nga sapatos alangan dili' ka magsapatos
# 	Ans =>
# Target==  oh oh oh dinha' gayod
# 	Ans =>  sosaban
# Target==  uo mag-propose nako' sa imo hapit na
# 	Ans =>
# Target==  three years lang baya' sila didto
# 	Ans =>  ad
# Target==  diri sa kuan gayod sa may iskuwilahan duol banda
# 	Ans =>  xp
# Target==  pila na may anak nimo karon
# 	Ans =>  aer
# 0 192.379440308 501.497375488
# 10 76.8099594116 394.712768555
# 20 153.107177734 434.580810547
# 30 7.18175363541 385.687072754
# 40 49.1121826172 328.356536865
# 50 17.9837532043 410.870758057
# 60 141.073287964 396.10748291
# 70 41.1092796326 399.175415039
# 80 56.4391441345 369.546813965
# 90 -3.66716623306 340.623535156
#
# ===============================
# epoch 15 : pseudo= 96.7668650086, cost= 404.615863759, previous_cost= 411.937701482, train_time = 1309.60871506 s
# 4
# 			 val_= 0.973727320206, test_time  = 1.75074601173 s
# ===============================
#
# Target==  mikalit man gayod kadto nga nga naa ing talk uniya' kuan pod ba kana' nga ?
# 	Ans =>  a
# Target==  ay nagtrabaho ko' sa kuan sa factory
# 	Ans =>  n
# Target==  gikuan kuno to ? gipalitan to og itlog
# 	Ans =>  a
# Target==  ayaw kay gutom gayod na nga alas-dusi na man
# 	Ans =>
# Target==  ma-level ba diay nako' nga sumbagay lang
# 	Ans =>
# Target==  sa akua diay dili' madunggan nimo
# 	Ans =>
# Target==  na sa bata'
# 	Ans =>
# Target==  asa mo dapit gasuroy-suroy
# 	Ans =>  a
# Target==  pariha ana' oscar ana' ba
# 	Ans =>  aan
# Target==  o adtuon lang nako' si jed
# 	Ans =>
# Target==  lech- litson na baboy
# 	Ans =>  a'p
# Target==  sa kuan lang kana' nga mga makaagi ko' og simbahan
# 	Ans =>  aa
# Target==  girl manglaag kita' ila shirla sunod ba
# 	Ans =>  v
# Target==  o mmm
# 	Ans =>  walvtltltlv
# Target==  uyabon uyab-uyab na man daw kuno
# 	Ans =>
# Target==  kato nga nabahaan ato' nga una ba
# 	Ans =>  vttz
# Target==  o ngano nalagot man ka ni ? o
# 	Ans =>
# Target==  sa february mag-lima siya kabulan
# 	Ans =>
# ...
# 	Ans =>
# Target==  iskuwila tanan o humana ang uban
# 	Ans =>
# Target==  o ato' ra man gihapon na ba inig
# 	Ans =>
# Target==  ? daghan og dalhon tika
# 	Ans =>  a
# Target==  wala' ing signal amo' nga bukid ? bukid
# 	Ans =>
# Target==  pait kaayo amo' nga kinabuhi' ingon ana' ra oy motor-motor pait kaayo
# 	Ans =>
# Target==  sapatos bag-o nga sapatos alangan dili' ka magsapatos
# 	Ans =>
# Target==  oh oh oh dinha' gayod
# 	Ans =>  nhn
# Target==  uo mag-propose nako' sa imo hapit na
# 	Ans =>
# Target==  three years lang baya' sila didto
# 	Ans =>  'ki
# Target==  diri sa kuan gayod sa may iskuwilahan duol banda
# 	Ans =>
# Target==  pila na may anak nimo karon
# 	Ans =>
# 0 31.9603881836 141.267181396
# 10 82.5294876099 170.156448364
# 20 62.0981216431 161.04447937
# 30 34.9555168152 152.939544678
# 40 49.4574890137 130.981262207
# 50 39.9413261414 146.21534729
# 60 20.947057724 152.356048584
# 70 33.3806877136 135.342300415
# 80 16.5227241516 119.734329224
# 90 30.4838809967 128.841491699
#
# ===============================
# epoch 95 : pseudo= 39.469946246, cost= 142.7046453, previous_cost= 143.227705597, train_time = 1337.81600285 s
# 4
# 			 val_= 0.988648388715, test_time  = 1.9139559269 s
# ===============================
#
# Target==  mikalit man gayod kadto nga nga naa ing talk uniya' kuan pod ba kana' nga ?
# 	Ans =>
# Target==  ay nagtrabaho ko' sa kuan sa factory
# 	Ans =>
# Target==  gikuan kuno to ? gipalitan to og itlog
# 	Ans =>  a
# Target==  ayaw kay gutom gayod na nga alas-dusi na man
# 	Ans =>  r
# Target==  ma-level ba diay nako' nga sumbagay lang
# 	Ans =>
# Target==  sa akua diay dili' madunggan nimo
# 	Ans =>  i''
# Target==  na sa bata'
# 	Ans =>
# Target==  asa mo dapit gasuroy-suroy
# 	Ans =>
# Target==  pariha ana' oscar ana' ba
# 	Ans =>
# Target==  o adtuon lang nako' si jed
# 	Ans =>
# Target==  lech- litson na baboy
# 	Ans =>
# Target==  sa kuan lang kana' nga mga makaagi ko' og simbahan
# 	Ans =>  ana
# Target==  girl manglaag kita' ila shirla sunod ba
# 	Ans =>
# Target==  o mmm
# 	Ans =>
# Target==  uyabon uyab-uyab na man daw kuno
# 	Ans =>
# Target==  kato nga nabahaan ato' nga una ba
# 	Ans =>
# Target==  o ngano nalagot man ka ni ? o
# 	Ans =>
# Target==  sa february mag-lima siya kabulan
# 	Ans =>
# Target==  musalig og kana' nga mga ingon ana' oy maningkamot ako' oy mangita' ko' og paagi kay lisod kaayo man gayod na ang
# 	Ans =>
# Target==  manok uniya' kaha iya elot unsa
# 	Ans =>
# Target==  og mas tigulang ko' sa imuha ba ?
# 	Ans =>
# Target==  lisod kana' ang bungol ba bungol baya' ko'
# 	Ans =>
# Target==  si ?
# 	Ans =>
# Target==  o i-announce
# 	Ans =>  iai
# Target==  kay malipong man kaha' siya ?
# 	Ans =>
# Target==  o wala' ? hinuon wala' man hinuon
# 	Ans =>
# Target==  bitaw day tama' gayod ka day
# 	Ans =>
# Target==  dinhi man gayod mi mabuhi' bay
# 	Ans =>
# Target==  ? wala' diay giapas ni alex
# 	Ans =>
# Target==  wala' ing tarong og iskuwila sigi lang og climb-climb na
# 	Ans =>
# Target==  usa lay nagdungan nimo dong
# 	Ans =>
# Target==  naako' wala' oy luuya oy
# 	Ans =>
# Target==  hapit na alas-dusi padulong siya duty ron
# 	Ans =>
# Target==  uniya' mama nimo nakauli' na
# 	Ans =>  apyy
# Target==  mao na nga ukasiyon na man libri gayod
# 	Ans =>
# Target==  dili' pod tama' tama' lang
# 	Ans =>
# Target==  guwapo man pod na ingon ana' salo-salo tanan mga
# 	Ans =>
# Target==  naa diay ka ing exam karon sayo man lagi
# 	Ans =>  l
# Target==  kana' nga dili' na siya magpalakas og kaon diay ti
# 	Ans =>
# Target==  unsa man nga naa man kay klasi inig gawas nimo sa klasi
# 	Ans =>  sss
# 0 27.4135742188 134.410842896
# 10 34.089466095 175.302001953
# 20 55.1681594849 155.685058594
# 30 22.7523212433 149.265472412
# 40 36.4488563538 128.657958984
# 50 53.2569236755 146.344161987
# 60 22.8376636505 144.298309326
# 70 8.85072040558 137.158355713
# 80 27.3459758759 125.091529846
# 90 11.8953475952 126.640670776
#
# ===============================
# epoch 96 : pseudo= 32.8321402739, cost= 139.200577603, previous_cost= 142.7046453, train_time = 1382.64783382 s
# 4
# 			 val_= 0.990688876659, test_time  = 1.97187280655 s
# ===============================
#
# Target==  sila vannie okay man na kay mga taba' man
# 	Ans =>
# Target==  pangit man na ang rain or shine hinay kaayo na oy
# 	Ans =>
# Target==  mura lagi og dili' ikaw ?
# 	Ans =>
# Target==  no nagkauyab man diay mo ato' niya no
# 	Ans =>
# Target==  o karon na anhi lang diri
# 	Ans =>
# Target==  taod-taod taod-taod na sad
# 	Ans =>  a
# Target==  ay sigi man musulti man siya sa akua piro wala' ko' kita' sa lalaki giingnan nako' ayaw sa paadtua og balay
# 	Ans =>
# Target==  cook nako' dinha' mag-cook puwidi mag-cook nako' dinha'
# 	Ans =>
# Target==  o kato lang siya one three
# 	Ans =>
# Target==  ting-break time ? ? ting-break time
# 	Ans =>  ka
# Target==  mao lagi siguro sa kuan putol-putol
# 	Ans =>
# Target==  uniya' kumusta man imo nga pa check-up balik nay
# 	Ans =>  aa
# Target==  useless lang gihapon imo nga sigi ka og pangutana sa akua
# 	Ans =>
# Target==  wal- wal- wala' diay bugas
# 	Ans =>
# Target==  ? kana' nga mga uso karon
# 	Ans =>
# Target==  oh wala' ing signal amo' nga bukid ?
# 	Ans =>
# Target==  o para ?
# 	Ans =>  ii
# Target==  wala' pa wala' pa
# 	Ans =>
# Target==  si neneng og si sweetie ra man to
# 	Ans =>     s
# Target==  dako' na na nga panalangin sa ginuo
# 	Ans =>
# Target==  ? age does not matter bitaw na ati
# 	Ans =>
# Target==  maayo og madayon maayo og dili'
# 	Ans =>
# Target==  namaligiya' man si caloy diri oh halos kami tanan namalit
# 	Ans =>
# Target==  dondie naunsa diay si dondie diay
# 	Ans =>
# Target==  prak- ? prak- ha
# 	Ans =>  a
# Target==  maayo unta' og kumplito to nga ?
# 	Ans =>
# Target==  layas ? layas ni nga bataa ni bisan
# 	Ans =>  n
# Target==  mao ana' man gayod kana' dili' na man gayod kana' ma-control tir
# 	Ans =>
# Target==  na-addict na kaayo si doogie ba o
# 	Ans =>
# Target==  basi og imo nga suwirti naa sa lain wala' dinha'
# 	Ans =>
# Target==  duol pa gayod ka sa mga bata' nimo imo nga mga anak
# 	Ans =>
# Target==  o bag-o ato' dili' ka ? tsoy ato'
# 	Ans =>
# Target==  thursday ba huwibis
# 	Ans =>
# Target==  pagkadako' sa pabo oy mura man og kabaw
# 	Ans =>
# Target==  wala' pa ing valid i_d si papa
# 	Ans =>
# Target==  last year pabuto man kadto last year
# 	Ans =>
# Target==  hala no luuya gayod niya gayod
# 	Ans =>
# Target==  ? unsa iya nga course kurso
# 	Ans =>
# Target==  ? magbaktas ? duol ra man pod
# 	Ans =>
# Target==  ha ?
# 	Ans =>
# 0 12.333899498 133.783294678
# 10 69.8180770874 168.694122314
# 20 64.4616775513 157.587188721
# 30 32.2750854492 141.941894531
# 40 27.0679683685 125.874191284
# 50 32.1804199219 149.62701416
# 60 13.4629974365 139.27255249
# 70 10.2979297638 128.774368286
# 80 13.6493930817 119.552078247
# 90 13.3211898804 128.961227417
#
# ===============================
# epoch 97 : pseudo= 33.8517993592, cost= 137.80420734, previous_cost= 139.200577603, train_time = 1401.35314298 s
# 4
# 			 val_= 0.990076043018, test_time  = 1.89661002159 s
# ===============================
#
# Target==  bumble bee ? sa ato' pa ? gayod diay ka
# 	Ans =>
# Target==  nindot na kadto imo nga kuan sa una
# 	Ans =>
# Target==  piro kad- kadali' ra man to nga si ati mildred
# 	Ans =>
# Target==  ? gahapon nakakuwarta kagahapon
# 	Ans =>
# Target==  ? wala' ra ba kay budget
# 	Ans =>
# Target==  ang tulo kakuan traha
# 	Ans =>  la
# Target==  nagtrabaho davao light
# 	Ans =>
# Target==  mao lagi ba unsa nga urasa muabot diay
# 	Ans =>
# Target==  ? ako' pod mupalit pod ko' og gatas sa ako' nga anak diri
# 	Ans =>
# Target==  unsa man ila nga gidula' ?
# 	Ans =>
# Target==  kuyawa gayod pila ang ?
# 	Ans =>
# Target==  ipalihog ko' ingon nga
# 	Ans =>
# Target==  ? sigi siya suroy-suroy
# 	Ans =>
# Target==  kuyawa no paspasa pod nila manganak no ?
# 	Ans =>
# Target==  ? ? unsa man nawala' man nadawat
# 	Ans =>
# Target==  ? uniya'
# 	Ans =>
# Target==  piro wala' na ka miadto
# 	Ans =>
# Target==  bala kaayo ka maunahan gani' ka gani'
# 	Ans =>
# Target==  ? mao gayod na
# 	Ans =>
# Target==  kay daghan man gayod kaayo sila mama gayod dira'
# 	Ans =>
# Target==  arkilaha ?
# 	Ans =>
# Target==  o asa man siya nag-iskuwila karon
# 	Ans =>
# Target==  uniya' wala'-wala' wala' mo ing video ato' nga
# 	Ans =>
# Target==  kuyog piro ? hapon na lagi kaayo maayo man to nga nakuha kadto ganiha kay
# 	Ans =>
# Target==  ? nangita' ta og kana' nga maayo unsa ing unsa og grasiya uniya' sa ginuo ba
# 	Ans =>
# Target==  ? usa na man lang ? mao diay wala' na lang
# 	Ans =>
# Target==  blue uniya' blue ra pod ako' nga
# 	Ans =>
# Target==  o trisi
# 	Ans =>
# Target==  mapundasiyunan ang kuan
# 	Ans =>
# Target==  magsakit-sakit biya' ni sarah og si janmar
# 	Ans =>
# Target==  o ngano diay muuban ka
# 	Ans =>
# Target==  ? ka didto sigi ra og tindog
# 	Ans =>
# Target==  ay usahay lang dili' man pod siya ingon nga dalo' piro
# 	Ans =>
# Target==  uniya' kanus-a man to muuli' imo nga bana
# 	Ans =>
# Target==  ? si luke ? wala' na man siya ing ? wala' na man
# 	Ans =>
# Target==  ikaw kumusta na man mo sa imo nga uyab
# 	Ans =>
# Target==  sa una mao man unta' to ang plano namo' sa una
# 	Ans =>
# Target==  ? sunod ini og magkita' ta ?
# 	Ans =>
# Target==  og wala' nawala' ? abi nako' og wala' pa
# 	Ans =>   aw
# Target==  o tabang ? kadto nga ? sa bohol ba
# 	Ans =>
# 0 21.4707355499 131.986755371
# 10 72.2306671143 154.439971924
# 20 44.834690094 150.0572052
# 30 25.3181552887 137.178924561
# 40 32.6793937683 119.690917969
# 50 11.0482730865 147.414825439
# 60 10.5967502594 134.150054932
# 70 30.0049171448 130.860992432
# 80 22.6817722321 120.37701416
# 90 13.3476991653 132.506286621
#
# ===============================
# epoch 98 : pseudo= 31.1193194274, cost= 134.540812257, previous_cost= 137.80420734, train_time = 1380.76140213 s
# 4
# 			 val_= 0.989715384003, test_time  = 1.89386701584 s
# ===============================
#
# Target==  uo didto uo uo kadto bitaw tribute ba to
# 	Ans =>
# Target==  ? college level man pod ?
# 	Ans =>  ki d diairy
# Target==  ambot oy tapos kuan
# 	Ans =>
# Target==  si manilyn kana' iya nga damit ihat- ihatod
# 	Ans =>
# Target==  kay manayaw mga bata' ?
# 	Ans =>
# Target==  na nga nag siyagit-siyagit
# 	Ans =>
# Target==  ? ? basta ang suman ha ? og naa mabilin bigiyan mo gayod ko'
# 	Ans =>
# Target==  ay okay lang okay lang gihapon
# 	Ans =>
# Target==  sila nanti naana' sila nga nanti naana'
# 	Ans =>
# Target==  mmm kanus-a man kadto mangha-
# 	Ans =>  m
# Target==  ? ?
# 	Ans =>
# Target==  didto siya na assign sa una mao nga didto gani' mi nagkita'
# 	Ans =>
# Target==  gahapon unsa diay ?
# 	Ans =>
# Target==  naa ing gamay naa sa ing buhat sakto ra naa ra ing kuan gayod
# 	Ans =>  tt'
# Target==  ? basta maayo lang nga pagkatrabaho basta dili' lang ingon nga
# 	Ans =>  a
# Target==  ay commercial ipaganda o ipaganda
# 	Ans =>
# Target==  tigtubig boy lang ta sa ilaha
# 	Ans =>  yiyi
# Target==  mawala'-wala' lagi ka dili' kaayo ta ka madungog
# 	Ans =>
# Target==  ? lagi impas na akua piro ang prublima diri ko' nga ma-flat-an mahurot sa hantakan tanan ?
# 	Ans =>
# Target==  natingala gani' siya nga duha ra daw kabulan kapin
# 	Ans =>
# Target==  dalan lang tika dalan tika
# 	Ans =>
# Target==  ay gibalita' na pod diay naana' pod bagiyo
# 	Ans =>
# Target==  anhi lang diri ini og human nimo og panglaba
# 	Ans =>
# Target==  naana' la ?
# 	Ans =>  aa
# Target==  laa- mukuan sala' gani' to sila musimba
# 	Ans =>  om
# Target==  aw o si lenny ang kauban niya si kuan maricris
# 	Ans =>
# Target==  ? lisod na ang ingon miana' mok
# 	Ans =>
# Target==  mmm ana' gayod kana' mari gayod kinahanglan
# 	Ans =>
# Target==  ? didto sa ingon nila nga guadalupe unsa kadto nga lugara kadto
# 	Ans =>
# Target==  iskuwila tanan o humana ang uban
# 	Ans =>  'nao
# Target==  o ato' ra man gihapon na ba inig
# 	Ans =>
# Target==  ? daghan og dalhon tika
# 	Ans =>
# Target==  wala' ing signal amo' nga bukid ? bukid
# 	Ans =>
# Target==  pait kaayo amo' nga kinabuhi' ingon ana' ra oy motor-motor pait kaayo
# 	Ans =>
# Target==  sapatos bag-o nga sapatos alangan dili' ka magsapatos
# 	Ans =>
# Target==  oh oh oh dinha' gayod
# 	Ans =>
# Target==  uo mag-propose nako' sa imo hapit na
# 	Ans =>
# Target==  three years lang baya' sila didto
# 	Ans =>
# Target==  diri sa kuan gayod sa may iskuwilahan duol banda
# 	Ans =>
# Target==  pila na may anak nimo karon
# 	Ans =>  a
# 0 16.2209148407 136.274810791
# 10 50.471282959 153.339141846
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-c882fe8aa1ac> in <module>()
# ----> 1 get_ipython().magic(u'time model3L_Noise_with313.fit( x_train, y_train, x_valid, y_valid, x_train_mask, y_train_mask , x_valid_mask, y_valid_mask )')
#
# /home/pika/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2302         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2303         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2304         return self.run_line_magic(magic_name, magic_arg_s)
#    2305
#    2306     #-------------------------------------------------------------------------
#
# /home/pika/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2223                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2224             with self.builtin_trap:
# -> 2225                 result = fn(*args,**kwargs)
#    2226             return result
#    2227
#
# /home/pika/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#
# /home/pika/anaconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /home/pika/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1160         if mode=='eval':
#    1161             st = clock2()
# -> 1162             out = eval(code, glob, local_ns)
#    1163             end = clock2()
#    1164         else:
#
# <timed eval> in <module>()
#
# <ipython-input-9-758523ae8796> in fit(self, x_train, y_train, x_test, y_test, x_mask, y_mask, x_test_mask, y_test_mask)
#     156             for index in range(len(x_train)):
#     157                 pseudo, cost, output_softmax = self.train( x_train[index] , y_train[index],
# --> 158                                                           x_mask[index], y_mask[index])
#     159                 cs += cost
#     160                 pseudo_cs += pseudo
#
# /home/pika/anaconda/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     595         t0_fn = time.time()
#     596         try:
# --> 597             outputs = self.fn()
#     598         except Exception:
#     599             if hasattr(self.fn, 'position_of_error'):
#
# /home/pika/anaconda/lib/python2.7/site-packages/theano/scan_module/scan_op.pyc in rval(p, i, o, n, allow_gc)
#     670         def rval(p=p, i=node_input_storage, o=node_output_storage, n=node,
#     671                  allow_gc=allow_gc):
# --> 672             r = p(n, [x[0] for x in i], o)
#     673             for o in node.outputs:
#     674                 compute_map[o][0] = True
#
# /home/pika/anaconda/lib/python2.7/site-packages/theano/scan_module/scan_op.pyc in <lambda>(node, args, outs)
#     659                         args,
#     660                         outs,
# --> 661                         self, node)
#     662         except (ImportError, theano.gof.cmodule.MissingGXX):
#     663             p = self.execute
#
# scan_perform.pyx in theano.scan_module.scan_perform.perform (/home/pika/.theano/compiledir_Linux-3.13--generic-x86_64-with-debian-jessie-sid-x86_64-2.7.9-64/scan_perform/mod.cpp:3537)()
#
# /home/pika/anaconda/lib/python2.7/site-packages/theano/gof/op.pyc in rval(p, i, o, n)
#     765         if ctx is graph.NoContext:
#     766             # default arguments are stored in the closure of `rval`
# --> 767             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
#     768                 r = p(n, [x[0] for x in i], o)
#     769                 for o in node.outputs:
#
# KeyboardInterrupt:

# %%
＃ Not used below

# %% [markdown]
# # Only Process once

# %%
''' 
[ Doing : ]
    - Read character from *.txt to build the corpus 

[ Result : ]

-- Without Develope Data:

Building corpus without develope data:
set([' ', "'", '-', '?', '_', 'a', 'c', 'b', 'e', 'd', 'g', 'f', 'i', 'h', 'k', 'j', 'm', 'l', 'o', 'n', 'q', 'p', 's', 'r', 'u', 't', 'w', 'v', 'y', 'x', 'z'])
Total len is : 31
Done Write to [./dataCebuano/corpus.txt]

-- With Develope Data:

Building corpus with develope data:
set([' ', "'", ')', '(', '-', '?', '_', 'a', 'c', 'b', 'e', 'd', 'g', 'f', 'i', 'h', 'k', 'j', 'm', 'l', 'o', 'n', 'q', 'p', 's', 'r', 'u', 't', 'w', 'v', 'y', 'x', 'z'])
Total len is : 33
Done Write to [./dataCebuano/corpus.txt]
'''

TRAINING_LABEL = "./dataCebuano/train.txt"
DEVELOPE_LABEL = "./dataCebuano/dev.txt"
WRITING_TO = "./dataCebuano/corpus.txt"

# Special part to build corpus
def buildCharacterCorpus(withDevelopeData = False) :
    corpus = set( )
    with open(TRAINING_LABEL, 'r') as ft:
        for lines in ft:
            for word in lines.split('\n')[0].split(' ')[1:]:
                if word[0] == '<':
                    # We take every <...> as <unk> 
                    unKnownTag = '?'
                    corpus.add( unKnownTag ) 
                else:
                    for char in word:
                        corpus.add(char.lower())
    
    if( withDevelopeData ) :
        with open(DEVELOPE_LABEL, 'r') as fd:
            for lines in fd:
                for word in lines.split('\n')[0].split(' ')[1:]:
                    if word[0] == '<':
                        unKnownTag = '?'
                        corpus.add( unKnownTag ) 
                        # corpus.add(word.split('\n')[0].lower())
                    else:
                        for char in word:
                            corpus.add(char.lower())
    
    corpus.add(' ')
    print "Building corpus with" + ("" if withDevelopeData else "out") + " develope data:"
    print corpus
    print "Total len is : " + str(len(corpus))
    
    
    with open(WRITING_TO, 'w+') as fw:
        for item in corpus:
            fw.write(item + '\n')        
    print "Done Write to [" + WRITING_TO + "]"
    return corpus

trainingCorpus = buildCharacterCorpus()
# Out:
# Building corpus without develope data:
# set([' ', "'", '-', '?', '_', 'a', 'c', 'b', 'e', 'd', 'g', 'f', 'i', 'h', 'k', 'j', 'm', 'l', 'o', 'n', 'q', 'p', 's', 'r', 'u', 't', 'w', 'v', 'y', 'x', 'z'])
# Total len is : 31
# Done Write to [./dataCebuano/corpus.txt]

# %%
# import theano
# from theano import tensor as T
# from theano.sandbox.rng_mrg import MRG_RandomStreams as RandomStreams
import numpy as np

from sklearn import cross_validation as cv
from sklearn import metrics
from sklearn import grid_search as gs
from sklearn.metrics import accuracy_score
from itertools import repeat

#proprocessor
from sklearn import preprocessing
from time import time

from itertools import repeat
import numpy as np
import random
from sklearn import preprocessing


def floatX(X):
    return np.asarray(X, dtype=theano.config.floatX)

def vectorized_result ( j , siz) :
    e = np.zeros((siz, 1))
    e[j] = 1.0
    return np.reshape( e, siz)

TRAINING_DATA   = './dataCebuano/train.f0_ffv_fbank.fea'
# VALIDATION_DATA = './dataCebuano/dev.f0_ffv_fbank.fea'
TRAIN_ARK  = './dataCebuano/train_Normalized_SELFVALID.ark'
# TRAIN_ARK  = './dataCebuano/train_Normalized_SELFVALID_LenLessThen600.ark'


def normalizeAndFilterData ( maxLength = 3000) :
    # Dataset
    x_data = []
    x_name = []
    record_seq = []

    with open( TRAINING_DATA, 'r') as f:
        for lines in f: 
            if '[' in lines :
                id = lines.split(' ')[0]
                x_name.append(id)
                seq = 0
            elif ']' in lines :
                if seq > maxLength :
                    x_name.pop()
                    del x_data[-seq:]
                else :
                    seq += 1
                    record_seq.append(seq)
                    x_data.append([float(x) for x in lines.split(' ') [2:-1] ])
            else :
                seq += 1
                x_data.append([float(x) for x in lines.split(' ') [2:-1] ])

    print "Normalized"
    x_data = preprocessing.scale( np.array(x_data) )

    # x_data[separate+1]
    # x_name
    bitch = record_seq.index(max(record_seq))
    print "Max len is ", record_seq[bitch]
    
    print "Total training data", len(x_name)

    # trainF = open(TRAIN_ARK, 'w+')
    with open(TRAIN_ARK, 'w+') as trainF:
        currentSeq = 0
        for nameIndex in range( len(x_name) ):

            trainF.write(str(x_name[nameIndex])+"  [\n")

            for valueIndex in range( (record_seq[nameIndex]) ):
                for featureIndex in range( len(x_data[0]) ):
                    if ( featureIndex+1) != len(x_data[0] ) :
                        trainF.write( str(x_data[ currentSeq  + valueIndex][featureIndex]) + " ")
                    else:
                        trainF.write( str(x_data[ currentSeq  + valueIndex][featureIndex]) )
                if valueIndex+1 == (record_seq[nameIndex]):
                    trainF.write(" ]\n")
                else:
                    trainF.write("\n")
            currentSeq += record_seq[nameIndex]

    print "MIssion ComplEte"


normalizeAndFilterData(3000)
# Out:
# Normalized
# The Max index id  370
# Max len is  2784
# Total training data 4145
# what is x_data len 1071703
# what is x_seq len 4145
# MIssion ComplEte

# %%
# Out:
# array([[ 0.01      ,  0.002     ],
#        [ 1.20000005,  1.10000002]], dtype=float32)
