# %% [markdown]
# # CTC version 1
#
#
#
#
# ### Paper Reference
# - [Connectionist Temporal Classification (IDSIA)](ftp://ftp.idsia.ch/pub/juergen/icml2006.pdf)
#
#
# ### English Test
# First we test English

# %%
# Include And 
import sys
sys.path.append("/home/pika/nntools/")

import theano
import theano.tensor as T
import numpy as np
from theano_toolkit import utils as U
from theano_toolkit import updates
from theano.printing import Print
from theano_toolkit.parameters import Parameters

import lasagne
from lasagne.layers import *

from time import time

import ctc_cost_2

import cPickle
import sys
sys.setrecursionlimit(100000)

from random import shuffle
# Out:
# Using gpu device 0: GeForce GTX 980
# /home/pika/nntools/lasagne/init.py:86: UserWarning: The uniform initializer no longer uses Glorot et al.'s approach to determine the bounds, but defaults to the range (-0.01, 0.01) instead. Please use the new GlorotUniform initializer to get the old behavior. GlorotUniform is now the default for all layers.
#   warnings.warn("The uniform initializer no longer uses Glorot et al.'s "

# %% [markdown]
# # Data

# %%
'''
Doing : 
    - Read data and return x_train, y_train
'''
# TRAINING_ACOUSTIC_FEATURE = "./dataCebuano/train.f0_ffv_fbank.fea"
# TRAINING_ACOUSTIC_FEATURE = "./dataCebuano/train_Normalized_SELFVALID.ark"
TRAINING_ACOUSTIC_FEATURE = "./dataCebuano/train_Normalized_SELFVALID_LenLessThen500.ark"

TRAINING_LABELS = "./dataCebuano/train.txt"
CHAR_CORPUS = "./dataCebuano/corpus.txt"


def readDataSet () :
    
    # -- Mapping char to integer and reverse
    char_map = {}    # eg. { a -> 1 }
    char_unMap = {}  # eg. { 1 -> a }
    with open( CHAR_CORPUS, 'r' ) as f:
        char_index = 0
        for lines in f:
            char_map  [ lines[:-1] ] = char_index
            char_unMap[ char_index ] = lines[:-1]
            char_index += 1
        # add Blank, take '.' as blank (not space)
        char_map['.'] = char_index
        char_unMap[char_index] = '.'
    
    
    # -- Reading X = id -> [ list of feature ] 
    idMapX = {}
    idDeck = []
    id = ''
    
    tmp_l = 0;
    with open( TRAINING_ACOUSTIC_FEATURE, 'r') as f:
        for lines in f: 
            if '[' in lines :
                id = lines.split(' ')[0]
                idDeck.append(id)
                idMapX[id] = []
            elif ']' in lines :
                if( len( lines.split('\n')[0].split(' ') [0:-1] ) != 33 ) :
                    print "err"
                    return 
                idMapX[id].append([float(x) for x in lines.split('\n')[0].split(' ') [:-1] ])
            else :
                if( len( lines.split('\n')[0].split(' ')) != 33 ):
                    print len( lines.split('\n')[0].split(' '))
                    print lines.split('\n')[0].split(' ')
                    print lines
                    print id
                    print "fuck"
                    return
                idMapX[id].append([float(x) for x in lines.split('\n')[0].split(' ') ])
    
    # Move to  3 - main - 3
    
    monoDimension = 33;
    zeroFeature = [0] * monoDimension
    #print len( zeroFeature ) 
    #print zeroFeature
    for id in idDeck:
        # print id
        tmpIdMapXWithID = []
        if len(idMapX[id]) < 6 :
            print "ERROR in length"
            return 
        for idxX in xrange( len(idMapX[id]) ):
            if idxX == 0:
                tmpIdMapXWithID.append( zeroFeature + zeroFeature + zeroFeature + idMapX[id][idxX] + idMapX[id][idxX+1] + idMapX[id][idxX+2] + idMapX[id][idxX+3] )    
            elif idxX == 1:
                tmpIdMapXWithID.append( zeroFeature + zeroFeature + idMapX[id][idxX-1] + idMapX[id][idxX] + idMapX[id][idxX+1] + idMapX[id][idxX+2] + idMapX[id][idxX+3] )  
            elif idxX == 2:
                tmpIdMapXWithID.append( zeroFeature + idMapX[id][idxX-2] + idMapX[id][idxX-1] + idMapX[id][idxX] + idMapX[id][idxX+1] + idMapX[id][idxX+2] + idMapX[id][idxX+3] )  
            elif idxX == (len(idMapX[id]) - 3 ):
                tmpIdMapXWithID.append( idMapX[id][idxX-3] + idMapX[id][idxX-2] + idMapX[id][idxX-1] + idMapX[id][idxX] + idMapX[id][idxX+1] + idMapX[id][idxX+2] + zeroFeature )  
            elif idxX == (len(idMapX[id]) - 2 ):
                tmpIdMapXWithID.append( idMapX[id][idxX-3] + idMapX[id][idxX-2] + idMapX[id][idxX-1] + idMapX[id][idxX] + idMapX[id][idxX+1] + zeroFeature + zeroFeature )  
            elif idxX == (len(idMapX[id]) - 1 ):
                tmpIdMapXWithID.append( idMapX[id][idxX-3] + idMapX[id][idxX-2] + idMapX[id][idxX-1] + idMapX[id][idxX] + zeroFeature + zeroFeature + zeroFeature )  
            else:
                tmpIdMapXWithID.append( idMapX[id][idxX-3] + idMapX[id][idxX-2] + idMapX[id][idxX-1] + idMapX[id][idxX] + idMapX[id][idxX+1] + idMapX[id][idxX+2] + idMapX[id][idxX+3] )  
        idMapX[id] = tmpIdMapXWithID
    
    print "Concate"
    
    # Standardlize X (Done in PrepreProcessing )
   
    # Shuffle the speaker to slice training and validation
    totalSpeech = len(idMapX)
    slicePointFive = totalSpeech // 20
    shuffle(idDeck)
    id_train = idDeck[slicePointFive+1:]
    id_valid = idDeck[:slicePointFive]
    
    idMapY = {} 
    
    # -- Reading Y = id -> [ Sentence(list of char[int] ) ]
    with open( TRAINING_LABELS, 'r') as f:
        specific = '?'
        for lines in f:
            yWithId = lines.split('\n')[0].split(' ', 1)
            idMapY[ yWithId[0] ] = []
            judgeSpecific = False
            for char in yWithId[1] :
                if char == '<' :
                    judgeSpecific = True;                
                if( judgeSpecific ):
                    if char == '>':
                        idMapY[ yWithId[0] ].append( char_map[specific] )
                        judgeSpecific = False
                else :
                    idMapY[ yWithId[0] ].append( char_map[char] )
    
    # -- concatenate X and Y
    x_train = []
    x_valid = []
    y_train = []
    y_valid = []
    
    for id in id_train:
        concateId = []
        for i in range( len( idMapX[id] ) ) :
            concateId.append( idMapX[id][i] )
        x_train.append( floatX( concateId )  )
        y_train.append( floatX( idMapY[id]) )
        
    for id in id_valid:
        concateId = []
        for i in range( len( idMapX[id] ) ) :
            concateId.append( idMapX[id][i] )
        x_valid.append( floatX( concateId ) )
        y_valid.append( floatX( idMapY[id]) )
        
    print "Dataset Finish : "
    print "total x_train = " + str(len(x_train))
    print x_train[0]
    print "total y_train = " + str(len(y_train))
    print y_train[0]
    print "total x_valid = " + str(len(x_valid))
    print x_valid[0]
    print "total y_valid = " + str(len(y_valid))
    print y_valid[0]
    
    return char_map, char_unMap, x_train, y_train, x_valid, y_valid

def floatX(x):
    return np.asarray(x, dtype=theano.config.floatX)


char_map, char_unMap, x_train, y_train, x_valid, y_valid = readDataSet()
# Out:
# Concate
# Dataset Finish :
# total x_train = 3722
# [[ 0.          0.          0.         ...,  0.7333411   1.11533034
#   -0.71583152]
#  [ 0.          0.          0.         ..., -0.78239328  0.04649827
#   -0.97195017]
#  [ 0.          0.          0.         ...,  1.09216201  1.3399446
#   -1.1914742 ]
#  ...,
#  [ 0.22230056  0.27325568 -0.030542   ...,  0.          0.          0.        ]
#  [ 0.12296346 -0.0282144  -0.20728323 ...,  0.          0.          0.        ]
#  [ 0.54621345  0.38485798  0.35828772 ...,  0.          0.          0.        ]]
# total y_train = 3722
# [ 16.   5.  22.   0.  16.   5.   5.  28.  18.   0.  19.   5.   0.  19.  10.
#    5.   0.  19.   5.   5.   0.  12.  19.  10.   0.   5.   9.  17.   5.  26.
#    0.  14.   5.  28.  12.  22.   5.]
# total x_valid = 195
# [[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   5.06372750e-01
#     6.06346667e-01  -7.82309353e-01]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,  -4.87222642e-01
#    -1.69904798e-01   2.80898559e-04]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,  -1.37560517e-01
#     4.92138594e-01   1.01360822e+00]
#  ...,
#  [  5.27318101e-04   6.63717151e-01   4.93163854e-01 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [ -2.78016418e-01   5.88251710e-01   3.58893156e-01 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [ -5.16767800e-01   3.76005948e-01   1.12593554e-01 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]]
# total y_valid = 195
# [ 22.  12.  17.   5.   0.  27.   5.  19.  19.  12.   8.   0.  18.  14.   5.
#   28.   0.  16.   5.  19.   0.  19.   5.   0.  14.   5.  28.   0.  16.  10.
#    5.   0.  25.   5.   7.   5.   1.   0.  16.   5.  19.]

# %%
# 500 -> 3722 / 195
# 600 -> 3821 / 201
# 3000 -> 3937 / 207
x_train[0].shape
# Out:
# (195, 231)

# %%
max( [X.shape[0] for X in x_train] )
# Out:
# 501

# %%
'''
    https://github.com/craffel/lstm_benchmarks/blob/master/lasagne/experiment.py
    
    Convert a list of matrices into batches of uniform length
    :parameters:
        - X : list of np.ndarray
            List of matrices
        - length : int
            Desired sequence length.  Smaller sequences will be padded with 0s,
            longer will be truncated.
        - batch_size : int
            Mini-batch size
    :returns:
        - X_batch : np.ndarray
            Tensor of time series matrix batches,
            shape=(n_batches, length, batch_size, n_features)
        - X_mask : np.ndarray
            shape=(n_batches, length, batch_size)
            Mask denoting whether to include each time step of each time series
            matrix
    '''
    
def make_batches_X(X, length, batch_size=30):
    n_batches = len(X)//batch_size
    X_batch = np.zeros( (n_batches, batch_size, length, X[0].shape[1]),
                         dtype=theano.config.floatX)
    X_mask  = np.zeros( (n_batches, length, batch_size ), 
                         dtype=theano.config.floatX)
    
    for b in range(n_batches): 
        for n in range(batch_size): # go thorough batch size       
            X_m = X[b*batch_size + n] # seq_length X feature dim            
            X_batch[b, n, :X_m.shape[0]] = X_m[:length]
            X_mask[b, :X_m.shape[0], n] = 1
            
    return X_batch, X_mask

def make_batches_Y( X, length, batch_size=30):
    n_batches = len(X)//batch_size
    
    X_batch = np.zeros( (n_batches, length, batch_size ), dtype='float32')
    
    X_mask = np.zeros(X_batch.shape, dtype=theano.config.floatX)
    
    for b in range(n_batches):
        for n in range(batch_size):
            X_m = X[ b*batch_size + n ]
            X_batch[b, :X_m.shape[0], n ] = X_m[:length]
            X_mask[b, :X_m.shape[0], n] = 1
    return X_batch, X_mask

# %%
batch_size = 40

# Find the longest sequence
length_x = max( max( [X.shape[0] for X in x_train] ),
                max( [X.shape[0] for X in x_valid] ))

length_y = max( max( [X.shape[0] for X in y_train] ),
                max( [X.shape[0] for X in y_valid] ))

# Convert to batches of time series of uniform length
# x_train_mask: seq_length X batch_size
# y_train_mask: output_length X batch_size
# y_pred_mask = x_train_mask, since pred by sequence
x_train, x_train_mask = make_batches_X(x_train, length_x, batch_size)
y_train, y_train_mask = make_batches_Y(y_train, length_y, batch_size)
x_valid, x_valid_mask = make_batches_X(x_valid, length_x, batch_size)
y_valid, y_valid_mask = make_batches_Y(y_valid, length_y, batch_size)

# %%
print x_train.shape
print y_train.shape
print x_valid.shape
print y_valid.shape
print "================mask================"
print x_train_mask.shape
print y_train_mask.shape

# print x_train_mask[0][400][0]
# Out:
# (93, 40, 501, 231)
# (93, 132, 40)
# (4, 40, 501, 231)
# (4, 132, 40)
# ================mask================
# (93, 501, 40)
# (93, 132, 40)

# %% [markdown]
# # Model Part

# %%
'''
credit by NLTK package of measure edit distance
'''

def _edit_dist_init(len1, len2):
    lev = []
    for i in range(len1):
        lev.append([0] * len2)  # initialize 2D array to zero
    for i in range(len1):
        lev[i][0] = i           # column 0: 0,1,2,3,4,...
    for j in range(len2):
        lev[0][j] = j           # row 0: 0,1,2,3,4,...
    return lev


def _edit_dist_step(lev, i, j, s1, s2, transpositions=False):
    c1 = s1[i - 1]
    c2 = s2[j - 1]

    # skipping a character in s1
    a = lev[i - 1][j] + 1
    # skipping a character in s2
    b = lev[i][j - 1] + 1
    # substitution
    c = lev[i - 1][j - 1] + (c1 != c2)

    # transposition
    d = c + 1  # never picked by default
    if transpositions and i > 1 and j > 1:
        if s1[i - 2] == c2 and s2[j - 2] == c1:
            d = lev[i - 2][j - 2] + 1

    # pick the cheapest
    lev[i][j] = min(a, b, c, d)


def check_label_error( real , predict, transpositions=False):
    ## length of real >= length of predict
    """
    Calculate the Levenshtein edit-distance between two strings.
    The edit distance is the number of characters that need to be
    substituted, inserted, or deleted, to transform s1 into s2.  For
    example, transforming "rain" to "shine" requires three steps,
    consisting of two substitutions and one insertion:
    "rain" -> "sain" -> "shin" -> "shine".  These operations could have
    been done in other orders, but at least three steps are needed.

    This also optionally allows transposition edits (e.g., "ab" -> "ba"),
    though this is disabled by default.

    :param s1, s2: The strings to be analysed
    :param transpositions: Whether to allow transposition edits
    :type s1: str
    :type s2: str
    :type transpositions: bool
    :rtype int
    """
    # set up a 2-D array
    len1 = len(predict)
    len2 = len(real)
    lev = _edit_dist_init(len1 + 1, len2 + 1)

    # iterate over the array
    for i in range(len1):
        for j in range(len2):
            _edit_dist_step(lev, i + 1, j + 1, predict, real, transpositions=transpositions)
            
    return lev[len1][len2]*1.0/len2


def clean_up( y ):
    """
    for final output clean up
    B(a − ab−) = B(−aa − −abb) = aab
    """
    answer = ""

    for i in range(len(y)):
        if y[i] == '.':
            continue
        else:
            if y[i-1] != y[i]:
                answer += y[i]
    
    return answer

def remap_back( y , actual):
    answer = ""
    
    for i in y:
        answer += char_unMap[i]
    
    if not actual:
        answer = clean_up(answer)
        
    return answer

def decode_all_actual( y, y_mask ,batch_size , actual=False):
    """
    y     : label_length X batch_size
    y_mask: label_length X batch_size
    """
    result = []
    for i in xrange(batch_size):
        mask = np.swapaxes( y_mask, 0, 1)[i]
        ans = np.swapaxes( y, 0 , 1)[i]
        result.append(remap_back( ans[np.nonzero(mask)] , actual ))
    return result


def decode_all_pred( y, y_mask ,batch_size , actual=False):
    """
    y     : label_length X batch_size
    y_mask: label_length X batch_size
    """
    result = []
    for i in xrange(batch_size):
        mask = np.swapaxes( y_mask, 0, 1)[i]
        ans = y[i]
        result.append(remap_back( ans[np.nonzero(mask)] , actual ))
    return result

def check_all( y, y_mask, y_pred, y_pred_mask, batch_size ):
    
    actual = decode_all_actual( y, y_mask, batch_size , True )
    predict = decode_all_pred( y_pred, y_pred_mask, batch_size , False )
    
    error = 0.
    for a,b in zip (actual, predict):
        error += check_label_error(a,b)
    
    return error/len(actual)

# %%
class end_to_end():  
    def __init__(self, input_shape, max_seq_length, hidden_layer,
                 batch, max_epochs, output_num_units,
                 patience, up_learning_rate, file_name):
        
        self.input_shape = input_shape # [batch, dim]
        
        self.hidden_layer = hidden_layer # hidden [l1, l2, l3]
        self.output_num_units = output_num_units # [ # of class ]
        
        self.batch = batch
        self.max_epochs = max_epochs
        
        self.up_learning_rate = up_learning_rate
                 
        self.patience = patience
        self.best_valid = np.inf
        self.best_valid_epoch = 0
        self.best_params = None
        
        self.train_history_ = []
        self.epochs = 0
        
        self.file_name = file_name
        
        self.max_seq_length = max_seq_length
        
        """
        input data type
        y_hat : T x B x C+1
        y : L x B
        y_hat_mask : T x B
        y_mask : L x B
        """
        
        print "Why model build so long ... "
        # T x B x F
        # B X T X F (Lasagne format)
        x = T.tensor3('X', dtype=theano.config.floatX)
        # L x B
        y = T.matrix ('y', dtype=theano.config.floatX)

        # L x B
        y_mask = T.matrix('y_mask', dtype=theano.config.floatX)
        # T x B
        y_hat_mask = T.matrix('y_hat_mask', dtype=theano.config.floatX)
    
        # Min/max sequence length
        MAX_LENGTH = max_seq_length
        
        # Number of training sequences in each batch
        N_BATCH = batch
        
        #===========================================================================================
        # dEEP lSTM
        #===========================================================================================
        print "Input : (N_BATCH) : " + str(N_BATCH) +", ML :" + str(MAX_LENGTH) + "ss :" + str(self.input_shape[1])
        
        # Recurrent layers expect input of shape
        # (batch size, max sequence length, number of features)
        l_in     = lasagne.layers.InputLayer( shape=( N_BATCH, MAX_LENGTH, self.input_shape[1] ) )
        # l_in_gau = lasagne.layers.GaussianNoiseLayer( l_in, sigma=0.5 )
        
        # LSTM layer 1
        l_forward_1   = lasagne.layers.LSTMLayer(l_in, num_units=hidden_layer[0], learn_init=True, peepholes=True)
        l_backward_1  = lasagne.layers.LSTMLayer(l_in, num_units=hidden_layer[0], backwards=True, learn_init=True, peepholes=True)
        l_recurrent_1 = ElemwiseSumLayer( [l_forward_1, l_backward_1] )

        
        # LSTM layer 2
        l_forward_2   = lasagne.layers.LSTMLayer(l_recurrent_1, num_units=hidden_layer[1], learn_init=True, peepholes=True)
        l_backward_2  = lasagne.layers.LSTMLayer(l_recurrent_1, num_units=hidden_layer[1], backwards=True, learn_init=True, peepholes=True)
        l_recurrent_2 = ElemwiseSumLayer( [l_forward_2, l_backward_2] )
        '''
        # LSTM layer 3
        l_forward_3   = lasagne.layers.LSTMLayer(l_recurrent_2, num_units=hidden_layer[2], learn_init=True, peepholes=True)
        l_backward_3  = lasagne.layers.LSTMLayer(l_recurrent_2, num_units=hidden_layer[2], backwards=True, learn_init=True, peepholes=True)
        l_recurrent_3 = ElemwiseSumLayer( [l_forward_3, l_backward_3] )
        
        # LSTM layer 4
        l_forward_4   = lasagne.layers.LSTMLayer(l_recurrent_3, num_units=hidden_layer[3], learn_init=True, peepholes=True)
        l_backward_4  = lasagne.layers.LSTMLayer(l_recurrent_3, num_units=hidden_layer[3], backwards=True, learn_init=True, peepholes=True)
        l_recurrent_4 = ElemwiseSumLayer( [l_forward_4, l_backward_4] )
        '''
        
        #l_reshape = lasagne.layers.ReshapeLayer(l_recurrent_4, (N_BATCH*MAX_LENGTH, hidden_layer[3])  )
        l_reshape = lasagne.layers.ReshapeLayer(l_recurrent_2, (N_BATCH*MAX_LENGTH, hidden_layer[1])  )

        
        #===========================================================================================
        # COMMON SETUP
        #===========================================================================================
        
        # Our output layer is a simple dense connection
        l_recurrent_out      = lasagne.layers.DenseLayer( l_reshape, num_units=output_num_units[0] , nonlinearity=lasagne.nonlinearities.identity)
        
        # Now, reshape the output back to the RNN format
        l_out_shp            = lasagne.layers.ReshapeLayer( l_recurrent_out, (N_BATCH, MAX_LENGTH, output_num_units[0]) )
        
        # dimshuffle to shape format (input_seq_len, batch_size, num_classes + 1)
        l_out_shp_ctc        = lasagne.layers.DimshuffleLayer( l_out_shp, (1, 0, 2))

        l_out_softmax        = lasagne.layers.NonlinearityLayer( l_recurrent_out, nonlinearity=lasagne.nonlinearities.softmax)
        l_out_softmax_shp    = lasagne.layers.ReshapeLayer( l_out_softmax, (N_BATCH, MAX_LENGTH, output_num_units[0] ))
        
        # since we use gaussian noise in input, False means use noise, True means dont use noise
        output_lin_ctc_train = lasagne.layers.get_output( l_out_shp_ctc, x, deterministic=False)
        output_softmax_train = lasagne.layers.get_output( l_out_softmax_shp, x, deterministic=False)
        
        output_lin_ctc_val   = lasagne.layers.get_output(l_out_shp_ctc, x, deterministic=True)
        output_softmax_val   = lasagne.layers.get_output(l_out_softmax_shp, x, deterministic=True)
        
        self.all_params      = lasagne.layers.get_all_params(l_out_shp)

        # the CTC cross entropy between y and linear output network
        pseudo_cost = ctc_cost_2.pseudo_cost(
            y, output_lin_ctc_train, y_mask, y_hat_mask,
            skip_softmax=True)
        
        
        pseudo_cost_grad = T.grad(pseudo_cost.mean(), self.all_params)
        true_cost        = ctc_cost_2.cost(y, output_softmax_train.dimshuffle(1, 0, 2), y_mask, y_hat_mask)
        cost             = T.mean(true_cost)
        updates          = lasagne.updates.rmsprop(pseudo_cost_grad, self.all_params, learning_rate = self.up_learning_rate)

        self.train = theano.function(
            inputs = [x, y, y_hat_mask, y_mask],
            outputs = [ pseudo_cost.mean(), cost, output_softmax_train ],
#             outputs = [output_lin_ctc, output_softmax, cost],
            updates=updates
        )
        
        self.predict = theano.function( 
            inputs=[x], 
            outputs = [ output_softmax_val] 
        )

        
    # x_mask and y_mask is the same
    # x_test_mask and y_test_mask is the same
    def fit(self, x_train, y_train, x_test,  y_test , x_mask, y_mask, x_test_mask, y_test_mask ):
        print " "
        print "start training!!!!"
        print " "
        sys.stdout.flush()
        
        for i in range(self.max_epochs):
            self.epochs +=1
            t0 = time()
            
            cs = 0.
            pseudo_cs = 0.
            for index in range(len(x_train)):
                pseudo, cost, output_softmax = self.train( x_train[index] , y_train[index],
                                                          x_mask[index], y_mask[index])
                cs += cost
                pseudo_cs += pseudo
                gg = index
                if index % 10 == 0:
                    print index, pseudo, cost
                sys.stdout.flush()
            
            cs /= len(x_train)
            pseudo_cs /= len(x_train)
            
#             cPickle.dump( self , open("./"+self.file_name+".pkl","wb"))
            if self.epochs <= 1:
                previous_cs = "-"
            else:
                previous_cs = self.train_history_[-1]['cost']
            print "\n==============================="
            print 'epoch {0} : pseudo= {1}, cost= {2}, previous_cost= {3}, train_time = {4} s'.format(self.epochs,
                                                                                                      pseudo_cs, 
                                                                                                      cs,
                                                                                                      previous_cs, 
                                                                                                      time() - t0)
            
            sys.stdout.flush()
            
            t0 = time()
            
#             print np.argmax(output_softmax[:],axis=2)
#             print decode_all( np.argmax(output_softmax[:],axis=2) , x_train_mask[gg],  batch_size , True)
            
            # save model first
            # dont know the LER performance yet
#             cPickle.dump( self , open("./"+self.file_name+".pkl","wb"))
    

            label_error_rate = 0.
            print len(x_test)
            for index in range( len(x_test) ) :

                prepre = self.predict( x_test[index])
                
                label_error_rate += check_all( y_test[index], y_test_mask[index],
                                              np.argmax(prepre[0],axis=2) , x_test_mask[index],
                                              batch_size)
                
                if (( index + self.epochs ) % 4 == 0 ):
                    ## print actual
                    y_actual = decode_all_actual( y_test[index], y_test_mask[index], batch_size , True)

                    ## print pred
                    y_predict = decode_all_pred( np.argmax(prepre[0],axis=2) , x_test_mask[index],  batch_size , False)
                
            label_error_rate /= len(x_test)
            self.train_history_.append({"epoch":self.epochs, "cost": cs, "LER":label_error_rate})
            
            print '\t\t\t val_= {0}, test_time  = {1} s'.format(label_error_rate, time() - t0)
            print "===============================\n"
            
            sys.stdout.flush()
            
            for a , b in zip (y_actual,y_predict):
                print "Target== ",a 
                print "\tAns => ",b
            
            sys.stdout.flush()
            
            """
            should use cost do early stopping
            """
            current_cs = self.train_history_[-1]['cost']
            current_epoch = self.train_history_[-1]['epoch']
            if current_cs < self.best_valid:
                self.best_valid = current_cs
                self.best_valid_epoch = current_epoch
                self.best_params = [w.get_value() for w in self.all_params]
                cPickle.dump( self , open("./"+self.file_name+".pkl","wb"))
                
            elif self.best_valid_epoch + self.patience <= current_epoch:
                print ""
                print "Early stopping."
                print self.best_valid_epoch,self.best_valid
                print "Best valid ler {:.6f} at epoch {}.".format(self.best_valid, self.best_valid_epoch)              
#                 for qq in range (len(self.all_params)):
#                     self.all_params[qq].set_value( self.best_params[qq] )
#                 break

            """
            can not use label error rate do early stopping
            """
#             current_ler = self.train_history_[-1]['LER']
#             current_epoch = self.train_history_[-1]['epoch']
#             if current_ler < self.best_valid:
# #                 print "********************* Now best ************************"
#                 sys.stdout.flush()
#                 self.best_valid = current_ler
#                 self.best_valid_epoch = current_epoch
#                 self.best_params = [w.get_value() for w in self.all_params]
# #                 cPickle.dump( self , open("./"+self.file_name+".pkl","wb"))
                
#             elif self.best_valid_epoch + self.patience <= current_epoch:
#                 print ""
#                 print "Early stopping."
#                 print self.best_valid_epoch,self.best_valid
#                 print "Best valid ler {:.6f} at epoch {}.".format(self.best_valid, self.best_valid_epoch)
#                 sys.stdout.flush()                
#                 for qq in range (len(self.all_params)):
#                     self.all_params[qq].set_value( self.best_params[qq] )
#                 break


#     def prediction(self, x, x_mask) :
        
#         abc =  self.predict(x, x_mask)
        
#         return np.argmax(abc[0], axis = 1 )

# %%
'''
ONE lAYER
'''

model2L_noNoise_with313 = end_to_end (
    input_shape      = (1, x_train.shape[3] ) , # batch of 1, (110, 30, 777, 117)
    max_seq_length = x_train.shape[2],
    hidden_layer     = [ 250, 250, 250, 250 ], # maximum layer to LSTM 3 layer only
    batch            = batch_size, 
    max_epochs       = 300, 
    output_num_units = [ len(char_unMap) ],
    up_learning_rate = 0.0001, 
    patience         = 7,
    file_name = "model2L_noNoise_with313"
)
# Out:
# /home/pika/nntools/lasagne/layers/helper.py:69: UserWarning: get_all_layers() has been changed to return layers in topological order. The former implementation is still available as get_all_layers_old(), but will be removed before the first release of Lasagne. To ignore this warning, use `warnings.filterwarnings('ignore', '.*topo.*')`.
#   warnings.warn("get_all_layers() has been changed to return layers in "
# /home/pika/anaconda/lib/python2.7/site-packages/theano/scan_module/scan.py:1017: Warning: In the strict mode, all neccessary shared variables must be passed as a part of non_sequences
#   'must be passed as a part of non_sequences', Warning)
# Why model build so long ...
# Input : (N_BATCH) : 40, ML :501ss :231
# /home/pika/anaconda/lib/python2.7/site-packages/theano/scan_module/scan_perform_ext.py:133: RuntimeWarning: numpy.ndarray size changed, may indicate binary incompatibility
#   from scan_perform.scan_perform import *

# %%
# %time model2L_noNoise_with313.fit( x_train, y_train, x_valid, y_valid, x_train_mask, y_train_mask , x_valid_mask, y_valid_mask )
# Out:
#
# start training!!!!
#
# 0 269.511474609 782.749755859
# 10 314.126922607 842.123168945
# 20 324.96862793 809.619628906
# 30 70.7194824219 647.16986084
# 40 403.392913818 844.845031738
# 50 304.96395874 742.491516113
# 60 391.941223145 775.288879395
# 70 274.355743408 682.536743164
# 80 48.2103767395 478.570068359
# 90 157.17779541 539.989135742
#
# ===============================
# epoch 1 : pseudo= 226.856914325, cost= 693.527586578, previous_cost= -, train_time = 1083.17062998 s
# 4
# 			 val_= 1.03746270646, test_time  = 1.24573993683 s
# ===============================
#
# Target==  bumble bee ? sa ato' pa ? gayod diay ka
# 	Ans =>  huizneijianaof?adabay'rydyjytigyi
# Target==  nindot na kadto imo nga kuan sa una
# 	Ans =>  iaithvyy ykuoi ajuilyiainiiya?yppp vua
# Target==  piro kad- kadali' ra man to nga si ati mildred
# 	Ans =>  u
# Target==  ? gahapon nakakuwarta kagahapon
# 	Ans =>  iapiaify?aiinaevpuso?itatoim rmkiqifnblstia'zan
# Target==  ? wala' ra ba kay budget
# 	Ans =>  iananafvb iar?yz
# Target==  ang tulo kakuan traha
# 	Ans =>  uaibianabjaialqliaiali?iasimaiaia
# Target==  nagtrabaho davao light
# 	Ans =>  huai tzinasigivaigioai
# Target==  mao lagi ba unsa nga urasa muabot diay
# 	Ans =>  iajtjiainaboiaia'
# Target==  ? ako' pod mupalit pod ko' og gatas sa ako' nga anak diri
# 	Ans =>  mnmfmbmaowaiaoyhiaoifibeiaiaaaaoyad a?aiatyhptitauiaiuiaip r yi
# Target==  unsa man ila nga gidula' ?
# 	Ans =>  'k
# Target==  kuyawa gayod pila ang ?
# 	Ans =>  juinyyaiyjiaiaiavjan
# Target==  ipalihog ko' ingon nga
# 	Ans =>  ulalsssstaioigbanobrjiqitan
# Target==  ? sigi siya suroy-suroy
# 	Ans =>  iziyuyuaiaiailflfprjpmvpjxjbqjr ?pjfvkoin
# Target==  kuyawa no paspasa pod nila manganak no ?
# 	Ans =>  isyooozofaytaiyaiyya'salxldvhohd
# Target==  ? ? unsa man nawala' man nadawat
# 	Ans =>  'syqwojo
# Target==  ? uniya'
# 	Ans =>  kakjk?
# Target==  piro wala' na ka miadto
# 	Ans =>  niayblzilaz
# Target==  bala kaayo ka maunahan gani' ka gani'
# 	Ans =>  or
# Target==  ? mao gayod na
# 	Ans =>
# Target==  kay daghan man gayod kaayo sila mama gayod dira'
# 	Ans =>  iznzjdyj?teyegoydhy
# Target==  arkilaha ?
# 	Ans =>  bnegtuwamaitarliaizanitizintot
# Target==  o asa man siya nag-iskuwila karon
# 	Ans =>  gdg?soaleyadrykymgmkytyryj uj tjioya
# Target==  uniya' wala'-wala' wala' mo ing video ato' nga
# 	Ans =>  a?gpyrq?ni?iaizyljtbai gannarbbao
# Target==  kuyog piro ? hapon na lagi kaayo maayo man to nga nakuha kadto ganiha kay
# 	Ans =>  wbnbnbnanbabybybbybybebebvyfac
# Target==  ? nangita' ta og kana' nga maayo unsa ing unsa og grasiya uniya' sa ginuo ba
# 	Ans =>  'klf
# Target==  ? usa na man lang ? mao diay wala' na lang
# 	Ans =>  q?q?mbqnmxio_qmno_oixaunoigiaeqonznqvoinobiainoaiaioin
# Target==  blue uniya' blue ra pod ako' nga
# 	Ans =>  ebemy eyeemy mie e ?y yr y jh y yyj
# Target==  o trisi
# 	Ans =>  jiaiaiuiaaiyz
# Target==  mapundasiyunan ang kuan
# 	Ans =>
# Target==  magsakit-sakit biya' ni sarah og si janmar
# 	Ans =>  hia'y'ya'risonoyyaijnaoannoasljynta
# Target==  o ngano diay muuban ka
# 	Ans =>  iacbiaiz dsla
# Target==  ? ka didto sigi ra og tindog
# 	Ans =>  sie cg
# Target==  ay usahay lang dili' man pod siya ingon nga dalo' piro
# 	Ans =>  'o
# Target==  uniya' kanus-a man to muuli' imo nga bana
# 	Ans =>  ia''riasntsa
# Target==  ? si luke ? wala' na man siya ing ? wala' na man
# 	Ans =>  get
# Target==  ikaw kumusta na man mo sa imo nga uyab
# 	Ans =>  de'iaswb?pyyrjajgivipsfoni
# Target==  sa una mao man unta' to ang plano namo' sa una
# 	Ans =>  i yyixigigpcp?hairlp?hr tyuy yp?ia
# Target==  ? sunod ini og magkita' ta ?
# 	Ans =>  ?i?i?io
# Target==  og wala' nawala' ? abi nako' og wala' pa
# 	Ans =>  or
# Target==  o tabang ? kadto nga ? sa bohol ba
# 	Ans =>
# 0 170.995727539 570.333984375
# 10 123.025512695 580.804626465
# 20 139.407409668 525.921264648
# 30 -66.5294418335 404.695526123
# 40 88.1822052002 491.15838623
# 50 240.693191528 607.130126953
# 60 92.2289352417 403.118896484
# 70 9.69920635223 313.656921387
# 80 18.2510261536 308.468780518
# 90 105.818260193 349.168579102
#
# ===============================
# epoch 2 : pseudo= 66.3054020277, cost= 444.461190829, previous_cost= 693.527586578, train_time = 1081.26437998 s
# 4
# 			 val_= 0.929430508324, test_time  = 1.16452598572 s
# ===============================
#
# Target==  uo didto uo uo kadto bitaw tribute ba to
# 	Ans =>  aa
# Target==  ? college level man pod ?
# 	Ans =>  ak
# Target==  ambot oy tapos kuan
# 	Ans =>  nanaiaiaigaiagia
# Target==  si manilyn kana' iya nga damit ihat- ihatod
# 	Ans =>  na
# Target==  kay manayaw mga bata' ?
# 	Ans =>  hggaaiaia
# Target==  na nga nag siyagit-siyagit
# 	Ans =>
# Target==  ? ? basta ang suman ha ? og naa mabilin bigiyan mo gayod ko'
# 	Ans =>  ababaab
# Target==  ay okay lang okay lang gihapon
# 	Ans =>  aa
# Target==  sila nanti naana' sila nga nanti naana'
# 	Ans =>  iapantpapa
# Target==  mmm kanus-a man kadto mangha-
# 	Ans =>  w
# Target==  ? ?
# 	Ans =>  aiaia
# Target==  didto siya na assign sa una mao nga didto gani' mi nagkita'
# 	Ans =>  'aaiaa
# Target==  gahapon unsa diay ?
# 	Ans =>  aaa iaai
# Target==  naa ing gamay naa sa ing buhat sakto ra naa ra ing kuan gayod
# 	Ans =>  iaaaaa
# Target==  ? basta maayo lang nga pagkatrabaho basta dili' lang ingon nga
# 	Ans =>  vsiqiqaia_
# Target==  ay commercial ipaganda o ipaganda
# 	Ans =>  inin
# Target==  tigtubig boy lang ta sa ilaha
# 	Ans =>  iayayjla
# Target==  mawala'-wala' lagi ka dili' kaayo ta ka madungog
# 	Ans =>  naiaaae
# Target==  ? lagi impas na akua piro ang prublima diri ko' nga ma-flat-an mahurot sa hantakan tanan ?
# 	Ans =>  rmog
# Target==  natingala gani' siya nga duha ra daw kabulan kapin
# 	Ans =>   ekaquv
# Target==  dalan lang tika dalan tika
# 	Ans =>  iaaaaoamoioiaaa
# Target==  ay gibalita' na pod diay naana' pod bagiyo
# 	Ans =>  if
# Target==  anhi lang diri ini og human nimo og panglaba
# 	Ans =>   a
# Target==  naana' la ?
# 	Ans =>  aa ai i o
# Target==  laa- mukuan sala' gani' to sila musimba
# 	Ans =>  akababababo
# Target==  aw o si lenny ang kauban niya si kuan maricris
# 	Ans =>  ahla
# Target==  ? lisod na ang ingon miana' mok
# 	Ans =>  ' '
# Target==  mmm ana' gayod kana' mari gayod kinahanglan
# 	Ans =>  cncncyc ff
# Target==  ? didto sa ingon nila nga guadalupe unsa kadto nga lugara kadto
# 	Ans =>  miao
# Target==  iskuwila tanan o humana ang uban
# 	Ans =>  b
# Target==  o ato' ra man gihapon na ba inig
# 	Ans =>  '
# Target==  ? daghan og dalhon tika
# 	Ans =>  c-c-osg
# Target==  wala' ing signal amo' nga bukid ? bukid
# 	Ans =>  aiaaaaaao
# Target==  pait kaayo amo' nga kinabuhi' ingon ana' ra oy motor-motor pait kaayo
# 	Ans =>  iammga
# Target==  sapatos bag-o nga sapatos alangan dili' ka magsapatos
# 	Ans =>  aaa a aaaa
# Target==  oh oh oh dinha' gayod
# 	Ans =>
# Target==  uo mag-propose nako' sa imo hapit na
# 	Ans =>  aa
# Target==  three years lang baya' sila didto
# 	Ans =>  kou
# Target==  diri sa kuan gayod sa may iskuwilahan duol banda
# 	Ans =>  dohaa
# Target==  pila na may anak nimo karon
# 	Ans =>  slyaa
# 0 10.5007448196 322.575317383
# 10 -5.53352069855 298.180664062
# 20 141.835571289 375.784637451
# 30 40.2947273254 275.169494629
# 40 234.309082031 423.218688965
# 50 260.493743896 453.210296631
# 60 172.140380859 332.599822998
# 70 146.187759399 308.897735596
# 80 175.503707886 298.57611084
# 90 196.189743042 335.507263184
#
# ===============================
# epoch 3 : pseudo= 125.93315063, cost= 327.619465161, previous_cost= 444.461190829, train_time = 1080.04736805 s
# 4
# 			 val_= 0.936294353263, test_time  = 1.17178201675 s
# ===============================
#
# Target==  mikalit man gayod kadto nga nga naa ing talk uniya' kuan pod ba kana' nga ?
# 	Ans =>
# Target==  ay nagtrabaho ko' sa kuan sa factory
# 	Ans =>  ahahwhl
# Target==  gikuan kuno to ? gipalitan to og itlog
# 	Ans =>  na
# Target==  ayaw kay gutom gayod na nga alas-dusi na man
# 	Ans =>  nnn
# Target==  ma-level ba diay nako' nga sumbagay lang
# 	Ans =>  asiaiai
# Target==  sa akua diay dili' madunggan nimo
# 	Ans =>
# Target==  na sa bata'
# 	Ans =>  aa
# Target==  asa mo dapit gasuroy-suroy
# 	Ans =>  aa
# Target==  pariha ana' oscar ana' ba
# 	Ans =>  aa
# Target==  o adtuon lang nako' si jed
# 	Ans =>  aiaa
# Target==  lech- litson na baboy
# 	Ans =>
# Target==  sa kuan lang kana' nga mga makaagi ko' og simbahan
# 	Ans =>  nonoy
# Target==  girl manglaag kita' ila shirla sunod ba
# 	Ans =>  a a
# Target==  o mmm
# 	Ans =>  n
# Target==  uyabon uyab-uyab na man daw kuno
# 	Ans =>  a
# Target==  kato nga nabahaan ato' nga una ba
# 	Ans =>  a
# Target==  o ngano nalagot man ka ni ? o
# 	Ans =>  mba
# Target==  sa february mag-lima siya kabulan
# 	Ans =>  aaa
# Target==  musalig og kana' nga mga ingon ana' oy maningkamot ako' oy mangita' ko' og paagi kay lisod kaayo man gayod na ang
# 	Ans =>  kkakaaa
# Target==  manok uniya' kaha iya elot unsa
# 	Ans =>  a
# Target==  og mas tigulang ko' sa imuha ba ?
# 	Ans =>  aaa
# Target==  lisod kana' ang bungol ba bungol baya' ko'
# 	Ans =>
# Target==  si ?
# 	Ans =>  a
# Target==  o i-announce
# 	Ans =>  a
# Target==  kay malipong man kaha' siya ?
# 	Ans =>  a
# Target==  o wala' ? hinuon wala' man hinuon
# 	Ans =>
# Target==  bitaw day tama' gayod ka day
# 	Ans =>  a
# Target==  dinhi man gayod mi mabuhi' bay
# 	Ans =>  aa
# Target==  ? wala' diay giapas ni alex
# 	Ans =>
# Target==  wala' ing tarong og iskuwila sigi lang og climb-climb na
# 	Ans =>   a a
# Target==  usa lay nagdungan nimo dong
# 	Ans =>
# Target==  naako' wala' oy luuya oy
# 	Ans =>  iaa
# Target==  hapit na alas-dusi padulong siya duty ron
# 	Ans =>
# Target==  uniya' mama nimo nakauli' na
# 	Ans =>  iaa
# Target==  mao na nga ukasiyon na man libri gayod
# 	Ans =>  a
# Target==  dili' pod tama' tama' lang
# 	Ans =>  si i i o
# Target==  guwapo man pod na ingon ana' salo-salo tanan mga
# 	Ans =>  aaa
# Target==  naa diay ka ing exam karon sayo man lagi
# 	Ans =>  ta ty
# Target==  kana' nga dili' na siya magpalakas og kaon diay ti
# 	Ans =>  a
# Target==  unsa man nga naa man kay klasi inig gawas nimo sa klasi
# 	Ans =>  wa
# 0 136.477767944 296.726959229
# 10 130.999206543 266.49432373
# 20 268.997528076 382.610656738
# 30 228.515609741 327.080627441
# 40 313.915283203 441.392181396
# 50 215.554244995 354.35748291
# 60 156.017608643 280.148376465
# 70 105.895362854 237.025558472
# 80 181.641387939 285.369659424
# 90 213.142745972 311.243041992
#
# ===============================
# epoch 4 : pseudo= 192.530983135, cost= 307.488393804, previous_cost= 327.619465161, train_time = 1077.71525693 s
# 4
# 			 val_= 0.949366648841, test_time  = 1.16356992722 s
# ===============================
#
# Target==  sila vannie okay man na kay mga taba' man
# 	Ans =>  bs
# Target==  pangit man na ang rain or shine hinay kaayo na oy
# 	Ans =>  a
# Target==  mura lagi og dili' ikaw ?
# 	Ans =>  a
# Target==  no nagkauyab man diay mo ato' niya no
# 	Ans =>
# Target==  o karon na anhi lang diri
# 	Ans =>  aog
# Target==  taod-taod taod-taod na sad
# 	Ans =>  a
# Target==  ay sigi man musulti man siya sa akua piro wala' ko' kita' sa lalaki giingnan nako' ayaw sa paadtua og balay
# 	Ans =>  a
# Target==  cook nako' dinha' mag-cook puwidi mag-cook nako' dinha'
# 	Ans =>
# Target==  o kato lang siya one three
# 	Ans =>  a
# Target==  ting-break time ? ? ting-break time
# 	Ans =>  uouo-
# Target==  mao lagi siguro sa kuan putol-putol
# 	Ans =>
# Target==  uniya' kumusta man imo nga pa check-up balik nay
# 	Ans =>
# Target==  useless lang gihapon imo nga sigi ka og pangutana sa akua
# 	Ans =>  l ha  ai a
# Target==  wal- wal- wala' diay bugas
# 	Ans =>
# Target==  ? kana' nga mga uso karon
# 	Ans =>  msa
# Target==  oh wala' ing signal amo' nga bukid ?
# 	Ans =>  a
# Target==  o para ?
# 	Ans =>  gagaga
# Target==  wala' pa wala' pa
# 	Ans =>
# Target==  si neneng og si sweetie ra man to
# 	Ans =>
# Target==  dako' na na nga panalangin sa ginuo
# 	Ans =>  aaa
# Target==  ? age does not matter bitaw na ati
# 	Ans =>
# Target==  maayo og madayon maayo og dili'
# 	Ans =>
# Target==  namaligiya' man si caloy diri oh halos kami tanan namalit
# 	Ans =>  aaaaa
# Target==  dondie naunsa diay si dondie diay
# 	Ans =>  -k
# Target==  prak- ? prak- ha
# 	Ans =>  vlv oa r p raraiaiuaudua
# Target==  maayo unta' og kumplito to nga ?
# 	Ans =>  a
# Target==  layas ? layas ni nga bataa ni bisan
# 	Ans =>
# Target==  mao ana' man gayod kana' dili' na man gayod kana' ma-control tir
# 	Ans =>  aa
# Target==  na-addict na kaayo si doogie ba o
# 	Ans =>
# Target==  basi og imo nga suwirti naa sa lain wala' dinha'
# 	Ans =>  a
# Target==  duol pa gayod ka sa mga bata' nimo imo nga mga anak
# 	Ans =>   a a
# Target==  o bag-o ato' dili' ka ? tsoy ato'
# 	Ans =>  aa
# Target==  thursday ba huwibis
# 	Ans =>  iaiai i i i i
# Target==  pagkadako' sa pabo oy mura man og kabaw
# 	Ans =>  nat
# Target==  wala' pa ing valid i_d si papa
# 	Ans =>
# Target==  last year pabuto man kadto last year
# 	Ans =>  a
# Target==  hala no luuya gayod niya gayod
# 	Ans =>   a a a
# Target==  ? unsa iya nga course kurso
# 	Ans =>  aia
# Target==  ? magbaktas ? duol ra man pod
# 	Ans =>
# Target==  ha ?
# 	Ans =>
# 0 81.309928894 210.272583008
# 10 145.149032593 252.185424805
# 20 304.064788818 398.299499512
# 30 163.956542969 264.614593506
# 40 256.049865723 355.434020996
# 50 179.222503662 315.593780518
# 60 179.215896606 269.028045654
# 70 84.9209365845 188.416641235
# 80 98.3510055542 194.866729736
# 90 182.915969849 278.811035156
#
# ===============================
# epoch 5 : pseudo= 149.981022825, cost= 256.820227018, previous_cost= 307.488393804, train_time = 1077.53340983 s
# 4
# 			 val_= 0.965879027049, test_time  = 1.16933083534 s
# ===============================
#
# Target==  bumble bee ? sa ato' pa ? gayod diay ka
# 	Ans =>  aa
# Target==  nindot na kadto imo nga kuan sa una
# 	Ans =>  aa
# Target==  piro kad- kadali' ra man to nga si ati mildred
# 	Ans =>
# Target==  ? gahapon nakakuwarta kagahapon
# 	Ans =>  a
# Target==  ? wala' ra ba kay budget
# 	Ans =>
# Target==  ang tulo kakuan traha
# 	Ans =>  aa
# Target==  nagtrabaho davao light
# 	Ans =>  a
# Target==  mao lagi ba unsa nga urasa muabot diay
# 	Ans =>  a
# Target==  ? ako' pod mupalit pod ko' og gatas sa ako' nga anak diri
# 	Ans =>  m
# Target==  unsa man ila nga gidula' ?
# 	Ans =>  ayyy
# Target==  kuyawa gayod pila ang ?
# 	Ans =>  a
# Target==  ipalihog ko' ingon nga
# 	Ans =>  aa
# Target==  ? sigi siya suroy-suroy
# 	Ans =>
# Target==  kuyawa no paspasa pod nila manganak no ?
# 	Ans =>
# Target==  ? ? unsa man nawala' man nadawat
# 	Ans =>  ga
# Target==  ? uniya'
# 	Ans =>  ?o?o  a o o
# Target==  piro wala' na ka miadto
# 	Ans =>  a
# Target==  bala kaayo ka maunahan gani' ka gani'
# 	Ans =>   a
# Target==  ? mao gayod na
# 	Ans =>
# Target==  kay daghan man gayod kaayo sila mama gayod dira'
# 	Ans =>  a
# Target==  arkilaha ?
# 	Ans =>  n
# Target==  o asa man siya nag-iskuwila karon
# 	Ans =>
# Target==  uniya' wala'-wala' wala' mo ing video ato' nga
# 	Ans =>       a
# Target==  kuyog piro ? hapon na lagi kaayo maayo man to nga nakuha kadto ganiha kay
# 	Ans =>
# Target==  ? nangita' ta og kana' nga maayo unsa ing unsa og grasiya uniya' sa ginuo ba
# 	Ans =>  ooo  ni
# Target==  ? usa na man lang ? mao diay wala' na lang
# 	Ans =>  ianqninaqiamama?nonioiaoaoa
# Target==  blue uniya' blue ra pod ako' nga
# 	Ans =>  mar
# Target==  o trisi
# 	Ans =>
# Target==  mapundasiyunan ang kuan
# 	Ans =>  fd d d
# Target==  magsakit-sakit biya' ni sarah og si janmar
# 	Ans =>
# Target==  o ngano diay muuban ka
# 	Ans =>  a
# Target==  ? ka didto sigi ra og tindog
# 	Ans =>
# Target==  ay usahay lang dili' man pod siya ingon nga dalo' piro
# 	Ans =>  aaaaa
# Target==  uniya' kanus-a man to muuli' imo nga bana
# 	Ans =>  a
# Target==  ? si luke ? wala' na man siya ing ? wala' na man
# 	Ans =>  ia
# Target==  ikaw kumusta na man mo sa imo nga uyab
# 	Ans =>  a
# Target==  sa una mao man unta' to ang plano namo' sa una
# 	Ans =>
# Target==  ? sunod ini og magkita' ta ?
# 	Ans =>  n n
# Target==  og wala' nawala' ? abi nako' og wala' pa
# 	Ans =>   a
# Target==  o tabang ? kadto nga ? sa bohol ba
# 	Ans =>  d
# 0 123.759803772 239.987060547
# 10 139.070755005 237.400588989
# 20 214.291091919 311.443664551
# 30 109.454032898 214.92414856
# 40 135.198043823 255.160491943
# 50 170.263290405 298.77557373
# 60 129.404464722 258.90145874
# 70 69.9140472412 175.02406311
# 80 85.7981948853 211.446777344
# 90 151.404190063 245.925811768
#
# ===============================
# epoch 6 : pseudo= 132.32086922, cost= 240.565575384, previous_cost= 256.820227018, train_time = 1077.48684812 s
# 4
# 			 val_= 0.960973794508, test_time  = 1.16023302078 s
# ===============================
#
# Target==  uo didto uo uo kadto bitaw tribute ba to
# 	Ans =>
# Target==  ? college level man pod ?
# 	Ans =>   a a a
# Target==  ambot oy tapos kuan
# 	Ans =>
# Target==  si manilyn kana' iya nga damit ihat- ihatod
# 	Ans =>
# Target==  kay manayaw mga bata' ?
# 	Ans =>  ga b
# Target==  na nga nag siyagit-siyagit
# 	Ans =>
# Target==  ? ? basta ang suman ha ? og naa mabilin bigiyan mo gayod ko'
# 	Ans =>  k----o-k-k-k-a
# Target==  ay okay lang okay lang gihapon
# 	Ans =>
# Target==  sila nanti naana' sila nga nanti naana'
# 	Ans =>  a
# Target==  mmm kanus-a man kadto mangha-
# 	Ans =>  na
# Target==  ? ?
# 	Ans =>
# Target==  didto siya na assign sa una mao nga didto gani' mi nagkita'
# 	Ans =>  a
# Target==  gahapon unsa diay ?
# 	Ans =>  a
# Target==  naa ing gamay naa sa ing buhat sakto ra naa ra ing kuan gayod
# 	Ans =>
# Target==  ? basta maayo lang nga pagkatrabaho basta dili' lang ingon nga
# 	Ans =>  ua
# Target==  ay commercial ipaganda o ipaganda
# 	Ans =>  ono
# Target==  tigtubig boy lang ta sa ilaha
# 	Ans =>
# Target==  mawala'-wala' lagi ka dili' kaayo ta ka madungog
# 	Ans =>  n
# Target==  ? lagi impas na akua piro ang prublima diri ko' nga ma-flat-an mahurot sa hantakan tanan ?
# 	Ans =>  k  n m o o o o o o g g
# Target==  natingala gani' siya nga duha ra daw kabulan kapin
# 	Ans =>  u
# Target==  dalan lang tika dalan tika
# 	Ans =>
# Target==  ay gibalita' na pod diay naana' pod bagiyo
# 	Ans =>
# Target==  anhi lang diri ini og human nimo og panglaba
# 	Ans =>  mamamat
# Target==  naana' la ?
# 	Ans =>
# Target==  laa- mukuan sala' gani' to sila musimba
# 	Ans =>
# Target==  aw o si lenny ang kauban niya si kuan maricris
# 	Ans =>  ngng k k  a a a
# Target==  ? lisod na ang ingon miana' mok
# 	Ans =>  m f
# Target==  mmm ana' gayod kana' mari gayod kinahanglan
# 	Ans =>
# Target==  ? didto sa ingon nila nga guadalupe unsa kadto nga lugara kadto
# 	Ans =>  qaoa
# Target==  iskuwila tanan o humana ang uban
# 	Ans =>  aa
# Target==  o ato' ra man gihapon na ba inig
# 	Ans =>  a
# Target==  ? daghan og dalhon tika
# 	Ans =>  ago
# Target==  wala' ing signal amo' nga bukid ? bukid
# 	Ans =>
# Target==  pait kaayo amo' nga kinabuhi' ingon ana' ra oy motor-motor pait kaayo
# 	Ans =>   a  a aapap
# Target==  sapatos bag-o nga sapatos alangan dili' ka magsapatos
# 	Ans =>  a
# Target==  oh oh oh dinha' gayod
# 	Ans =>  a
# Target==  uo mag-propose nako' sa imo hapit na
# 	Ans =>
# Target==  three years lang baya' sila didto
# 	Ans =>  a a
# Target==  diri sa kuan gayod sa may iskuwilahan duol banda
# 	Ans =>
# Target==  pila na may anak nimo karon
# 	Ans =>   n
# 0 70.7075424194 196.90057373
# 10 126.541374207 224.141082764
# 20 135.656204224 229.780975342
# 30 68.2980270386 180.030532837
# 40 153.471237183 251.074417114
# 50 88.3453598022 222.876953125
# 60 115.227172852 228.901733398
# 70 86.027671814 181.767440796
# 80 73.2920303345 181.313949585
# 90 126.203208923 235.096191406
#
# ===============================
# epoch 7 : pseudo= 108.747024228, cost= 214.564571093, previous_cost= 240.565575384, train_time = 1077.49080491 s
# 4
# 			 val_= 0.969005154931, test_time  = 1.14159297943 s
# ===============================
#
# Target==  mikalit man gayod kadto nga nga naa ing talk uniya' kuan pod ba kana' nga ?
# 	Ans =>
# Target==  ay nagtrabaho ko' sa kuan sa factory
# 	Ans =>  kan
# Target==  gikuan kuno to ? gipalitan to og itlog
# 	Ans =>  n
# Target==  ayaw kay gutom gayod na nga alas-dusi na man
# 	Ans =>
# Target==  ma-level ba diay nako' nga sumbagay lang
# 	Ans =>   nn
# Target==  sa akua diay dili' madunggan nimo
# 	Ans =>
# Target==  na sa bata'
# 	Ans =>  a
# Target==  asa mo dapit gasuroy-suroy
# 	Ans =>
# Target==  pariha ana' oscar ana' ba
# 	Ans =>
# Target==  o adtuon lang nako' si jed
# 	Ans =>
# Target==  lech- litson na baboy
# 	Ans =>
# Target==  sa kuan lang kana' nga mga makaagi ko' og simbahan
# 	Ans =>  maiiid d
# Target==  girl manglaag kita' ila shirla sunod ba
# 	Ans =>
# Target==  o mmm
# 	Ans =>
# Target==  uyabon uyab-uyab na man daw kuno
# 	Ans =>
# Target==  kato nga nabahaan ato' nga una ba
# 	Ans =>  a
# Target==  o ngano nalagot man ka ni ? o
# 	Ans =>
# Target==  sa february mag-lima siya kabulan
# 	Ans =>
# Target==  musalig og kana' nga mga ingon ana' oy maningkamot ako' oy mangita' ko' og paagi kay lisod kaayo man gayod na ang
# 	Ans =>
# Target==  manok uniya' kaha iya elot unsa
# 	Ans =>
# Target==  og mas tigulang ko' sa imuha ba ?
# 	Ans =>
# Target==  lisod kana' ang bungol ba bungol baya' ko'
# 	Ans =>
# Target==  si ?
# 	Ans =>
# Target==  o i-announce
# 	Ans =>  a
# Target==  kay malipong man kaha' siya ?
# 	Ans =>
# Target==  o wala' ? hinuon wala' man hinuon
# 	Ans =>   a a
# Target==  bitaw day tama' gayod ka day
# 	Ans =>  a
# Target==  dinhi man gayod mi mabuhi' bay
# 	Ans =>
# Target==  ? wala' diay giapas ni alex
# 	Ans =>
# Target==  wala' ing tarong og iskuwila sigi lang og climb-climb na
# 	Ans =>
# Target==  usa lay nagdungan nimo dong
# 	Ans =>
# Target==  naako' wala' oy luuya oy
# 	Ans =>
# Target==  hapit na alas-dusi padulong siya duty ron
# 	Ans =>
# Target==  uniya' mama nimo nakauli' na
# 	Ans =>
# Target==  mao na nga ukasiyon na man libri gayod
# 	Ans =>
# Target==  dili' pod tama' tama' lang
# 	Ans =>
# Target==  guwapo man pod na ingon ana' salo-salo tanan mga
# 	Ans =>   a
# Target==  naa diay ka ing exam karon sayo man lagi
# 	Ans =>  t t t t t a a
# Target==  kana' nga dili' na siya magpalakas og kaon diay ti
# 	Ans =>
# Target==  unsa man nga naa man kay klasi inig gawas nimo sa klasi
# 	Ans =>  un
# 0 101.424156189 207.656402588
# 10 72.2991714478 182.458953857
# 20 131.877593994 226.937789917
# 30 49.1974372864 168.148300171
# 40 146.289672852 262.23614502
# 50 114.829200745 219.802276611
# 60 112.604309082 221.959320068
# 70 108.799736023 191.942703247
# 80 146.792434692 231.638397217
# 90 110.208595276 220.16242981
#
# ===============================
# epoch 8 : pseudo= 99.5353638844, cost= 205.577697098, previous_cost= 214.564571093, train_time = 1075.11145496 s
# 4
# 			 val_= 0.977085081417, test_time  = 1.13654303551 s
# ===============================
#
# Target==  sila vannie okay man na kay mga taba' man
# 	Ans =>
# Target==  pangit man na ang rain or shine hinay kaayo na oy
# 	Ans =>
# Target==  mura lagi og dili' ikaw ?
# 	Ans =>
# Target==  no nagkauyab man diay mo ato' niya no
# 	Ans =>
# Target==  o karon na anhi lang diri
# 	Ans =>  i'
# Target==  taod-taod taod-taod na sad
# 	Ans =>
# Target==  ay sigi man musulti man siya sa akua piro wala' ko' kita' sa lalaki giingnan nako' ayaw sa paadtua og balay
# 	Ans =>  a
# Target==  cook nako' dinha' mag-cook puwidi mag-cook nako' dinha'
# 	Ans =>
# Target==  o kato lang siya one three
# 	Ans =>
# Target==  ting-break time ? ? ting-break time
# 	Ans =>  wgai
# Target==  mao lagi siguro sa kuan putol-putol
# 	Ans =>
# Target==  uniya' kumusta man imo nga pa check-up balik nay
# 	Ans =>
# Target==  useless lang gihapon imo nga sigi ka og pangutana sa akua
# 	Ans =>
# Target==  wal- wal- wala' diay bugas
# 	Ans =>   ? ?
# Target==  ? kana' nga mga uso karon
# 	Ans =>
# Target==  oh wala' ing signal amo' nga bukid ?
# 	Ans =>
# Target==  o para ?
# 	Ans =>
# Target==  wala' pa wala' pa
# 	Ans =>  iia
# Target==  si neneng og si sweetie ra man to
# 	Ans =>  aana
# Target==  dako' na na nga panalangin sa ginuo
# 	Ans =>  a
# Target==  ? age does not matter bitaw na ati
# 	Ans =>
# Target==  maayo og madayon maayo og dili'
# 	Ans =>
# Target==  namaligiya' man si caloy diri oh halos kami tanan namalit
# 	Ans =>  a
# Target==  dondie naunsa diay si dondie diay
# 	Ans =>  a
# Target==  prak- ? prak- ha
# 	Ans =>  alaoao
# Target==  maayo unta' og kumplito to nga ?
# 	Ans =>  a
# Target==  layas ? layas ni nga bataa ni bisan
# 	Ans =>  o
# Target==  mao ana' man gayod kana' dili' na man gayod kana' ma-control tir
# 	Ans =>  a
# Target==  na-addict na kaayo si doogie ba o
# 	Ans =>
# Target==  basi og imo nga suwirti naa sa lain wala' dinha'
# 	Ans =>
# Target==  duol pa gayod ka sa mga bata' nimo imo nga mga anak
# 	Ans =>  na a
# Target==  o bag-o ato' dili' ka ? tsoy ato'
# 	Ans =>
# Target==  thursday ba huwibis
# 	Ans =>  dd d d
# Target==  pagkadako' sa pabo oy mura man og kabaw
# 	Ans =>
# Target==  wala' pa ing valid i_d si papa
# 	Ans =>
# Target==  last year pabuto man kadto last year
# 	Ans =>
# Target==  hala no luuya gayod niya gayod
# 	Ans =>  mamamam ma a a
# Target==  ? unsa iya nga course kurso
# 	Ans =>  a
# Target==  ? magbaktas ? duol ra man pod
# 	Ans =>  mmm
# Target==  ha ?
# 	Ans =>  i
# 0 104.335083008 199.925201416
# 10 74.030166626 180.099487305
# 20 100.125076294 192.597381592
# 30 67.5373840332 183.585113525
# 40 105.737808228 219.448806763
# 50 104.195510864 202.788787842
# 60 138.466949463 225.91003418
# 70 109.175987244 181.453445435
# 80 86.1949386597 184.017318726
# 90 128.468933105 224.746856689
#
# ===============================
# epoch 9 : pseudo= 98.2061764912, cost= 199.92249897, previous_cost= 205.577697098, train_time = 1075.07188511 s
# 4
# 			 val_= 0.971237995797, test_time  = 1.13156604767 s
# ===============================
#
# Target==  bumble bee ? sa ato' pa ? gayod diay ka
# 	Ans =>
# Target==  nindot na kadto imo nga kuan sa una
# 	Ans =>
# Target==  piro kad- kadali' ra man to nga si ati mildred
# 	Ans =>
# Target==  ? gahapon nakakuwarta kagahapon
# 	Ans =>
# Target==  ? wala' ra ba kay budget
# 	Ans =>
# Target==  ang tulo kakuan traha
# 	Ans =>
# Target==  nagtrabaho davao light
# 	Ans =>
# Target==  mao lagi ba unsa nga urasa muabot diay
# 	Ans =>  a
# Target==  ? ako' pod mupalit pod ko' og gatas sa ako' nga anak diri
# 	Ans =>  m
# Target==  unsa man ila nga gidula' ?
# 	Ans =>  o o o
# Target==  kuyawa gayod pila ang ?
# 	Ans =>
# Target==  ipalihog ko' ingon nga
# 	Ans =>
# Target==  ? sigi siya suroy-suroy
# 	Ans =>
# Target==  kuyawa no paspasa pod nila manganak no ?
# 	Ans =>
# Target==  ? ? unsa man nawala' man nadawat
# 	Ans =>
# Target==  ? uniya'
# 	Ans =>  n
# Target==  piro wala' na ka miadto
# 	Ans =>  t
# Target==  bala kaayo ka maunahan gani' ka gani'
# 	Ans =>
# Target==  ? mao gayod na
# 	Ans =>  a
# Target==  kay daghan man gayod kaayo sila mama gayod dira'
# 	Ans =>
# Target==  arkilaha ?
# 	Ans =>
# Target==  o asa man siya nag-iskuwila karon
# 	Ans =>
# Target==  uniya' wala'-wala' wala' mo ing video ato' nga
# 	Ans =>  gggaoan
# Target==  kuyog piro ? hapon na lagi kaayo maayo man to nga nakuha kadto ganiha kay
# 	Ans =>  a
# Target==  ? nangita' ta og kana' nga maayo unsa ing unsa og grasiya uniya' sa ginuo ba
# 	Ans =>   na
# Target==  ? usa na man lang ? mao diay wala' na lang
# 	Ans =>
# Target==  blue uniya' blue ra pod ako' nga
# 	Ans =>  aa
# Target==  o trisi
# 	Ans =>
# Target==  mapundasiyunan ang kuan
# 	Ans =>  a
# Target==  magsakit-sakit biya' ni sarah og si janmar
# 	Ans =>
# Target==  o ngano diay muuban ka
# 	Ans =>
# Target==  ? ka didto sigi ra og tindog
# 	Ans =>  n
# Target==  ay usahay lang dili' man pod siya ingon nga dalo' piro
# 	Ans =>   a
# Target==  uniya' kanus-a man to muuli' imo nga bana
# 	Ans =>
# Target==  ? si luke ? wala' na man siya ing ? wala' na man
# 	Ans =>   ' a
# Target==  ikaw kumusta na man mo sa imo nga uyab
# 	Ans =>
# Target==  sa una mao man unta' to ang plano namo' sa una
# 	Ans =>
# Target==  ? sunod ini og magkita' ta ?
# 	Ans =>
# Target==  og wala' nawala' ? abi nako' og wala' pa
# 	Ans =>
# Target==  o tabang ? kadto nga ? sa bohol ba
# 	Ans =>    kaun
# 0 88.531211853 187.830230713
# 10 77.0859680176 188.811172485
# 20 137.271286011 229.280731201
# 30 58.0678977966 170.464614868
# 40 116.633506775 205.32131958
# 50 92.9777450562 194.787597656
# 60 117.262062073 212.463409424
# 70 83.8465805054 178.497528076
# 80 92.5470581055 178.31149292
# 90 128.510040283 224.386398315
#
# ===============================
# epoch 10 : pseudo= 92.5499826657, cost= 193.92393789, previous_cost= 199.92249897, train_time = 1075.26221299 s
# 4
# 			 val_= 0.97144132165, test_time  = 1.14660406113 s
# ===============================
#
# Target==  uo didto uo uo kadto bitaw tribute ba to
# 	Ans =>
# Target==  ? college level man pod ?
# 	Ans =>  at ta t
# Target==  ambot oy tapos kuan
# 	Ans =>
# Target==  si manilyn kana' iya nga damit ihat- ihatod
# 	Ans =>  a
# Target==  kay manayaw mga bata' ?
# 	Ans =>  a
# Target==  na nga nag siyagit-siyagit
# 	Ans =>  ss
# Target==  ? ? basta ang suman ha ? og naa mabilin bigiyan mo gayod ko'
# 	Ans =>
# Target==  ay okay lang okay lang gihapon
# 	Ans =>  t
# Target==  sila nanti naana' sila nga nanti naana'
# 	Ans =>   a ww
# Target==  mmm kanus-a man kadto mangha-
# 	Ans =>  aa
# Target==  ? ?
# 	Ans =>
# Target==  didto siya na assign sa una mao nga didto gani' mi nagkita'
# 	Ans =>
# Target==  gahapon unsa diay ?
# 	Ans =>  a
# Target==  naa ing gamay naa sa ing buhat sakto ra naa ra ing kuan gayod
# 	Ans =>
# Target==  ? basta maayo lang nga pagkatrabaho basta dili' lang ingon nga
# 	Ans =>  n
# Target==  ay commercial ipaganda o ipaganda
# 	Ans =>  wee
# Target==  tigtubig boy lang ta sa ilaha
# 	Ans =>
# Target==  mawala'-wala' lagi ka dili' kaayo ta ka madungog
# 	Ans =>  o
# Target==  ? lagi impas na akua piro ang prublima diri ko' nga ma-flat-an mahurot sa hantakan tanan ?
# 	Ans =>  ia
# Target==  natingala gani' siya nga duha ra daw kabulan kapin
# 	Ans =>
# Target==  dalan lang tika dalan tika
# 	Ans =>
# Target==  ay gibalita' na pod diay naana' pod bagiyo
# 	Ans =>
# Target==  anhi lang diri ini og human nimo og panglaba
# 	Ans =>
# Target==  naana' la ?
# 	Ans =>  aa
# Target==  laa- mukuan sala' gani' to sila musimba
# 	Ans =>  ggg
# Target==  aw o si lenny ang kauban niya si kuan maricris
# 	Ans =>  a dk
# Target==  ? lisod na ang ingon miana' mok
# 	Ans =>  k
# Target==  mmm ana' gayod kana' mari gayod kinahanglan
# 	Ans =>
# Target==  ? didto sa ingon nila nga guadalupe unsa kadto nga lugara kadto
# 	Ans =>
# Target==  iskuwila tanan o humana ang uban
# 	Ans =>  a
# Target==  o ato' ra man gihapon na ba inig
# 	Ans =>
# Target==  ? daghan og dalhon tika
# 	Ans =>  e
# Target==  wala' ing signal amo' nga bukid ? bukid
# 	Ans =>
# Target==  pait kaayo amo' nga kinabuhi' ingon ana' ra oy motor-motor pait kaayo
# 	Ans =>  da
# Target==  sapatos bag-o nga sapatos alangan dili' ka magsapatos
# 	Ans =>
# Target==  oh oh oh dinha' gayod
# 	Ans =>   a a a
# Target==  uo mag-propose nako' sa imo hapit na
# 	Ans =>
# Target==  three years lang baya' sila didto
# 	Ans =>  dy
# Target==  diri sa kuan gayod sa may iskuwilahan duol banda
# 	Ans =>
# Target==  pila na may anak nimo karon
# 	Ans =>
# 0 82.9388656616 179.21105957
# 10 99.879234314 192.458343506
# 20 178.637130737 276.417480469
# 30 56.2588272095 158.787384033
# 40 131.971237183 213.487762451
# 50 127.766014099 213.890914917
# 60 96.8123321533 194.45249939
# 70 87.7824859619 172.261428833
# 80 86.2641601562 187.391723633
# 90 84.237663269 190.34854126
#
# ===============================
# epoch 11 : pseudo= 90.4828347852, cost= 189.355298934, previous_cost= 193.92393789, train_time = 1075.0103879 s
# 4
# 			 val_= 0.97637214161, test_time  = 1.13131713867 s
# ===============================
#
# Target==  mikalit man gayod kadto nga nga naa ing talk uniya' kuan pod ba kana' nga ?
# 	Ans =>
# Target==  ay nagtrabaho ko' sa kuan sa factory
# 	Ans =>  aaaa
# Target==  gikuan kuno to ? gipalitan to og itlog
# 	Ans =>
# Target==  ayaw kay gutom gayod na nga alas-dusi na man
# 	Ans =>
# Target==  ma-level ba diay nako' nga sumbagay lang
# 	Ans =>  pgga
# Target==  sa akua diay dili' madunggan nimo
# 	Ans =>
# Target==  na sa bata'
# 	Ans =>
# Target==  asa mo dapit gasuroy-suroy
# 	Ans =>
# Target==  pariha ana' oscar ana' ba
# 	Ans =>
# Target==  o adtuon lang nako' si jed
# 	Ans =>
# Target==  lech- litson na baboy
# 	Ans =>
# Target==  sa kuan lang kana' nga mga makaagi ko' og simbahan
# 	Ans =>
# Target==  girl manglaag kita' ila shirla sunod ba
# 	Ans =>  dnananandadadadadadada
# Target==  o mmm
# 	Ans =>  m?
# Target==  uyabon uyab-uyab na man daw kuno
# 	Ans =>
# Target==  kato nga nabahaan ato' nga una ba
# 	Ans =>  a
# Target==  o ngano nalagot man ka ni ? o
# 	Ans =>  ioioi
# Target==  sa february mag-lima siya kabulan
# 	Ans =>
# Target==  musalig og kana' nga mga ingon ana' oy maningkamot ako' oy mangita' ko' og paagi kay lisod kaayo man gayod na ang
# 	Ans =>   n
# Target==  manok uniya' kaha iya elot unsa
# 	Ans =>
# Target==  og mas tigulang ko' sa imuha ba ?
# 	Ans =>
# Target==  lisod kana' ang bungol ba bungol baya' ko'
# 	Ans =>
# Target==  si ?
# 	Ans =>
# Target==  o i-announce
# 	Ans =>
# Target==  kay malipong man kaha' siya ?
# 	Ans =>
# Target==  o wala' ? hinuon wala' man hinuon
# 	Ans =>   ad a'
# Target==  bitaw day tama' gayod ka day
# 	Ans =>  a
# Target==  dinhi man gayod mi mabuhi' bay
# 	Ans =>
# Target==  ? wala' diay giapas ni alex
# 	Ans =>
# Target==  wala' ing tarong og iskuwila sigi lang og climb-climb na
# 	Ans =>
# Target==  usa lay nagdungan nimo dong
# 	Ans =>
# Target==  naako' wala' oy luuya oy
# 	Ans =>
# Target==  hapit na alas-dusi padulong siya duty ron
# 	Ans =>
# Target==  uniya' mama nimo nakauli' na
# 	Ans =>
# Target==  mao na nga ukasiyon na man libri gayod
# 	Ans =>
# Target==  dili' pod tama' tama' lang
# 	Ans =>  -g-
# Target==  guwapo man pod na ingon ana' salo-salo tanan mga
# 	Ans =>
# Target==  naa diay ka ing exam karon sayo man lagi
# 	Ans =>
# Target==  kana' nga dili' na siya magpalakas og kaon diay ti
# 	Ans =>
# Target==  unsa man nga naa man kay klasi inig gawas nimo sa klasi
# 	Ans =>
# 0 87.8620758057 179.253143311
# 10 72.5862731934 180.530303955
# 20 75.8517456055 178.970977783
# 30 53.466091156 162.214187622
# 40 88.2782592773 181.955688477
# 50 100.563484192 188.484161377
# 60 79.7187652588 178.817703247
# 70 46.1106987 143.014007568
# 80 65.3693466187 167.968902588
# 90 56.2463264465 168.735290527
#
# ===============================
# epoch 12 : pseudo= 78.5718333132, cost= 178.289649471, previous_cost= 189.355298934, train_time = 1075.03382206 s
# 4
# 			 val_= 0.97577176733, test_time  = 1.15206098557 s
# ===============================
#
# Target==  sila vannie okay man na kay mga taba' man
# 	Ans =>
# Target==  pangit man na ang rain or shine hinay kaayo na oy
# 	Ans =>
# Target==  mura lagi og dili' ikaw ?
# 	Ans =>
# Target==  no nagkauyab man diay mo ato' niya no
# 	Ans =>
# Target==  o karon na anhi lang diri
# 	Ans =>
# Target==  taod-taod taod-taod na sad
# 	Ans =>
# Target==  ay sigi man musulti man siya sa akua piro wala' ko' kita' sa lalaki giingnan nako' ayaw sa paadtua og balay
# 	Ans =>
# Target==  cook nako' dinha' mag-cook puwidi mag-cook nako' dinha'
# 	Ans =>
# Target==  o kato lang siya one three
# 	Ans =>
# Target==  ting-break time ? ? ting-break time
# 	Ans =>  w
# Target==  mao lagi siguro sa kuan putol-putol
# 	Ans =>  srsrsrsrkrkrk
# Target==  uniya' kumusta man imo nga pa check-up balik nay
# 	Ans =>
# Target==  useless lang gihapon imo nga sigi ka og pangutana sa akua
# 	Ans =>
# Target==  wal- wal- wala' diay bugas
# 	Ans =>
# Target==  ? kana' nga mga uso karon
# 	Ans =>
# Target==  oh wala' ing signal amo' nga bukid ?
# 	Ans =>
# Target==  o para ?
# 	Ans =>
# Target==  wala' pa wala' pa
# 	Ans =>   a
# Target==  si neneng og si sweetie ra man to
# 	Ans =>
# Target==  dako' na na nga panalangin sa ginuo
# 	Ans =>
# Target==  ? age does not matter bitaw na ati
# 	Ans =>
# Target==  maayo og madayon maayo og dili'
# 	Ans =>    n
# Target==  namaligiya' man si caloy diri oh halos kami tanan namalit
# 	Ans =>  a
# Target==  dondie naunsa diay si dondie diay
# 	Ans =>  w
# Target==  prak- ? prak- ha
# 	Ans =>  la
# Target==  maayo unta' og kumplito to nga ?
# 	Ans =>
# Target==  layas ? layas ni nga bataa ni bisan
# 	Ans =>
# Target==  mao ana' man gayod kana' dili' na man gayod kana' ma-control tir
# 	Ans =>
# Target==  na-addict na kaayo si doogie ba o
# 	Ans =>
# Target==  basi og imo nga suwirti naa sa lain wala' dinha'
# 	Ans =>
# Target==  duol pa gayod ka sa mga bata' nimo imo nga mga anak
# 	Ans =>  aaaaaaoaoaoao
# Target==  o bag-o ato' dili' ka ? tsoy ato'
# 	Ans =>
# Target==  thursday ba huwibis
# 	Ans =>
# Target==  pagkadako' sa pabo oy mura man og kabaw
# 	Ans =>
# Target==  wala' pa ing valid i_d si papa
# 	Ans =>
# Target==  last year pabuto man kadto last year
# 	Ans =>
# Target==  hala no luuya gayod niya gayod
# 	Ans =>  pn n
# Target==  ? unsa iya nga course kurso
# 	Ans =>
# Target==  ? magbaktas ? duol ra man pod
# 	Ans =>
# Target==  ha ?
# 	Ans =>
# 0 101.743179321 202.009628296
# 10 59.7032966614 175.31338501
# 20 74.9282608032 175.503158569
# 30 44.0503196716 145.720077515
# 40 135.121444702 230.457855225
# 50 76.6981658936 175.890731812
# 60 112.201683044 189.338897705
# 70 43.1670303345 148.014541626
# 80 53.012928009 155.442169189
# 90 52.6111717224 158.605117798
#
# ===============================
# epoch 13 : pseudo= 72.2284793444, cost= 171.269370951, previous_cost= 178.289649471, train_time = 1075.62993097 s
# 4
# 			 val_= 0.974839072202, test_time  = 1.15214705467 s
# ===============================
#
# Target==  bumble bee ? sa ato' pa ? gayod diay ka
# 	Ans =>
# Target==  nindot na kadto imo nga kuan sa una
# 	Ans =>
# Target==  piro kad- kadali' ra man to nga si ati mildred
# 	Ans =>  a
# Target==  ? gahapon nakakuwarta kagahapon
# 	Ans =>
# Target==  ? wala' ra ba kay budget
# 	Ans =>
# Target==  ang tulo kakuan traha
# 	Ans =>
# Target==  nagtrabaho davao light
# 	Ans =>
# Target==  mao lagi ba unsa nga urasa muabot diay
# 	Ans =>  aa
# Target==  ? ako' pod mupalit pod ko' og gatas sa ako' nga anak diri
# 	Ans =>  m
# Target==  unsa man ila nga gidula' ?
# 	Ans =>   k k
# Target==  kuyawa gayod pila ang ?
# 	Ans =>
# Target==  ipalihog ko' ingon nga
# 	Ans =>
# Target==  ? sigi siya suroy-suroy
# 	Ans =>
# Target==  kuyawa no paspasa pod nila manganak no ?
# 	Ans =>
# Target==  ? ? unsa man nawala' man nadawat
# 	Ans =>  ?aaaatalal???k?
# Target==  ? uniya'
# 	Ans =>
# Target==  piro wala' na ka miadto
# 	Ans =>  a
# Target==  bala kaayo ka maunahan gani' ka gani'
# 	Ans =>
# Target==  ? mao gayod na
# 	Ans =>  sna
# Target==  kay daghan man gayod kaayo sila mama gayod dira'
# 	Ans =>
# Target==  arkilaha ?
# 	Ans =>
# Target==  o asa man siya nag-iskuwila karon
# 	Ans =>
# Target==  uniya' wala'-wala' wala' mo ing video ato' nga
# 	Ans =>
# Target==  kuyog piro ? hapon na lagi kaayo maayo man to nga nakuha kadto ganiha kay
# 	Ans =>  a
# Target==  ? nangita' ta og kana' nga maayo unsa ing unsa og grasiya uniya' sa ginuo ba
# 	Ans =>    a ooo
# Target==  ? usa na man lang ? mao diay wala' na lang
# 	Ans =>
# Target==  blue uniya' blue ra pod ako' nga
# 	Ans =>   a a
# Target==  o trisi
# 	Ans =>
# Target==  mapundasiyunan ang kuan
# 	Ans =>
# Target==  magsakit-sakit biya' ni sarah og si janmar
# 	Ans =>
# Target==  o ngano diay muuban ka
# 	Ans =>
# Target==  ? ka didto sigi ra og tindog
# 	Ans =>  g
# Target==  ay usahay lang dili' man pod siya ingon nga dalo' piro
# 	Ans =>
# Target==  uniya' kanus-a man to muuli' imo nga bana
# 	Ans =>
# Target==  ? si luke ? wala' na man siya ing ? wala' na man
# 	Ans =>  a k
# Target==  ikaw kumusta na man mo sa imo nga uyab
# 	Ans =>
# Target==  sa una mao man unta' to ang plano namo' sa una
# 	Ans =>
# Target==  ? sunod ini og magkita' ta ?
# 	Ans =>  i
# Target==  og wala' nawala' ? abi nako' og wala' pa
# 	Ans =>
# Target==  o tabang ? kadto nga ? sa bohol ba
# 	Ans =>  aaiagigigi
# 0 62.106502533 155.48348999
# 10 70.3948745728 174.153030396
# 20 67.2827224731 158.048355103
# 30 67.3566665649 161.110519409
# 40 55.7157363892 139.972442627
# 50 90.1953735352 182.026260376
# 60 75.9967498779 164.509979248
# 70 47.1962242126 139.021148682
# 80 62.1109275818 154.851959229
# 90 39.7944946289 155.28352356
#
# ===============================
# epoch 14 : pseudo= 61.5210824474, cost= 162.201808724, previous_cost= 171.269370951, train_time = 1075.02398396 s
# 4
# 			 val_= 0.983955742242, test_time  = 1.15417599678 s
# ===============================
#
# Target==  uo didto uo uo kadto bitaw tribute ba to
# 	Ans =>
# Target==  ? college level man pod ?
# 	Ans =>  aty
# Target==  ambot oy tapos kuan
# 	Ans =>
# Target==  si manilyn kana' iya nga damit ihat- ihatod
# 	Ans =>  ggnnnnnnnnn
# Target==  kay manayaw mga bata' ?
# 	Ans =>
# Target==  na nga nag siyagit-siyagit
# 	Ans =>
# Target==  ? ? basta ang suman ha ? og naa mabilin bigiyan mo gayod ko'
# 	Ans =>
# Target==  ay okay lang okay lang gihapon
# 	Ans =>
# Target==  sila nanti naana' sila nga nanti naana'
# 	Ans =>
# Target==  mmm kanus-a man kadto mangha-
# 	Ans =>
# Target==  ? ?
# 	Ans =>
# Target==  didto siya na assign sa una mao nga didto gani' mi nagkita'
# 	Ans =>
# Target==  gahapon unsa diay ?
# 	Ans =>
# Target==  naa ing gamay naa sa ing buhat sakto ra naa ra ing kuan gayod
# 	Ans =>
# Target==  ? basta maayo lang nga pagkatrabaho basta dili' lang ingon nga
# 	Ans =>  umuaoa
# Target==  ay commercial ipaganda o ipaganda
# 	Ans =>  aa
# Target==  tigtubig boy lang ta sa ilaha
# 	Ans =>
# Target==  mawala'-wala' lagi ka dili' kaayo ta ka madungog
# 	Ans =>  n
# Target==  ? lagi impas na akua piro ang prublima diri ko' nga ma-flat-an mahurot sa hantakan tanan ?
# 	Ans =>
# Target==  natingala gani' siya nga duha ra daw kabulan kapin
# 	Ans =>
# Target==  dalan lang tika dalan tika
# 	Ans =>
# Target==  ay gibalita' na pod diay naana' pod bagiyo
# 	Ans =>
# Target==  anhi lang diri ini og human nimo og panglaba
# 	Ans =>   slslslil
# Target==  naana' la ?
# 	Ans =>
# Target==  laa- mukuan sala' gani' to sila musimba
# 	Ans =>
# Target==  aw o si lenny ang kauban niya si kuan maricris
# 	Ans =>
# Target==  ? lisod na ang ingon miana' mok
# 	Ans =>  yk
# Target==  mmm ana' gayod kana' mari gayod kinahanglan
# 	Ans =>
# Target==  ? didto sa ingon nila nga guadalupe unsa kadto nga lugara kadto
# 	Ans =>
# Target==  iskuwila tanan o humana ang uban
# 	Ans =>  d l l lal
# Target==  o ato' ra man gihapon na ba inig
# 	Ans =>    a a a a
# Target==  ? daghan og dalhon tika
# 	Ans =>  oa
# Target==  wala' ing signal amo' nga bukid ? bukid
# 	Ans =>
# Target==  pait kaayo amo' nga kinabuhi' ingon ana' ra oy motor-motor pait kaayo
# 	Ans =>  ta
# Target==  sapatos bag-o nga sapatos alangan dili' ka magsapatos
# 	Ans =>
# Target==  oh oh oh dinha' gayod
# 	Ans =>
# Target==  uo mag-propose nako' sa imo hapit na
# 	Ans =>
# Target==  three years lang baya' sila didto
# 	Ans =>
# Target==  diri sa kuan gayod sa may iskuwilahan duol banda
# 	Ans =>
# Target==  pila na may anak nimo karon
# 	Ans =>
# 0 45.0023155212 141.198699951
# 10 57.3313407898 155.707931519
# 20 58.531879425 172.678405762
# 30 51.1004829407 148.405593872
# 40 48.8996047974 140.432189941
# 50 62.7071037292 164.123565674
# 60 76.6772689819 161.761383057
# 70 53.8210449219 152.293457031
# 80 63.2692832947 159.281768799
# 90 85.7580718994 187.746627808
#
# ===============================
# epoch 15 : pseudo= 58.087875438, cost= 159.468961326, previous_cost= 162.201808724, train_time = 1074.94723606 s
# 4
# 			 val_= 0.97180040608, test_time  = 1.12649893761 s
# ===============================
#
# Target==  mikalit man gayod kadto nga nga naa ing talk uniya' kuan pod ba kana' nga ?
# 	Ans =>
# Target==  ay nagtrabaho ko' sa kuan sa factory
# 	Ans =>  a t
# Target==  gikuan kuno to ? gipalitan to og itlog
# 	Ans =>  atag
# Target==  ayaw kay gutom gayod na nga alas-dusi na man
# 	Ans =>
# Target==  ma-level ba diay nako' nga sumbagay lang
# 	Ans =>
# Target==  sa akua diay dili' madunggan nimo
# 	Ans =>
# Target==  na sa bata'
# 	Ans =>
# Target==  asa mo dapit gasuroy-suroy
# 	Ans =>
# Target==  pariha ana' oscar ana' ba
# 	Ans =>
# Target==  o adtuon lang nako' si jed
# 	Ans =>
# Target==  lech- litson na baboy
# 	Ans =>
# Target==  sa kuan lang kana' nga mga makaagi ko' og simbahan
# 	Ans =>
# Target==  girl manglaag kita' ila shirla sunod ba
# 	Ans =>  gngngn
# Target==  o mmm
# 	Ans =>
# Target==  uyabon uyab-uyab na man daw kuno
# 	Ans =>
# Target==  kato nga nabahaan ato' nga una ba
# 	Ans =>
# Target==  o ngano nalagot man ka ni ? o
# 	Ans =>  ggg gigi
# Target==  sa february mag-lima siya kabulan
# 	Ans =>
# Target==  musalig og kana' nga mga ingon ana' oy maningkamot ako' oy mangita' ko' og paagi kay lisod kaayo man gayod na ang
# 	Ans =>
# Target==  manok uniya' kaha iya elot unsa
# 	Ans =>
# Target==  og mas tigulang ko' sa imuha ba ?
# 	Ans =>
# Target==  lisod kana' ang bungol ba bungol baya' ko'
# 	Ans =>  a a
# Target==  si ?
# 	Ans =>
# Target==  o i-announce
# 	Ans =>
# Target==  kay malipong man kaha' siya ?
# 	Ans =>
# Target==  o wala' ? hinuon wala' man hinuon
# 	Ans =>  sisixinxcxoimin
# Target==  bitaw day tama' gayod ka day
# 	Ans =>  a
# Target==  dinhi man gayod mi mabuhi' bay
# 	Ans =>
# Target==  ? wala' diay giapas ni alex
# 	Ans =>
# Target==  wala' ing tarong og iskuwila sigi lang og climb-climb na
# 	Ans =>  a
# Target==  usa lay nagdungan nimo dong
# 	Ans =>  aa
# Target==  naako' wala' oy luuya oy
# 	Ans =>
# Target==  hapit na alas-dusi padulong siya duty ron
# 	Ans =>
# Target==  uniya' mama nimo nakauli' na
# 	Ans =>
# Target==  mao na nga ukasiyon na man libri gayod
# 	Ans =>
# Target==  dili' pod tama' tama' lang
# 	Ans =>  a
# Target==  guwapo man pod na ingon ana' salo-salo tanan mga
# 	Ans =>
# Target==  naa diay ka ing exam karon sayo man lagi
# 	Ans =>
# Target==  kana' nga dili' na siya magpalakas og kaon diay ti
# 	Ans =>
# Target==  unsa man nga naa man kay klasi inig gawas nimo sa klasi
# 	Ans =>  t
# 0 56.442565918 157.149932861
# 10 70.7189254761 176.445709229
# 20 106.30922699 212.469482422
# 30 66.2654495239 162.017623901
# 40 57.3753929138 156.986114502
# 50 71.0060958862 162.73147583
# 60 99.6066818237 218.338592529
# 70 51.3945198059 144.775421143
# 80 66.573890686 160.124008179
# 90 74.7339096069 175.941375732
#
# ===============================
# epoch 16 : pseudo= 73.4104136703, cost= 174.475905716, previous_cost= 159.468961326, train_time = 1074.94359803 s
# 4
# 			 val_= 0.975346465692, test_time  = 1.13148188591 s
# ===============================
#
# Target==  sila vannie okay man na kay mga taba' man
# 	Ans =>
# Target==  pangit man na ang rain or shine hinay kaayo na oy
# 	Ans =>
# Target==  mura lagi og dili' ikaw ?
# 	Ans =>
# Target==  no nagkauyab man diay mo ato' niya no
# 	Ans =>
# Target==  o karon na anhi lang diri
# 	Ans =>  a
# Target==  taod-taod taod-taod na sad
# 	Ans =>
# Target==  ay sigi man musulti man siya sa akua piro wala' ko' kita' sa lalaki giingnan nako' ayaw sa paadtua og balay
# 	Ans =>
# Target==  cook nako' dinha' mag-cook puwidi mag-cook nako' dinha'
# 	Ans =>
# Target==  o kato lang siya one three
# 	Ans =>
# Target==  ting-break time ? ? ting-break time
# 	Ans =>  ga
# Target==  mao lagi siguro sa kuan putol-putol
# 	Ans =>   ?
# Target==  uniya' kumusta man imo nga pa check-up balik nay
# 	Ans =>
# Target==  useless lang gihapon imo nga sigi ka og pangutana sa akua
# 	Ans =>  nan
# Target==  wal- wal- wala' diay bugas
# 	Ans =>
# Target==  ? kana' nga mga uso karon
# 	Ans =>     a
# Target==  oh wala' ing signal amo' nga bukid ?
# 	Ans =>
# Target==  o para ?
# 	Ans =>  y
# Target==  wala' pa wala' pa
# 	Ans =>
# Target==  si neneng og si sweetie ra man to
# 	Ans =>
# Target==  dako' na na nga panalangin sa ginuo
# 	Ans =>
# Target==  ? age does not matter bitaw na ati
# 	Ans =>
# Target==  maayo og madayon maayo og dili'
# 	Ans =>  a a
# Target==  namaligiya' man si caloy diri oh halos kami tanan namalit
# 	Ans =>
# Target==  dondie naunsa diay si dondie diay
# 	Ans =>  a
# Target==  prak- ? prak- ha
# 	Ans =>  ala
# Target==  maayo unta' og kumplito to nga ?
# 	Ans =>
# Target==  layas ? layas ni nga bataa ni bisan
# 	Ans =>  cpcptptpp
# Target==  mao ana' man gayod kana' dili' na man gayod kana' ma-control tir
# 	Ans =>
# Target==  na-addict na kaayo si doogie ba o
# 	Ans =>
# Target==  basi og imo nga suwirti naa sa lain wala' dinha'
# 	Ans =>
# Target==  duol pa gayod ka sa mga bata' nimo imo nga mga anak
# 	Ans =>  ai'
# Target==  o bag-o ato' dili' ka ? tsoy ato'
# 	Ans =>
# Target==  thursday ba huwibis
# 	Ans =>
# Target==  pagkadako' sa pabo oy mura man og kabaw
# 	Ans =>
# Target==  wala' pa ing valid i_d si papa
# 	Ans =>
# Target==  last year pabuto man kadto last year
# 	Ans =>
# Target==  hala no luuya gayod niya gayod
# 	Ans =>  g'
# Target==  ? unsa iya nga course kurso
# 	Ans =>
# Target==  ? magbaktas ? duol ra man pod
# 	Ans =>
# Target==  ha ?
# 	Ans =>
# 0 60.5626945496 164.606994629
# 10 51.0398254395 159.637054443
# 20 48.6511650085 155.739364624
# 30 49.7391548157 154.305709839
# 40 62.029712677 147.766571045
# 50 41.9130020142 151.06350708
# 60 64.3042831421 170.802093506
# 70 60.4975471497 146.793273926
# 80 54.6980705261 151.869567871
# 90 78.2494735718 169.119049072
#
# ===============================
# epoch 17 : pseudo= 60.7276804011, cost= 160.842493037, previous_cost= 174.475905716, train_time = 1075.43621802 s
# 4
# 			 val_= 0.978007875633, test_time  = 1.15247416496 s
# ===============================
#
# Target==  bumble bee ? sa ato' pa ? gayod diay ka
# 	Ans =>
# Target==  nindot na kadto imo nga kuan sa una
# 	Ans =>
# Target==  piro kad- kadali' ra man to nga si ati mildred
# 	Ans =>
# Target==  ? gahapon nakakuwarta kagahapon
# 	Ans =>
# Target==  ? wala' ra ba kay budget
# 	Ans =>
# Target==  ang tulo kakuan traha
# 	Ans =>
# ...
# Target==  dondie naunsa diay si dondie diay
# 	Ans =>  m du
# Target==  prak- ? prak- ha
# 	Ans =>  a  mig  ka taa
# Target==  maayo unta' og kumplito to nga ?
# 	Ans =>  banang pa po g kaa
# Target==  layas ? layas ni nga bataa ni bisan
# 	Ans =>  a aa ki asa
# Target==  mao ana' man gayod kana' dili' na man gayod kana' ma-control tir
# 	Ans =>  aoakala a gia gi li la mo gai na ka rapao pap
# Target==  na-addict na kaayo si doogie ba o
# 	Ans =>  aa bikao ga bag si ma
# Target==  basi og imo nga suwirti naa sa lain wala' dinha'
# 	Ans =>  la lii suan i na sana  mimga i'
# Target==  duol pa gayod ka sa mga bata' nimo imo nga mga anak
# 	Ans =>  dawaon pay kadta ka a pa tan m
# Target==  o bag-o ato' dili' ka ? tsoy ato'
# 	Ans =>  obuto sa ii a so gila ko
# Target==  thursday ba huwibis
# 	Ans =>  pisslula ba nudis
# Target==  pagkadako' sa pabo oy mura man og kabaw
# 	Ans =>  a padako kayo sata abuong dioo g tawba
# Target==  wala' pa ing valid i_d si papa
# 	Ans =>  a pa ban ayi papa
# Target==  last year pabuto man kadto last year
# 	Ans =>  aa -au tooo laa
# Target==  hala no luuya gayod niya gayod
# 	Ans =>  aria uaonau maiu
# Target==  ? unsa iya nga course kurso
# 	Ans =>  ? pa si ya n ku puso
# Target==  ? magbaktas ? duol ra man pod
# 	Ans =>  m pana kau na o
# Target==  ha ?
# 	Ans =>  a naa
# 0 -10.8109273911 55.9653816223
# 10 -1.03823781013 64.4868164062
# 20 -4.13614082336 66.8319320679
# 30 -15.4252567291 72.2331466675
# 40 -5.17421197891 54.0352363586
# 50 -12.7698078156 60.6938171387
# 60 -8.78385448456 63.744392395
# 70 -14.4101629257 57.8553695679
# 80 -8.04267597198 53.7268066406
# 90 -0.365563213825 60.227722168
#
# ===============================
# epoch 141 : pseudo= -6.62954105309, cost= 60.0009293095, previous_cost= 59.8389211675, train_time = 1058.68735886 s
# 4
# 			 val_= 0.730350145695, test_time  = 1.22981381416 s
# ===============================
#
# Target==  bumble bee ? sa ato' pa ? gayod diay ka
# 	Ans =>  nako ma galiy a sata bagatin tdi ka
# Target==  nindot na kadto imo nga kuan sa una
# 	Ans =>  ina ka ta i mang kuaan ga ga n
# Target==  piro kad- kadali' ra man to nga si ati mildred
# 	Ans =>   sa baa po ki nia ia
# Target==  ? gahapon nakakuwarta kagahapon
# 	Ans =>    kun na gakayt ma dgan
# Target==  ? wala' ra ba kay budget
# 	Ans =>  aa u ka nma' ka ka ga
# Target==  ang tulo kakuan traha
# 	Ans =>  t mapa ma ka a
# Target==  nagtrabaho davao light
# 	Ans =>  naya naba dna bala
# Target==  mao lagi ba unsa nga urasa muabot diay
# 	Ans =>  na na nayn' gansa ma ga pa muao ku
# Target==  ? ako' pod mupalit pod ko' og gatas sa ako' nga anak diri
# 	Ans =>  a  nga pa patiy mg pal ko pong dapasa kua a na niara
# Target==  unsa man ila nga gidula' ?
# 	Ans =>
# Target==  kuyawa gayod pila ang ?
# 	Ans =>  i a duan iy dila
# Target==  ipalihog ko' ingon nga
# 	Ans =>  ip ia
# Target==  ? sigi siya suroy-suroy
# 	Ans =>   ki gi ga mosio
# Target==  kuyawa no paspasa pod nila manganak no ?
# 	Ans =>  ia ma mgho sa sa sa poa o iamama ma pmmno si
# Target==  ? ? unsa man nawala' man nadawat
# 	Ans =>  aumi o ao ba nla wa  ma dia da wa
# Target==  ? uniya'
# 	Ans =>  ? kan nha
# Target==  piro wala' na ka miadto
# 	Ans =>  a bana na ka niya u sunna?
# Target==  bala kaayo ka maunahan gani' ka gani'
# 	Ans =>  pala a ta uanangg nlai
# Target==  ? mao gayod na
# 	Ans =>  na dy na
# Target==  kay daghan man gayod kaayo sila mama gayod dira'
# 	Ans =>  ikaka nang ka ka si la mang mang a di na
# Target==  arkilaha ?
# 	Ans =>  sila a da lai
# Target==  o asa man siya nag-iskuwila karon
# 	Ans =>   gay iagiaa na
# Target==  uniya' wala'-wala' wala' mo ing video ato' nga
# 	Ans =>  ?ana ana ma i paa mana mansana a n ti sila a to na
# Target==  kuyog piro ? hapon na lagi kaayo maayo man to nga nakuha kadto ganiha kay
# 	Ans =>  mulak a aakon naa diaro' ga ka na ka a nao ka nao niyk
# Target==  ? nangita' ta og kana' nga maayo unsa ing unsa og grasiya uniya' sa ginuo ba
# 	Ans =>   i ka a ta g  sa d a mu  ka sa sa igi ma
# Target==  ? usa na man lang ? mao diay wala' na lang
# 	Ans =>  ?ta a mala ba maoo diy g a ka ma
# Target==  blue uniya' blue ra pod ako' nga
# 	Ans =>  nia wo niagh la puonda napo wa ma
# Target==  o trisi
# 	Ans =>   sini
# Target==  mapundasiyunan ang kuan
# 	Ans =>  madiiia a gaunga
# Target==  magsakit-sakit biya' ni sarah og si janmar
# 	Ans =>   kasotaki gan ng isara kasi niya mg ma
# Target==  o ngano diay muuban ka
# 	Ans =>  na a ng anha daan moban ka
# Target==  ? ka didto sigi ra og tindog
# 	Ans =>   na nito ima kay mido
# Target==  ay usahay lang dili' man pod siya ingon nga dalo' piro
# 	Ans =>  a paa nang i ma ta agada sano
# Target==  uniya' kanus-a man to muuli' imo nga bana
# 	Ans =>  ua nia' kanska makalo mia ma to na
# Target==  ? si luke ? wala' na man siya ing ? wala' na man
# 	Ans =>  a si a nag ga sana sia ga kaagad
# Target==  ikaw kumusta na man mo sa imo nga uyab
# 	Ans =>  kawama si la ao ma si mo mona
# Target==  sa una mao man unta' to ang plano namo' sa una
# 	Ans =>  sasa ma ma kato klanla na mgsa na
# Target==  ? sunod ini og magkita' ta ?
# 	Ans =>  igo nana kino iy ia ga i ka ta
# Target==  og wala' nawala' ? abi nako' og wala' pa
# 	Ans =>  kan na ka bau adgi na ka ma
# Target==  o tabang ? kadto nga ? sa bohol ba
# 	Ans =>   kabua a mingo kakao i ko sa bug bo
# 0 -13.0196256638 56.3764724731
# 10 -0.584175884724 64.7963256836
# 20 -11.0231733322 67.2624893188
# 30 2.14263606071 69.0388946533
# 40 -9.37140083313 53.6033859253
# 50 -3.69017839432 69.2108612061
# 60 0.982167065144 63.5973739624
# 70 -3.57142043114 57.3761672974
# 80 -4.00238800049 54.0776176453
# 90 -11.3734426498 59.0349502563
#
# ===============================
# epoch 142 : pseudo= -6.94866363983, cost= 59.3827340731, previous_cost= 60.0009293095, train_time = 1059.92215705 s
# 4
# 			 val_= 0.706626781527, test_time  = 1.21854281425 s
# ===============================
#
# Target==  uo didto uo uo kadto bitaw tribute ba to
# 	Ans =>  aiakoo ka si ga kausa ta iiiapo
# Target==  ? college level man pod ?
# 	Ans =>  o koa ka gaanio ka nataa ka
# Target==  ambot oy tapos kuan
# 	Ans =>   mat dlatr pu  a
# Target==  si manilyn kana' iya nga damit ihat- ihatod
# 	Ans =>  maiiasaann na i ia
# Target==  kay manayaw mga bata' ?
# 	Ans =>   mana na ba
# Target==  na nga nag siyagit-siyagit
# 	Ans =>  ma
# Target==  ? ? basta ang suman ha ? og naa mabilin bigiyan mo gayod ko'
# 	Ans =>  ba sanomaga kolaia mabi dai ni po
# Target==  ay okay lang okay lang gihapon
# 	Ans =>  ta rsia ma kpanana gayan
# Target==  sila nanti naana' sila nga nanti naana'
# 	Ans =>  ala ana ko na na sa lan ti naa na
# Target==  mmm kanus-a man kadto mangha-
# 	Ans =>   pausia s maa
# Target==  ? ?
# 	Ans =>  a i inka o ka a
# Target==  didto siya na assign sa una mao nga didto gani' mi nagkita'
# 	Ans =>  idisiy na san sao lai mg ida rongakuta
# Target==  gahapon unsa diay ?
# 	Ans =>  apa a ka i ko
# Target==  naa ing gamay naa sa ing buhat sakto ra naa ra ing kuan gayod
# 	Ans =>  gnlaka ma basio sa atu nai kuadi
# Target==  ? basta maayo lang nga pagkatrabaho basta dili' lang ingon nga
# 	Ans =>  bodita aba kasa ma ma pa ma tabn ma sabili ia?
# Target==  ay commercial ipaganda o ipaganda
# 	Ans =>   to a na i taga dia  k
# Target==  tigtubig boy lang ta sa ilaha
# 	Ans =>   kao gi  ka a g ka
# Target==  mawala'-wala' lagi ka dili' kaayo ta ka madungog
# 	Ans =>  oankolaaa i gi ia ma a
# Target==  ? lagi impas na akua piro ang prublima diri ko' nga ma-flat-an mahurot sa hantakan tanan ?
# 	Ans =>  lagisa saku kouto gima di mbapa pa kuaoaapapt
# Target==  natingala gani' siya nga duha ra daw kabulan kapin
# 	Ans =>  ia nanglia nau nana o kaun a adb
# Target==  dalan lang tika dalan tika
# 	Ans =>  ska tao da i a
# Target==  ay gibalita' na pod diay naana' pod bagiyo
# 	Ans =>   gigalana pa dia na na kabadi
# Target==  anhi lang diri ini og human nimo og panglaba
# 	Ans =>  nia i i i mua kanglata
# Target==  naana' la ?
# 	Ans =>  naalala
# Target==  laa- mukuan sala' gani' to sila musimba
# 	Ans =>  nlakog ga kann ian iaba
# Target==  aw o si lenny ang kauban niya si kuan maricris
# 	Ans =>  wsi kawanisi kamamii a ka mg panan sia
# Target==  ? lisod na ang ingon miana' mok
# 	Ans =>   ka a dia lao
# Target==  mmm ana' gayod kana' mari gayod kinahanglan
# 	Ans =>   magaanidaia
# Target==  ? didto sa ingon nila nga guadalupe unsa kadto nga lugara kadto
# 	Ans =>  duo di saio dia sl mua ua o diyt na day
# Target==  iskuwila tanan o humana ang uban
# 	Ans =>
# Target==  o ato' ra man gihapon na ba inig
# 	Ans =>   uanankai
# Target==  ? daghan og dalhon tika
# 	Ans =>  too  bam ka ka
# Target==  wala' ing signal amo' nga bukid ? bukid
# 	Ans =>   sina kaook
# Target==  pait kaayo amo' nga kinabuhi' ingon ana' ra oy motor-motor pait kaayo
# 	Ans =>   kia mo naglagagha ma kay o a kulnato n bakay
# Target==  sapatos bag-o nga sapatos alangan dili' ka magsapatos
# 	Ans =>  uapo mabuokto ma na dia sato
# Target==  oh oh oh dinha' gayod
# 	Ans =>   madia
# Target==  uo mag-propose nako' sa imo hapit na
# 	Ans =>   ma o kuos mlako sai baiona
# Target==  three years lang baya' sila didto
# 	Ans =>   a
# Target==  diri sa kuan gayod sa may iskuwilahan duol banda
# 	Ans =>  disa suanusa mastnan diman da
# Target==  pila na may anak nimo karon
# 	Ans =>  dina man kat ma
# 0 2.52467346191 56.5684585571
# 10 -9.93716907501 63.1102828979
# 20 -8.00631713867 66.0062408447
# 30 3.79015660286 69.1305999756
# 40 -11.3771219254 53.9405632019
# 50 -7.54358243942 59.7253341675
# 60 1.4317253828 62.9529495239
# 70 -17.1335296631 57.8266105652
# 80 -15.0321903229 53.8856506348
# 90 -11.777636528 58.1727523804
#
# ===============================
# epoch 143 : pseudo= -7.28123898035, cost= 58.713104125, previous_cost= 59.3827340731, train_time = 1061.9902389 s
# 4
# 			 val_= 0.716525402266, test_time  = 1.23768591881 s
# ===============================
#
# Target==  mikalit man gayod kadto nga nga naa ing talk uniya' kuan pod ba kana' nga ?
# 	Ans =>  itl ma gdto a maatopo na kuiaanig pon ba kaba nsn
# Target==  ay nagtrabaho ko' sa kuan sa factory
# 	Ans =>   na paoa kan
# Target==  gikuan kuno to ? gipalitan to og itlog
# 	Ans =>  ia bana uasibguanang karo na ka gato si giuo
# Target==  ayaw kay gutom gayod na nga alas-dusi na man
# 	Ans =>   po gnalas u sian
# Target==  ma-level ba diay nako' nga sumbagay lang
# 	Ans =>  a ga no ma dnaa ma ma sabang gawaa
# Target==  sa akua diay dili' madunggan nimo
# 	Ans =>  msanandimgagi nadalaa
# Target==  na sa bata'
# 	Ans =>  ako saa kana
# Target==  asa mo dapit gasuroy-suroy
# 	Ans =>  apo moa da si disu li sa ra
# Target==  pariha ana' oscar ana' ba
# 	Ans =>  pa na musa kanabaa
# Target==  o adtuon lang nako' si jed
# 	Ans =>   atun lang mak a
# Target==  lech- litson na baboy
# 	Ans =>  a ii sa na babaygi
# Target==  sa kuan lang kana' nga mga makaagi ko' og simbahan
# 	Ans =>  k  a anaaaa na si sa
# Target==  girl manglaag kita' ila shirla sunod ba
# 	Ans =>  ia uoua sta la say la sa g ba
# Target==  o mmm
# 	Ans =>   u
# Target==  uyabon uyab-uyab na man daw kuno
# 	Ans =>  ka koi tiatonai ga angktowko  a
# Target==  kato nga nabahaan ato' nga una ba
# 	Ans =>  mana maanasa mai
# Target==  o ngano nalagot man ka ni ? o
# 	Ans =>  o a a a na ga kay naa
# Target==  sa february mag-lima siya kabulan
# 	Ans =>  aka dalimai pasia kaku san
# Target==  musalig og kana' nga mga ingon ana' oy maningkamot ako' oy mangita' ko' og paagi kay lisod kaayo man gayod na ang
# 	Ans =>  a a a
# Target==  manok uniya' kaha iya elot unsa
# 	Ans =>  bano iaasa ianoa
# Target==  og mas tigulang ko' sa imuha ba ?
# 	Ans =>   sia's si bula na ko simua mao maati
# Target==  lisod kana' ang bungol ba bungol baya' ko'
# 	Ans =>  niasa mana buo ba baobi ko
# Target==  si ?
# 	Ans =>  a sa kaia gi dgta
# Target==  o i-announce
# 	Ans =>   si baadala
# Target==  kay malipong man kaha' siya ?
# 	Ans =>  a a giikong mang basiagay
# Target==  o wala' ? hinuon wala' man hinuon
# 	Ans =>   wana nanguanla ma ganao
# Target==  bitaw day tama' gayod ka day
# 	Ans =>  li ta diataha sia ka ba
# Target==  dinhi man gayod mi mabuhi' bay
# 	Ans =>  siia nai da di o pili ta
# Target==  ? wala' diay giapas ni alex
# 	Ans =>  akua aa daita pata ka i
# Target==  wala' ing tarong og iskuwila sigi lang og climb-climb na
# 	Ans =>   dara pi nag inklasila na'
# Target==  usa lay nagdungan nimo dong
# 	Ans =>  iania na ku ia mado
# Target==  naako' wala' oy luuya oy
# 	Ans =>  kla kato laa k mulau
# Target==  hapit na alas-dusi padulong siya duty ron
# 	Ans =>  apikalin ko si iamai otio
# Target==  uniya' mama nimo nakauli' na
# 	Ans =>  mna a a a
# Target==  mao na nga ukasiyon na man libri gayod
# 	Ans =>  uana uapua sia na ba diba bi
# Target==  dili' pod tama' tama' lang
# 	Ans =>  i a nana ta mana
# Target==  guwapo man pod na ingon ana' salo-salo tanan mga
# 	Ans =>  apa poan na na sau sa si pa moo
# Target==  naa diay ka ing exam karon sayo man lagi
# 	Ans =>  aa na gaka alan pay ma maiy
# Target==  kana' nga dili' na siya magpalakas og kaon diay ti
# 	Ans =>  ka na g uii ma banapa okao dayt
# Target==  unsa man nga naa man kay klasi inig gawas nimo sa klasi
# 	Ans =>  a ma nama ki ka kaka li kaa sa ua sa sia s
# 0 -9.46170806885 54.8989143372
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-96efb20fc75d> in <module>()
# ----> 1 get_ipython().magic(u'time model2L_noNoise_with313.fit( x_train, y_train, x_valid, y_valid, x_train_mask, y_train_mask , x_valid_mask, y_valid_mask )')
#
# /home/pika/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2302         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2303         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2304         return self.run_line_magic(magic_name, magic_arg_s)
#    2305
#    2306     #-------------------------------------------------------------------------
#
# /home/pika/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2223                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2224             with self.builtin_trap:
# -> 2225                 result = fn(*args,**kwargs)
#    2226             return result
#    2227
#
# /home/pika/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#
# /home/pika/anaconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /home/pika/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1160         if mode=='eval':
#    1161             st = clock2()
# -> 1162             out = eval(code, glob, local_ns)
#    1163             end = clock2()
#    1164         else:
#
# <timed eval> in <module>()
#
# <ipython-input-9-4cd8bf92a8d3> in fit(self, x_train, y_train, x_test, y_test, x_mask, y_mask, x_test_mask, y_test_mask)
#     153             for index in range(len(x_train)):
#     154                 pseudo, cost, output_softmax = self.train( x_train[index] , y_train[index],
# --> 155                                                           x_mask[index], y_mask[index])
#     156                 cs += cost
#     157                 pseudo_cs += pseudo
#
# /home/pika/anaconda/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     595         t0_fn = time.time()
#     596         try:
# --> 597             outputs = self.fn()
#     598         except Exception:
#     599             if hasattr(self.fn, 'position_of_error'):
#
# /home/pika/anaconda/lib/python2.7/site-packages/theano/scan_module/scan_op.pyc in rval(p, i, o, n, allow_gc)
#     670         def rval(p=p, i=node_input_storage, o=node_output_storage, n=node,
#     671                  allow_gc=allow_gc):
# --> 672             r = p(n, [x[0] for x in i], o)
#     673             for o in node.outputs:
#     674                 compute_map[o][0] = True
#
# /home/pika/anaconda/lib/python2.7/site-packages/theano/scan_module/scan_op.pyc in <lambda>(node, args, outs)
#     659                         args,
#     660                         outs,
# --> 661                         self, node)
#     662         except (ImportError, theano.gof.cmodule.MissingGXX):
#     663             p = self.execute
#
# KeyboardInterrupt:

# %%
＃ Not used below

# %% [markdown]
# # Only Process once

# %%
''' 
[ Doing : ]
    - Read character from *.txt to build the corpus 

[ Result : ]

-- Without Develope Data:

Building corpus without develope data:
set([' ', "'", '-', '?', '_', 'a', 'c', 'b', 'e', 'd', 'g', 'f', 'i', 'h', 'k', 'j', 'm', 'l', 'o', 'n', 'q', 'p', 's', 'r', 'u', 't', 'w', 'v', 'y', 'x', 'z'])
Total len is : 31
Done Write to [./dataCebuano/corpus.txt]

-- With Develope Data:

Building corpus with develope data:
set([' ', "'", ')', '(', '-', '?', '_', 'a', 'c', 'b', 'e', 'd', 'g', 'f', 'i', 'h', 'k', 'j', 'm', 'l', 'o', 'n', 'q', 'p', 's', 'r', 'u', 't', 'w', 'v', 'y', 'x', 'z'])
Total len is : 33
Done Write to [./dataCebuano/corpus.txt]
'''

TRAINING_LABEL = "./dataCebuano/train.txt"
DEVELOPE_LABEL = "./dataCebuano/dev.txt"
WRITING_TO = "./dataCebuano/corpus.txt"

# Special part to build corpus
def buildCharacterCorpus(withDevelopeData = False) :
    corpus = set( )
    with open(TRAINING_LABEL, 'r') as ft:
        for lines in ft:
            for word in lines.split('\n')[0].split(' ')[1:]:
                if word[0] == '<':
                    # We take every <...> as <unk> 
                    unKnownTag = '?'
                    corpus.add( unKnownTag ) 
                else:
                    for char in word:
                        corpus.add(char.lower())
    
    if( withDevelopeData ) :
        with open(DEVELOPE_LABEL, 'r') as fd:
            for lines in fd:
                for word in lines.split('\n')[0].split(' ')[1:]:
                    if word[0] == '<':
                        unKnownTag = '?'
                        corpus.add( unKnownTag ) 
                        # corpus.add(word.split('\n')[0].lower())
                    else:
                        for char in word:
                            corpus.add(char.lower())
    
    corpus.add(' ')
    print "Building corpus with" + ("" if withDevelopeData else "out") + " develope data:"
    print corpus
    print "Total len is : " + str(len(corpus))
    
    
    with open(WRITING_TO, 'w+') as fw:
        for item in corpus:
            fw.write(item + '\n')        
    print "Done Write to [" + WRITING_TO + "]"
    return corpus

trainingCorpus = buildCharacterCorpus()
# Out:
# Building corpus without develope data:
# set([' ', "'", '-', '?', '_', 'a', 'c', 'b', 'e', 'd', 'g', 'f', 'i', 'h', 'k', 'j', 'm', 'l', 'o', 'n', 'q', 'p', 's', 'r', 'u', 't', 'w', 'v', 'y', 'x', 'z'])
# Total len is : 31
# Done Write to [./dataCebuano/corpus.txt]

# %%
# import theano
# from theano import tensor as T
# from theano.sandbox.rng_mrg import MRG_RandomStreams as RandomStreams
import numpy as np

from sklearn import cross_validation as cv
from sklearn import metrics
from sklearn import grid_search as gs
from sklearn.metrics import accuracy_score
from itertools import repeat

#proprocessor
from sklearn import preprocessing
from time import time

from itertools import repeat
import numpy as np
import random
from sklearn import preprocessing


def floatX(X):
    return np.asarray(X, dtype=theano.config.floatX)

def vectorized_result ( j , siz) :
    e = np.zeros((siz, 1))
    e[j] = 1.0
    return np.reshape( e, siz)

TRAINING_DATA   = './dataCebuano/train.f0_ffv_fbank.fea'
# VALIDATION_DATA = './dataCebuano/dev.f0_ffv_fbank.fea'
TRAIN_ARK  = './dataCebuano/train_Normalized_SELFVALID.ark'
# TRAIN_ARK  = './dataCebuano/train_Normalized_SELFVALID_LenLessThen600.ark'


def normalizeAndFilterData ( maxLength = 3000) :
    # Dataset
    x_data = []
    x_name = []
    record_seq = []

    with open( TRAINING_DATA, 'r') as f:
        for lines in f: 
            if '[' in lines :
                id = lines.split(' ')[0]
                x_name.append(id)
                seq = 0
            elif ']' in lines :
                if seq > maxLength :
                    x_name.pop()
                    del x_data[-seq:]
                else :
                    seq += 1
                    record_seq.append(seq)
                    x_data.append([float(x) for x in lines.split(' ') [2:-1] ])
            else :
                seq += 1
                x_data.append([float(x) for x in lines.split(' ') [2:-1] ])

    print "Normalized"
    x_data = preprocessing.scale( np.array(x_data) )

    # x_data[separate+1]
    # x_name
    bitch = record_seq.index(max(record_seq))
    print "Max len is ", record_seq[bitch]
    
    print "Total training data", len(x_name)

    # trainF = open(TRAIN_ARK, 'w+')
    with open(TRAIN_ARK, 'w+') as trainF:
        currentSeq = 0
        for nameIndex in range( len(x_name) ):

            trainF.write(str(x_name[nameIndex])+"  [\n")

            for valueIndex in range( (record_seq[nameIndex]) ):
                for featureIndex in range( len(x_data[0]) ):
                    if ( featureIndex+1) != len(x_data[0] ) :
                        trainF.write( str(x_data[ currentSeq  + valueIndex][featureIndex]) + " ")
                    else:
                        trainF.write( str(x_data[ currentSeq  + valueIndex][featureIndex]) )
                if valueIndex+1 == (record_seq[nameIndex]):
                    trainF.write(" ]\n")
                else:
                    trainF.write("\n")
            currentSeq += record_seq[nameIndex]

    print "MIssion ComplEte"


normalizeAndFilterData(3000)
# Out:
# Normalized
# The Max index id  370
# Max len is  2784
# Total training data 4145
# what is x_data len 1071703
# what is x_seq len 4145
# MIssion ComplEte

# %%
# Out:
# array([[ 0.01      ,  0.002     ],
#        [ 1.20000005,  1.10000002]], dtype=float32)
