# %% [markdown]
# # CTC version 1
#
#
#
#
# ### Paper Reference
# - [Connectionist Temporal Classification (IDSIA)](ftp://ftp.idsia.ch/pub/juergen/icml2006.pdf)
#
#
# ### English Test
# First we test English

# %%
# Include And 
import sys
sys.path.append("/home/pika/nntools/")

import theano
import theano.tensor as T
import numpy as np
from theano_toolkit import utils as U
from theano_toolkit import updates
from theano.printing import Print
from theano_toolkit.parameters import Parameters

import lasagne
from lasagne.layers import *

from time import time

import ctc_cost_2

import cPickle
import sys
sys.setrecursionlimit(100000)

from random import shuffle

# %% [markdown]
# # Data

# %%
'''
Doing : 
    - Read data and return x_test, y_test
'''
# TRAINING_ACOUSTIC_FEATURE = "./dataCebuano/train.f0_ffv_fbank.fea"
# TRAINING_ACOUSTIC_FEATURE = "./dataCebuano/train_Normalized_SELFVALID.ark"
# TRAINING_ACOUSTIC_FEATURE = "./dataCebuano/train_Normalized_SELFVALID_LenLessThen500.ark"
# TRAINING_LABELS = "./dataCebuano/train.txt"

# TESTING_ACOUSTIC_FEATURE = './dataCebuano/dev_Normalized_SELFVALID_originLength.ark'
TESTING_ACOUSTIC_FEATURE = './dataCebuano/dev_Normalized_SELFVALID_LenLessThen500.ark'
TESTING_LABELS = './dataCebuano/dev.txt'


CHAR_CORPUS = "./dataCebuano/corpus.txt"


def readDataSet () :
    
    # -- Mapping char to integer and reverse
    char_map = {}    # eg. { a -> 1 }
    char_unMap = {}  # eg. { 1 -> a }
    with open( CHAR_CORPUS, 'r' ) as f:
        char_index = 0
        for lines in f:
            char_map  [ lines[:-1] ] = char_index
            char_unMap[ char_index ] = lines[:-1]
            char_index += 1
        # add Blank, take '.' as blank (not space)
        char_map['.'] = char_index
        char_unMap[char_index] = '.'
    
    
    # -- Reading X = id -> [ list of feature ] 
    idMapX = {}
    idDeck = []
    id = ''
    
    tmp_l = 0;
    with open( TESTING_ACOUSTIC_FEATURE, 'r') as f:
        for lines in f: 
            if '[' in lines :
                id = lines.split(' ')[0]
                idDeck.append(id)
                idMapX[id] = []
            elif ']' in lines :
                if( len( lines.split('\n')[0].split(' ') [0:-1] ) != 33 ) :
                    print "err"
                    return 
                idMapX[id].append([float(x) for x in lines.split('\n')[0].split(' ') [:-1] ])
            else :
                if( len( lines.split('\n')[0].split(' ')) != 33 ):
                    print len( lines.split('\n')[0].split(' '))
                    print lines.split('\n')[0].split(' ')
                    print lines
                    print id
                    print "fuck"
                    return
                idMapX[id].append([float(x) for x in lines.split('\n')[0].split(' ') ])
    
    # Move to  3 - main - 3
    '''
    monoDimension = 33;
    zeroFeature = [0] * monoDimension
    #print len( zeroFeature ) 
    #print zeroFeature
    for id in idDeck:
        # print id
        tmpIdMapXWithID = []
        if len(idMapX[id]) < 6 :
            print "ERROR in length"
            return 
        for idxX in xrange( len(idMapX[id]) ):
            if idxX == 0:
                tmpIdMapXWithID.append( zeroFeature + zeroFeature + zeroFeature + idMapX[id][idxX] + idMapX[id][idxX+1] + idMapX[id][idxX+2] + idMapX[id][idxX+3] )    
            elif idxX == 1:
                tmpIdMapXWithID.append( zeroFeature + zeroFeature + idMapX[id][idxX-1] + idMapX[id][idxX] + idMapX[id][idxX+1] + idMapX[id][idxX+2] + idMapX[id][idxX+3] )  
            elif idxX == 2:
                tmpIdMapXWithID.append( zeroFeature + idMapX[id][idxX-2] + idMapX[id][idxX-1] + idMapX[id][idxX] + idMapX[id][idxX+1] + idMapX[id][idxX+2] + idMapX[id][idxX+3] )  
            elif idxX == (len(idMapX[id]) - 3 ):
                tmpIdMapXWithID.append( idMapX[id][idxX-3] + idMapX[id][idxX-2] + idMapX[id][idxX-1] + idMapX[id][idxX] + idMapX[id][idxX+1] + idMapX[id][idxX+2] + zeroFeature )  
            elif idxX == (len(idMapX[id]) - 2 ):
                tmpIdMapXWithID.append( idMapX[id][idxX-3] + idMapX[id][idxX-2] + idMapX[id][idxX-1] + idMapX[id][idxX] + idMapX[id][idxX+1] + zeroFeature + zeroFeature )  
            elif idxX == (len(idMapX[id]) - 1 ):
                tmpIdMapXWithID.append( idMapX[id][idxX-3] + idMapX[id][idxX-2] + idMapX[id][idxX-1] + idMapX[id][idxX] + zeroFeature + zeroFeature + zeroFeature )  
            else:
                tmpIdMapXWithID.append( idMapX[id][idxX-3] + idMapX[id][idxX-2] + idMapX[id][idxX-1] + idMapX[id][idxX] + idMapX[id][idxX+1] + idMapX[id][idxX+2] + idMapX[id][idxX+3] )  
        idMapX[id] = tmpIdMapXWithID
    
    print "Concate"
    '''
    # Standardlize X (Done in PrepreProcessing )
   
    id_test = idDeck
    
    idMapY = {} 
    
    checkPara = 0
    # -- Reading Y = id -> [ Sentence(list of char[int] ) ]
    with open( TESTING_LABELS, 'r') as f:
        specific = '?'
        for lines in f:
            yWithId = lines.split('\n')[0].split(' ', 1)
            idMapY[ yWithId[0] ] = []
            judgeSpecific = False
            for char in yWithId[1] :
                if char == '(' and checkPara == 0 : 
                    checkPara = 3
                elif checkPara > 0 :
                    checkPara -= 1
                    if checkPara == 0 :
                        idMapY[ yWithId[0] ].append( char_map[specific] )
                else :
                    if char == '<' :
                        judgeSpecific = True;                
                    if( judgeSpecific ):
                        if char == '>':
                            idMapY[ yWithId[0] ].append( char_map[specific] )
                            judgeSpecific = False
                    else :
                        idMapY[ yWithId[0] ].append( char_map[char.lower()] )
    
    # -- concatenate X and Y
    x_test = []
    y_test = []
    idCollect = []
    for id in id_test:
        concateId = []
        for i in range( len( idMapX[id] ) ) :
            concateId.append( idMapX[id][i] )
        x_test.append( floatX( concateId )  )
        y_test.append( floatX( idMapY[id]) )
        idCollect.append( id )
    
    print "Dataset Finish : "
    print "total x_test = " + str(len(x_test))
    print x_test[0]
    print "total y_test = " + str(len(y_test))
    print y_test[0]
    
    return char_map, char_unMap, x_test, y_test, idCollect

def floatX(x):
    return np.asarray(x, dtype=theano.config.floatX)

# Original 4381
# lessthen500 4157

char_map, char_unMap, x_test, y_test, idCollect = readDataSet()
# Out:
# Dataset Finish :
# total x_test = 4157
# [[-1.48412788 -1.32281327 -1.62171197 ...,  0.41936278  0.861175
#    2.51489568]
#  [-0.99721181 -1.39681101 -1.95588279 ...,  0.34756452  0.92658424
#    2.46758008]
#  [-1.3102293  -1.76679909 -1.80736244 ...,  0.27932435  0.69767028
#    2.47513175]
#  ...,
#  [ 1.13258958  0.5556218   0.08627325 ...,  1.43581188  1.62581968
#    0.10516509]
#  [ 0.98845166  0.43940517 -0.13650745 ...,  0.99968147  1.29053867
#    0.42814341]
#  [ 0.88903505  0.2681343  -0.54493833 ...,  1.25104654  1.52039433
#    1.29349518]]
# total y_test = 4157
# [ 24.  19.  12.  28.   5.   1.   0.  14.  24.  16.  24.  22.  25.   5.   0.
#   16.   5.  19.   0.  12.  16.  18.   0.  19.  10.   5.   0.   8.  29.   5.
#   16.   0.  10.   5.  19.  12.  19.   5.   0.  15.  24.  19.   0.  21.   5.
#   22.   5.  23.   0.  14.   5.   9.  25.  18.   0.  15.  24.  19.]

# %%
# 500 -> 3722 / 195
# 600 -> 3821 / 201
# 3000 -> 3937 / 207
print x_test[0].shape
print y_test[0].shape
# Out:
# (288, 33)
# (58,)

# %%
len(x_test)
# Out:
# 4157

# %%
print max( [X.shape[0] for X in x_test] )
print max( [Y.shape[0] for Y in y_test] )
# Out:
# 501
# 127

# %%
'''
def make_batches_X(XLen, X, length, batch_size=30):
    n_batches = int(round(XLen*1./batch_size))
    X_batch = np.zeros( (n_batches, batch_size, length, X[0].shape[1]),
                       dtype=theano.config.floatX)
    X_mask  = np.zeros( (n_batches, length, batch_size ), 
                       dtype=theano.config.floatX)

    count = 0
    for b in range(n_batches): 
        for n in range(batch_size): # go thorough batch size
            
            if ( XLen > (b*batch_size + n )):
                count += 1
                
                X_m = X[b*batch_size + n] # seq_length X feature dim
                X_batch[b, n, :X_m.shape[0]] = X_m[:length]
                X_mask[b, :X_m.shape[0], n] = 1
    print count
            
    return X_batch, X_mask

'''

def make_batches_X(X, length, batch_size=30):
    n_batches = len(X)//batch_size
    X_batch = np.zeros( (n_batches, batch_size, length, X[0].shape[1]),
                         dtype=theano.config.floatX)
    X_mask  = np.zeros( (n_batches, length, batch_size ), 
                         dtype=theano.config.floatX)
    
    for b in range(n_batches): 
        for n in range(batch_size): # go thorough batch size       
            X_m = X[b*batch_size + n] # seq_length X feature dim            
            X_batch[b, n, :X_m.shape[0]] = X_m[:length]
            X_mask[b, :X_m.shape[0], n] = 1
            
    return X_batch, X_mask

def make_batches_Y( X, length, batch_size=30):
    n_batches = len(X)//batch_size
    
    X_batch = np.zeros( (n_batches, length, batch_size ), dtype='float32')
    
    X_mask = np.zeros(X_batch.shape, dtype=theano.config.floatX)
    
    for b in range(n_batches):
        for n in range(batch_size):
            X_m = X[ b*batch_size + n ]
            X_batch[b, :X_m.shape[0], n ] = X_m[:length]
            X_mask[b, :X_m.shape[0], n] = 1
    return X_batch, X_mask

# %%
'''
batch_size = 12

# Find the longest sequence
# length_x = max( [X.shape[0] for X in x_test] )

# length_x = 1670
length_y = 206

# Convert to batches of time series of uniform length
# x_test_mask: seq_length X batch_size
# y_test_mask: output_length X batch_size
# y_pred_mask = x_test_mask, since pred by sequence


# x_test, x_test_mask = make_batches_X(len(x_test), x_test, length_x, batch_size)
y_test, y_test_mask = make_batches_X(len(y_test), y_test, length_y, batch_size)
'''

batch_size = 40
# batch_size = 12

# Find the longest sequence
length_x = max( [X.shape[0] for X in x_test] )
length_y = max( [X.shape[0] for X in y_test] )

# Convert to batches of time series of uniform length
# x_train_mask: seq_length X batch_size
# y_train_mask: output_length X batch_size
# y_pred_mask = x_train_mask, since pred by sequence
x_test, x_test_mask = make_batches_X(x_test, length_x, batch_size)
y_test, y_test_mask = make_batches_Y(y_test, length_y, batch_size)

# %%
print x_test.shape
print y_test.shape
print "===============mask================"
print x_test_mask.shape
print y_test_mask.shape

# print x_test_mask[0][400][0]
# Out:
# (103, 40, 501, 33)
# (103, 127, 40)
# ===============mask================
# (103, 501, 40)
# (103, 127, 40)

# %% [markdown]
# # Model Part

# %%
def _count_grade( r, h):
    d = np.zeros((len(r)+1)*(len(h)+1), dtype=np.uint8)
    d = d.reshape((len(r)+1, len(h)+1))
    for i in range(len(r)+1):
        for j in range(len(h)+1):
            if i == 0:
                d[0][j] = j
            elif j == 0:
                d[i][0] = i
    # computation
    for i in range(1, len(r)+1):
        for j in range(1, len(h)+1):
            if r[i-1] == h[j-1]:
                d[i][j] = d[i-1][j-1]
            else:
                substitution = d[i-1][j-1] + 1
                insertion    = d[i][j-1] + 1
                deletion     = d[i-1][j] + 1
                d[i][j] = min(substitution, insertion, deletion)
    point = float(d[len(r)][len(h)])/float(len(r))
    # print point 
    return point

# %%
print _count_grade( "hello", "hi")
# Out:
# 0.8

# %%
'''
credit by NLTK package of measure edit distance
'''
# real, hypothesis
def wer(r, h):
    """
        Calculation of WER with Levenshtein distance.
        Works only for iterables up to 254 elements (uint8).
        O(nm) time ans space complexity.

        >>> wer("who is there".split(), "is there".split()) 
        1
        >>> wer("who is there".split(), "".split()) 
        3
        >>> wer("".split(), "who is there".split()) 
        3
    """
    # initialisation
    import numpy
    d = numpy.zeros((len(r)+1)*(len(h)+1), dtype=numpy.uint8)
    d = d.reshape((len(r)+1, len(h)+1))
    for i in range(len(r)+1):
        for j in range(len(h)+1):
            if i == 0:
                d[0][j] = j
            elif j == 0:
                d[i][0] = i

    # computation
    for i in range(1, len(r)+1):
        for j in range(1, len(h)+1):
            if r[i-1] == h[j-1]:
                d[i][j] = d[i-1][j-1]
            else:
                substitution = d[i-1][j-1] + 1
                insertion    = d[i][j-1] + 1
                deletion     = d[i-1][j] + 1
                d[i][j] = min(substitution, insertion, deletion)

    return d[len(r)][len(h)] * 1.0 / len(r)


def _edit_dist_init(len1, len2):
    lev = []
    for i in range(len1):
        lev.append([0] * len2)  # initialize 2D array to zero
    for i in range(len1):
        lev[i][0] = i           # column 0: 0,1,2,3,4,...
    for j in range(len2):
        lev[0][j] = j           # row 0: 0,1,2,3,4,...
    return lev


def _edit_dist_step(lev, i, j, s1, s2, transpositions=False):
    c1 = s1[i - 1]
    c2 = s2[j - 1]

    # skipping a character in s1
    a = lev[i - 1][j] + 1
    # skipping a character in s2
    b = lev[i][j - 1] + 1
    # substitution
    c = lev[i - 1][j - 1] + (c1 != c2)

    # transposition
    d = c + 1  # never picked by default
    if transpositions and i > 1 and j > 1:
        if s1[i - 2] == c2 and s2[j - 2] == c1:
            d = lev[i - 2][j - 2] + 1

    # pick the cheapest
    lev[i][j] = min(a, b, c, d)


def check_label_error( real , predict, transpositions=False):
    ## length of real >= length of predict
    """
    Calculate the Levenshtein edit-distance between two strings.
    The edit distance is the number of characters that need to be
    substituted, inserted, or deleted, to transform s1 into s2.  For
    example, transforming "rain" to "shine" requires three steps,
    consisting of two substitutions and one insertion:
    "rain" -> "sain" -> "shin" -> "shine".  These operations could have
    been done in other orders, but at least three steps are needed.

    This also optionally allows transposition edits (e.g., "ab" -> "ba"),
    though this is disabled by default.

    :param s1, s2: The strings to be analysed
    :param transpositions: Whether to allow transposition edits
    :type s1: str
    :type s2: str
    :type transpositions: bool
    :rtype int
    """
    # set up a 2-D array
    len1 = len(predict)
    len2 = len(real)
    lev = _edit_dist_init(len1 + 1, len2 + 1)

    # iterate over the array
    for i in range(len1):
        for j in range(len2):
            _edit_dist_step(lev, i + 1, j + 1, predict, real, transpositions=transpositions)
            
    return lev[len1][len2]*1.0/len2


def clean_up( y ):
    """
    for final output clean up
    B(a − ab−) = B(−aa − −abb) = aab
    """
    answer = ""

    for i in range(len(y)):
        if y[i] == '.':
            continue
        else:
            if y[i-1] != y[i]:
                answer += y[i]
    
    return answer

def remap_back( y , actual):
    answer = ""
    
    for i in y:
        answer += char_unMap[i]
    
    if not actual:
        answer = clean_up(answer)
        
    return answer

def decode_all_actual( y, y_mask ,batch_size , actual=False):
    """
    y     : label_length X batch_size
    y_mask: label_length X batch_size
    """
    result = []
    for i in xrange(batch_size):
        mask = np.swapaxes( y_mask, 0, 1)[i]
        ans = np.swapaxes( y, 0 , 1)[i]
        result.append(remap_back( ans[np.nonzero(mask)] , actual ))
    return result


def decode_all_pred( y, y_mask ,batch_size , actual=False):
    """
    y     : label_length X batch_size
    y_mask: label_length X batch_size
    """
    result = []
    for i in xrange(batch_size):
        mask = np.swapaxes( y_mask, 0, 1)[i]
        ans = y[i]
        result.append(remap_back( ans[np.nonzero(mask)] , actual ))
    return result

def check_all( y, y_mask, y_pred, y_pred_mask, batch_size ):
    
    actual = decode_all_actual( y, y_mask, batch_size , True )
    predict = decode_all_pred( y_pred, y_pred_mask, batch_size , False )
    
    error = 0.
    for a,b in zip (actual, predict):
        error += check_label_error(a,b)
    
    return error/len(actual)

# %%
class end_to_end():  
    def __init__(self, input_shape, max_seq_length, hidden_layer,
                 batch, max_epochs, output_num_units,
                 patience, up_learning_rate, file_name):
        
        self.input_shape = input_shape # [batch, dim]
        
        self.hidden_layer = hidden_layer # hidden [l1, l2, l3]
        self.output_num_units = output_num_units # [ # of class ]
        
        self.batch = batch
        self.max_epochs = max_epochs
        
        self.up_learning_rate = up_learning_rate
                 
        self.patience = patience
        self.best_valid = np.inf
        self.best_valid_epoch = 0
        self.best_params = None
        
        self.train_history_ = []
        self.epochs = 0
        
        self.file_name = file_name
        
        self.max_seq_length = max_seq_length
        
        """
        input data type
        y_hat : T x B x C+1
        y : L x B
        y_hat_mask : T x B
        y_mask : L x B
        """
        
        print "Why model build so long ... "
        # T x B x F
        # B X T X F (Lasagne format)
        x = T.tensor3('X', dtype=theano.config.floatX)
        # L x B
        y = T.matrix ('y', dtype=theano.config.floatX)

        # L x B
        y_mask = T.matrix('y_mask', dtype=theano.config.floatX)
        # T x B
        y_hat_mask = T.matrix('y_hat_mask', dtype=theano.config.floatX)
    
        # Min/max sequence length
        MAX_LENGTH = max_seq_length
        
        # Number of training sequences in each batch
        N_BATCH = batch
        
        #===========================================================================================
        # dEEP lSTM
        #===========================================================================================
        print "Input : (N_BATCH) : " + str(N_BATCH) +", ML :" + str(MAX_LENGTH) + "ss :" + str(self.input_shape[1])
        
        # Recurrent layers expect input of shape
        # (batch size, max sequence length, number of features)
        l_in     = lasagne.layers.InputLayer( shape=( N_BATCH, MAX_LENGTH, self.input_shape[1] ) )
        l_in_gau = lasagne.layers.GaussianNoiseLayer( l_in, sigma=0.5 )
        
        # LSTM layer 1
        l_forward_1   = lasagne.layers.LSTMLayer(l_in_gau, num_units=hidden_layer[0], learn_init=True, peepholes=True)
        l_backward_1  = lasagne.layers.LSTMLayer(l_in_gau, num_units=hidden_layer[0], backwards=True, learn_init=True, peepholes=True)
        l_recurrent_1 = ElemwiseSumLayer( [l_forward_1, l_backward_1] )

        
        # LSTM layer 2
        l_forward_2   = lasagne.layers.LSTMLayer(l_recurrent_1, num_units=hidden_layer[1], learn_init=True, peepholes=True)
        l_backward_2  = lasagne.layers.LSTMLayer(l_recurrent_1, num_units=hidden_layer[1], backwards=True, learn_init=True, peepholes=True)
        l_recurrent_2 = ElemwiseSumLayer( [l_forward_2, l_backward_2] )
        '''
        # LSTM layer 3
        l_forward_3   = lasagne.layers.LSTMLayer(l_recurrent_2, num_units=hidden_layer[2], learn_init=True, peepholes=True)
        l_backward_3  = lasagne.layers.LSTMLayer(l_recurrent_2, num_units=hidden_layer[2], backwards=True, learn_init=True, peepholes=True)
        l_recurrent_3 = ElemwiseSumLayer( [l_forward_3, l_backward_3] )
        
        # LSTM layer 4
        l_forward_4   = lasagne.layers.LSTMLayer(l_recurrent_3, num_units=hidden_layer[3], learn_init=True, peepholes=True)
        l_backward_4  = lasagne.layers.LSTMLayer(l_recurrent_3, num_units=hidden_layer[3], backwards=True, learn_init=True, peepholes=True)
        l_recurrent_4 = ElemwiseSumLayer( [l_forward_4, l_backward_4] )
        '''
        
        #l_reshape = lasagne.layers.ReshapeLayer(l_recurrent_4, (N_BATCH*MAX_LENGTH, hidden_layer[3])  )
        l_reshape = lasagne.layers.ReshapeLayer(l_recurrent_2, (N_BATCH*MAX_LENGTH, hidden_layer[1])  )

        
        #===========================================================================================
        # COMMON SETUP
        #===========================================================================================
        
        # Our output layer is a simple dense connection
        l_recurrent_out      = lasagne.layers.DenseLayer( l_reshape, num_units=output_num_units[0] , nonlinearity=lasagne.nonlinearities.identity)
        
        # Now, reshape the output back to the RNN format
        l_out_shp            = lasagne.layers.ReshapeLayer( l_recurrent_out, (N_BATCH, MAX_LENGTH, output_num_units[0]) )
        
        # dimshuffle to shape format (input_seq_len, batch_size, num_classes + 1)
        l_out_shp_ctc        = lasagne.layers.DimshuffleLayer( l_out_shp, (1, 0, 2))

        l_out_softmax        = lasagne.layers.NonlinearityLayer( l_recurrent_out, nonlinearity=lasagne.nonlinearities.softmax)
        l_out_softmax_shp    = lasagne.layers.ReshapeLayer( l_out_softmax, (N_BATCH, MAX_LENGTH, output_num_units[0] ))
        
        # since we use gaussian noise in input, False means use noise, True means dont use noise
        output_lin_ctc_train = lasagne.layers.get_output( l_out_shp_ctc, x, deterministic=False)
        output_softmax_train = lasagne.layers.get_output( l_out_softmax_shp, x, deterministic=False)
        
        output_lin_ctc_val   = lasagne.layers.get_output(l_out_shp_ctc, x, deterministic=True)
        output_softmax_val   = lasagne.layers.get_output(l_out_softmax_shp, x, deterministic=True)
        
        self.all_params      = lasagne.layers.get_all_params(l_out_shp)
    
        # the CTC cross entropy between y and linear output network
        pseudo_cost = ctc_cost_2.pseudo_cost(
            y, output_lin_ctc_train, y_mask, y_hat_mask,
            skip_softmax=True)
        
        
        pseudo_cost_grad = T.grad(pseudo_cost.mean(), self.all_params)
        true_cost        = ctc_cost_2.cost(y, output_softmax_train.dimshuffle(1, 0, 2), y_mask, y_hat_mask)
        cost             = T.mean(true_cost)
        
        pseudo_cost_scaled_grads = lasagne.updates.total_norm_constraint(pseudo_cost_grad, 5)
        updates_rms          = lasagne.updates.rmsprop(pseudo_cost_scaled_grads, self.all_params, learning_rate = self.up_learning_rate)
        updates = lasagne.updates.apply_momentum(updates_rms,  self.all_params, momentum=0.9)
        
        self.train = theano.function(
            inputs = [x, y, y_hat_mask, y_mask],
            outputs = [ pseudo_cost.mean(), cost, output_softmax_train ],
#             outputs = [output_lin_ctc, output_softmax, cost],
            updates=updates
        )
        
        self.predict = theano.function( 
            inputs=[x], 
            outputs = [ output_softmax_val] 
        )

        
    # x_mask and y_mask is the same
    # x_test_mask and y_test_mask is the same
    def fit(self, x_train, y_train, x_test,  y_test , x_mask, y_mask, x_test_mask, y_test_mask ):
        print " "
        print "start training!!!!"
        print " "
        sys.stdout.flush()
        
        for i in range(self.max_epochs):
            self.epochs +=1
            t0 = time()
            
            cs = 0.
            pseudo_cs = 0.
            for index in range(len(x_train)):
                pseudo, cost, output_softmax = self.train( x_train[index] , y_train[index],
                                                          x_mask[index], y_mask[index])
                cs += cost
                pseudo_cs += pseudo
                gg = index
                if index % 10 == 0:
                    print index, pseudo, cost
                sys.stdout.flush()
            
            cs /= len(x_train)
            pseudo_cs /= len(x_train)
            
#             cPickle.dump( self , open("./"+self.file_name+".pkl","wb"))
            if self.epochs <= 1:
                previous_cs = "-"
            else:
                previous_cs = self.train_history_[-1]['cost']
            print "\n==============================="
            print 'epoch {0} : pseudo= {1}, cost= {2}, previous_cost= {3}, train_time = {4} s'.format(self.epochs,
                                                                                                      pseudo_cs, 
                                                                                                      cs,
                                                                                                      previous_cs, 
                                                                                                      time() - t0)
            
            sys.stdout.flush()
            
            t0 = time()
            
#             print np.argmax(output_softmax[:],axis=2)
#             print decode_all( np.argmax(output_softmax[:],axis=2) , x_train_mask[gg],  batch_size , True)
            
            # save model first
            # dont know the LER performance yet
#             cPickle.dump( self , open("./"+self.file_name+".pkl","wb"))
    

            label_error_rate = 0.
            print len(x_test)
            for index in range( len(x_test) ) :

                prepre = self.predict( x_test[index])
                
                label_error_rate += check_all( y_test[index], y_test_mask[index],
                                              np.argmax(prepre[0],axis=2) , x_test_mask[index],
                                              batch_size)
                
                if (( index + self.epochs ) % 4 == 0 ):
                    ## print actual
                    y_actual = decode_all_actual( y_test[index], y_test_mask[index], batch_size , True)

                    ## print pred
                    y_predict = decode_all_pred( np.argmax(prepre[0],axis=2) , x_test_mask[index],  batch_size , False)
                
            label_error_rate /= len(x_test)
            self.train_history_.append({"epoch":self.epochs, "cost": cs, "LER":label_error_rate})
            
            print '\t\t\t val_= {0}, test_time  = {1} s'.format(label_error_rate, time() - t0)
            print "===============================\n"
            
            sys.stdout.flush()
            
            for a , b in zip (y_actual,y_predict):
                print "Target== ",a 
                print "\tAns => ",b
            
            sys.stdout.flush()
            
            """
            should use cost do early stopping
            """
            current_cs = self.train_history_[-1]['cost']
            current_epoch = self.train_history_[-1]['epoch']
            if current_cs < self.best_valid:
                self.best_valid = current_cs
                self.best_valid_epoch = current_epoch
                self.best_params = [w.get_value() for w in self.all_params]
                cPickle.dump( self , open("./"+self.file_name+".pkl","wb"))
                
            elif self.best_valid_epoch + self.patience <= current_epoch:
                print ""
                print "Early stopping."
                print self.best_valid_epoch,self.best_valid
                print "Best valid ler {:.6f} at epoch {}.".format(self.best_valid, self.best_valid_epoch)              
#                 for qq in range (len(self.all_params)):
#                     self.all_params[qq].set_value( self.best_params[qq] )
#                 break

            """
            can not use label error rate do early stopping
            """
#             current_ler = self.train_history_[-1]['LER']
#             current_epoch = self.train_history_[-1]['epoch']
#             if current_ler < self.best_valid:
# #                 print "********************* Now best ************************"
#                 sys.stdout.flush()
#                 self.best_valid = current_ler
#                 self.best_valid_epoch = current_epoch
#                 self.best_params = [w.get_value() for w in self.all_params]
# #                 cPickle.dump( self , open("./"+self.file_name+".pkl","wb"))
                
#             elif self.best_valid_epoch + self.patience <= current_epoch:
#                 print ""
#                 print "Early stopping."
#                 print self.best_valid_epoch,self.best_valid
#                 print "Best valid ler {:.6f} at epoch {}.".format(self.best_valid, self.best_valid_epoch)
#                 sys.stdout.flush()                
#                 for qq in range (len(self.all_params)):
#                     self.all_params[qq].set_value( self.best_params[qq] )
#                 break


#     def prediction(self, x, x_mask) :
        
#         abc =  self.predict(x, x_mask)
        
#         return np.argmax(abc[0], axis = 1 )

# %% [markdown]
# # ONE LAYER, Predict
#
#
#     model1L_noNoise_with212 = end_to_end (
#         input_shape      = (1, x_train.shape[3] ) , # batch of 1, (110, 30, 777, 117)
#         max_seq_length = x_train.shape[2],
#         hidden_layer     = [ 250, 250, 250, 250 ], # maximum layer to LSTM 3 layer only
#         batch            = batch_size,
#         max_epochs       = 300,
#         output_num_units = [ len(char_unMap) ],
#         up_learning_rate = 0.0001,
#         patience         = 7,
#         file_name = "model1L_noNoise_with212"
#     )
#
#
# ### Saved Model
# Model name = model1L_noNoise_with212_e119bkp.pkl
#
# '''

# %%
import gc
gc.collect()

# del model1

#with open('model1L_noNoise_with212_e119bkp.pkl', 'rb') as f:
with open('model2L_Noise_momemtumClip_nocaoncate3.pkl', 'rb') as f:
    model2L_Noise_with313 = cPickle.load(f)
# Out:
# /home/pika/anaconda/lib/python2.7/site-packages/theano/scan_module/scan_perform_ext.py:133: RuntimeWarning: numpy.ndarray size changed, may indicate binary incompatibility
#   from scan_perform.scan_perform import *

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
7

print len(model2L_Noise_with313.train_history_)
histo = pd.DataFrame(model2L_Noise_with313.train_history_)

print histo
print histo['LER'].describe()

my_plot = histo['LER'].plot(title="Error rate Trend",legend=None)
my_plot.set_xlabel("Epoch")
my_plot.set_ylabel("LER")
# Out:
# 36
#          LER        cost  epoch
# 0   0.943158  468.392454      1
# 1   0.950767  301.812839      2
# 2   0.950603  261.765153      3
# 3   0.969544  182.107850      4
# 4   0.996930  125.503498      5
# 5   1.000000  117.969517      6
# 6   0.999385  112.822766      7
# 7   1.000000  111.452354      8
# 8   0.999510  110.366964      9
# 9   0.999668  109.569705     10
# 10  0.999931  107.905650     11
# 11  0.989345  106.226178     12
# 12  0.889503  101.658646     13
# 13  0.842913   95.349372     14
# 14  0.768761   91.012493     15
# 15  0.757205   87.417402     16
# 16  0.705955   84.552951     17
# 17  0.673064   82.308877     18
# 18  0.666830   80.563364     19
# 19  0.669895   78.955966     20
# 20  0.645490   77.323546     21
# 21  0.659498   76.031179     22
# 22  0.644572   74.998814     23
# 23  0.633412   74.308755     24
# 24  0.640504   72.835661     25
# 25  0.639993   72.094652     26
# 26  0.653678   72.489782     27
# 27  0.630679   70.904861     28
# 28  0.634961   70.018954     29
# 29  0.639530   69.581604     30
# 30  0.633967   68.617826     31
# 31  0.629003   67.186253     32
# 32  0.614001   66.455289     33
# 33  0.638278   65.844452     34
# 34  0.629497   65.600844     35
# 35  0.631400   64.367242     36
# count    36.000000
# mean      0.776984
# std       0.159156
# min       0.614001
# 25%       0.639217
# 50%       0.671480
# 75%       0.955461
# max       1.000000
# dtype: float64

# %%
my_plot2 = histo['cost'].plot(title="cost Trend",legend=None)
my_plot2.set_xlabel("Epoch")
my_plot2.set_ylabel("cost")

# %%
histo.to_pickle('./ver2-L2-noise-Gclip.pa')

# %%
# ref : http://stackoverflow.com/questions/16568964/make-a-multiline-plot-from-csv-file-in-matplotlib
# ref : http://pbpython.com/simple-graphing-pandas.html

l1histo = pd.read_pickle('./ver1-L1-313-nonoise.pa')
l2histo = pd.read_pickle('./ver2-L2-noise-Gclip.pa')
l3histo = pd.read_pickle('./ver1-L3-313-nonoise.pa')
# l4histo = pd.read_pickle('./ver1-L1-313-noise.pa')
l4histo = pd.read_pickle('./ver1-L2-313-noise-Gclip.pa')
l5histo = pd.read_pickle('./ver1-L2-313-noise.pa')

my_plot3 = l1histo['LER'].plot(label="L1 LER", color='r',legend=True, figsize=(12, 8), sharex=True)
my_plot3 = l2histo['LER'].plot(label="L2 LER", color='g',legend=True)
my_plot3 = l3histo['LER'].plot(label="L3 LER", color='b',legend=True)
my_plot3 = l4histo['LER'].plot(label="L1-N LER", color='k',legend=True)
my_plot3 = l5histo['LER'].plot(label="L2-N LER", color='Pink',legend=True)
plt.legend(loc='best')
my_plot3.set_xlabel("Epoch")
my_plot3.set_ylabel("LER")

my_plot3 = l1histo['cost'].plot(secondary_y=True, style='--', color='r', label="L1 Cost",legend=True)
my_plot3 = l2histo['cost'].plot(secondary_y=True, style='--', color='g', label="L2 Cost",legend=True)
my_plot3 = l3histo['cost'].plot(secondary_y=True, style='--', color='b', label="L3 Cost",legend=True)
my_plot3 = l4histo['cost'].plot(secondary_y=True, style='--', color='k', label="L1-N Cost",legend=True)
my_plot3 = l5histo['cost'].plot(secondary_y=True, style='--', color='Pink', label="L2-N Cost",legend=True)
my_plot3.set_xlabel("Epoch")
my_plot3.set_ylabel("Cost")
plt.title("Learning Cost")
plt.grid(alpha=0.4) 
plt.legend(loc='center right')
# plt.add_legend()
fig = my_plot3.get_figure()
fig.savefig("ver2_L1toL3_withNoise2_charAnal.png")

# %%
label_error_rate = 0.
pr_error_rate = 0.
wr_error_rate = 0.
pr_count = 0
print len(x_test)
WRITE_RESULT = "./dataCebuano/dev_predict_result_2L_noise_GClip_with313_epo46.txt"

with open(WRITE_RESULT, 'w+') as f:
    for index in range( len(x_test) ) :
        prepre = model2L_Noise_with313.predict( x_test[index])
        ## print actual
        y_actual = decode_all_actual( y_test[index], y_test_mask[index], batch_size , True)
        ## print pred
        y_predict = decode_all_pred( np.argmax(prepre[0],axis=2) , x_test_mask[index],  batch_size , False)
        for a, b in zip( y_actual, y_predict):
            print "---------"
            print "Target : ", a
            print "Predict: ", b
            print _count_grade(a,b)
            pr_error_rate += _count_grade( a, b)
            wr_error_rate += wer( a.split(' '), b.split(' ') )
            f.write(idCollect[pr_count])
            f.write(' ')
            f.write(b);
            f.write('\n');
            pr_count += 1
        
        
        label_error_rate += check_all( y_test[index], y_test_mask[index],
                         np.argmax(prepre[0],axis=2), x_test_mask[index],
                         batch_size) 

    label_error_rate /= len(x_test)
    pr_error_rate /= pr_count
    wr_error_rate /= pr_count
    print "Total Sentence : ", pr_count
    print "chun label_error_rate : ", label_error_rate
    print "Lees label_error_rate : ", pr_error_rate
    print "true word_errir_rate : ", wr_error_rate

print "Mission Complete"

'''
iter 119
103
Total Sentence :  4120
chun label_error_rate :  0.728992975104
Lee's label_error_rate :  0.728992975104
Mission Complete

'''
# Out:
# 103
# ---------
# Target :  uniya' kumusta man imo nga exam ganina jun pasar kadto jun
# Predict:  niya kuussa ma na angita sana ga ni tanpata podo
# 0.51724137931
# ---------
# Target :  ? patay tug-an ta ka sa imo nga mama karon
# Predict:  ?atatato kaa di ka samongmabaron
# 0.452380952381
# ---------
# Target :  kulatahan gayod ka nga arlyn karon jun
# Predict:  pamatahon gay dina amli muamdon
# 0.552631578947
# ---------
# Target :  basta magbinayot lang ka jun makuha' man nimo jun
# Predict:  bata mag gilay napara da na mabuo ma iodi
# 0.510204081633
# ---------
# Target :  jun ngano nga gikasab-an ngano nga gitira man ka ni sir rotoy jun
# Predict:  dan gano nga igita gadaano nga i ti no ma kaa nianuto do
# 0.476923076923
# ---------
# Target :  ngano nga gitira man ka ni sir rotoy
# Predict:  naanong gay dii ra  ma ginito
# 0.555555555556
# ---------
# Target :  ngano nga gitira ka ni sir rotoy
# Predict:  nanin dii na kasareti
# 0.59375
# ---------
# Target :  wala' oy wala' na kaayo
# Predict:  la' ka wala makao
# 0.391304347826
# ---------
# Target :  aircon man lami' man ang aircon
# Predict:  alto maba ka bato
# 0.645161290323
# ---------
# Target :  ? gidiritso gihapon nako'
# Predict:   gipo giypo nato
# 0.48
# ---------
# Target :  mantika' man ni dea ako' nga gidala mao nga mangatanggal og kuan
# Predict:  moki ka man ni dia  dil nala mao ng mtandan ma kon
# 0.4375
# ---------
# Target :  wala' man ka wala' man kay ayo jun dili' man gayod ka magkudkod og lubi
# Predict:  wa ko kausa aigo dina odto mako po dil ioba
# 0.661971830986
# ---------
# Target :  gi-try nag-try na ka og dupang-dupang jun wala' pa
# Predict:  dida nara ta na kai mapamgamo pado ma ba
# 0.62
# ---------
# Target :  ka- ka-try na ka og dupang-dupang
# Predict:  ?adapaay naka no' g puta ng bato
# 0.606060606061
# ---------
# Target :  diay nimo gipakuan sa buhok ni allen diay
# Predict:  ma kay dioa gipa kuan sabuo ma alla ba
# 0.439024390244
# ---------
# Target :  ? mao diay nabayot ka karon
# Predict:  m mao da mapayyo pakaron
# 0.333333333333
# ---------
# Target :  mao na na ang bayad kay korohan
# Predict:  maro ma ng baradi aa
# 0.548387096774
# ---------
# Target :  mao na na nga nabayot ka na karon kay wala' natambalan no
# Predict:  mao mabalita  garo siata ng balano
# 0.561403508772
# ---------
# Target :  uniya' daghan ta- daghan customer dinha' jun karindiriya jun
# Predict:  niya dalo pawa bara gatomo  mala ga sio danioga
# 0.65
# ---------
# Target :  unsa pa man ato' nga maayo nga isturiyahan jun
# Predict:  asa kawa nato nga kwastoa aan gay
# 0.565217391304
# ---------
# Target :  kadto nga kuan jun
# Predict:  kato g  kuano
# 0.388888888889
# ---------
# Target :  kumusta man imuha nga kuan jun
# Predict:  kaota ngn duan do
# 0.633333333333
# ---------
# Target :  kumusta ang kato gayod jun
# Predict:  duutan kapa ma dn
# 0.538461538462
# ---------
# Target :  kumusta imuha nga itlog jun
# Predict:  bitao diti go ja
# 0.740740740741
# ---------
# Target :  kadto imo nga crush jun ?
# Predict:  usa ato nm ngamohannnku dayan ago sayd
# 1.08
# ---------
# Target :  lalaki man daw ingon si alex
# Predict:  kalati man da a kakani
# 0.5
# ---------
# Target :  hilak gayod ka jun hilak gayod
# Predict:  ilila do sa da diiha diyad
# 0.6
# ---------
# Target :  kahilak gayod ka sir rotoy jun
# Predict:  paino gi na simoto dad
# 0.566666666667
# ---------
# Target :  ? pag-sure dinha' ayaw pag- paghilom-hilom dinha' kay madunggan
# Predict:  ?y pagio sa a po  gilagino ba da mgadigin ba ? dulli
# 0.68253968254
# ---------
# Target :  nasuyaan mitapad sa akua kay siyimpri kana' imo nga amigo guwapo kaayo
# Predict:  asi ra a  tapa sa moaa  sini ba kali o nga ami duhto na kaao
# 0.5
# ---------
# Target :  uniya' jun matagaan pa gayod ka karon jun libriha dayon ko' jun
# Predict:  la dun batali ba nadg tu ro bod dadi dan didon
# 0.603174603175
# ---------
# Target :  mao baya- tamang-tama' gayod one hundred gayod ang bayad gayod
# Predict:  m pari aosa po' gi balano gayd da ng baya gaod
# 0.564516129032
# ---------
# Target :  ha unsa ? unsa matoy
# Predict:  ?usaung onsamakoy
# 0.5
# ---------
# Target :  o nangatol ba ka karon
# Predict:   ananatan baa daron
# 0.363636363636
# ---------
# Target :  uniya' asa man ang lana nimo
# Predict:  nniyaka ma nakara ni nimoii
# 0.535714285714
# ---------
# Target :  asa man imuha nga lana gihipos nimo
# Predict:  asa ma ni ma a nula na dilito ng sulo
# 0.514285714286
# ---------
# Target :  o hipusa na ayaw kaayo hutda ha kay para
# Predict:  o  disuusana aiya kaio ngodara para
# 0.45
# ---------
# Target :  para dili' ko' magsigi og hatag sa imuha og lana
# Predict:  pala dili ka' nga magti di gaata g sayna dra na
# 0.5
# ---------
# Target :  gibutangan man kaya nimo na og lubi
# Predict:  gili nutanan ma ka nimana nag diro bi
# 0.485714285714
# ---------
# Target :  kadto unta' nga lubi imo nga gipang-ayo ana' kay para
# Predict:  utan ta wulo da nang gutalan waa dinka sara
# 0.641509433962
# ---------
# Target :  dili' ba ang gipang-ayo unta' nimo sa mang-
# Predict:  a an gitaano un tanimatala
# 0.558139534884
# ---------
# Target :  sa manghihilot kay kadto nga
# Predict:  sa ma li totato ng
# 0.5
# ---------
# Target :  dupang-dupang ambot naka-try na ba ko' sa una og dupang-dupang mura og siguro
# Predict:  dutanga dasa wan do lakasara nabakusao nanga gotaunupara  si guro
# 0.532467532468
# ---------
# Target :  mga elementary ko' naka-try na siguro ko' og dupang
# Predict:  mawa ka gaongtadi ka nakataa da ga garo ka buko
# 0.607843137255
# ---------
# Target :  dupang gipa- unsa lang man nako' kadto miadto lang man mi sa monkayo uniya' gipa-
# Predict:  dopan gkaonga na man na kuto nagto la manisana ngakaa danga nsa
# 0.493827160494
# ---------
# Target :  gipahiran ra man ko' og bato ato' sa mananambal didto uo
# Predict:  dikana na di i bata a tod ta nala nanani ba dito ?
# 0.535714285714
# ---------
# Target :  ? naa man to bato nga kana' nga
# Predict:   ka u bato namon ta batona kana
# 0.612903225806
# ---------
# Target :  magsiga-siga gani' ? gani' og
# Predict:  magsigasuda da ndlagibadan dali ron
# 0.655172413793
# ---------
# Target :  basta ang bato kana' nga magsiga-siga ang bato ba
# Predict:  unsaa nako' makana ma tigatoda nako ba
# 0.510204081633
# ---------
# Target :  mga grade five siguro ko' ato' grade four
# Predict:  nawa dita gi gara gatoi ato
# 0.658536585366
# ---------
# Target :  gipaunsaan pod nako' piro
# Predict:  gi' kausan dana ka'  kala
# 0.6
# ---------
# Target :  nagbalik-balik lang man gayod ako' nga kalintura gayod wala' ing ipikto kadto nga pagpaspas sa iyaha nga buhok ba
# Predict:  abali mbali di a mag gadao kani natananaga daala a ka tota no nga pa gpasta sa hangan di i bao
# 0.495575221239
# ---------
# Target :  o pila gayod to ka simana sigi ko' og
# Predict:  ssila gaga ka simana ka digo
# 0.486486486486
# ---------
# Target :  uo kay natambalan na man ikaw mabayot pod kapag natambalan na ka ato'
# Predict:   w ka natangmana na makito mabayit to ta babata ngbala na kato'
# 0.405797101449
# ---------
# Target :  wala' na man nag-standby ra man sila diri
# Predict:  la' na ma na gitamba na ma di ladiri
# 0.341463414634
# ---------
# Target :  ako' nga mga kauban ganina nag-exam
# Predict:  awaa kaodani dangan na ga ko
# 0.628571428571
# ---------
# Target :  si dianne nangita' og lalaki
# Predict:  sidunya nanita giha ka
# 0.464285714286
# ---------
# Target :  o ato' nga baboy nga tambok ba
# Predict:   m agta ng babo na ka nga ga gaado
# 0.666666666667
# ---------
# Target :  ? uniya' kumusta man ang
# Predict:  akanna kunustama la
# 0.5
# ---------
# Target :  kadungog piro naa pod lagi pod ing bili
# Predict:  adibatttili
# 0.820512820513
# ---------
# Target :  ? hello ?
# Predict:  ? i
# 0.777777777778
# ---------
# Target :  piro mura man lagi ganiha ra ko' og sigi hello diri wala' gayod ka ka
# Predict:  nabaa ma gai dili maag si lagi tigi gana te kay ta
# 0.608695652174
# ---------
# Target :  wala' kay wala' ko' madunggan
# Predict:  wul ka ala' ka na taan
# 0.448275862069
# ---------
# Target :  unsa man to imo nga lutuon uniya'
# Predict:  kadsa ma ti malitaa buniya'
# 0.484848484848
# ---------
# Target :  unsa diay imo nga lutuon uniya'
# Predict:  ansa daa magapud agya
# 0.548387096774
# ---------
# Target :  paulion man kaha ko' nimo karon nga ?
# Predict:  wallo maga kaimokaro te si
# 0.540540540541
# ---------
# Target :  ikaw na gayod ing luto' dinha' gayod
# Predict:  pi o gg di
# 0.805555555556
# ---------
# Target :  unsa man ako' nga paliton
# Predict:  magiy maama pdi pun
# 0.72
# ---------
# Target :  unsa-unsa gani' akua nga dad-on
# Predict:  an ansa ka niato nagda-k
# 0.516129032258
# ---------
# Target :  unsa ako' nga dad-on ba ?
# Predict:  undako'n bas lan ba
# 0.48
# ---------
# Target :  unsa ako' nga dad-on ba ? karon nga hapon
# Predict:  unsa ato'ng bati ko?ia karn ma kun
# 0.487804878049
# ---------
# Target :  ayaw na lang ko' og ayaw na lang gayod ko' pabut-a
# Predict:  ao na lang kutaan balan  ka kaba t
# 0.52
# ---------
# Target :  ikaw na lang gayod
# Predict:  ikaa pailantod
# 0.444444444444
# ---------
# Target :  ikaw na lang ing buot dinha' ba ikaw na lang ing buot ba unsa ing dad-on nako'
# Predict:  ikaa dangiko ila sa kika dana koko ba day dadina po
# 0.564102564103
# ---------
# Target :  wala' ing klaro nimo
# Predict:  wa sanoon dim
# 0.7
# ---------
# Target :  mmhm tan-awa ra gayod anaon ko' uniya' dili' man diay
# Predict:   aaw adpabao kidia do
# 0.660377358491
# ---------
# Target :  unsa man imo nga gusto kay basi inig dala pod nako' dinha' dili' naa pod ka ganahan
# Predict:  asa mamanga mangi a ila kai bala tamaa in dila ko kai kaugnan
# 0.55421686747
# ---------
# Target :  dili' nako' nimo paulion mao
# Predict:  sanao' nima ka
# 0.607142857143
# ---------
# Target :  uniya' ang kadto nga risibo sa mga cards naa dinha'
# Predict:  uya akato ngaasi usa mo nga ku naa diya
# 0.450980392157
# ---------
# Target :  o kuhaon pa man pod na mao biya' to ana' lang gayod to gayod
# Predict:  kuan po am mo gita ma na a o bua
# 0.6
# ---------
# Target :  ? unsa gani' ako' nga dad-on dinha'
# Predict:  naunta dina o' n tatoding
# 0.542857142857
# ---------
# Target :  unsa ako' nga dad-on ba na
# Predict:  atar podaonbata
# 0.615384615385
# ---------
# Target :  unsa ako' nga dad-on
# Predict:  ansa apon dad u
# 0.45
# ---------
# Target :  ? mag-drive thru na lang ta
# Predict:  ?a ma da i wa nalan
# 0.592592592593
# ---------
# Target :  drive thru na lang kadto nga sa kuan
# Predict:  nai tran na la patota a
# 0.555555555556
# ---------
# Target :  mag-drive thru na lang ta
# Predict:  angdiri u na lang tu
# 0.4
# ---------
# Target :  dad-a dad-on kadto dili' ta muagi dinha' didto ra kita' ato'
# Predict:  dai pasa dartan ta da twa gati  ana
# 0.666666666667
# ---------
# Target :  ? ako' nga dad-on si marky dinha' kay para ato' nga ipakaon uniya' nga udto
# Predict:  ? a to taansi maa gi dina i paaaita ka wa diit
# 0.6
# ---------
# Target :  mahurot na daw kadto iyaha nga kuan
# Predict:  muro pa tabatuniya o ka
# 0.514285714286
# ---------
# Target :  nahurot na kadto iya nga isa kasako three weeks ra ?
# Predict:  mawuri mo sinakakako lii saa ui  saota
# 0.711538461538
# ---------
# Target :  unsa man diay imo nga gibuhat diay imo na nga gikuha' to nga laundry
# Predict:  wata ga  i di mon na ga kangato gmudi
# 0.617647058824
# ---------
# Target :  imo ng gikuha' to nga sa laundry
# Predict:  ima na g ato' n kalagi
# 0.5625
# ---------
# Target :  hello imo ng gikuha' ba ang sa laundry
# Predict:  sala il na ma gikua baan sa iadri
# 0.473684210526
# ---------
# Target :  unsa nako' pag ?
# Predict:  itaki o
# 0.75
# ---------
# Target :  abi ko' ikaw ing mibayad dinha' karon unsa
# Predict:  kabi kaka dali didad
# 0.714285714286
# ---------
# Target :  muhatag man ko' nimo kaha' og two thousand uniya' karon utangan na pod ko' og one hundred
# Predict:  muaa ma nga ko nimowaata ka na' karota i at
# 0.651685393258
# ---------
# Target :  naa ko' ing gibilin dinha' ma
# Predict:  napo gite gi gia do
# 0.620689655172
# ---------
# Target :  ?
# Predict:  ?ba natiao
# 9.0
# ---------
# Target :  wala' ko' lutuon
# Predict:  wala ko' na madto magato idala
# 1.25
# ---------
# Target :  dad madungog tika
# Predict:  ma amagulog paka
# 0.470588235294
# ---------
# Target :  brownout
# Predict:  baraaro
# 0.75
# ---------
# Target :  wala' kadungog kadungog ka nako'
# Predict:  abango abaho ka ngako
# 0.53125
# ---------
# Target :  kadungog ka nako' ganina lang ko' sigi pangutana kadungog ba ka nako' ?
# Predict:  saguo  kanag ata ko po diy bamotaka baho bakalapa
# 0.577464788732
# ---------
# Target :  o lagi-lagi ? tama' na tama' na samuka oy ?
# Predict:   nagulan paababanaok
# 0.697674418605
# ---------
# Target :  miingon ko' ga-brownout
# Predict:  mulang kao babana
# 0.652173913043
# ---------
# Target :  wala' ko' ing lutuon pagdala og pagkaon
# Predict:  wwa aka na pa uon pa balaon papaoon
# 0.461538461538
# ---------
# Target :  wala' ko' ing lutuon pagdala og pagkaon
# Predict:  wlako nadtoan pag balao patao
# 0.461538461538
# ---------
# Target :  ikaw gani' pagdala
# Predict:  kika kawita nha
# 0.611111111111
# ---------
# Target :  ikaw gani' pagdala samuka oy
# Predict:  isa ka ba nga pamma bamka
# 0.607142857143
# ---------
# Target :  ay kuno ay unsa imo nga kaunon ron ?
# Predict:   mana a aiowala
# 0.722222222222
# ---------
# Target :  ayaw na lang dad ayaw na lang ayaw na lang og uli' matulog na lang ko'
# Predict:   naa  ayro naona mabao na
# 0.7
# ---------
# Target :  ayaw na lang og uli' kay matulog na lang ko'
# Predict:  aum  da ka ngaporo naku
# 0.704545454545
# ---------
# Target :  sigi ikaw na gani' ikaw na gayod ing paghunahuna' gayod oy unsa oy
# Predict:  iato ma bao ito mani pain
# 0.772727272727
# ---------
# Target :  ayaw na lang lagi og uli'
# Predict:  mib
# 0.96
# ---------
# Target :  ayaw na lang lagi og anhi maghunahuna' pa ka og unsa imo nga paliton
# Predict:  aro lagi nniamu a baka bako
# 0.720588235294
# ---------
# Target :  dili' kay maghunahuna' pa ka unsa imo nga paliton dili' ayaw na lang paghuna' para wala' kay hunahunaon
# Predict:  dbi kay magoraa panama a pa kaalum mon pagamaa pao nam
# 0.611650485437
# ---------
# Target :  ayaw na lang og anhi
# Predict:   mon
# 0.85
# ---------
# Target :  ? dili' kuhaa dinhi
# Predict:  a gikuhamon
# 0.631578947368
# ---------
# Target :  ikaw gani' bahala' gago
# Predict:  kipo bagaino na ba ba
# 0.739130434783
# ---------
# Target :  ikaw gani' bahala' unsa man ka wala' ka kasabot og ikaw ang bahala'
# Predict:  aita bang inan ba on ta mka mababakaati nana
# 0.626865671642
# ---------
# Target :  ko' nga pagkaon gani' dala gamit
# Predict:  mtaga nang banaano
# 0.6875
# ---------
# Target :  saba' kaayo ang iro'
# Predict:   n ka anaa
# 0.7
# ---------
# Target :  o humana naana' nako' ganina utangan kadto nako' og
# Predict:  amalo na mako matawan ka mako baman
# 0.607843137255
# ---------
# Target :  uo utangan gani' siya nako' og one hundred
# Predict:  ?pa aman ka nan d
# 0.714285714286
# ---------
# Target :  utangan siya og one hundred
# Predict:  apaan kabamon da
# 0.666666666667
# ---------
# Target :  oh imbis kay utangan ko' og one hundred
# Predict:  ki ata kolaman
# 0.769230769231
# ---------
# Target :  ?
# Predict:  muba ngm
# 8.0
# ---------
# Target :  wala' pa ka mihatag og one fifty dira' sa imo nga friend mubayad pa ko' uniya' sa wala'
# Predict:  wa pako ng mga ta buganu nausa nta m baakono
# 0.701149425287
# ---------
# Target :  unta' ka mihatag og kuwarta
# Predict:  waa ta kanmgata og gapa
# 0.518518518519
# ---------
# Target :  maayo biya' kadto og sa imo nga balay ikaw ha
# Predict:  mao ba ko simalgakoma
# 0.622222222222
# ---------
# Target :  pila man ni kaminuto imo nga call bi
# Predict:  una ma na ka mngapam kadi
# 0.583333333333
# ---------
# Target :  uo uniya' natubag na kadto imo nga ang imo nga gipa-answer nako'
# Predict:  ?niya katog ba kataa nmu aimong gapanta nako'
# 0.46875
# ---------
# Target :  naka nakatubag na ba ka kato ang gipapangutana nimo nako' ba
# Predict:  ?a kaa ato n ganna baka kato' maamogi patahotana nako' ba
# 0.45
# ---------
# Target :  kato gayod iniyo nga kuan gayod
# Predict:  atanga ka dinnanga kuan ban
# 0.483870967742
# ---------
# Target :  gaunsa na man diay mo dinha' karon
# Predict:  ? naangay namn ka ma dira ran
# 0.529411764706
# ---------
# Target :  unsa diay uras imo nga klasi
# Predict:  ana dinawata nga kato
# 0.535714285714
# ---------
# Target :  unsa oy dili' maklaro
# Predict:  atao alakaaro
# 0.571428571429
# ---------
# Target :  unsa diay urasa imo nga klasi
# Predict:  ada diaanato' ng ma slati
# 0.551724137931
# ---------
# Target :  uniya'-uniya' kinsa ing nakasukol sa imo nga kuan
# Predict:   ka itana kato kua ka no nga g kuan
# 0.612244897959
# ---------
# Target :  sa imo nga kasamukan ba imo nga assignment
# Predict:  kay auka katan ba imapay n nan o
# 0.619047619048
# ---------
# Target :  kadto gayod kadto nga nangayo' ka nako' ba kadto nga ingon ka nga ako' to siya nga kuanon
# Predict:  at ng gad kato ng naaa an naama na ataina ba basa giyakoa na
# 0.550561797753
# ---------
# Target :  asa imo nga ? gayod
# Predict:  pan maataatao
# 0.736842105263
# ---------
# Target :  ? uniya'
# Predict:  taana
# 0.75
# ---------
# Target :  uniya' kumusta na man mo dinha'
# Predict:  ? kia kuustanaanng mga dira
# 0.516129032258
# ---------
# Target :  kumusta na man mo dinha'
# Predict:  aus ta na ngan ma diha
# 0.375
# ---------
# Target :  ? naana' mo ing maistra
# Predict:   apa lan ma la
# 0.652173913043
# ---------
# Target :  okay ra ?
# Predict:  aki bapa ?
# 0.666666666667
# ---------
# Target :  piro klaro na iniyo nga klasi dili' na kana' ang pariha sa una nga kuan ?
# Predict:  karkuaro na ngag di ga dili na banan paria taunna ako an
# 0.452054794521
# ---------
# Target :  wala' ing maistra
# Predict:  aaas pa
# 0.705882352941
# ---------
# Target :  ? nag-exam namo'
# Predict:  ? kaingan naho
# 0.5
# ---------
# Target :  kanus-a diay mahuman iniyo nga klasi
# Predict:  kanusa diagani nngapato
# 0.527777777778
# ---------
# Target :  mmm bayinti-dos
# Predict:  lag tado
# 0.733333333333
# ---------
# Target :  pariha ra diay sa amo' bayinti-dos man sad mahuman amo' nga klasi
# Predict:  ariyia datamo baditason kayo sa lanamokato
# 0.569230769231
# ---------
# Target :  o kanus-a man mo mamalik
# Predict:  awanang tabalo mamane
# 0.583333333333
# ---------
# Target :  kanus-a man mo mamalik og iskuwila ?
# Predict:  anana man na mamani ka gpu ma
# 0.5
# ---------
# Target :  dugaya ba ?
# Predict:  agaya bo atan bo
# 0.818181818182
# ---------
# Target :  ana' man gayod kana' mga pitsa dos kuno
# Predict:  ana na gadaba gisa dao stalo
# 0.512820512821
# ---------
# Target :  o ana'-ana' sila
# Predict:   nanna anag pala
# 0.5
# ---------
# Target :  o pitsa uno kuno
# Predict:   ataun kano
# 0.4375
# ---------
# Target :  ambot lang oy kay basin diay og mausab pa kana'
# Predict:  bo kaa ka basa di maapa ana
# 0.489361702128
# ---------
# Target :  wala' kita' kabalo maisbog pa kana'
# Predict:  ? wataro ba baibuka na
# 0.628571428571
# ---------
# Target :  uniya' muuli' ka sa iniyo ana'
# Predict:  ? pabali ka ao niyaana
# 0.533333333333
# ---------
# Target :  aw adto ka mag-pasko
# Predict:   abo ka magpaso
# 0.3
# ---------
# Target :  ? uniya' inig ka new year adto ka sa ?
# Predict:  n kai ata kakas
# 0.710526315789
# ---------
# Target :  ? pari-pariha ra diay sa amo'
# Predict:  ka di iaba parsaiya kasamo
# 0.655172413793
# ---------
# Target :  cha kinsa man kauban nimo dinha' karon
# Predict:  ? usa man taoba ga ga dia?an
# 0.552631578947
# ---------
# Target :  aw wala' usab diay sila
# Predict:  ? waasa di sa laklti
# 0.652173913043
# ---------
# Target :  ? wala' gayod ko' kabalo gayod
# Predict:  kaninsaa maka apaaga a
# 0.733333333333
# ---------
# Target :  kuan ra ? amo' nga giluto' kay mao ra may madalit kay klasi pa mi ron nga taod-taod
# Predict:  uo na  lardaso na a mo g gilota maaamina mga o dali' ka og kaasi goo ma na bo ban
# 0.614457831325
# ---------
# Target :  noodles imo- noodles imo nga giluto' ?
# Predict:  lugo  sa ugo  sa ma nga iluut
# 0.657894736842
# ---------
# Target :  kay klasi pa mi ? muhapit pa mi og iskuwilahan kay klasi pa mi ba
# Predict:  a kadiy ko nano bi daki sa musalua mang kasi po a ba
# 0.569230769231
# ---------
# Target :  ? sigi sunod ra ko'
# Predict:  an karaw dii sidoro
# 0.947368421053
# ---------
# Target :  mamalik para ba sa iskuwilahan mga alas-siyiti
# Predict:  wa malir pura gay okalaahon mga naa nog sit
# 0.521739130435
# ---------
# Target :  nagluto' na mi daan kay nanihapon na mi daan
# Predict:  to gani d ta ma nihaso na daan
# 0.477272727273
# ---------
# Target :  unsa ing klasi nakarga ron nga subject
# Predict:  aog kaasi nako' g daan mo sabi
# 0.578947368421
# ---------
# Target :  auxiliary machi- machinery
# Predict:  diri masilisibui
# 0.730769230769
# ---------
# Target :  nangaon na lang mi daan sayo ko' og kaon kay
# Predict:  n gay ungingan la gadao skangontood tao sa
# 0.613636363636
# ---------
# Target :  alas-diyis ra mi ka ?
# Predict:  sdi si ma dataa?o
# 0.666666666667
# ---------
# Target :  sa chemistry namo'
# Predict:  asa mako  paninasoni namo
# 0.888888888889
# ---------
# Target :  aw natubag na man to tanan
# Predict:   nato bagta mang to od kana
# 0.461538461538
# ---------
# Target :  gi-check-an na man to nga ma'am
# Predict:  inika na ma to g man
# 0.451612903226
# ---------
# Target :  ? salamat kaayo ato' ha
# Predict:  ka arulamo pi ato a
# 0.608695652174
# ---------
# Target :  okay na nag nagklaro klaro na gamay amo' nga klasi
# Predict:  pakay bara karon latara la g kaarlo man daba a mo ghasi
# 0.62
# ---------
# Target :  ikaw dinha' kumusta na man ka dinha'
# Predict:  insa daauuta nga nadia
# 0.555555555556
# ---------
# Target :  naa pa ing uban naa pa ing uban naa pa ing uban nga subject ti nga wala' pa ing kuan ba
# Predict:  matao ba mata ban mapayoba man sa dito maalata in kua ba
# 0.551724137931
# ---------
# Target :  wala' pa ing ? wala' pa ing kana' nga maistra gani'
# Predict:  a napa isidakaalan ka sa ba maika lani
# 0.549019607843
# ---------
# Target :  ila pa nga gi-arrange amo' nga schedule kay naa pa ing uban nga conflict
# Predict:  ila pag grag ga nasidaa mapansaban batan
# 0.583333333333
# ---------
# Target :  aw klaro-klaro klaro na man ang naa nay maistro nga subject namo'
# Predict:   o ka  kua na ma mana mana ditoa masa bit nam'
# 0.523076923077
# ---------
# Target :  sig- sigi na kami og discuss ba
# Predict:   sgi na ib ko
# 0.677419354839
# ---------
# Target :  mag ay exam exam na gani' mi
# Predict:  mo kanso isa mo gani?i
# 0.607142857143
# ---------
# Target :  o magsugod pa exam exam
# Predict:   mansagod kaanto nisn
# 0.565217391304
# ---------
# Target :  muuli' ko' karon nga sabado
# Predict:  mali ka ma mansabado
# 0.444444444444
# ---------
# Target :  ang ila nga giingon kay
# Predict:  paua ngadiinam kaka
# 0.565217391304
# ---------
# Target :  mura og bayinti-dos man to ila nga giingon
# Predict:  mura banto buro si ma dalansino
# 0.595238095238
# ---------
# Target :  aw siguro kay dungan-dungan ra man ta gasugod og klasi
# Predict:   s ma ka dio dua na ba gasu ga dogt si
# 0.574074074074
# ---------
# Target :  aw ? gayod ta kay ?
# Predict:  o saduman gayd ba ta gi
# 0.736842105263
# ---------
# Target :  pitsa bayinti-singko man pod mi gasugod uniya' kamo sad
# Predict:  sisa ponsikonga ban li ga su gad natamo sad
# 0.490909090909
# ---------
# Target :  pitsa sayis siguro
# Predict:  ssuan siuro
# 0.555555555556
# ---------
# Target :  unsa diay mo nga pitsaha diay magsugod og balik diay
# Predict:  iga da ngo tad s dang ngasabani te
# 0.653846153846
# ---------
# Target :  ini og kahuman gayod sa bag-o nga bag-o nga tuig
# Predict:  gitaunman ga dia abi  bahoto oy
# 0.625
# ---------
# Target :  ? ? pitsa bayinti-dos gayod mo mukuan
# Predict:  a n oo ka ita dito dbo na ma dakuan
# 0.594594594595
# ---------
# Target :  nakaanha' ko' dinha' sa talisay to nga pasko
# Predict:  ina kanan ko'  diasa a kalinisa na pako
# 0.431818181818
# ---------
# Target :  ?
# Predict:  nabo smaa mambai
# 16.0
# ---------
# Target :  kay mura og mag-party man sila ?
# Predict:  a ra gaa ba ? ten sa no
# 0.59375
# ---------
# Target :  adto ko' sa amua mag-new year
# Predict:  ba masa mahaa ma
# 0.689655172414
# ---------
# Target :  mga kuan siguro last week last week padulong mag magpadulong
# Predict:  oma kuan giy duro la nslatispaduong mag par masa buoobaaro
# 0.583333333333
# ---------
# Target :  laliman kapila ang gatas ana' ?
# Predict:  inasa kadaa kaa
# 0.709677419355
# ---------
# Target :  kuan pa lang na two thousand
# Predict:  nasauna pausa
# 0.678571428571
# ---------
# Target :  kuan pa lang na isa ka week pa lang na two weeks na asa kakuha' ana' diritso
# Predict:  abo naagiasa au na namaa a ti ta
# 0.710526315789
# ---------
# Target :  tulo-tulo gayod singot nimo og banat ana' ?
# Predict:  a aulo si gi na iobaa la
# 0.651162790698
# ---------
# Target :  uniya' ikaw kumusta man imo nga anak dinha' ha pila na ang idad
# Predict:  naira a lana analiya ba i i
# 0.650793650794
# ---------
# Target :  pila ang idad dili' dako'-dako' naunsa man na siya oy
# Predict:  dilaiga d aa ko a
# 0.754716981132
# ---------
# Target :  pila ang idad gani' pila idad
# Predict:  ila gi ioa
# 0.689655172414
# ---------
# Target :  upat katuig og
# Predict:  sa aa sa sim
# 0.785714285714
# ---------
# Target :  maayo kay nakakuan ka ana' ikaw nagbantay ana' asa imo nga asawa
# Predict:  ba la sata n ta baidola na ba da nana sia sao
# 0.5625
# ---------
# Target :  nag-apply pod or nagtrabaho naa pod imo asawa
# Predict:  da a na ta la mo ta
# 0.688888888889
# ---------
# Target :  maayo na oy kay sabay mo nagkuan maayo kay
# Predict:  ai ato na mu  o
# 0.738095238095
# ---------
# Target :  kuan niniyo iniyo anak niniyo para kuan mo ba padako' usa ba para
# Predict:  a gi alan naaa tia pa ka  sasata
# 0.661538461538
# ---------
# Target :  puwidi man kaha' mabiyaan ang anak niniyo
# Predict:  ilima a mabula na naua i
# 0.585365853659
# ---------
# Target :  puwidi man kaha' mabiyaan na naa man kaha ang kuan ana' mura
# Predict:  ili mo na na ay a taiana a bal
# 0.65
# ---------
# Target :  maayo ih kay naa ang ingon ana'
# Predict:  g aa lao
# 0.838709677419
# ---------
# Target :  ako' ani ako' ra gayod isa pait kaayo ang kahimtang nako'
# Predict:  akwan na buliba ati kaniata na
# 0.631578947368
# ---------
# Target :  bisitahon lang ko' once ? month ra ana' ra gayod
# Predict:  ta asana paaa alao
# 0.729166666667
# ---------
# Target :  gahot pod ko' og kuan nako' ani ngita' og trabaho kay na unsa na lang kaunon nako'
# Predict:  aro ko  a at ia kuran aaiolo na a kaalao'
# 0.634146341463
# ---------
# Target :  para sabay-sabay nakita' dili' ba
# Predict:   sata dala sa
# 0.727272727273
# ---------
# Target :  wala' mao gani' mangita' usa kita' og trabaho para naa kita'
# Predict:  ala ao ga aila naama ara na ti
# 0.566666666667
# ---------
# Target :  hello
# Predict:
# 1.0
# ---------
# Target :  ay ka-remember ka kay kuan kay weng
# Predict:  pa gida da baaa baa ai
# 0.742857142857
# ---------
# Target :  ba classmate nato' ? ba si weng ba
# Predict:  broi matanaa dabi
# 0.735294117647
# ---------
# Target :  kadto nagtrabaho man kadto siya ? sa kuan dili' ba
# Predict:  artokawassalagi lakuna o
# 0.72
# ---------
# Target :  sa sutherland ba ? kadto uniya' basin og naa ing naa ing hire did- didto
# Predict:  tala a na a alao dibalio io
# 0.736111111111
# ---------
# Target :  nakakuan ka hearing ka
# Predict:  ?aatiita
# 0.818181818182
# ---------
# Target :  basin naka-hearing ka ba uniya'
# Predict:  masi ma kadi baala
# 0.645161290323
# ---------
# Target :  or ila kuan pod justin basin naka-hearing pod ka
# Predict:  lauwai ita
# 0.833333333333
# ---------
# Target :  mura og nakit-an man nako' kadto nag-post sa f_b niya
# Predict:  ki pa ngaao da balauta giiy
# 0.698113207547
# ---------
# Target :  kamo kay close man mo ato' nga
# Predict:  aaooao
# 0.8
# ---------
# Target :  kadto si kuan diay
# Predict:  agi mu
# 0.777777777778
# ---------
# Target :  ? si bossing george diay asa na man diay kadto ha
# Predict:  a sio siy ialanma di
# 0.673469387755
# ---------
# Target :  naghulat pa ko' sa ako' nga tawag pod ? uban nga kumpaniya nga ako' nga gi-
# Predict:  nagkulapa maka atamo po kaa bano panipoko
# 0.626666666667
# ---------
# Target :  pila na diay ka katuig diay
# Predict:  silanga na ka natorida
# 0.481481481481
# ---------
# Target :  sa imuha nga pagtrabaho
# Predict:  mompo kabao
# 0.739130434783
# ---------
# Target :  maayo pa ka uyab-uyab
# Predict:  naypaka diyabuya
# 0.428571428571
# ---------
# Target :  naana' lagi bantog gani' nangita' ko' og trabaho
# Predict:  naana ma gi nangtokari nangata ko gtrrabao
# 0.354166666667
# ---------
# Target :  kanus-a diay ka mang-apply diay
# Predict:  kanalari kamanala da
# 0.483870967742
# ---------
# Target :  kanus-a diay ka mang-apply og usab
# Predict:  ka na sa nay tamurolita
# 0.676470588235
# ---------
# Target :  wala' diay ka nang-apply sa uban
# Predict:  la' ga kahanaya sabad
# 0.5
# ---------
# Target :  paabot pod ko' sa tawag piro dili' ko' mupasalig pod
# Predict:  a bo sa makatawa ?ro digi popakalipo
# 0.5
# ---------
# Target :  nangita' pod ko' og lain nga ka-apply-an pod sa kumpaniya
# Predict:  digita olaa maya po abaniya
# 0.59649122807
# ---------
# Target :  maayo lang unta' og kaluy-an kita' ani
# Predict:  nalianta talagi antani
# 0.631578947368
# ---------
# Target :  maayo unta' og kaluy-an kita' ani
# Predict:  mayotapali an kaha di
# 0.545454545455
# ---------
# Target :  wala' diay kay ? na mu-abroad
# Predict:  wala' pal ki bala pa boga
# 0.51724137931
# ---------
# Target :  basta ikaw kusog kaayo ka sa akua
# Predict:  birito po ki na takua
# 0.606060606061
# ---------
# Target :  sa atua nga mga ka-batch diay wala' kay kaila nga naa na trabaho
# Predict:  ?tama ka ba diwala kay kaina na nadisaba
# 0.453125
# ---------
# Target :  mao ani maningkamot na lang ta ani
# Predict:  maa ni magitamo ta an taani
# 0.323529411765
# ---------
# Target :  maningkamot na lang ta ani
# Predict:  manigkam ta tan
# 0.461538461538
# ---------
# Target :  maningkamot na lang ta ani
# Predict:  nanikamo tarang paani
# 0.346153846154
# ---------
# Target :  maayo gani' ka kay wala' wala' pa ka nagminiyo'
# Predict:  maikani ta ba nalapa kanamidi'
# 0.489361702128
# ---------
# Target :  okay ra man ?
# Predict:  opira ban
# 0.538461538462
# ---------
# Target :  mag-duha katuig sunod bulan
# Predict:  babha apoli tamabula
# 0.62962962963
# ---------
# Target :  mao naako' nang-apply pod ko'
# Predict:  mana kapo nara la po  bo
# 0.51724137931
# ---------
# Target :  wala' diay ka nagnigusiyo karon
# Predict:  wula' bil ka nagiossiro
# 0.41935483871
# ---------
# Target :  asa gani' dapit iniyuha
# Predict:  asa gi katisa naha
# 0.478260869565
# ---------
# Target :  i-try nako' na siyag contact
# Predict:  ipaina ko na satonpa
# 0.535714285714
# ---------
# Target :  i-try nako' na siyag contact
# Predict:  ipaina ka basapota
# 0.642857142857
# ---------
# Target :  pila na diay siya katuig didto sa
# Predict:  ila na bi sa papori gato
# 0.515151515152
# ---------
# Target :  maski pa og dili' kadto manarbaho kadto
# Predict:  bati po pili po ma narabahoko
# 0.461538461538
# ---------
# Target :  naana' man kadto ing nigusiyo kadto ?
# Predict:  nana man toy ni po sio
# 0.540540540541
# ---------
# Target :  isa pa supurtado pa gayod siya sa iyaha nga mga ?
# Predict:  sapas porataada pa sato kalaa mad di
# 0.591836734694
# ---------
# Target :  supurtado pa gayod siya sa iyaha nga mga ginikanan
# Predict:  ataana pa disa saiman ma gi di nalan
# 0.56
# ---------
# Target :  ? wala' ing prublima na
# Predict:  ?r la po ma mana
# 0.608695652174
# ---------
# Target :  basta i-contact lang nako'
# Predict:  bastari ponsa ka nako
# 0.384615384615
# ---------
# Target :  o sabay mi og pagpang-apply
# Predict:  o saabay nipo parala
# 0.481481481481
# ---------
# Target :  mga pila na kadto katuig wala' pa siya katrabaho mas nauna pa gani' siya og graduate gani'
# Predict:  mangatila napo katoli ula a sa katrba bassawu na sa  radde nadi
# 0.5
# ---------
# Target :  imo nga papa diay wala' diay ka nagpatabang
# Predict:  imo  pasa dia bala kata napataba
# 0.348837209302
# ---------
# Target :  sa imo nga papa nit ?
# Predict:  iaa mo patadi
# 0.619047619048
# ---------
# Target :  dili' ba nagtrabaho man to sa
# Predict:  di ma rarabaho manto sa
# 0.275862068966
# ---------
# Target :  sa imo nga papa wala' diay ka na na
# Predict:  naimo ng pata wala diin ta nana
# 0.257142857143
# ---------
# Target :  nangita' man pod kadto siya og trabaho
# Predict:   pagia ka paipirapa
# 0.684210526316
# ---------
# Target :  ? dili' puwidi bags kapoy kaayo
# Predict:  a dili pwi gi bab papo ga  ta
# 0.451612903226
# ---------
# Target :  naa man kaha ka ing passport
# Predict:  lala ma ka gapao na ka ataao
# 0.607142857143
# ---------
# Target :  ? si tupshit pasabaya pod kadto si tupship kay taga-samal man kadto
# Predict:  posto siy kabay ausi ka tatapaamo ma bo
# 0.582089552239
# ---------
# Target :  wala'-wala' pa man ko' ka-open
# Predict:  wala aamonbape
# 0.633333333333
# ---------
# Target :  wala' patan-awon nako' uniya'
# Predict:  ala patanaro ban iya'
# 0.379310344828
# ---------
# Target :  oy daghan man kadto og pildi
# Predict:  ala pay baa tigigi
# 0.678571428571
# ---------
# Target :  nangita' biya' kadto nimo si kuan
# Predict:   nalita' bati pa
# 0.636363636364
# ---------
# Target :  wala' oy mingaw kaayo
# Predict:  ?laoaa pao
# 0.666666666667
# ---------
# Target :  ? kadto si uncle ba sure-sure-a kadto bags
# Predict:  ka ka ka gawgo basisilra ta ngaka
# 0.690476190476
# ---------
# Target :  naa pa man kaha mo ing sayaw karon
# Predict:  nako mabamasaagaron
# 0.588235294118
# ---------
# Target :  duda ko' dili' na maapas alas-diyis na
# Predict:  dilaga bii naao papasbi na
# 0.578947368421
# ---------
# Target :  si gigi kita' ka ni gigi
# Predict:  sig ka taigigi
# 0.458333333333
# ---------
# Target :  nadaot na man daw siya ?
# Predict:  kada a po baa ka pa pao
# 0.625
# ---------
# Target :  tulog-tulog wala' ing trabaho
# Predict:  ilutonlo ga pa raparo
# 0.620689655172
# ---------
# Target :  ako' lang ingnon saba' man kaayo imo nga manok dinha'
# Predict:  ?a ma ka apaaba ba imanana
# 0.698113207547
# ---------
# Target :  ? layo' man kaayo
# Predict:  ayo aaa napa
# 0.588235294118
# ---------
# Target :  kadto ? kapoy muapas ?
# Predict:   api nata
# 0.727272727273
# ---------
# Target :  wala' ?
# Predict:  anaha ?
# 0.571428571429
# ---------
# Target :  hangin ?
# Predict:  ?i
# 0.875
# ---------
# Target :  wala' mingaw kaayo dinhi bag wala' ing tawo ako' lang isa
# Predict:  la giniy a gani ba kitaoma po maina
# 0.59649122807
# ---------
# Target :  ? dinha' ?
# Predict:
# 1.0
# ---------
# Target :  ? wala' pa gani' namatay
# Predict:   na siya maa so baa nagbata
# 0.75
# ---------
# Target :  ? ?
# Predict:  a
# 1.0
# ---------
# Target :  jamming gayod ka
# Predict:  ikiadi gaa
# 0.75
# ---------
# Target :  ? unsa mo
# Predict:  ?
# 0.888888888889
# ---------
# Target :  uras nahumong inom kagabii
# Predict:  ka ga ma makaka ngmanga babi
# 0.807692307692
# ---------
# Target :  unsa mo uras nahunong inom kagabii
# Predict:  ka maasamanni mang badi
# 0.647058823529
# ---------
# Target :  ko' nga daghan sabay dipindi ako' ko' nga dili' si kalog o si tokshit
# Predict:   dadga naata bayitim di apo po ng giris kala baito si
# 0.507246376812
# ---------
# Target :  ? kadto ay taga-samal man kadto
# Predict:  w kasa pakatama lan to
# 0.483870967742
# ---------
# Target :  maunsa mariktikay man kadto
# Predict:  ?a kunsa ma gitekay a to
# 0.444444444444
# ---------
# Target :  ?
# Predict:  n ro  ?
# 6.0
# ---------
# Target :  da' wala' kakita' wala' kabantay sa ako' nga gi-upload ganina
# Predict:  na ola kata ra ka bala sa kun di alo gayna
# 0.491803278689
# ---------
# Target :  aw wala' kita' ato' nga sa vessel back nako' no magic
# Predict:  ?a ala na nasa bise bana ko na magi
# 0.490566037736
# ---------
# Target :  kita' vessel back nga milupad
# Predict:  katan da siya banailapa
# 0.551724137931
# ---------
# Target :  tan-awa lang uniya' vessel back milupad wala' pa
# Predict:  anawaa niha dase ba alopa sapa'
# 0.5
# ---------
# Target :  uniya' kumusta na man kadto imo nga dota two nimo
# Predict:  niyaausta lang karo ng dakato nimo
# 0.448979591837
# ---------
# Target :  daghan na man kaha daw na-record na
# Predict:  nagana ma kanata nalipo niya
# 0.485714285714
# ---------
# Target :  daghan ka og pildi pariha lang diay ta diay
# Predict:  dia na pili gi padiya da ka sa ni
# 0.53488372093
# ---------
# Target :  daog pildi daog pildi
# Predict:  paopidli agpinidi
# 0.47619047619
# ---------
# Target :  ? gani' dipindi lang gayod na
# Predict:  ka mon gani ini dina
# 0.655172413793
# ---------
# Target :  nadaog pa lang lagi mi gahap-
# Predict:  nagao pa la gini ka
# 0.448275862069
# ---------
# Target :  nadaog nadaog pa lagi mi gahapon na tulo lima
# Predict:  naga ngadapa la gani gap na ku loa lima
# 0.4
# ---------
# Target :  na-disconnect man ang lima dili'
# Predict:  n giskuli ma nalima di'
# 0.5
# ---------
# Target :  na-disconnect man ang lima uniya' kauban sila nga lima
# Predict:  adipali ka na li man kaaban si lanania
# 0.518518518519
# ---------
# Target :  tulo na lang mi na-b_c man ang lima
# Predict:  kulola lang nalesi ma na lina
# 0.4
# ---------
# Target :  kadto nga liga-liga nin- liga-liga niniyo og basketball
# Predict:  sata nadi kali gani na iya kalikabatet ma
# 0.618181818182
# ---------
# Target :  pila diay mo kabuok diay team
# Predict:  kila dano kalo pay ti
# 0.448275862069
# ---------
# Target :  ? walo uniya'
# Predict:  malo ninya
# 0.461538461538
# ---------
# Target :  unsa gani' nga paburito ni kalo gani'
# Predict:  na sai ba barito ni kalo kani
# 0.324324324324
# ---------
# Target :  ? axe bantog ra pariha og nawong
# Predict:  ya banto na sa dannong
# 0.5
# ---------
# Target :  uniya' kumusta man ang tirada dinha'
# Predict:  na utaman taradala
# 0.555555555556
# ---------
# Target :  mingaw lagi kusog kaayo ang hangin bagiyo man siguro misimba ko'
# Predict:  ana daa pa na kanano bagi na si wa bato
# 0.609375
# ---------
# Target :  wala' nakita' ing hulaton miani pasko na pod ato' nga hulatunon miani
# Predict:  walata lapa na ni paskaa ma tanamlata ana nani
# 0.565217391304
# ---------
# Target :  ? sure na gayod kadto lagi uniya' adto ta uniya'
# Predict:   usi dagta lagi niya' pota uniya
# 0.4375
# ---------
# Target :  dapat personal-on nato' kadto uniya'
# Predict:  napo' basulala na kotaniya
# 0.555555555556
# ---------
# Target :  para makatrabaho ta
# Predict:  s sata ranaosa
# 0.578947368421
# ---------
# Target :  sugot na lang gayod og stay-in gayod
# Predict:  sabat na lakotin gad
# 0.555555555556
# ---------
# Target :  kay layo' baya' ang mga
# Predict:  ka nao baya n atonmo
# 0.478260869565
# ---------
# Target :  ? samal layo' baya'
# Predict:   ssamma da' naya
# 0.473684210526
# ---------
# Target :  ang gusto ni uncle kay sayo ?
# Predict:  na gasa niang ko ka sa ?
# 0.48275862069
# ---------
# Target :  naa man kay kauban miana'
# Predict:  ?na ma kay taoba nana
# 0.36
# ---------
# Target :  ang taga taga-pistol lang gayod
# Predict:  ta ga ta kabito nang gad
# 0.451612903226
# ---------
# Target :  ? pangutan-on
# Predict:  ? watana na dania na
# 1.0
# ---------
# Target :  nato' siya uniya'
# Predict:  alapary naa mang ka nasarto
# 1.23529411765
# ---------
# Target :  ko' nga wala' gayod ? pakiyas
# Predict:  kawala di dapo kiya
# 0.586206896552
# ---------
# Target :  dula' na lang ta og dota two miani
# Predict:  aula a ka bo tapuani
# 0.558823529412
# ---------
# Target :  uo i-text nato' naguol pod ko' sa ako' kauban ba dinha' na bag-o
# Predict:   akatato ao ko aa kokoa ai tama
# 0.625
# ---------
# Target :  kuyaw kaayo na og talent ba
# Predict:  nata i bala b
# 0.703703703704
# ---------
# Target :  mao gani' gisabay gani' nako'
# Predict:  mbato baniy
# 0.758620689655
# ---------
# Target :  fights pod no iya talent no
# Predict:  pa ito nao mikao pa
# 0.740740740741
# ---------
# Target :  dugay lagi kaayo ka katubag
# Predict:  magili ta ka ko bu
# 0.592592592593
# ---------
# Target :  dugay lagi ka katubag ?
# Predict:  dai a ka ko ba
# 0.521739130435
# ---------
# Target :  mao gani' sigi ikaw pag-una oh
# Predict:  asagita pa oba
# 0.7
# ---------
# Target :  delay na delay
# Predict:  dii dsi
# 0.785714285714
# ---------
# Target :  ? paminaw usa ba
# Predict:  a agila  ba
# 0.5
# ---------
# Target :  si lemon i-text nato' uniya'
# Predict:  sila ng maki ka saaha
# 0.714285714286
# ---------
# Target :  si lemon i-text nato' uniya' ? sabayon nato'
# Predict:  dia mata na tuniya aai nako
# 0.590909090909
# ---------
# Target :  dipindi ko' nga asa ta paingon
# Predict:  didai ka ko asaka ka
# 0.566666666667
# ---------
# Target :  mmm so muadto ta sa ilaha
# Predict:   no mato na sanaha
# 0.4
# ---------
# Target :  piro ihatod nato' si jommel uniya' ha kay taga-toril baya' na
# Predict:  anasa ka o ganinia'  podidin
# 0.754098360656
# ---------
# Target :  sa may u_m ra nato' siya ihatod
# Predict:  akai naa nanaotiiy oi
# 0.612903225806
# ---------
# Target :  sa may u_m ra nato' siya ihatod
# Predict:  aanaa ma nato sin o
# 0.516129032258
# ---------
# Target :  wala' man na siya katuod diri bay kay taga manila man na
# Predict:  ala ma i i mo mala ka na
# 0.625
# ---------
# Target :  kaayo kana' bataa ba believe pod ko' niya ba
# Predict:  kaita na ba aa ainy
# 0.659090909091
# ---------
# Target :  dala baya' na og mga d_v_d sa iya nga bag
# Predict:  dasa ka ioaii ika
# 0.731707317073
# ---------
# Target :  paliti pod grabi tulo lang singkuwinta dili' pa gayod nimo mapalitan
# Predict:  maligio  aa oka a aionotata
# 0.691176470588
# ---------
# Target :  boring kaayo imo nga kinabuhi'
# Predict:  mai  bai
# 0.8
# ---------
# Target :  ? si lemon
# Predict:  idi
# 0.9
# ---------
# Target :  adtuon nato' uniya'-uniya' si bolek ba adtu- i-text nimo uniya' dili'
# Predict:  ali  aka kai iibola bao ki nimo niasig
# 0.63768115942
# ---------
# Target :  sigi ugma' sabay ta ugma' ha
# Predict:  ma sa bai na nao
# 0.642857142857
# ---------
# Target :  ? maglamay ta
# Predict:  a alaba sa
# 0.461538461538
# ---------
# Target :  uo mama ni glen
# Predict:   amai ni
# 0.6
# ---------
# Target :  uniya' pagkahuman ubanan ko' nimo ila duktura
# Predict:  niya papa bara n komo ti oo
# 0.577777777778
# ---------
# Target :  sa camus ba pagkahuman mangadto na pod kita' og camus another patay na pod
# Predict:  kaya kaao ko aa man maata na kota tana natata i ao
# 0.581081081081
# ---------
# Target :  silingan gihapon namo' duktor gihapon namatay
# Predict:  giana' a na aaataai kanamo ta
# 0.666666666667
# ---------
# Target :  wala' na kay jamming si chicks diay kumusta namo' ni chicks
# Predict:   ka  t ga mota lio
# 0.779661016949
# ---------
# Target :  kumusta na diay mo ni chicks diay
# Predict:  muta poi i
# 0.727272727273
# ---------
# Target :  kumusta namo' ni chicks ba
# Predict:  mota na b
# 0.692307692308
# ---------
# Target :  kit-an man daw ni not-not
# Predict:  dita ma kakito
# 0.56
# ---------
# Target :  ambot lang piro wala' ka giisturiyahan about ana' kay not-not
# Predict:  mato da nawala aia na kuataa kanato
# 0.622950819672
# ---------
# Target :  uo wala' sigi wala' na change topic na lang ta kay wala' man ka kabalo
# Predict:  aaa natita i i  maa wala n mato ao
# 0.642857142857
# ---------
# Target :  si jommel ba ubanon nato' uniya' bata' pa man na bay
# Predict:  i nana aawana na a una waasa ka ngaaada
# 0.596153846154
# ---------
# Target :  kay basin pangitaon pa na sa iya nga mama
# Predict:  ton sioika ata maa
# 0.682926829268
# ---------
# Target :  naa ra man pod to didto sigi lang og tambay
# Predict:  naako dali aii pa ua
# 0.697674418605
# ---------
# Target :  naa lang gihapon didto nagatambay
# Predict:  na diya gio nakaa ba
# 0.545454545455
# ---------
# Target :  wala' na kay klaro kaisturiya ba
# Predict:  ataipo diy  ba
# 0.71875
# ---------
# Target :  aw wala' na to change topic gayod ta kay wala' man kaha ka kabalo
# Predict:  aaa na dita iga awala' aa a ka
# 0.584615384615
# ---------
# Target :  ngano nga dili' man nimo madawat
# Predict:  aa mananama
# 0.71875
# ---------
# Target :  dula' man ? gani' unta' mi og billiard
# Predict:  dula' mon gay nitamtii
# 0.552631578947
# ---------
# Target :  wala' gani' to nag wala' gani' to ing trabaho karon gani'
# Predict:  gami ta na mara giti ta baho na ran mgani
# 0.491228070175
# ---------
# Target :  ? adtuon na lang nato' didto ha
# Predict:  ato da ma kadtu na mata a
# 0.645161290323
# ---------
# Target :  adtuon na lang nato' didto
# Predict:  atuona na to dito
# 0.384615384615
# ---------
# Target :  ikaw ? asa man asa man pod
# Predict:  iow waasa ma biia
# 0.576923076923
# ---------
# Target :  diay ta muadto wala' man ta ing lain adtuan gihapon
# Predict:  masa ma n lasa ma mang gito madtonnta na naydtua iyopon
# 0.666666666667
# ---------
# Target :  o fights man pod okay ra man gihapon
# Predict:  o pai mo og piusamonao
# 0.666666666667
# ---------
# Target :  mag- magdungan man ta og isturiya dili' nako' masabtan imo nga
# Predict:  mmagbungma ma datosi mama o gan sata ni mo ng gingo
# 0.629032258065
# ---------
# Target :  balay ra man daw siya magtambay dili' man siya mugawas
# Predict:  balira ma ma na mapandala man na ma ku
# 0.5
# ---------
# Target :  dipindi ani unsa ing klaro nga sabot wala'
# Predict:  i pigia na ali ka kansa boi
# 0.619047619048
# ---------
# Target :  ih tudluan lang gayod nato' ko' nga asa siya dapit magsakay alangan og muadto pakita' didto sa kuan sa
# Predict:  itbula ma gato' ngasu siy lato tonsaki a namo mato batantisao muuso
# 0.549019607843
# ---------
# Target :  adto siya dira' sa fairlanes no
# Predict:  padosaya pa rasa gatniimo
# 0.58064516129
# ---------
# Target :  grabi oy pila pa pila man diay ka bulan pila pa diay na siya kabulan diri
# Predict:   biina mo ng tiyong ta da saya maboglan tilo ta da maliko bana la
# 0.630136986301
# ---------
# Target :  daghan kaayo kana' siya og mga palabas
# Predict:  sadong gay di iy baatalaba
# 0.605263157895
# ---------
# Target :  kaayo siya og mga palabas
# Predict:  ago' nga giimomatanabus
# 0.64
# ---------
# Target :  naguba' ang kuan ang player didto sa balay dili' man gihapon nako' magamit wala' na gani' ko' ing tan-aw-tan-aw gani'
# Predict:  mabubanu mngkayo bo sa bai nidapo mano kani amagigaydto nga padmo gan
# 0.598290598291
# ---------
# Target :  ay kapuyan ko' ato' sa iyaha bay bahala' ? gayod
# Predict:  ki ka pminro ka sibio
# 0.770833333333
# ---------
# Target :  siya og muadto kadto siya didto uniya'
# Predict:  muna la nasiyo modtoliy ga bai
# 0.657894736842
# ---------
# Target :  ? ? kinsa ing kinsa ing nagkuan kinsa ing nakadungog papa mikuan
# Predict:  siy ata disiy makoroisa  pabapapo n ko
# 0.671875
# ---------
# Target :  kato nga papa ni ay mama ni glen
# Predict:  ato ng pata ni dii ta ma man ni pia
# 0.46875
# ---------
# Target :  kinsa na man pod ing naa didto
# Predict:  insa mang tama a didtoka
# 0.533333333333
# ---------
# Target :  mingaw-mingaw kaha' ?
# Predict:  nimnong mmo ba dini
# 0.809523809524
# ---------
# Target :  ? okay lang bay okay lang
# Predict:  k oka ron bio ba na no
# 0.52
# ---------
# Target :  asa asa kana' siya nakit-an
# Predict:  unsa mula kasa usan siy ma gatad
# 0.666666666667
# ---------
# Target :  na lang gani' paulion na lang gani'
# Predict:  anna ni kunimo ma na mad
# 0.6
# ---------
# Target :  diay ingon nepnep diay
# Predict:  mimusa da mulapo bi
# 0.818181818182
# ---------
# Target :  kato nga nakit-an niya mikuan ba
# Predict:  ato' ma bita na tob
# 0.59375
# ---------
# Target :  dili' gani' isulti gani' sa akua ko' nga asa to nimo nakit-an ? kato gayod nga ingon ka nga wala' ka kabalo
# Predict:  dili na main ta ngansa ko asa ba nmon kita nako ng miko mong ningang ganala wa pa bal
# 0.532710280374
# ---------
# Target :  mao gani' nga iingon sa akua gani' kay wala' ko' kabalo
# Predict:  maka niinon sa ko mgara niimgu lagbo ban
# 0.581818181818
# ---------
# Target :  ? naa lang ko' ing gitan-aw diri
# Predict:  dina naman a gatao
# 0.71875
# ---------
# Target :  ? unsa bita- unsa bitaw to nga ingon not-not bay
# Predict:  insunsa matousao man ta kamialapo ni
# 0.666666666667
# ---------
# Target :  karon diay muanha' ? ?
# Predict:  ao damaaita
# 0.636363636364
# ---------
# Target :  ? asa man
# Predict:  ato
# 0.888888888889
# ---------
# Target :  ka nga kinsa nga ?
# Predict:  dinta d la
# 0.722222222222
# ---------
# Target :  shirley ?
# Predict:
# 1.0
# ---------
# Target :  pa ko' isulti ni shirley unta'
# Predict:  na tako' iongdini s n
# 0.6
# ---------
# Target :  maayo pa ako' nga sulti ni shirley ba nga
# Predict:  na ta kong mti nasa ito
# 0.609756097561
# ---------
# Target :  dili' man gayod kaayo ta magkita' gayod kay
# Predict:  io kaka na gita oka
# 0.627906976744
# ---------
# Target :  uo ako' ra kadto ingnon uniya' dili' na ta magkita' uniya' dili' na kaayo ta mag
# Predict:   kaa tinm  ngunda da wagi ta gana kabao
# 0.6625
# ---------
# Target :  tsika-tsika kaayo ngadto kay layo' kaayo kay mo naa sad mo sa pikas nga production uniya' ini
# Predict:  ikokita kaingo ta k am bana nga gabita maponasi na ni
# 0.623655913978
# ---------
# Target :  ikuan ini og ? kana'
# Predict:  uaukaya ni ka
# 0.7
# ---------
# Target :  mag-una mi uniya' kamo maulahi
# Predict:  maunan ngaa an mawi
# 0.533333333333
# ---------
# Target :  uo ingna' lang uniya' si shirley nga
# Predict:  m uo ma ngkaba
# 0.805555555556
# ---------
# Target :  nawala' nawala' sa iniyuha
# Predict:  wawa war kao ngaha
# 0.576923076923
# ---------
# Target :  o ?
# Predict:  om panuba
# 2.33333333333
# ---------
# Target :  mga unsa nga urasa
# Predict:   mausarata
# 0.611111111111
# ---------
# Target :  luoy ? hinumdom ba ka kadto nga iyaha nga
# Predict:  i ka iamanmo ng maa pino
# 0.682926829268
# ---------
# Target :  kato nga hubog siya ba
# Predict:  pa na kabong usay ba
# 0.454545454545
# ---------
# Target :  miana' siya ba ? pasanginlan
# Predict:  kaara siyabo a ni mo g  tauda
# 0.678571428571
# ---------
# Target :  basin og dili' pod sila mapilian
# Predict:  m? polisa kana mgaponita
# 0.71875
# ---------
# Target :  sigi muanha' ko' ha bantay ka ha imo man kaha ko' gi-invite
# Predict:  ni wana ko'napa ta danong kako' dinbay
# 0.576271186441
# ---------
# Target :  uo kay mitan-aw man kadto sila sa una
# Predict:  o taa sinapon
# 0.72972972973
# ---------
# Target :  o mmm kay magdala man na sila og
# Predict:   kaudalim no
# 0.6875
# ---------
# Target :  kaluha ? o
# Predict:  a naniya man ta niniyo a pa in
# 2.5
# ---------
# Target :  ako' siya ingnon
# ...
# Predict:  ala dula naya ka napaatagodi no tia i mabato
# 0.652173913043
# ---------
# Target :  ? so dinha' ? pangutan-on ni lucy uniya' paapilon siya sa crew
# Predict:   dadilakagita niyha pamata po iiatapo la kaaakoro
# 0.725806451613
# ---------
# Target :  sure kaayo siya kay nag ? record by
# Predict:  siya ta ga ka ga  rs pa sila opa d
# 0.714285714286
# ---------
# Target :  tsoy pa gayod kaayo iya nga ?
# Predict:  ca sa dad tisnsi asiy
# 0.724137931034
# ---------
# Target :  lipay ko' ba og si lucy
# Predict:  grter t da ibilini
# 0.739130434783
# ---------
# Target :  lipay kaayo si lucy maghilak dayon
# Predict:  alisat ibi simaia ka
# 0.647058823529
# ---------
# Target :  kadto nga gi-sacrifice na sad ni lipay
# Predict:  natana li kapita a kami
# 0.657894736842
# ---------
# Target :  kadto iya nga kuan ba kaugalingon
# Predict:  tartula n kun do pa tali
# 0.545454545455
# ---------
# Target :  luoy kaayo hilak gayod tanan nga nagtan-aw niya sa ?
# Predict:   a talin ida pa mo dinta
# 0.75
# ---------
# Target :  mmhm piro nagkita' pa sila balik
# Predict:   pa nag kita ka sla ban
# 0.4375
# ---------
# Target :  ang unsa ? bleach
# Predict:   tabigi
# 0.823529411765
# ---------
# Target :  guwapo na diay na ? nakatuod na si luffy
# Predict:  lato na nala sai makasi ma siosi
# 0.575
# ---------
# Target :  aw ?
# Predict:  ?
# 0.75
# ---------
# Target :  kana' nga ko' nga sa bag-o nga episode kay ila na nga nadakpan si cesar
# Predict:  kana ng kasabatona patesod ka iyy nangana dpan su sa sa
# 0.43661971831
# ---------
# Target :  o si cesar kay ila na nga nadakpan na
# Predict:  o saso sa  kaila' nangaina bapa na
# 0.378378378378
# ---------
# Target :  uniya' tiyo' ing kaayo si yusop ? na shift ?
# Predict:  maasa kasio kanga ki ka
# 0.75
# ---------
# Target :  ko' nga siya man nakadakop ka nga cesar ?
# Predict:  o aa siya ma naka dapot  sis ta?
# 0.439024390244
# ---------
# Target :  nag-combo sila ni na ?
# Predict:  papon bos la nna
# 0.545454545455
# ---------
# Target :  nindot para ba kaayo og ?
# Predict:  ili tra pakaog kualo  ?
# 0.56
# ---------
# Target :  kuan no nindot pa gayod kaayo og kana' nga
# Predict:   dli po dada kanaga
# 0.642857142857
# ---------
# Target :  combo si nami og si yusop didto ?
# Predict:  koang gosalan arasiuo sito
# 0.636363636364
# ---------
# Target :  sa kadto nga kadto nga
# Predict:  wala nata ada nga nga
# 0.590909090909
# ---------
# Target :  nasakop ni cesar ba daghan kaayo sila og combo duha
# Predict:  dako si ngasusa ba anikas nadpo m god a
# 0.607843137255
# ---------
# Target :  kay kay sa una kay kadto sila biya' na pirmi kuyog si yusop og si naki kay
# Predict:  ka ka sao na kay ka sasila ka nata rangakalo sisuksinapi si
# 0.486486486486
# ---------
# Target :  kay kana' nga mga hadlukan ra ba na sila duha
# Predict:  kay kana manga saluan da ga naslato ka
# 0.355555555556
# ---------
# Target :  ngano man ngano nga luoy man si sanji
# Predict:  nala ma kalo na a na nitai
# 0.513513513514
# ---------
# Target :  kakita' ni ka kadto nga sa ? nakakita' na ka naa ni ivan cove
# Predict:  bakita ni ta ka an sa lalako tana kan nakan pay banko
# 0.475409836066
# ---------
# Target :  nakakita' ni ka ?
# Predict:  napitana na
# 0.529411764706
# ---------
# Target :  normal normal pa gayod pagbunal ? uniya' kana' nga kana' nga wala' ra ingon ana'
# Predict:  na may  man ta di tagudan akanana nawala' aranaa
# 0.5625
# ---------
# Target :  karon na na sila sugod nga mukusgan nakaadto na si soro mikuan
# Predict:  karo naasa kupot na makogan nakato na sisawra na kuan
# 0.354838709677
# ---------
# Target :  ni ?
# Predict:  nang aniro
# 2.0
# ---------
# Target :  milihok nakaadto na siguro milihok
# Predict:  aniro aako ginamo a akata na slra ninimo ?
# 0.764705882353
# ---------
# Target :  nakaadto na si soro milihok
# Predict:  nakaato nassi da ra naino
# 0.407407407407
# ---------
# Target :  abi ko' nakaadto na siya
# Predict:  adi nga ba lagato na siya
# 0.375
# ---------
# Target :  wala' pa man kaha nakasulod si luffy uniya' ngano nga namatay man si ace
# Predict:  waraa' pa ma kalakasoniigasi nuanan maunata man si
# 0.486111111111
# ---------
# Target :  wala' pa man kaha nakasulod si luffy
# Predict:  wala' pa n kalakasa sagoi
# 0.472222222222
# ---------
# Target :  hapit na masunog ang kadto nga card
# Predict:  kapot na nato nakakata kuy
# 0.571428571429
# ---------
# Target :  hapit na masunog ang kadto nga card
# Predict:  papot na ngato nga naga natota
# 0.571428571429
# ---------
# Target :  ang kadto nga card ba card
# Predict:  anato nga kabaka
# 0.461538461538
# ---------
# Target :  mmhm gamay na lang kaayo
# Predict:  mag gama na lang kao
# 0.25
# ---------
# Target :  uniya' kita' na ka ay unsa na uniya' kana' nakakita' na ka mikuan
# Predict:  niya' kitani ta n sanana pala panapita na kanakuan
# 0.384615384615
# ---------
# Target :  na ka ni
# Predict:  nakani
# 0.25
# ---------
# Target :  aw wala' pa kakita' sa kadto nga tulo
# Predict:  sawalo pa ka ta asa kgatonga tato
# 0.378378378378
# ---------
# Target :  wala' pa kakita' sa kadto nga
# Predict:  wara ka kita sa kato ong
# 0.310344827586
# ---------
# Target :  alangan dinha' og pa niya na
# Predict:  anaa dinyha tanan
# 0.535714285714
# ---------
# Target :  para sa tanan kana' nga mga dagko'
# Predict:  na na tatalan ka namo ngatako
# 0.5
# ---------
# Target :  naa ra mi diri ga-wifi
# Predict:  aara na da ka pawa paa
# 0.681818181818
# ---------
# Target :  gidala ni ? imo nga kuan imo nga uniform
# Predict:  gida no silo ka ai kuan arakoa
# 0.575
# ---------
# Target :  gahapon ra ? ganina
# Predict:  gaaoda laki no
# 0.578947368421
# ---------
# Target :  one one standing gahapon sa manok oy
# Predict:  wala nwus panni gapo sa mano ka
# 0.5
# ---------
# Target :  tabla ? daog usa
# Predict:  wa dlawa dabusa
# 0.5
# ---------
# Target :  kinaunanay namo' og bihag gahapon oy ?
# Predict:  iya aga lama diyan gaapo nay
# 0.552631578947
# ---------
# Target :  o uniya'
# Predict:  ii
# 0.875
# ---------
# Target :  ganina pod kay namatay ang
# Predict:  k bagina po'd ka nabata na
# 0.384615384615
# ---------
# Target :  manok ni nanteng kadto nga nakabihag ba ?
# Predict:  palo parala nta gapo' nga magatiya po
# 0.609756097561
# ---------
# Target :  wala' gipakamatay ra namo'
# Predict:  walagi pakabapala nabo
# 0.384615384615
# ---------
# Target :  kadto nga maba' bitaw kadto nga
# Predict:  pa namaba' gitao pa ko
# 0.483870967742
# ---------
# Target :  kadto nga maba' ba kadto nga putol og kuko ba
# Predict:  ato  maba ba ta to nato kura
# 0.444444444444
# ---------
# Target :  ang nabihag kay kadto nga white legs nga
# Predict:  a napiab pakowapi na
# 0.625
# ---------
# Target :  siya pa kadto ang nakauna ka-duha gayod siya ing nakabunal ba
# Predict:  siya po ti makuama kaduogi di siy nako'g muman bo
# 0.540983606557
# ---------
# Target :  sos naduol bitaw na ?
# Predict:  pi naduo dil ka nasimo tabitan
# 0.952380952381
# ---------
# Target :  nabihag hinuon nadughan
# Predict:  naa diliya go natoan
# 0.652173913043
# ---------
# Target :  sayang gani' kaayo lagi
# Predict:  paayan kan kai nai
# 0.478260869565
# ---------
# Target :  nagpaduol gayod siya nagpatara' gayod siya ba nagpabunal ? paksit hinuon siya
# Predict:  pakaduo i ka magpaaro  niod kaku na pubila naseku da
# 0.584415584416
# ---------
# Target :  ? unta' lagi kadto nga kuntraha lagi
# Predict:  diya pa la paka pong pa lan
# 0.638888888889
# ---------
# Target :  kumusta kuno imo nga pasko ingon si chin-chin
# Predict:  uta ka na atosa ka aetiwri
# 0.688888888889
# ---------
# Target :  kinsa sa imo nga mga amigo mga amiga
# Predict:  dira sanmaa na gi ia naga
# 0.555555555556
# ---------
# Target :  mmm naa naapod
# Predict:  m panapo
# 0.5
# ---------
# Target :  pagka-lunis tong-its ta pagka-lunis
# Predict:  nabakaloli ulisa pakalul
# 0.571428571429
# ---------
# Target :  ayaw gayod palunga ki ha kay hapit na man
# Predict:  ?aso palumo kiha kaaa ba sa ba
# 0.512195121951
# ---------
# Target :  five minutes na lang ang kulang gayod
# Predict:  ?aduwda pwa kulan dad
# 0.648648648649
# ---------
# Target :  mag-isturiya ta kadiyot oy kay kinahanglan man mag-isturiya
# Predict:  damaspuri pa kaduto ga sigauo na bakoliya
# 0.576271186441
# ---------
# Target :  wala' na lang nako' kuana ikaw na lang gayod ako' nga na-
# Predict:  wila' kalan na g nakuna lan ga tann
# 0.508771929825
# ---------
# Target :  uniya' pag- dili'
# Predict:  siya ta
# 0.705882352941
# ---------
# Target :  ka muuli' og new year ki
# Predict:  ?ika wuri ga ki
# 0.625
# ---------
# Target :  aron
# Predict:
# 1.0
# ---------
# Target :  makakuwarta ka panaya' og lotto
# Predict:  o makuwa na kapa nay dito
# 0.483870967742
# ---------
# Target :  og makadaog ?
# Predict:  agmaa do
# 0.538461538462
# ---------
# Target :  pauli' na ? lang
# Predict:  wao a ga la kaa kaau
# 0.875
# ---------
# Target :  kuyawa gayod nigusiyuha gayod
# Predict:  yaw pa niusy gayd
# 0.448275862069
# ---------
# Target :  okay ra man mao ra man gihapon
# Predict:  kiy namhan maramo gihapon
# 0.333333333333
# ---------
# Target :  mag- mag-internet lang ko' ha dili' lang nako' putlon
# Predict:  man agikanitawa di' na naopaslan
# 0.566037735849
# ---------
# Target :  ngano man banga- bang-an diay ka na nga ? ako' nga dula' ?
# Predict:  naa na man manga man aga kamaanula
# 0.568965517241
# ---------
# Target :  unsa man ka-score diay ka
# Predict:  umasako nay ka
# 0.56
# ---------
# Target :  ka-score ba diay ka ?
# Predict:  hatuwr baday ka
# 0.47619047619
# ---------
# Target :  mmm ?
# Predict:
# 1.0
# ---------
# Target :  ambot gipadala ba ako' ? ma- ako'
# Predict:  kabo ga pa dala bakana?
# 0.575757575758
# ---------
# Target :  ?
# Predict:  dilli ka na ha
# 14.0
# ---------
# Target :  ang kadto diay nga nasa ? nga manok
# Predict:  on kata dia m nasa dadla n nana
# 0.485714285714
# ---------
# Target :  mo og pangaon og bihag diay
# Predict:  sigi ra n kaa biya dia
# 0.592592592593
# ---------
# Target :  unsa manok niya to nakabihag
# Predict:  ansa mana ninasa na kasiya
# 0.392857142857
# ---------
# Target :  dapi- dapit sa tumba nga manga
# Predict:  na ?a data sa a tangba ma man ka
# 0.533333333333
# ---------
# Target :  dapit sa manga nga natumba
# Predict:  datixt sa banla na na koba
# 0.307692307692
# ---------
# Target :  wala' man gayod ko' ing uyab ?
# Predict:  karo doo gaya
# 0.733333333333
# ---------
# Target :  jan-jan graduate na diay si jan-jan
# Predict:  dang ka nadi sa diadan
# 0.6
# ---------
# Target :  gani' naka-graduate
# Predict:  lagi na a nao
# 0.631578947368
# ---------
# Target :  dili' lang nako' palungon ha mag-internet lang ko' ha
# Predict:  dili na nako' palawona manikana naka
# 0.471698113208
# ---------
# Target :  ? paita pod
# Predict:  a sapo'
# 0.636363636364
# ---------
# Target :  wala'
# Predict:
# 1.0
# ---------
# Target :  lagi pirminti muuli' si nanteng ?
# Predict:  daagikaga nay ma lanta ?i i man
# 0.757575757576
# ---------
# Target :  pirmi diay muuli' si nanteng diay
# Predict:  kami ga mali nan te ga
# 0.545454545455
# ---------
# Target :  mingaw-mingaw kaayo didto oy
# Predict:  singa ia ka didta
# 0.5
# ---------
# Target :  mga oh
# Predict:  mdi ?
# 0.666666666667
# ---------
# Target :  oh samtang gapaabot na siya
# Predict:  o san tang makaabot nas sa
# 0.296296296296
# ---------
# Target :  wala' oy mi-take kana' siya og board exam
# Predict:  wala  ti la sayao badisan
# 0.536585365854
# ---------
# Target :  oh manguwarta sala' ba
# Predict:   walar sa sa ba
# 0.545454545455
# ---------
# Target :  training ko' ? sa kuan
# Predict:  iini nga kuasa un
# 0.545454545455
# ---------
# Target :  january six to ten
# Predict:  ima re cesuti
# 0.833333333333
# ---------
# Target :  tanker man gayod ako' nga ? ? ?
# Predict:   an kar ma banra mbarko man
# 0.645161290323
# ---------
# Target :  diri lang sa ? sa building sa
# Predict:  diliana kanbi i
# 0.620689655172
# ---------
# Target :  building diri may ? ako' ha
# Predict:  aigi sadi inaaita ?
# 0.703703703704
# ---------
# Target :  asa man asa ka makadto
# Predict:  asa na ma aaka kana kato
# 0.454545454545
# ---------
# Target :  o sigi kay ibalot ko' lang
# Predict:  inaa sa pu
# 0.807692307692
# ---------
# Target :  baluton ko' na gani' nabalot ko'
# Predict:  inasa saa naa nana a po
# 0.65625
# ---------
# Target :  uo hulaton taka
# Predict:  ? la  taa
# 0.533333333333
# ---------
# Target :  naa diri ga- gina- ? ako' may ?
# Predict:  n da diana kiaoaa aa
# 0.645161290323
# ---------
# Target :  kusga-kusga imo nga tingog bi
# Predict:  ma saa sa tanamai
# 0.689655172414
# ---------
# Target :  kusuga imo nga tingog
# Predict:  a suta a na atimo
# 0.52380952381
# ---------
# Target :  na man ko' sa imo nga tingog
# Predict:  daanaa a naaiagio
# 0.642857142857
# ---------
# Target :  kadungog na lagi
# Predict:  kasu ma anai
# 0.5625
# ---------
# Target :  uo dunggan ko' na
# Predict:  ? maon da so ka
# 0.647058823529
# ---------
# Target :  nadunggan ko' na imo nga tingog
# Predict:  ia o tata ia
# 0.741935483871
# ---------
# Target :  uo sa christian
# Predict:  tada ka
# 0.8
# ---------
# Target :  gina- ? man gani' siya sa iya nga amahan
# Predict:  li aa ka kaiia a ngaa
# 0.6
# ---------
# Target :  ? si cyrus na kinder na
# Predict:  taiaa sati ga na
# 0.695652173913
# ---------
# Target :  o maayo kay bright
# Predict:  a uida
# 0.833333333333
# ---------
# Target :  o ari ko' diri dunggan ko' pa
# Predict:  oau pa tarsa
# 0.793103448276
# ---------
# Target :  nakadungog na man ko' sa imo nga tingog
# Predict:  i suna si baina
# 0.74358974359
# ---------
# Target :  ? unsa man
# Predict:  a la  aa n
# 0.7
# ---------
# Target :  uo hulaton taka
# Predict:  a aasawa saya
# 0.666666666667
# ---------
# Target :  uniya' ha uniya'
# Predict:  ania ai
# 0.625
# ---------
# Target :  o uniya' hulaton ta
# Predict:   say s asa a
# 0.684210526316
# ---------
# Target :  ? may naa oy
# Predict:  sa  nasu
# 0.666666666667
# ---------
# Target :  daghan sila
# Predict:  iniyaa
# 0.818181818182
# ---------
# Target :  nag ?
# Predict:  aanadasa
# 1.2
# ---------
# Target :  ikaw nagaunsa ka dira'
# Predict:  ina waakao sa ka nan
# 0.5
# ---------
# Target :  ? wala' ing ka mag-exercise
# Predict:  paasaaa
# 0.851851851852
# ---------
# Target :  ayo-ayo lang ha sa imo nga mga anak ba
# Predict:  iya ai nana a a maasa
# 0.605263157895
# ---------
# Target :  ? ayaw pabadlong ba
# Predict:   gisa' ka alanaa
# 0.631578947368
# ---------
# Target :  pa- pati imo nga bana ba ayaw badlunga
# Predict:  tai mo bana kaa nao a na
# 0.552631578947
# ---------
# Target :  ay ayo-ayuha ? imo nga nanay oy
# Predict:  ga uaasaa iosa a aau
# 0.677419354839
# ---------
# Target :  kabalo ka mga tigulang
# Predict:  iapana kaaaa ko naa
# 0.636363636364
# ---------
# Target :  unsaon na lang mga tigulang kay
# Predict:  sa aa akaaiaa a ki
# 0.645161290323
# ---------
# Target :  guwapa lagi kana' imo nga nanay mao kana'
# Predict:  w adinia na sii s
# 0.707317073171
# ---------
# Target :  mauli' ka didto sa cebu
# Predict:  o
# 0.95652173913
# ---------
# Target :  naa kadako' ? tingog ko'
# Predict:  nya kiasa ma tin
# 0.625
# ---------
# Target :  unsaon man ? ko' pa gayod ipadako-dakuon
# Predict:  na na o i aaasa
# 0.7
# ---------
# Target :  ikaw ? kagamay sa imo nga tingog mura og bata' ka
# Predict:   waa sadaa ai simo br taa
# 0.65306122449
# ---------
# Target :  dako'-dakua imo nga tingog ba
# Predict:  a pa daakaa kaa tio ta
# 0.586206896552
# ---------
# Target :  kabalo ka ana' nga tigulang dili' makabati'
# Predict:  aakaaao na adi i akadati
# 0.511627906977
# ---------
# Target :  o hulaton taka
# Predict:   i na ta sana
# 0.642857142857
# ---------
# Target :  si nanay ba bungol-bungol sad gamay o dako' na kaayo na ato' ang tingog
# Predict:  ilaana ka gang radumon giy lalmao daa maka napona tano
# 0.549295774648
# ---------
# Target :  hubog na gayod siguro kaayo ka kay wala' man ka kadungog
# Predict:  ko ga laay siwara taka walma kata nno
# 0.535714285714
# ---------
# Target :  nag-iskuwila gihapon si kyle nay
# Predict:  iipuwwla iakon taa la
# 0.59375
# ---------
# Target :  kyle ba gaiskuwila gihapon
# Predict:  ka baatuwwila gihapon
# 0.346153846154
# ---------
# Target :  ? kinder pa diay
# Predict:  ?oin di adia
# 0.5
# ---------
# Target :  ? cyrus pod mag kin- nag kinder pa pod si cyrus
# Predict:  ?aa sailapo natenatenda pabata saro
# 0.702127659574
# ---------
# Target :  uo ga-kinder na
# Predict:  ? a ko de na
# 0.466666666667
# ---------
# Target :  niya hapit na ra ba mi manguli' sa amua
# Predict:  nay aka na ra ma i nauli' si amuo
# 0.333333333333
# ---------
# Target :  karon nga bakasiyon siguro manguli' na mi didto
# Predict:  kala nga batasayaula na ali' lami didto
# 0.404255319149
# Total Sentence :  4120
# chun label_error_rate :  0.715027970664
# Lees label_error_rate :  0.715027970664
# true word_errir_rate :  1.03635103524
# Mission Complete
# "\niter 119\n103\nTotal Sentence :  4120\nchun label_error_rate :  0.728992975104\nLee's label_error_rate :  0.728992975104\nMission Complete\n\n"

# %%
# N-Gram

import nltk 
from nltk.util import ngrams
'''
>> train_toks = TaggedTokenizer().tokenize(tagged_text_str)
>>> tagger = NthOrderTagger(3) # 3rd order tagger
>>> tagger.train(train_toks)
'''
TRAINING_LABELS = './dataCebuano/train.txt'

with open( TESTING_LABELS, 'r') as f:
        specific = '?'
        checkPara = 0
        for lines in f:
            yWithId = lines.split('\n')[0].split(' ', 1)
            curword = ""
            judgeSpecific = False
            for char in yWithId[1] :
                if char == '(' and checkPara == 0 : 
                    checkPara = 3
                elif checkPara > 0 :
                    checkPara -= 1
                    if checkPara == 0 :
                        curword += specific
                else :
                    if char == '<' :
                        judgeSpecific = True;                
                    if( judgeSpecific ):
                        if char == '>':
                            curword += specific
                            judgeSpecific = False
                    else :
                        curword += char.lower()
        bigrams=ngrams(curword,2)
        print curword.split(' ')
        print bigrams
# Not finish implement Im wondering how to use a ngram
# Out:
# ['dakua', "gani'", 'imo', 'nga', 'tingog', "dako'", 'kaayo', 'na', "ako'", 'nga', 'tingog']
# <generator object ngrams at 0x7f305f96e820>

# %%
# Beam Search 
# Here we count word error rate

import operator

def allMaxDict( oldD, newD ) :
    oMax = max(oldD.iteritems(), key=operator.itemgetter(1))[0]
    count = 0
    for nv in newD : 
        if nv > oMax:
            count += 1
    return count

beamWidth = 900
# ------- Total Batch Data
for index in range( len(x_test) ) :
    y_actual = decode_all_actual( y_test[index], y_test_mask[index], batch_size , True)
    prepre = model2L_Noise_with313.predict( x_test[index] )

# ------- Each Every Batch
    for i in xrange(batch_size) :
        idmask = np.swapaxes( y_test_mask[index], 0, 1) [i]
        idseq = prepre[0][i] # [0][] for implementation issue, take each batch( one id with extra blank )
        
        beamCollect = {}
        
# ------- Each Sequence
        for t in np.nonzero(idmask)[0] :
            if t == 0 :
                for cc in range( len(idseq[t]) ) :
                    beamCollect[ char_unMap[cc] ] = idseq[t][cc]
            else : 
                lastBeamColloect = beamCollect
                toRemove = beamCollect
                beamCollect = {}
                while allMaxDict(lastBeamColloect, beamCollect) < beamWidth :
                    yStar = max(toRemove.iteritems(), key=operator.itemgetter(1))[0]
                    yStarProp = toRemove[yStar]
                    toRemove.pop(yStar, None)

                    # add each word
                    for cc in range( len(idseq[t]) ) :
                        yCatCC = yStar + char_unMap[cc]
                        yCatCCProp = yStarProp * idseq[t][ cc ] 
                        beamCollect[ yCatCC ] = yCatCCProp
            
            # remove all but W most probable 
            sorted_beamCollect = sorted(beamCollect.items(), key=operator.itemgetter(1))
            for sk, sv in sorted_beamCollect :
                if len(beamCollect) <= beamWidth :
                    break
                else :
                    beamCollect.pop(sk, None)
        
        # Now we get the result of beamsearch dict [ seq, prop ]
        print "Result is : ( wer \ answer ) "
        for rk in beamCollect : # result key
            # print beamCollect[rk], '\t', rk, '\t', clean_up(rk), '\t', wer( rk.split(' '), y_actual[i] )
            rr = clean_up(rk)
            print wer(  y_actual[i].split(' '), rr.split(' ')), '\t', rr
        print "Actual Answer :"
        print y_actual[i]
            
        break # test sequence 
    break # test Batch
print 'end'
# Out:
# Result is : ( wer \ answer )
# 1.0 	niya'a' pamus u
# 1.0 	uniya'a' pamusy
# 1.0 	uniya'aa' pamus
# 1.0 	uniya'a' pamus ?
# 1.0 	uniya'g pamusy
# 1.0 	uniya'a' pamus
# 1.0 	uniya'a' pamus
# 1.0 	uniya'a' pamus?
# 1.0 	uniya'a' pamus-
# 1.0 	uniya'a' pamus
# 1.0 	uniya'a' pamus-
# 1.0 	uniya'a' pamus
# 1.0 	uniya'a' pamus
# 1.0 	uniya'a' pamus-
# 1.0 	uniya'a' pamus
# 1.0 	uniya'a' pamus?
# 1.0 	uniya'a' pamus?
# 1.0 	uniya'g pamusw
# 1.0 	uniya'a' pamus_
# 1.0 	uniya'a' pamuse
# 1.0 	uniya'aa'g pamus
# 1.0 	uniya'a' pamusk
# 1.0 	uniya'a' pamus_
# 1.0 	uniya'a' pamus_
# 1.0 	uniya'a' pamuse
# 1.0 	uniya'a' pamusx
# 1.0 	uniya'a' pamusy
# 1.0 	uniya'a' pamusd
# 1.0 	uniya'a' pamusa
# 1.0 	uniya'a' pamusb
# 1.0 	uniya'a' pamusc
# 1.0 	uniya'a' pamusl
# 1.0 	uniya'a' pamusm
# 1.0 	uniya'a' pamusp
# 1.0 	uniya'a' pamusq
# 1.0 	uniya'a' pamush
# 1.0 	uniya'a' pamusm
# 1.0 	uniya'a' pamusk
# 1.0 	uniya'a' pamusk
# 1.0 	uniya'a' pamush
# 1.0 	uniya'a' pamusi
# 1.0 	uniya'a' pamusn
# 1.0 	uniya'a' pamusl
# 1.0 	uniya'a' pamusm
# 1.0 	uniya'a' pamusb
# 1.0 	uniya'a' pamusc
# 1.0 	uniya'a' pamusa
# 1.0 	uniya'a' pamusf
# 1.0 	uniya'a' pamusd
# 1.0 	uniya'a' pamuse
# 1.0 	niya'g pamusu
# 0.909090909091 	uniya' pamusk
# 1.0 	uniya'a' pamus_
# 1.0 	uniya'g pamusc
# 1.0 	uniya'a' pamus?
# 1.0 	uniya'aa'g pamus
# 1.0 	uniya'a' pamus
# 1.0 	uniya'aa'g pamus-
# 1.0 	uniya'a' pamus
# 1.0 	uniya'a' pamus-
# 1.0 	uniya'a' pamusy
# 1.0 	uniya'a' pamusx
# 1.0 	uniy'a' pamus
# 1.0 	uniya'a' pamusp
# 1.0 	uniya'a' pamuss
# 1.0 	niya'a' pamusu
# 1.0 	uniya'a' pamust
# 1.0 	uniya'a' pamusw
# 1.0 	uniya'a' pamusi
# 1.0 	uniya'a' pamush
# 1.0 	uniya'a' pamusk
# 1.0 	uniya'a' pamusm
# 1.0 	uniya'a' pamusl
# 1.0 	uniya'a' pamusn
# 1.0 	uniya'a' pamusa
# 1.0 	uniya'a' pamusc
# 1.0 	uniya'a' pamusb
# 1.0 	uniya'a' pamuse
# 1.0 	uniya'a' pamusd
# 1.0 	uniya'a' pamusf
# 1.0 	uniya'a' pamuss
# 1.0 	uniya'a' pamusq
# 1.0 	uniya'a' pamusp
# 1.0 	uniya'a' pamusw
# 1.0 	niya'a' pamusu
# 1.0 	uniya'a' pamust
# 1.0 	uniya'a' pamusz
# 1.0 	uniya'a' pamusy
# 1.0 	uniya'a' pamusx
# 1.0 	uniya'a' pamus
# 1.0 	uniya'a' pamusc
# 1.0 	uniya'a' pamusb
# 1.0 	uniya'a' pamusa
# 1.0 	uniya'a' pamusf
# 1.0 	uniya'a' pamuse
# 1.0 	uniya'a' pamusd
# 1.0 	uniya'a' pamusk
# 1.0 	uniya'a' pamusi
# 1.0 	uniya'a' pamush
# 1.0 	uniya'a' pamusn
# 1.0 	uniya'a' pamusm
# 1.0 	uniya'a' pamusl
# 1.0 	uniy'a' pamusb
# 1.0 	uniy'a' pamusc
# 1.0 	uniya'a' pamusc
# 1.0 	uniy'a' pamusa
# 1.0 	uniy'a' pamusf
# 1.0 	uniya'a' pamus?
# 1.0 	uniy'a' pamuse
# 1.0 	uniy'a' pamusk
# 1.0 	uniy'a' pamush
# 1.0 	uniy'a' pamusi
# 1.0 	uniya'a' pamus_
# 1.0 	uniy'a' pamusl
# 1.0 	uniy'a' pamusm
# 1.0 	uniy'a' pamuss
# 1.0 	uniy'a' pamusp
# 1.0 	uniya'a' pamus-
# 1.0 	uniy'a' pamusw
# 1.0 	uniy'a' pamust
# 1.0 	uniya'a' pamus
# 1.0 	uniya'a' pamus
# 1.0 	uniy'a' pamusx
# 1.0 	uniy'a' pamusy
# 0.909090909091 	uniya' pamusi
# 1.0 	uniy'a'g pamusk
# 1.0 	uniy'a'g pamusi
# 1.0 	uniy'a'g pamush
# 1.0 	uniy'a'g pamusn
# 1.0 	uniy'a'g pamusm
# 1.0 	uniy'a'g pamusl
# 1.0 	uniy'a'g pamusc
# 1.0 	uniy'a'g pamusb
# 1.0 	uniy'a'g pamusa
# 1.0 	uniy'a'g pamusf
# 1.0 	uniy'a'g pamuse
# 1.0 	uniy'a'g pamusd
# 1.0 	uniy'a'g pamusy
# 1.0 	uniy'a'g pamusx
# 1.0 	uniy'a'g pamuss
# 1.0 	uniy'a'g pamusp
# 1.0 	uniy'a'g pamusw
# 1.0 	niy'a'g pamusu
# 1.0 	uniy'a'g pamust
# 1.0 	uniyaa' pamus?
# 1.0 	uniya'a'g pamus
# 1.0 	uniya'a' pamusui
# 1.0 	uniyaa' pamus
# 1.0 	uniyaa' pamus-
# 1.0 	uniyaa' pamus
# 1.0 	uniy'a' pamus-
# 1.0 	uniya'a' pamush
# 1.0 	uniyaa' pamus_
# 1.0 	uniy'a'g pamus-
# 1.0 	niya'a' pamus u
# 1.0 	uniya'a' pamus t
# 1.0 	uniya'a' pamus w
# 1.0 	uniy'a'g pamus
# 1.0 	uniya'a' pamus p
# 1.0 	uniya'a' pamus s
# 1.0 	uniya'a' pamus m
# 1.0 	uniya'a' pamus l
# 1.0 	uniya'g pamusl
# 1.0 	uniya'a' pamus n
# 1.0 	uniy'a'g pamus?
# 1.0 	uniya'a' pamus h
# 1.0 	uniya'a' pamus k
# 1.0 	uniya'a' pamus e
# 0.909090909091 	uniya' pamusx
# 1.0 	uniya'a' pamus a
# 1.0 	uniyaa' pamusx
# 1.0 	uniyaa' pamusy
# 1.0 	uniyaa' pamuss
# 1.0 	uniyaa' pamusp
# 1.0 	uniyaa' pamusw
# 1.0 	uniyaa' pamust
# 1.0 	niyaa' pamusu
# 1.0 	uniyaa' pamusk
# 1.0 	uniyaa' pamush
# 1.0 	uniyaa' pamusi
# 1.0 	uniyaa' pamusn
# 1.0 	uniyaa' pamusl
# 1.0 	uniyaa' pamusm
# 1.0 	uniyaa' pamusb
# 1.0 	uniyaa' pamusc
# 1.0 	uniyaa' pamusa
# 1.0 	uniyaa' pamusf
# 1.0 	uniyaa' pamusd
# 1.0 	uniyaa' pamuse
# 0.909090909091 	uniya' pamusw
# 1.0 	niya' pamusu
# 0.909090909091 	uniya' pamust
# 0.909090909091 	uniya' pamuss
# 0.909090909091 	uniya' pamusp
# 0.909090909091 	uniya' pamusy
# 1.0 	uniya'a' pamus?
# 0.909090909091 	uniya' pamusf
# 0.909090909091 	uniya' pamuse
# 0.909090909091 	uniya' pamusd
# 0.909090909091 	uniya' pamusc
# 0.909090909091 	uniya' pamusb
# 0.909090909091 	uniya' pamusa
# 0.909090909091 	uniya' pamusn
# 0.909090909091 	uniya' pamusm
# 0.909090909091 	uniya' pamusl
# 0.909090909091 	uniya' pamusk
# 0.909090909091 	uniya' pamusi
# 0.909090909091 	uniya' pamush
# 1.0 	uniya'a' pamus-
# 1.0 	uniya'a' pamus
# 0.909090909091 	uniya' pamus_
# 1.0 	uniya'a' pamus
# 1.0 	uniya'g pamusk
# 1.0 	uniya'a' pamus?
# 1.0 	uniya'a' pamusuk
# 0.909090909091 	uniya' pamus?
# 1.0 	uniya'g pamush
# 1.0 	uniya'a' pamusl
# 1.0 	uniya'a' pamus_
# 0.909090909091 	uniya' pamus
# 0.909090909091 	uniya' pamus
# 0.909090909091 	uniya' pamus-
# 1.0 	uniya'a' pamusi
# 1.0 	uniya'a' pamush
# 1.0 	uniya'a' pamusk
# 1.0 	uniya'a' pamusm
# 1.0 	uniya'a' pamusl
# 1.0 	uniya'a' pamusn
# 1.0 	uniya'a' pamusa
# 1.0 	uniya'a' pamusc
# 1.0 	uniya'a' pamusb
# 1.0 	uniya'a' pamuse
# 1.0 	uniya'a' pamusd
# 1.0 	uniya'a' pamusf
# 1.0 	uniya'a' pamusy
# 1.0 	uniya'a' pamusx
# 1.0 	uniya'a' pamusn
# 1.0 	uniya'a' pamusum
# 1.0 	uniya'a' pamusq
# 1.0 	uniya'a' pamusp
# 1.0 	uniya'a' pamuss
# 1.0 	niya'a' pamusu
# 1.0 	uniya'a' pamust
# 1.0 	uniya'a' pamusw
# 1.0 	uniya'a' pamusn
# 0.909090909091 	uniya' pamus?
# 1.0 	uniya'a' pamusl
# 1.0 	uniya'a' pamusm
# 1.0 	uniya'a' pamusk
# 1.0 	uniya'a' pamush
# 1.0 	uniya'a' pamusi
# 1.0 	uniya'a' pamusf
# 1.0 	uniya'a' pamusd
# 1.0 	uniya'a' pamuse
# 1.0 	uniya'a' pamusb
# 1.0 	uniya'a' pamusc
# 1.0 	uniya'a' pamusa
# 0.909090909091 	uniya' pamus
# 0.909090909091 	uniya' pamus-
# 1.0 	uniya'a' pamusx
# 1.0 	uniya'a' pamusy
# 1.0 	uniya'a' pamust
# 1.0 	niya'a' pamusu
# 1.0 	uniya'a' pamuss
# 0.909090909091 	uniya' pamus
# 1.0 	uniy'a' pamusm
# 1.0 	uniya'a' pamusm
# 1.0 	uniya'a' pamusx
# 1.0 	niya'a' pamusu
# 1.0 	uniya'a' pamust
# 1.0 	uniya'a' pamusw
# 1.0 	uniya'a' pamusp
# 1.0 	uniya'a' pamuss
# 1.0 	uniya'g pamus-
# 1.0 	uniya'a' pamusm
# 1.0 	uniya'a' pamus_
# 1.0 	uniya'a' pamusn
# 1.0 	uniya'a' pamusi
# 1.0 	uniya'a' pamush
# 1.0 	uniya'a' pamusk
# 1.0 	uniya'a' pamuse
# 1.0 	uniya'a' pamusd
# 1.0 	uniya'a' pamusf
# 1.0 	uniya'g pamus
# 1.0 	uniya'a' pamusc
# 1.0 	uniya'a' pamusb
# 1.0 	uniya'a' pamus
# 1.0 	uniya'a' pamusd
# 1.0 	uniya'a' pamusl
# 1.0 	uniya'a' pamus-
# 0.909090909091 	uniya' pamusx
# 1.0 	uniya'a' pamusa
# 0.909090909091 	uniya' pamusw
# 0.909090909091 	uniya' pamust
# 1.0 	niya' pamusu
# 1.0 	uniya'a' pamusf
# 0.909090909091 	uniya' pamusp
# 0.909090909091 	uniya' pamusq
# 0.909090909091 	uniya' pamusn
# 0.909090909091 	uniya' pamusl
# 0.909090909091 	uniya' pamusk
# 0.909090909091 	uniya' pamush
# 0.909090909091 	uniya' pamusi
# 0.909090909091 	uniya' pamusf
# 0.909090909091 	uniya' pamusd
# 0.909090909091 	uniya' pamuse
# 0.909090909091 	uniya' pamusb
# 0.909090909091 	uniya' pamusc
# 1.0 	uniya'a'g pamus s
# 1.0 	uniya'a' pamuse
# 0.909090909091 	uniya' pamus_
# 1.0 	uniya'a' pamus?
# 1.0 	uniya'a' pamusf
# 1.0 	uniya'a' pamusua
# 1.0 	uniya'a' pamus-
# 1.0 	uniya'a' pamus
# 1.0 	uniya'a'g pamus
# 1.0 	uniya'a' pamuss
# 1.0 	uniya'a' pamusn
# 1.0 	uniya'a' pamusi
# 1.0 	uniya'a' pamust
# 1.0 	uniya'a'g pamus m
# 1.0 	uniya'a' pamusi
# 1.0 	uniya'a' pamusus
# 1.0 	uniya'a' pamust
# 1.0 	uniya'a' pamusq
# 1.0 	uniya'a' pamus i
# 1.0 	niya'a' pamusu
# 1.0 	uniya'g pamusn
# 1.0 	uniya'a' pamus ?
# 1.0 	uniya'a' pamusw
# 1.0 	uniya'a' pamusuw
# 1.0 	uniya'a' pamusp
# 1.0 	uniya'a' pamush
# 1.0 	uniya'a' pamusum
# 1.0 	uniya'a' pamusq
# 1.0 	uniya'a' pamus m
# 1.0 	niya'a' pamusu
# 1.0 	uniya'a' pamuss
# 1.0 	uniya'a' pamusx
# 1.0 	uniya'a' pamusy
# 1.0 	uniya'a' pamusk
# 1.0 	uniya'a'g pamus h
# 0.909090909091 	uniya' pamusy
# 1.0 	uniya'a' pamusc
# 1.0 	uniya'a' pamusx
# 1.0 	uniya'a' pamusy
# 1.0 	uniya'a' pamusup
# 1.0 	uniya'a' pamus
# 1.0 	uniya'a' pamusy
# 1.0 	uniya'a' pamuse
# 1.0 	uniya'a'g pamus_
# 1.0 	uniya'a'g pamusd
# 1.0 	uniya'a'g pamuse
# 1.0 	uniya'a'g pamusf
# 1.0 	uniya'a'g pamusa
# 1.0 	uniya'a'g pamusb
# 1.0 	uniya'a'g pamusc
# 1.0 	uniya'a'g pamusl
# 1.0 	uniya'a'g pamusm
# 1.0 	uniya'a'g pamusn
# 1.0 	uniya'a'g pamush
# 1.0 	uniya'a'g pamusi
# 1.0 	uniya'a'g pamusk
# 1.0 	uniya'a'g pamust
# 1.0 	niya'a'g pamusu
# 1.0 	uniya'a'g pamusw
# 1.0 	uniya'a'g pamusp
# 1.0 	uniya'a'g pamusq
# 1.0 	uniya'a'g pamuss
# 1.0 	uniya'a'g pamusx
# 1.0 	uniya'a'g pamusy
# 1.0 	uniya'g pamust
# 1.0 	uniya'a'g pamus k
# 1.0 	uniya'a' pamusd
# 1.0 	uniya'a' pamusuw
# 1.0 	uniya'a'g pamus
# 1.0 	uniya'a'g pamus-
# 1.0 	uniya'a'g pamus
# 1.0 	uniya'a' pamus
# 1.0 	uniya'g pamusf
# 1.0 	uniya'a' pamush
# 1.0 	uniya'a'g pamus?
# 1.0 	uniya'a' pamus-
# 1.0 	uniya'a' pamus
# 1.0 	uniy'a' pamus
# 1.0 	uniy'a' pamus-
# 1.0 	uniy'a' pamus
# 1.0 	uniya'a' pamus
# 1.0 	uniya'a' pamus?
# 1.0 	uniya'a' pamusb
# 1.0 	uniya'a' pamusi
# 1.0 	uniya'a' pamusu
# 1.0 	uniy'a' pamus_
# 1.0 	uniya'a' pamusu
# 1.0 	uniy'a' pamusk
# 1.0 	uniy'a' pamusi
# 1.0 	uniy'a' pamush
# 1.0 	uniy'a' pamusn
# 1.0 	uniy'a' pamusm
# 1.0 	uniy'a' pamusl
# 1.0 	uniy'a' pamusc
# 1.0 	uniy'a' pamusb
# 1.0 	uniy'a' pamusa
# 1.0 	uniya'a' pamusf
# 1.0 	uniy'a' pamusf
# 1.0 	uniy'a' pamuse
# 1.0 	uniya'a' pamusw
# 1.0 	uniy'a' pamusy
# 1.0 	uniya'a' pamusk
# 1.0 	uniya'a' pamusy
# 1.0 	uniya'a' pamusx
# 1.0 	uniy'a' pamuss
# 1.0 	uniy'a' pamusq
# 1.0 	uniy'a' pamusp
# 1.0 	uniy'a' pamusw
# 1.0 	niy'a' pamusu
# 1.0 	uniy'a' pamust
# 1.0 	uniya'a' pamusb
# 1.0 	uniya'a' pamusu
# 1.0 	uniya'a'g pamus p
# 1.0 	uniya'a' pamusl
# 1.0 	uniya'a' pamus_
# 1.0 	uniy'a' pamus_
# 1.0 	uniya'a' pamus w
# 1.0 	uniy'a' pamusl
# 1.0 	uniya'a'g pamus
# 1.0 	uniy'a' pamus
# 1.0 	niya'a' pamusu
# 1.0 	uniy'a' pamusi
# 1.0 	uniy'a' pamusn
# 1.0 	uniy'a' pamush
# 1.0 	uniya'g pamusc
# 1.0 	niya'a' pamusu
# 1.0 	uniya'a'g pamus_
# 1.0 	uniya'a' pamus
# 1.0 	uniy'a' pamusk
# 1.0 	uniya'a' pamusn
# 1.0 	uniy'a' pamuse
# 1.0 	uniya'g pamusb
# 0.909090909091 	uniya' pamusa
# 1.0 	uniy'a' pamusf
# 1.0 	uniya'a' pamusd
# 1.0 	uniya'g pamusp
# 1.0 	uniy'a' pamusc
# 1.0 	uniya'a' pamusq
# 1.0 	uniy'a' pamus
# 1.0 	uniya'g pamusn
# 1.0 	uniya'a' pamus-
# 1.0 	uniya'a' pamusp
# 1.0 	uniya'a' pamusup
# 1.0 	uniya'g pamus_
# 1.0 	uniy'a' pamus?
# 1.0 	uniya'a' pamus?
# 1.0 	uniy'a' pamusx
# 1.0 	uniya'a' pamusf
# 1.0 	uniy'a' pamusy
# 1.0 	uniya'a' pamusw
# 1.0 	niya'a' pamusu
# 1.0 	uniya'a' pamust
# 1.0 	uniya'a' pamuss
# 1.0 	uniya'aa'g pamus?
# 1.0 	uniya'a' pamusp
# 1.0 	uniya'g pamusi
# 1.0 	uniya'a' pamusy
# 1.0 	uniya'a' pamusx
# 1.0 	uniya'a' pamusf
# 1.0 	uniya'a' pamuse
# 1.0 	uniya'a' pamusd
# 1.0 	uniya'a' pamusc
# 1.0 	uniya'a' pamusb
# 1.0 	uniya'a' pamusa
# 1.0 	niy'a' pamusu
# 1.0 	uniya'a' pamusn
# 1.0 	uniya'a' pamusm
# 1.0 	uniya'a' pamusl
# 1.0 	uniya'a' pamusk
# 1.0 	uniya'a' pamusi
# 1.0 	uniya'a' pamush
# 1.0 	uniy'a' pamusw
# 1.0 	uniya'g pamusd
# 1.0 	uniya'a' pamus_
# 1.0 	uniy'a' pamusp
# 1.0 	uniy'a' pamusq
# 1.0 	uniya'a' pamust
# 1.0 	uniya'a'g pamus?
# 1.0 	uniy'a' pamuss
# 1.0 	uniya'g pamusm
# 1.0 	uniya'a' pamus ?
# 1.0 	uniya'a' pamuss
# 1.0 	uniya'g pamus_
# 1.0 	uniya'a' pamus?
# 1.0 	uniya'a'g pamusy
# 1.0 	uniya'a' pamus
# 1.0 	uniya'g pamusi
# 1.0 	uniya'a' pamus-
# 1.0 	uniya'a' pamust
# 1.0 	uniya'a' pamusut
# 1.0 	uniya'g pamuss
# 1.0 	uniya'g pamusx
# 1.0 	uniya'g pamuse
# 1.0 	uniya'a' pamusa
# 1.0 	uniya'g pamusd
# 1.0 	niya'a' pamusu
# 1.0 	uniya'a' pamusa
# 1.0 	uniya'a' pamusc
# 1.0 	uniya'a' pamusb
# 1.0 	uniya'a' pamuse
# 1.0 	uniya'a' pamusd
# 1.0 	uniya'a' pamusf
# 1.0 	uniya'a' pamusi
# 1.0 	uniya'a' pamusk
# 1.0 	uniya'a' pamusm
# 1.0 	uniya'a' pamusl
# 1.0 	uniya'a'g pamusw
# 1.0 	uniya'a' pamusq
# 1.0 	uniya'a' pamusp
# 1.0 	uniya'a' pamuss
# 1.0 	niya'a' pamusu
# 1.0 	uniya'a'g pamust
# 1.0 	uniya'a' pamusw
# 1.0 	uniya'a' pamusy
# 1.0 	uniya'a' pamusx
# 1.0 	uniya'aa' pamus
# 1.0 	uniya'aa'g pamus_
# 0.909090909091 	uniya' pamus
# 1.0 	uniya'aa'g pamusb
# 1.0 	uniya'aa'g pamusa
# 1.0 	uniya'aa'g pamusf
# 1.0 	uniya'aa'g pamuse
# 1.0 	uniya'aa'g pamusk
# 1.0 	uniya'aa'g pamusi
# 1.0 	uniya'aa'g pamush
# 0.909090909091 	uniya' pamus-
# 0.909090909091 	uniya' pamus
# 1.0 	uniya'aa'g pamusl
# 1.0 	uniya'aa'g pamuss
# 1.0 	uniy'a' pamus?
# 1.0 	uniy'a' pamus_
# 1.0 	uniya'aa'g pamusw
# 1.0 	niya'aa'g pamusu
# 1.0 	uniya'aa'g pamust
# 1.0 	uniya'g pamusy
# 1.0 	uniya'aa'g pamusy
# 1.0 	uniya'a' pamusw
# 1.0 	uniya'a' pamus_
# 0.909090909091 	uniya' pamus?
# 1.0 	uniya'aa' pamust
# 1.0 	niya'aa' pamusu
# 1.0 	uniya'aa' pamusw
# 1.0 	uniya'aa' pamusp
# 1.0 	uniya'aa' pamusq
# 1.0 	uniya'aa' pamuss
# 1.0 	uniya'aa' pamusx
# 1.0 	uniya'aa' pamusy
# 1.0 	uniya'a' pamus
# 1.0 	uniya'aa' pamusd
# 1.0 	uniya'aa' pamuse
# 1.0 	uniya'aa' pamusf
# 1.0 	uniya'aa' pamusa
# 1.0 	uniya'aa' pamusb
# 1.0 	uniya'aa' pamusc
# 1.0 	uniya'aa' pamusl
# 1.0 	uniya'aa' pamusm
# 1.0 	uniya'aa' pamusn
# 1.0 	uniya'aa' pamush
# 1.0 	uniya'aa' pamusi
# 1.0 	uniya'a' pamus?
# 1.0 	uniya'aa' pamusk
# 0.909090909091 	uniya' pamusa
# 0.909090909091 	uniya' pamusb
# 0.909090909091 	uniya' pamusc
# 0.909090909091 	uniya' pamusd
# 0.909090909091 	uniya' pamuse
# 0.909090909091 	uniya' pamusf
# 0.909090909091 	uniya' pamush
# 1.0 	uniya'a'g pamusf
# 1.0 	uniya'aa' pamus_
# 0.909090909091 	uniya' pamusl
# 0.909090909091 	uniya' pamusm
# 0.909090909091 	uniya' pamusn
# 0.909090909091 	uniya' pamusp
# 0.909090909091 	uniya' pamusq
# 0.909090909091 	uniya' pamuss
# 0.909090909091 	uniya' pamust
# 1.0 	niya' pamusu
# 0.909090909091 	uniya' pamusw
# 0.909090909091 	uniya' pamusx
# 1.0 	uniy'a' pamus?
# 1.0 	uniya'aa'g pamus?
# 1.0 	uniya'a' pamusk
# 1.0 	uniy'a' pamus-
# 1.0 	uniy'a' pamusn
# 1.0 	uniy'a' pamus
# 1.0 	uniya'a' pamusl
# 0.909090909091 	uniya' pamus_
# 1.0 	uniya'a'g pamusb
# 1.0 	uniya'a' pamusn
# 1.0 	uniya'a' pamus
# 1.0 	uniya'a' pamusp
# 0.909090909091 	uniya' pamusy
# 1.0 	uniya'a' pamusuk
# 1.0 	uniya'a' pamuss
# 1.0 	uniya'g pamusq
# 1.0 	uniya'a' pamusw
# 1.0 	uniya'a'g pamusm
# 1.0 	niy'a' pamusu
# 0.909090909091 	uniya' pamuss
# 1.0 	uniya'g pamusb
# 1.0 	uniya'a' pamusy
# 1.0 	uniya'a' pamus
# 1.0 	uniya'a' pamusx
# 1.0 	uniya'g pamusp
# 1.0 	uniya'a' pamusa
# 1.0 	uniya'g pamus
# 1.0 	uniya'a' pamus?
# 1.0 	uniya'g pamuse
# 0.909090909091 	uniya' pamusm
# 1.0 	niya'a'g pamusu
# 1.0 	uniya'g pamuss
# 1.0 	uniya'a'g pamuss
# 1.0 	uniya'a'g pamusq
# 1.0 	uniya'a'g pamusp
# 1.0 	uniya'a'g pamusw
# 1.0 	niya'a'g pamusu
# 1.0 	uniya'a'g pamust
# 1.0 	uniy'a' pamusd
# 1.0 	uniya'a'g pamusy
# 1.0 	uniya'a'g pamusx
# 1.0 	uniya'a'g pamus-
# 1.0 	uniy'a' pamusa
# 1.0 	uniy'a' pamusb
# 1.0 	uniya'a'g pamus
# 1.0 	uniya'a'g pamusc
# 1.0 	uniya'a'g pamusb
# 1.0 	uniya'a'g pamusa
# 1.0 	uniya'g pamusm
# 1.0 	uniya'a'g pamusf
# 1.0 	uniya'a'g pamuse
# 1.0 	uniya'a'g pamusd
# 1.0 	uniya'a'g pamusk
# 1.0 	uniya'a'g pamusi
# 1.0 	uniya'a'g pamush
# 1.0 	uniya'a'g pamusn
# 1.0 	uniya'a'g pamusm
# 1.0 	uniya'a'g pamusl
# 1.0 	uniya'g pamusl
# 1.0 	uniya'a'g pamusx
# 1.0 	uniya'aa' pamus
# 1.0 	uniya'g pamush
# 1.0 	uniya'g pamusk
# 1.0 	uniya'a'g pamuss
# 1.0 	uniya'a'g pamusp
# 1.0 	uniya'a'g pamusq
# 1.0 	uniya'a'g pamus_
# 1.0 	uniya'aa' pamus
# 1.0 	uniya'aa' pamus-
# 1.0 	niya'a'g pamusu
# 1.0 	uniya'a'g pamusk
# 1.0 	uniya'a'g pamush
# 1.0 	uniya'a'g pamusi
# 1.0 	uniya'a'g pamusn
# 1.0 	uniya'a'g pamusl
# 1.0 	uniya'a'g pamusm
# 1.0 	uniya'a'g pamusb
# 1.0 	uniya'a'g pamusc
# 1.0 	uniya'g pamusw
# 1.0 	uniya'a'g pamusa
# 1.0 	uniya'aa' pamus?
# 1.0 	uniya'a'g pamusd
# 1.0 	uniya'a'g pamuse
# 1.0 	uniya'a'g pamusa
# 1.0 	uniya'g pamus-
# 1.0 	uniya'a'g pamusc
# 1.0 	uniya'aa' pamus?
# 1.0 	uniya'a'g pamuse
# 1.0 	uniya'a'g pamusd
# 1.0 	uniya'a'g pamusf
# 1.0 	uniya'a'g pamusi
# 1.0 	uniya'a'g pamush
# 1.0 	uniya'a'g pamusk
# 1.0 	uniya'a'g pamus?
# 1.0 	uniya'a'g pamusl
# 1.0 	uniya'a'g pamusn
# 1.0 	uniya'a'g pamusq
# 1.0 	uniya'a'g pamusp
# 1.0 	uniya'a'g pamuss
# 1.0 	uniya'a'g pamus
# 1.0 	uniya'a'g pamust
# 1.0 	uniya'a'g pamusw
# 1.0 	uniya'a'g pamusy
# 1.0 	uniya'a'g pamusx
# 1.0 	uniya'a' pamusn
# 1.0 	uniya'aa' pamus_
# 1.0 	uniya'a'g pamus
# 1.0 	uniya'a'g pamus-
# 1.0 	uniya'a'g pamus?
# 1.0 	uniya'aa' pamusc
# 1.0 	uniya'aa' pamusb
# 1.0 	uniya'aa' pamusa
# 1.0 	uniya'g pamus
# 1.0 	uniya'aa' pamusf
# 1.0 	uniya'aa' pamuse
# 1.0 	uniya'aa' pamusd
# 1.0 	uniya'aa' pamusk
# 1.0 	uniya'aa' pamusi
# 1.0 	uniya'aa' pamush
# 1.0 	uniya'aa' pamusn
# 1.0 	uniya'aa' pamusm
# 1.0 	uniya'aa' pamusl
# 1.0 	uniya'aa' pamuss
# 1.0 	uniya'aa' pamusq
# 1.0 	uniya'aa' pamusp
# 1.0 	uniya'aa' pamusw
# 1.0 	niya'aa' pamusu
# 1.0 	uniya'aa' pamust
# 1.0 	uniya'aa' pamusy
# 1.0 	uniya'aa' pamusx
# 1.0 	uniya'a'g pamus_
# 1.0 	uniya'a' pamust
# 1.0 	uniya'aa'g pamust
# 1.0 	niya'aa'g pamusu
# 1.0 	uniya'aa'g pamusw
# 1.0 	uniya'aa'g pamusp
# 1.0 	uniya'aa'g pamusq
# 1.0 	uniya'aa'g pamuss
# 1.0 	niya'a'g pamus u
# 1.0 	uniya'a'g pamus t
# 1.0 	uniya'a'g pamus w
# 1.0 	uniya'aa'g pamusx
# 1.0 	uniya'aa'g pamusy
# 1.0 	uniya'g pamus
# 1.0 	uniya'aa'g pamusd
# 1.0 	uniya'aa'g pamuse
# 1.0 	uniya'aa'g pamusf
# 1.0 	uniya'a'g pamus i
# 1.0 	uniya'aa'g pamusa
# 1.0 	uniya'aa'g pamusb
# 1.0 	uniya'aa' pamus-
# 1.0 	uniya'aa'g pamusl
# 1.0 	uniya'aa'g pamusm
# 1.0 	uniya'aa'g pamusn
# 1.0 	uniya'aa'g pamush
# 1.0 	uniya'aa'g pamusi
# 1.0 	uniya'aa'g pamusk
# 1.0 	uniya'a' pamuss
# 1.0 	uniya'a' pamusp
# 1.0 	uniya'a' pamusw
# 1.0 	uniya'a' pamust
# 1.0 	niya'a' pamusu
# 1.0 	uniya'a' pamusx
# 1.0 	uniya'aa'g pamus_
# 1.0 	uniya'g pamus?
# 1.0 	uniya'a' pamus
# 1.0 	uniya'a' pamusb
# 1.0 	uniya'a' pamusc
# 1.0 	uniya'a' pamusa
# 1.0 	uniya'a' pamusf
# 1.0 	uniya'a' pamusd
# 1.0 	uniya'a' pamuss
# 1.0 	uniya'a'g pamus
# 1.0 	uniya'a' pamush
# 1.0 	uniya'a' pamusi
# 1.0 	uniya'a' pamusn
# 1.0 	uniya'a' pamusl
# 1.0 	uniya'a' pamusm
# 1.0 	uniya'aa'g pamusc
# 1.0 	uniya'a'g pamus ?
# 1.0 	uniya'a' pamusw
# 1.0 	uniya'a' pamusa
# 1.0 	uniya'a'g pamus-
# 1.0 	uniya'aa'g pamus
# 1.0 	uniya'a' pamusc
# 1.0 	uniya'g pamus?
# 1.0 	uniya'aa'g pamus-
# 1.0 	uniya'aa'g pamus
# 1.0 	uniy'a' pamusd
# 1.0 	uniya'a'g pamus
# 1.0 	uniya'g pamusx
# 1.0 	uniya'a' pamusb
# 1.0 	uniya'aa'g pamusd
# 1.0 	uniya'a' pamush
# 1.0 	uniya'a' pamus
# 1.0 	uniya'a' pamus
# 1.0 	uniy'a' pamusx
# 1.0 	niya'g pamusu
# 1.0 	uniya'a' pamus
# 1.0 	uniya'a' pamus_
# 1.0 	uniya'a' pamus-
# 1.0 	uniya'a' pamusus
# 1.0 	uniya'a' pamus
# 1.0 	uniya'a' pamuse
# 1.0 	uniya'a' pamusut
# 1.0 	niya'a' pamusu
# 1.0 	uniya'a' pamus
# 1.0 	uniya'aa'g pamusn
# 1.0 	niya'a' pamusu
# 1.0 	uniya'a' pamus_
# 1.0 	uniya'a' pamusua
# 1.0 	uniya'aa'g pamusm
# 1.0 	uniya'a' pamust
# 1.0 	uniya'a' pamusui
# 1.0 	uniya'a' pamusw
# 1.0 	uniya'a' pamus
# 1.0 	uniya'a'g pamus l
# 1.0 	uniya'a' pamus
# 1.0 	uniya'a' pamusp
# 1.0 	uniya'aa'g pamusp
# 1.0 	uniya'a' pamuss
# 1.0 	uniy'a'g pamus_
# 1.0 	uniya'a' pamus a
# 1.0 	uniya'a' pamus e
# 1.0 	uniya'a' pamus k
# 1.0 	uniya'a' pamus h
# 1.0 	uniya'a' pamus i
# 1.0 	uniya'a' pamus n
# 1.0 	uniya'a' pamus l
# 1.0 	uniya'a' pamus_
# 1.0 	uniya'a' pamus s
# 1.0 	uniya'a' pamus p
# 1.0 	uniy'a' pamusd
# 1.0 	uniya'a' pamus t
# 1.0 	uniya'a' pamusp
# 1.0 	uniya'g pamusf
# 1.0 	uniya'a' pamusu
# 1.0 	uniya'a' pamus_
# 1.0 	uniya'a' pamus l
# 1.0 	uniya'a' pamus m
# 1.0 	uniya'a' pamus n
# 1.0 	uniya'aa'g pamusx
# 1.0 	uniya'a' pamus h
# 1.0 	uniya'a' pamus i
# 1.0 	uniya'a' pamus k
# 1.0 	uniya'a' pamus e
# 1.0 	uniya'a' pamusm
# 1.0 	uniya'a' pamus a
# 0.909090909091 	uniya' pamuse
# 1.0 	uniya'a'g pamus n
# 1.0 	uniya'a' pamus t
# 1.0 	niya'a' pamus u
# 1.0 	uniya'a' pamus w
# 1.0 	uniya'a' pamus p
# 1.0 	uniya'a' pamusi
# 1.0 	uniya'a' pamus s
# 1.0 	uniya'a' pamus?
# 1.0 	uniya'a' pamus
# 1.0 	uniya'aa'g pamusc
# 1.0 	uniya'g pamust
# 1.0 	uniya'a'g pamus e
# 1.0 	uniya'g pamusa
# 1.0 	uniya'a' pamus
# 1.0 	uniya'a' pamus-
# 1.0 	uniy'a' pamust
# 1.0 	uniya'a' pamush
# 1.0 	uniy'a'g pamus
# 0.909090909091 	uniya' pamus-
# 0.909090909091 	uniya' pamus
# 1.0 	uniya'a'g pamus a
# 0.909090909091 	uniya' pamus
# 0.909090909091 	uniya' pamus?
# 1.0 	uniya'a' pamusx
# 1.0 	uniya'a' pamusy
# 1.0 	uniya'a' pamus-
# 1.0 	uniya'a' pamusp
# 1.0 	uniya'a' pamusq
# 1.0 	uniya'a' pamusw
# 1.0 	uniya'a' pamust
# 1.0 	niya'a' pamusu
# 1.0 	uniya'a' pamusk
# 0.909090909091 	uniya' pamus_
# 1.0 	uniya'a' pamusi
# 1.0 	uniya'a' pamusn
# 1.0 	uniya'a' pamusl
# 1.0 	uniya'a' pamusm
# 1.0 	uniya'a' pamusb
# 1.0 	uniya'a' pamusc
# 1.0 	uniya'a' pamusa
# 1.0 	uniya'a' pamusf
# 1.0 	uniya'a' pamusd
# 1.0 	uniya'a' pamuse
# 0.909090909091 	uniya' pamusm
# 0.909090909091 	uniya' pamusl
# 0.909090909091 	uniya' pamusn
# 0.909090909091 	uniya' pamusi
# 0.909090909091 	uniya' pamush
# 0.909090909091 	uniya' pamusk
# 0.909090909091 	uniya' pamusd
# 0.909090909091 	uniya' pamusf
# 0.909090909091 	uniya' pamusa
# 0.909090909091 	uniya' pamusc
# 0.909090909091 	uniya' pamusb
# 1.0 	uniya'g pamusa
# 0.909090909091 	uniya' pamusy
# 0.909090909091 	uniya' pamusx
# 1.0 	niya' pamusu
# 0.909090909091 	uniya' pamust
# 0.909090909091 	uniya' pamusw
# 0.909090909091 	uniya' pamusq
# 0.909090909091 	uniya' pamusp
# 0.909090909091 	uniya' pamuss
# Actual Answer :
# uniya' kumusta man imo nga exam ganina jun pasar kadto jun
# end

# %%
''' 
[ Doing : ]
    - Read character from *.txt to build the corpus 

[ Result : ]

-- Without Develope Data:

Building corpus without develope data:
set([' ', "'", '-', '?', '_', 'a', 'c', 'b', 'e', 'd', 'g', 'f', 'i', 'h', 'k', 'j', 'm', 'l', 'o', 'n', 'q', 'p', 's', 'r', 'u', 't', 'w', 'v', 'y', 'x', 'z'])
Total len is : 31
Done Write to [./dataCebuano/corpus.txt]

-- With Develope Data:

Building corpus with develope data:
set([' ', "'", ')', '(', '-', '?', '_', 'a', 'c', 'b', 'e', 'd', 'g', 'f', 'i', 'h', 'k', 'j', 'm', 'l', 'o', 'n', 'q', 'p', 's', 'r', 'u', 't', 'w', 'v', 'y', 'x', 'z'])
Total len is : 33
Done Write to [./dataCebuano/corpus.txt]
'''

TRAINING_LABEL = "./dataCebuano/train.txt"
DEVELOPE_LABEL = "./dataCebuano/dev.txt"
WRITING_TO = "./dataCebuano/corpus.txt"

# Special part to build corpus
def buildCharacterCorpus(withDevelopeData = False) :
    corpus = set( )
    with open(TRAINING_LABEL, 'r') as ft:
        for lines in ft:
            for word in lines.split('\n')[0].split(' ')[1:]:
                if word[0] == '<':
                    # We take every <...> as <unk> 
                    unKnownTag = '?'
                    corpus.add( unKnownTag ) 
                else:
                    for char in word:
                        corpus.add(char.lower())
    
    if( withDevelopeData ) :
        with open(DEVELOPE_LABEL, 'r') as fd:
            for lines in fd:
                for word in lines.split('\n')[0].split(' ')[1:]:
                    if word[0] == '<':
                        unKnownTag = '?'
                        corpus.add( unKnownTag ) 
                        # corpus.add(word.split('\n')[0].lower())
                    else:
                        for char in word:
                            corpus.add(char.lower())
    
    corpus.add(' ')
    print "Building corpus with" + ("" if withDevelopeData else "out") + " develope data:"
    print corpus
    print "Total len is : " + str(len(corpus))
    
    
    with open(WRITING_TO, 'w+') as fw:
        for item in corpus:
            fw.write(item + '\n')        
    print "Done Write to [" + WRITING_TO + "]"
    return corpus

trainingCorpus = buildCharacterCorpus()

# %%
# import theano
# from theano import tensor as T
# from theano.sandbox.rng_mrg import MRG_RandomStreams as RandomStreams
import numpy as np

from sklearn import cross_validation as cv
from sklearn import metrics
from sklearn import grid_search as gs
from sklearn.metrics import accuracy_score
from itertools import repeat

#proprocessor
from sklearn import preprocessing
from time import time

from itertools import repeat
import numpy as np
import random
from sklearn import preprocessing


def floatX(X):
    return np.asarray(X, dtype=theano.config.floatX)

def vectorized_result ( j , siz) :
    e = np.zeros((siz, 1))
    e[j] = 1.0
    return np.reshape( e, siz)

# TRAINING_DATA   = './dataCebuano/train.f0_ffv_fbank.fea'
TEST_DATA = './dataCebuano/dev.f0_ffv_fbank.fea'
# TRAIN_ARK  = './dataCebuano/train_Normalized_SELFVALID.ark'

TEST_ARK  = './dataCebuano/dev_Normalized_SELFVALID_LenLessThen500.ark'


def normalizeAndFilterData ( maxLength = 3000) :
    # Dataset
    x_data = []
    x_name = []
    record_seq = []

    with open( TEST_DATA, 'r') as f:
        for lines in f: 
            if '[' in lines :
                id = lines.split(' ')[0]
                x_name.append(id)
                seq = 0
            elif ']' in lines :
                if seq > maxLength :
                    x_name.pop()
                    del x_data[-seq:]
                else :
                    seq += 1
                    record_seq.append(seq)
                    x_data.append([float(x) for x in lines.split(' ') [2:-1] ])
            else :
                seq += 1
                x_data.append([float(x) for x in lines.split(' ') [2:-1] ])

    print "Normalized"
    x_data = preprocessing.scale( np.array(x_data) )

    # x_data[separate+1]
    # x_name
    bitch = record_seq.index(max(record_seq))
    print "Max len is ", record_seq[bitch]
    
    print "Total training data", len(x_name)

    # trainF = open(TRAIN_ARK, 'w+')
    with open(TEST_ARK, 'w+') as trainF:
        currentSeq = 0
        for nameIndex in range( len(x_name) ):

            trainF.write(str(x_name[nameIndex])+"  [\n")

            for valueIndex in range( (record_seq[nameIndex]) ):
                for featureIndex in range( len(x_data[0]) ):
                    if ( featureIndex+1) != len(x_data[0] ) :
                        trainF.write( str(x_data[ currentSeq  + valueIndex][featureIndex]) + " ")
                    else:
                        trainF.write( str(x_data[ currentSeq  + valueIndex][featureIndex]) )
                if valueIndex+1 == (record_seq[nameIndex]):
                    trainF.write(" ]\n")
                else:
                    trainF.write("\n")
            currentSeq += record_seq[nameIndex]

    print "MIssion ComplEte"


normalizeAndFilterData(500)
# Out:
# Normalized
# Max len is  501
# Total training data 4157
# MIssion ComplEte

# %%
# This block is to do the viterbi algorithm 

# Here we count word error rate
for index in range( len(x_test) ) :
    prepre = model2L_Noise_with313.predict( x_test[index] )
    for i in xrange(batch_size) :
        # Process Every Batch
        idmask = np.swapaxes( y_test_mask[index], 0, 1) [i]
        idseq = prepre[0][i] # [0] for implementation issue, take each batch( one id with extra blank )

        viterbiDelta = []
        viterbiBackTracking = []
        
        for t in np.nonzero(idmask)[0] :
            # Process Every Sequence 
            delta = []
            backTrack = []
            if t == 0:
                for c in idseq[t] :
                    delta.append( c )
                    backTrack.append( -1 )
            else :
                for c in idseq[t]:
                    multiply = [ last * c for last in viterbiDelta[t-1] ]
                    delta.append( max(multiply) )
                    backTrack.append( multiply.index(max(multiply)) )
            viterbiDelta.append( delta )  
            viterbiBackTracking.append( backTrack )
        
        
        bestAns = ""
        lastT = len(viterbiDelta) - 1
        lastChar = viterbiDelta[lastT].index( max( viterbiDelta[lastT] ) )
        
        while lastChar != -1 :
            bestAns = char_unMap[ lastChar ] + bestAns
            lastChar = viterbiBackTracking[lastT][lastChar]
            lastT -= 1
        
        bestAns = clean_up( bestAns )
        
        # Not Viterbi, multiply all max probability 
        ans =np.argmax(prepre[0],axis=2)[i]
        result = remap_back( ans[np.nonzero(idmask)] , False )
        
        if bestAns != result : 
            print "???"
        print "-------------------"
        print "Viterbi, cleanup : ", bestAns
        print "multipl, cleanup : ", result
        
    break
print 'end'
